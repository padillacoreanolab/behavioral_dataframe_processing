# %% [markdown]
# # Notebook 1: MED-PC Extracting the Recording Data and Metadata

# %% [markdown]
# # Importing the Python Libraries

# %%
import sys
import glob
import collections
from collections import defaultdict
import os
from datetime import datetime
import pathlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from medpc2excel.medpc_read import medpc_read
from moviepy.editor import *

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %% [markdown]
# # Getting the Metadata from all the MED-PC Recording Files

# %% [markdown]
# - Every MED-PC Recording file has Metadata about time, data, subject, group, experiment name, script used, and the MED-PC box number on the top of the recording file. We will first extract that information
#     - Metadata can be background information or context about data(or files) that is often different from the actual data that is intended to be recorded.
#         For more information on Metadata: https://en.wikipedia.org/wiki/Metadata

# %% [raw]
# # Getting all the file paths of the recording files(that happen to all end in `.txt`)
# all_med_pc_file = glob.glob("./example_recordings/*.txt")

# %% [markdown]
# - The path of the directory that this notebook is in. This will be where relative paths will be based off of

# %%
current_working_directory = os.getcwd()

# %%
current_working_directory
# Out:
# '/root/projects/behavioral_dataframe_processing/results/2022_07_20_repeated_id_fix'

# %% [markdown]
# - All the other files in this directory. If you want to use a folder in here such as the `data` folder, you'd type `./data/{name_of_folder}` where you replace `{name_of_folder}` with the name of the folder without the `{}`. You will do this in the cells following the one below
#     - The `./` means the path will reference the current directory that the command is being used from

# %%
os.listdir(current_working_directory)
# Out:
# ['data',
#  'example_recordings',
#  'scripts',
#  '03_calculating_port_entry_precision.ipynb',
#  '.ipynb_checkpoints',
#  'README.MD',
#  'proc',
#  '02_calculating_latencies.ipynb',
#  '04_syncing_with_video.ipynb',
#  '01_extracting_recording_data_and_metadata.ipynb']

# %% [markdown]
# ## NOTE: If you are using your own data, the following path must be changed to the directory where your MED-PC recording files are located(if they are not in the specied folder). It is recommended to create a sub folder in the `data` folder(that is in the same folder as this notebook) for each group of session you want to process and put the recording files in there

# %% [markdown]
# - Use the cell below instead if you're using your own data. You must change the cell below by clicking on the cell and then pressing the `esc` key. Then press the `Y` button on your keyboard. If you want to switch it back do the same but press the `R` button instead. This switches it from a cell that is run as if it's code, or back to a cell where it's just treated as text
#     - **NOTE: If you are using a different folder, then change the path in the cell below**
#     - The asterisk is called a wild card which will tell the computer to find all files/folders that match this pattern. The `*` means that any pattern of any length can be replaced with it. The `**` tells the computer to look in all folders that are in the specified folder. For more information: https://linuxhint.com/bash_wildcard_tutorial/
#     - For more information on finding the path of your folder that contains the recording files: https://www.computerhope.com/issues/ch001708.htm

# %%
all_med_pc_file = glob.glob("./data/**/*.txt")

# %%
all_med_pc_file[:10]
# Out:
# ['./data/textfiles/2022-07-19_13h38m_Subject 1.txt',
#  './data/textfiles/2022-07-18_15h10m_Subject 4.txt',
#  './data/textfiles/2022-07-18_11h27m_Subject 3.txt',
#  './data/textfiles/2022-07-18_14h04m_Subject 1.txt',
#  './data/textfiles/2022-07-18_11h27m_Subject 4.txt',
#  './data/textfiles/2022-07-19_12h27m_Subject 1.txt',
#  './data/textfiles/2022-07-18_08h24m_Subject 1.txt',
#  './data/textfiles/2022-07-18_16h39m_Subject 2.txt',
#  './data/textfiles/2022-07-18_09h57m_Subject 3.txt',
#  './data/textfiles/2022-07-18_16h39m_Subject 3.txt']

# %% [markdown]
# - Example of what the MED-PC Recording file looks like

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt
#
#
#
#
#
#
#
# Start Date: 07/19/22
#
# End Date: 07/19/22
#
# Subject: 1
#
# Experiment: C57_vs_CD1_Comparison
#
# Group: Cage 5
#
# Box: 2
#
# Start Time: 13:38:55
#
# End Time: 14:41:48
#
# MSN: CD1_reward_training
#
# A:    4399.000
#
# D:    9000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    3660.000

# %% [markdown]
# - We will be extracting the first 10 or so lines that look like:
#
# ```
# File: C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (2).txt
#
# Start Date: 05/06/22
#
# End Date: 05/06/22
#
# Subject: 3.4 (2)
#
# Experiment: Pilot of Pilot
#
# Group: Cage 4
#
# Box: 1
#
# Start Time: 12:59:58
#
# End Time: 14:02:38
#
# MSN: levelNP_CS_reward_laserepochON1st_noshock
# ```

# %% [markdown]
# - We will just find all the lines that start with `"File", "Start Date", "End Date", "Subject", "Experiment", "Group", "Box", "Start Time", "End Time", or "MSN"`. And get the metadata from those lines. And then stop once all the metadata types have been collected

# %%
# This makes a nested dictionary of file paths to each individual metadata type
file_path_to_meta_data = extract.metadata.get_all_med_pc_meta_data_from_files(list_of_files=all_med_pc_file)

# %%
# The metadata for the first file
for key, value in file_path_to_meta_data.items():
    print("File path: {}".format(key))
    print("Metadata types and associated values: {}".format(value))
    break
# Out:
# File path: ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# Metadata types and associated values: {'File': 'C:\\MED-PC\\Data\\2022-07-19_13h38m_Subject 1.txt', 'Start Date': '07/19/22', 'End Date': '07/19/22', 'Subject': '1', 'Experiment': 'C57_vs_CD1_Comparison', 'Group': 'Cage 5', 'Box': '2', 'Start Time': '13:38:55', 'End Time': '14:41:48', 'MSN': 'CD1_reward_training'}

# %% [markdown]
# ## Making a Dataframe out of the Metadata

# %% [markdown]
# - A Dataframe is essentially a "programmable" spreadsheet. But instead of clicking on cells, you will have to tell Python how you want to interact with the spreadsheet
#     - For more information: https://realpython.com/pandas-dataframe/

# %%
# Turning the dictionary into a Pandas Dataframe
metadata_df = pd.DataFrame.from_dict(file_path_to_meta_data, orient="index")
# Resetting the index because currently the file path is the index 
metadata_df = metadata_df.reset_index()

# %%
metadata_df.head()
# Out:
#                                               index  \
# 0  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 1  ./data/textfiles/2022-07-18_15h10m_Subject 4.txt
# 2  ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 3  ./data/textfiles/2022-07-18_14h04m_Subject 1.txt
# 4  ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt   07/19/22  07/19/22
# 1  C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_14h04m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
#
#   Subject             Experiment   Group Box Start Time  End Time  \
# 0       1  C57_vs_CD1_Comparison  Cage 5   2   13:38:55  14:41:48
# 1       4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 2       3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 3       1  C57_vs_CD1_comparison  Cage 5   1   14:04:40  15:08:03
# 4       4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
#
#                    MSN
# 0  CD1_reward_training
# 1  CD1_reward_training
# 2  C57_reward_training
# 3  CD1_reward_training
# 4  C57_reward_training

# %%
metadata_df.tail()
# Out:
#                                                index  \
# 39  ./data/textfiles/2022-07-18_14h04m_Subject 3.txt
# 40  ./data/textfiles/2022-07-18_16h39m_Subject 1.txt
# 41  ./data/textfiles/2022-07-19_13h38m_Subject 2.txt
# 42  ./data/textfiles/2022-07-18_12h43m_Subject 2.txt
# 43  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
#
#                                               File Start Date  End Date  \
# 39  C:\MED-PC\Data\2022-07-18_14h04m_Subject 3.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 41  C:\MED-PC\Data\2022-07-19_13h38m_Subject 2.txt   07/19/22  07/19/22
# 42  C:\MED-PC\Data\2022-07-18_12h43m_Subject 2.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-18_11h27m_Subject 2.txt   07/18/22  07/18/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 39       3  C57_vs_CD1_comparison  Cage 5   3   14:04:40  15:08:03
# 40       1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 41       2  C57_vs_CD1_Comparison  Cage 5   3   13:38:55  14:41:48
# 42       2  C57_vs_CD1_comparison  Cage 4   2   12:43:28  13:54:48
# 43       2  C57_vs_CD1_Comparison   Cage3   2   11:27:37  12:35:25
#
#                     MSN
# 39  CD1_reward_training
# 40  C57_reward_training
# 41  CD1_reward_training
# 42  CD1_reward_training
# 43  C57_reward_training

# %% [markdown]
# - Make a column that is just the file name

# %%
# Changing the file path to Windows format, then back to Linux format
# Then just taking the file name
metadata_df["file_name"] = metadata_df["File"].apply(lambda x: os.path.basename(pathlib.Path(pathlib.PureWindowsPath(x))).strip())

# %%
metadata_df
# Out:
#                                                index  \
# 0   ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 1   ./data/textfiles/2022-07-18_15h10m_Subject 4.txt
# 2   ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 3   ./data/textfiles/2022-07-18_14h04m_Subject 1.txt
# 4   ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
# 5   ./data/textfiles/2022-07-19_12h27m_Subject 1.txt
# 6   ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 7   ./data/textfiles/2022-07-18_16h39m_Subject 2.txt
# 8   ./data/textfiles/2022-07-18_09h57m_Subject 3.txt
# 9   ./data/textfiles/2022-07-18_16h39m_Subject 3.txt
# 10  ./data/textfiles/2022-07-18_14h04m_Subject 2.txt
# 11  ./data/textfiles/2022-07-18_16h39m_Subject 4.txt
# 12  ./data/textfiles/2022-07-18_09h57m_Subject 1.txt
# 13  ./data/textfiles/2022-07-18_15h10m_Subject 3.txt
# 14  ./data/textfiles/2022-07-19_09h54m_Subject 3.txt
# 15  ./data/textfiles/2022-07-19_11h11m_Subject 2.txt
# 16  ./data/textfiles/2022-07-18_12h43m_Subject 4.txt
# 17  ./data/textfiles/2022-07-18_09h57m_Subject 4.txt
# 18  ./data/textfiles/2022-07-18_15h10m_Subject 2.txt
# 19  ./data/textfiles/2022-07-19_09h54m_Subject 2.txt
# 20  ./data/textfiles/2022-07-18_12h43m_Subject 3.txt
# 21  ./data/textfiles/2022-07-19_11h10m_Subject 4.txt
# 22  ./data/textfiles/2022-07-19_09h54m_Subject 4.txt
# 23  ./data/textfiles/2022-07-19_12h27m_Subject 4.txt
# 24  ./data/textfiles/2022-07-18_08h25m_Subject 2.txt
# 25  ./data/textfiles/2022-07-18_09h57m_Subject 2.txt
# 26  ./data/textfiles/2022-07-19_13h38m_Subject 4.txt
# 27  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 28  ./data/textfiles/2022-07-18_12h43m_Subject 1.txt
# 29  ./data/textfiles/2022-07-18_14h04m_Subject 4.txt
# 30  ./data/textfiles/2022-07-18_15h10m_Subject 1.txt
# 31  ./data/textfiles/2022-07-19_09h54m_Subject 1.txt
# 32  ./data/textfiles/2022-07-19_12h27m_Subject 2.txt
# 33  ./data/textfiles/2022-07-19_11h11m_Subject 1.txt
# 34  ./data/textfiles/2022-07-19_12h27m_Subject 3.txt
# 35  ./data/textfiles/2022-07-18_08h25m_Subject 3.txt
# 36  ./data/textfiles/2022-07-19_13h38m_Subject 3.txt
# 37  ./data/textfiles/2022-07-19_11h12m_Subject 3.txt
# 38  ./data/textfiles/2022-07-18_11h27m_Subject 1.txt
# 39  ./data/textfiles/2022-07-18_14h04m_Subject 3.txt
# 40  ./data/textfiles/2022-07-18_16h39m_Subject 1.txt
# 41  ./data/textfiles/2022-07-19_13h38m_Subject 2.txt
# 42  ./data/textfiles/2022-07-18_12h43m_Subject 2.txt
# 43  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt   07/19/22  07/19/22
# 1   C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 2   C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 3   C:\MED-PC\Data\2022-07-18_14h04m_Subject 1.txt   07/18/22  07/18/22
# 4   C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
# 5   C:\MED-PC\Data\2022-07-19_12h27m_Subject 1.txt   07/19/22  07/19/22
# 6   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 7   C:\MED-PC\Data\2022-07-18_16h39m_Subject 2.txt   07/18/22  07/19/22
# 8   C:\MED-PC\Data\2022-07-18_09h57m_Subject 3.txt   07/18/22  07/18/22
# 9   C:\MED-PC\Data\2022-07-18_16h39m_Subject 3.txt   07/18/22  07/19/22
# 10  C:\MED-PC\Data\2022-07-18_14h04m_Subject 2.txt   07/18/22  07/18/22
# 11  C:\MED-PC\Data\2022-07-18_16h39m_Subject 4.txt   07/18/22  07/19/22
# 12  C:\MED-PC\Data\2022-07-18_09h57m_Subject 1.txt   07/18/22  07/18/22
# 13  C:\MED-PC\Data\2022-07-18_15h10m_Subject 3.txt   07/18/22  07/18/22
# 14  C:\MED-PC\Data\2022-07-19_09h54m_Subject 3.txt   07/19/22  07/19/22
# 15  C:\MED-PC\Data\2022-07-19_11h11m_Subject 2.txt   07/19/22  07/19/22
# 16  C:\MED-PC\Data\2022-07-18_12h43m_Subject 4.txt   07/18/22  07/18/22
# 17  C:\MED-PC\Data\2022-07-18_09h57m_Subject 4.txt   07/18/22  07/18/22
# 18  C:\MED-PC\Data\2022-07-18_15h10m_Subject 2.txt   07/18/22  07/18/22
# 19  C:\MED-PC\Data\2022-07-19_09h54m_Subject 2.txt   07/19/22  07/19/22
# 20  C:\MED-PC\Data\2022-07-18_12h43m_Subject 3.txt   07/18/22  07/18/22
# 21  C:\MED-PC\Data\2022-07-19_11h10m_Subject 4.txt   07/19/22  07/19/22
# 22  C:\MED-PC\Data\2022-07-19_09h54m_Subject 4.txt   07/19/22  07/19/22
# 23  C:\MED-PC\Data\2022-07-19_12h27m_Subject 4.txt   07/19/22  07/19/22
# 24  C:\MED-PC\Data\2022-07-18_08h25m_Subject 2.txt   07/18/22  07/18/22
# 25  C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 26  C:\MED-PC\Data\2022-07-19_13h38m_Subject 4.txt   07/19/22  07/19/22
# 27  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 28  C:\MED-PC\Data\2022-07-18_12h43m_Subject 1.txt   07/18/22  07/18/22
# 29  C:\MED-PC\Data\2022-07-18_14h04m_Subject 4.txt   07/18/22  07/18/22
# 30  C:\MED-PC\Data\2022-07-18_15h10m_Subject 1.txt   07/18/22  07/18/22
# 31  C:\MED-PC\Data\2022-07-19_09h54m_Subject 1.txt   07/19/22  07/19/22
# 32  C:\MED-PC\Data\2022-07-19_12h27m_Subject 2.txt   07/19/22  07/19/22
# 33  C:\MED-PC\Data\2022-07-19_11h11m_Subject 1.txt   07/19/22  07/19/22
# 34  C:\MED-PC\Data\2022-07-19_12h27m_Subject 3.txt   07/19/22  07/19/22
# 35  C:\MED-PC\Data\2022-07-18_08h25m_Subject 3.txt   07/18/22  07/18/22
# 36  C:\MED-PC\Data\2022-07-19_13h38m_Subject 3.txt   07/19/22  07/19/22
# 37  C:\MED-PC\Data\2022-07-19_11h12m_Subject 3.txt   07/19/22  07/19/22
# 38  C:\MED-PC\Data\2022-07-18_11h27m_Subject 1.txt   07/18/22  07/18/22
# 39  C:\MED-PC\Data\2022-07-18_14h04m_Subject 3.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 41  C:\MED-PC\Data\2022-07-19_13h38m_Subject 2.txt   07/19/22  07/19/22
# 42  C:\MED-PC\Data\2022-07-18_12h43m_Subject 2.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-18_11h27m_Subject 2.txt   07/18/22  07/18/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0        1  C57_vs_CD1_Comparison  Cage 5   2   13:38:55  14:41:48
# 1        4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 2        3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 3        1  C57_vs_CD1_comparison  Cage 5   1   14:04:40  15:08:03
# 4        4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
# 5        1  C57_vs_CD1_Comparison   Cage4   2   12:27:39  13:29:52
# 6        1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  09:50:24
# 7        2  C57_vs_CD1_Comparison  Cage 1   3   16:39:59  09:52:50
# 8        3  C57_vs_CD1_Comparison   Cage2   3   09:57:57  11:10:02
# 9        3  C57_vs_CD1_Comparison  Cage 1   4   16:39:59  09:52:50
# 10       2  C57_vs_CD1_comparison  Cage 5   2   14:04:40  15:08:03
# 11       4  C57_vs_CD1_Comparison  Cage 1   1   16:39:59  09:52:50
# 12       1  C57_vs_CD1_Comparison   Cage2   1   09:57:57  11:10:02
# 13       3  C57_vs_CD1_Comparison  Cage 6   3   15:10:30  16:20:28
# 14       3  C57_vs_CD1_Comparison   Cage2   4   09:54:52  11:05:02
# 15       2  C57_vs_CD1_comparison   Cage3   3   11:11:52  12:18:52
# 16       4  C57_vs_CD1_comparison  Cage 4   4   12:43:28  13:54:48
# 17       4  C57_vs_CD1_Comparison   Cage2   4   09:57:57  11:10:02
# 18       2  C57_vs_CD1_Comparison  Cage 6   2   15:10:30  16:20:28
# 19       2  C57_vs_CD1_Comparison   Cage2   3   09:54:52  11:05:02
# 20       3  C57_vs_CD1_comparison  Cage 4   3   12:43:28  13:54:48
# 21       4  C57_vs_CD1_comparison   Cage3   1   11:10:24  12:18:52
# 22       4  C57_vs_CD1_Comparison   Cage2   1   09:54:52  11:05:02
# 23       4  C57_vs_CD1_Comparison   Cage4   1   12:27:39  13:29:52
# 24       2  C57_vs_CD1_Comparison   Cage1   2   08:25:48  09:50:24
# 25       2  C57_vs_CD1_Comparison   Cage2   2   09:57:57  11:10:02
# 26       4  C57_vs_CD1_Comparison  Cage 5   1   13:38:55  14:41:48
# 27       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  15:55:10
# 28       1  C57_vs_CD1_comparison  Cage 4   1   12:43:28  13:54:48
# 29       4  C57_vs_CD1_comparison  Cage 5   4   14:04:40  15:08:03
# 30       1  C57_vs_CD1_Comparison  Cage 6   1   15:10:30  16:20:28
# 31       1  C57_vs_CD1_Comparison   Cage2   2   09:54:52  11:05:02
# 32       2  C57_vs_CD1_Comparison   Cage4   3   12:27:39  13:29:52
# 33       1  C57_vs_CD1_comparison   Cage3   2   11:11:34  12:18:52
# 34       3  C57_vs_CD1_Comparison   Cage4   4   12:27:39  13:29:52
# 35       3  C57_vs_CD1_Comparison   Cage1   3   08:25:48  09:50:24
# 36       3  C57_vs_CD1_Comparison  Cage 5   4   13:38:55  14:41:48
# 37       3  C57_vs_CD1_comparison   Cage3   4   11:12:05  12:18:52
# 38       1  C57_vs_CD1_Comparison   Cage3   1   11:27:37  12:35:25
# 39       3  C57_vs_CD1_comparison  Cage 5   3   14:04:40  15:08:03
# 40       1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 41       2  C57_vs_CD1_Comparison  Cage 5   3   13:38:55  14:41:48
# 42       2  C57_vs_CD1_comparison  Cage 4   2   12:43:28  13:54:48
# 43       2  C57_vs_CD1_Comparison   Cage3   2   11:27:37  12:35:25
#
#                     MSN                        file_name
# 0   CD1_reward_training  2022-07-19_13h38m_Subject 1.txt
# 1   CD1_reward_training  2022-07-18_15h10m_Subject 4.txt
# 2   C57_reward_training  2022-07-18_11h27m_Subject 3.txt
# 3   CD1_reward_training  2022-07-18_14h04m_Subject 1.txt
# 4   C57_reward_training  2022-07-18_11h27m_Subject 4.txt
# 5   C57_reward_training  2022-07-19_12h27m_Subject 1.txt
# 6   C57_reward_training  2022-07-18_08h24m_Subject 1.txt
# 7   C57_reward_training  2022-07-18_16h39m_Subject 2.txt
# 8   C57_reward_training  2022-07-18_09h57m_Subject 3.txt
# 9   C57_reward_training  2022-07-18_16h39m_Subject 3.txt
# 10  CD1_reward_training  2022-07-18_14h04m_Subject 2.txt
# 11  C57_reward_training  2022-07-18_16h39m_Subject 4.txt
# 12  C57_reward_training  2022-07-18_09h57m_Subject 1.txt
# 13  CD1_reward_training  2022-07-18_15h10m_Subject 3.txt
# 14  C57_reward_training  2022-07-19_09h54m_Subject 3.txt
# 15  C57_reward_training  2022-07-19_11h11m_Subject 2.txt
# 16  CD1_reward_training  2022-07-18_12h43m_Subject 4.txt
# 17  C57_reward_training  2022-07-18_09h57m_Subject 4.txt
# 18  CD1_reward_training  2022-07-18_15h10m_Subject 2.txt
# 19  C57_reward_training  2022-07-19_09h54m_Subject 2.txt
# 20  CD1_reward_training  2022-07-18_12h43m_Subject 3.txt
# 21  C57_reward_training  2022-07-19_11h10m_Subject 4.txt
# 22  C57_reward_training  2022-07-19_09h54m_Subject 4.txt
# 23  C57_reward_training  2022-07-19_12h27m_Subject 4.txt
# 24  C57_reward_training  2022-07-18_08h25m_Subject 2.txt
# 25  C57_reward_training  2022-07-18_09h57m_Subject 2.txt
# 26  CD1_reward_training  2022-07-19_13h38m_Subject 4.txt
# 27  CD1_reward_training  2022-07-19_14h52m_Subject 4.txt
# 28  CD1_reward_training  2022-07-18_12h43m_Subject 1.txt
# 29  CD1_reward_training  2022-07-18_14h04m_Subject 4.txt
# 30  CD1_reward_training  2022-07-18_15h10m_Subject 1.txt
# 31  C57_reward_training  2022-07-19_09h54m_Subject 1.txt
# 32  C57_reward_training  2022-07-19_12h27m_Subject 2.txt
# 33  C57_reward_training  2022-07-19_11h11m_Subject 1.txt
# 34  C57_reward_training  2022-07-19_12h27m_Subject 3.txt
# 35  C57_reward_training  2022-07-18_08h25m_Subject 3.txt
# 36  CD1_reward_training  2022-07-19_13h38m_Subject 3.txt
# 37  C57_reward_training  2022-07-19_11h12m_Subject 3.txt
# 38  C57_reward_training  2022-07-18_11h27m_Subject 1.txt
# 39  CD1_reward_training  2022-07-18_14h04m_Subject 3.txt
# 40  C57_reward_training  2022-07-18_16h39m_Subject 1.txt
# 41  CD1_reward_training  2022-07-19_13h38m_Subject 2.txt
# 42  CD1_reward_training  2022-07-18_12h43m_Subject 2.txt
# 43  C57_reward_training  2022-07-18_11h27m_Subject 2.txt

# %% [markdown]
# - Getting the numbers out of the column that contains the cage information

# %%
metadata_df["cage"] = metadata_df["Group"].apply(lambda x: x.lower().strip("cage").strip())

# %%
metadata_df["cage"].head()
# Out:
# 0    5
# 1    6
# 2    3
# 3    5
# 4    3
# Name: cage, dtype: object

# %% [markdown]
# - Adding a new column that combines the cage and subject ID into a new ID

# %%
metadata_df["cage_and_subject"] = metadata_df.apply(lambda x: "cage_{}_subject_{}".format(x["cage"], x["Subject"]), axis=1)

# %%
metadata_df
# Out:
#                                                index  \
# 0   ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 1   ./data/textfiles/2022-07-18_15h10m_Subject 4.txt
# 2   ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 3   ./data/textfiles/2022-07-18_14h04m_Subject 1.txt
# 4   ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
# 5   ./data/textfiles/2022-07-19_12h27m_Subject 1.txt
# 6   ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 7   ./data/textfiles/2022-07-18_16h39m_Subject 2.txt
# 8   ./data/textfiles/2022-07-18_09h57m_Subject 3.txt
# 9   ./data/textfiles/2022-07-18_16h39m_Subject 3.txt
# 10  ./data/textfiles/2022-07-18_14h04m_Subject 2.txt
# 11  ./data/textfiles/2022-07-18_16h39m_Subject 4.txt
# 12  ./data/textfiles/2022-07-18_09h57m_Subject 1.txt
# 13  ./data/textfiles/2022-07-18_15h10m_Subject 3.txt
# 14  ./data/textfiles/2022-07-19_09h54m_Subject 3.txt
# 15  ./data/textfiles/2022-07-19_11h11m_Subject 2.txt
# 16  ./data/textfiles/2022-07-18_12h43m_Subject 4.txt
# 17  ./data/textfiles/2022-07-18_09h57m_Subject 4.txt
# 18  ./data/textfiles/2022-07-18_15h10m_Subject 2.txt
# 19  ./data/textfiles/2022-07-19_09h54m_Subject 2.txt
# 20  ./data/textfiles/2022-07-18_12h43m_Subject 3.txt
# 21  ./data/textfiles/2022-07-19_11h10m_Subject 4.txt
# 22  ./data/textfiles/2022-07-19_09h54m_Subject 4.txt
# 23  ./data/textfiles/2022-07-19_12h27m_Subject 4.txt
# 24  ./data/textfiles/2022-07-18_08h25m_Subject 2.txt
# 25  ./data/textfiles/2022-07-18_09h57m_Subject 2.txt
# 26  ./data/textfiles/2022-07-19_13h38m_Subject 4.txt
# 27  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 28  ./data/textfiles/2022-07-18_12h43m_Subject 1.txt
# 29  ./data/textfiles/2022-07-18_14h04m_Subject 4.txt
# 30  ./data/textfiles/2022-07-18_15h10m_Subject 1.txt
# 31  ./data/textfiles/2022-07-19_09h54m_Subject 1.txt
# 32  ./data/textfiles/2022-07-19_12h27m_Subject 2.txt
# 33  ./data/textfiles/2022-07-19_11h11m_Subject 1.txt
# 34  ./data/textfiles/2022-07-19_12h27m_Subject 3.txt
# 35  ./data/textfiles/2022-07-18_08h25m_Subject 3.txt
# 36  ./data/textfiles/2022-07-19_13h38m_Subject 3.txt
# 37  ./data/textfiles/2022-07-19_11h12m_Subject 3.txt
# 38  ./data/textfiles/2022-07-18_11h27m_Subject 1.txt
# 39  ./data/textfiles/2022-07-18_14h04m_Subject 3.txt
# 40  ./data/textfiles/2022-07-18_16h39m_Subject 1.txt
# 41  ./data/textfiles/2022-07-19_13h38m_Subject 2.txt
# 42  ./data/textfiles/2022-07-18_12h43m_Subject 2.txt
# 43  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt   07/19/22  07/19/22
# 1   C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 2   C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 3   C:\MED-PC\Data\2022-07-18_14h04m_Subject 1.txt   07/18/22  07/18/22
# 4   C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
# 5   C:\MED-PC\Data\2022-07-19_12h27m_Subject 1.txt   07/19/22  07/19/22
# 6   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 7   C:\MED-PC\Data\2022-07-18_16h39m_Subject 2.txt   07/18/22  07/19/22
# 8   C:\MED-PC\Data\2022-07-18_09h57m_Subject 3.txt   07/18/22  07/18/22
# 9   C:\MED-PC\Data\2022-07-18_16h39m_Subject 3.txt   07/18/22  07/19/22
# 10  C:\MED-PC\Data\2022-07-18_14h04m_Subject 2.txt   07/18/22  07/18/22
# 11  C:\MED-PC\Data\2022-07-18_16h39m_Subject 4.txt   07/18/22  07/19/22
# 12  C:\MED-PC\Data\2022-07-18_09h57m_Subject 1.txt   07/18/22  07/18/22
# 13  C:\MED-PC\Data\2022-07-18_15h10m_Subject 3.txt   07/18/22  07/18/22
# 14  C:\MED-PC\Data\2022-07-19_09h54m_Subject 3.txt   07/19/22  07/19/22
# 15  C:\MED-PC\Data\2022-07-19_11h11m_Subject 2.txt   07/19/22  07/19/22
# 16  C:\MED-PC\Data\2022-07-18_12h43m_Subject 4.txt   07/18/22  07/18/22
# 17  C:\MED-PC\Data\2022-07-18_09h57m_Subject 4.txt   07/18/22  07/18/22
# 18  C:\MED-PC\Data\2022-07-18_15h10m_Subject 2.txt   07/18/22  07/18/22
# 19  C:\MED-PC\Data\2022-07-19_09h54m_Subject 2.txt   07/19/22  07/19/22
# 20  C:\MED-PC\Data\2022-07-18_12h43m_Subject 3.txt   07/18/22  07/18/22
# 21  C:\MED-PC\Data\2022-07-19_11h10m_Subject 4.txt   07/19/22  07/19/22
# 22  C:\MED-PC\Data\2022-07-19_09h54m_Subject 4.txt   07/19/22  07/19/22
# 23  C:\MED-PC\Data\2022-07-19_12h27m_Subject 4.txt   07/19/22  07/19/22
# 24  C:\MED-PC\Data\2022-07-18_08h25m_Subject 2.txt   07/18/22  07/18/22
# 25  C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 26  C:\MED-PC\Data\2022-07-19_13h38m_Subject 4.txt   07/19/22  07/19/22
# 27  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 28  C:\MED-PC\Data\2022-07-18_12h43m_Subject 1.txt   07/18/22  07/18/22
# 29  C:\MED-PC\Data\2022-07-18_14h04m_Subject 4.txt   07/18/22  07/18/22
# 30  C:\MED-PC\Data\2022-07-18_15h10m_Subject 1.txt   07/18/22  07/18/22
# 31  C:\MED-PC\Data\2022-07-19_09h54m_Subject 1.txt   07/19/22  07/19/22
# 32  C:\MED-PC\Data\2022-07-19_12h27m_Subject 2.txt   07/19/22  07/19/22
# 33  C:\MED-PC\Data\2022-07-19_11h11m_Subject 1.txt   07/19/22  07/19/22
# 34  C:\MED-PC\Data\2022-07-19_12h27m_Subject 3.txt   07/19/22  07/19/22
# 35  C:\MED-PC\Data\2022-07-18_08h25m_Subject 3.txt   07/18/22  07/18/22
# 36  C:\MED-PC\Data\2022-07-19_13h38m_Subject 3.txt   07/19/22  07/19/22
# 37  C:\MED-PC\Data\2022-07-19_11h12m_Subject 3.txt   07/19/22  07/19/22
# 38  C:\MED-PC\Data\2022-07-18_11h27m_Subject 1.txt   07/18/22  07/18/22
# 39  C:\MED-PC\Data\2022-07-18_14h04m_Subject 3.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 41  C:\MED-PC\Data\2022-07-19_13h38m_Subject 2.txt   07/19/22  07/19/22
# 42  C:\MED-PC\Data\2022-07-18_12h43m_Subject 2.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-18_11h27m_Subject 2.txt   07/18/22  07/18/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0        1  C57_vs_CD1_Comparison  Cage 5   2   13:38:55  14:41:48
# 1        4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 2        3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 3        1  C57_vs_CD1_comparison  Cage 5   1   14:04:40  15:08:03
# 4        4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
# 5        1  C57_vs_CD1_Comparison   Cage4   2   12:27:39  13:29:52
# 6        1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  09:50:24
# 7        2  C57_vs_CD1_Comparison  Cage 1   3   16:39:59  09:52:50
# 8        3  C57_vs_CD1_Comparison   Cage2   3   09:57:57  11:10:02
# 9        3  C57_vs_CD1_Comparison  Cage 1   4   16:39:59  09:52:50
# 10       2  C57_vs_CD1_comparison  Cage 5   2   14:04:40  15:08:03
# 11       4  C57_vs_CD1_Comparison  Cage 1   1   16:39:59  09:52:50
# 12       1  C57_vs_CD1_Comparison   Cage2   1   09:57:57  11:10:02
# 13       3  C57_vs_CD1_Comparison  Cage 6   3   15:10:30  16:20:28
# 14       3  C57_vs_CD1_Comparison   Cage2   4   09:54:52  11:05:02
# 15       2  C57_vs_CD1_comparison   Cage3   3   11:11:52  12:18:52
# 16       4  C57_vs_CD1_comparison  Cage 4   4   12:43:28  13:54:48
# 17       4  C57_vs_CD1_Comparison   Cage2   4   09:57:57  11:10:02
# 18       2  C57_vs_CD1_Comparison  Cage 6   2   15:10:30  16:20:28
# 19       2  C57_vs_CD1_Comparison   Cage2   3   09:54:52  11:05:02
# 20       3  C57_vs_CD1_comparison  Cage 4   3   12:43:28  13:54:48
# 21       4  C57_vs_CD1_comparison   Cage3   1   11:10:24  12:18:52
# 22       4  C57_vs_CD1_Comparison   Cage2   1   09:54:52  11:05:02
# 23       4  C57_vs_CD1_Comparison   Cage4   1   12:27:39  13:29:52
# 24       2  C57_vs_CD1_Comparison   Cage1   2   08:25:48  09:50:24
# 25       2  C57_vs_CD1_Comparison   Cage2   2   09:57:57  11:10:02
# 26       4  C57_vs_CD1_Comparison  Cage 5   1   13:38:55  14:41:48
# 27       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  15:55:10
# 28       1  C57_vs_CD1_comparison  Cage 4   1   12:43:28  13:54:48
# 29       4  C57_vs_CD1_comparison  Cage 5   4   14:04:40  15:08:03
# 30       1  C57_vs_CD1_Comparison  Cage 6   1   15:10:30  16:20:28
# 31       1  C57_vs_CD1_Comparison   Cage2   2   09:54:52  11:05:02
# 32       2  C57_vs_CD1_Comparison   Cage4   3   12:27:39  13:29:52
# 33       1  C57_vs_CD1_comparison   Cage3   2   11:11:34  12:18:52
# 34       3  C57_vs_CD1_Comparison   Cage4   4   12:27:39  13:29:52
# 35       3  C57_vs_CD1_Comparison   Cage1   3   08:25:48  09:50:24
# 36       3  C57_vs_CD1_Comparison  Cage 5   4   13:38:55  14:41:48
# 37       3  C57_vs_CD1_comparison   Cage3   4   11:12:05  12:18:52
# 38       1  C57_vs_CD1_Comparison   Cage3   1   11:27:37  12:35:25
# 39       3  C57_vs_CD1_comparison  Cage 5   3   14:04:40  15:08:03
# 40       1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 41       2  C57_vs_CD1_Comparison  Cage 5   3   13:38:55  14:41:48
# 42       2  C57_vs_CD1_comparison  Cage 4   2   12:43:28  13:54:48
# 43       2  C57_vs_CD1_Comparison   Cage3   2   11:27:37  12:35:25
#
#                     MSN                        file_name cage  \
# 0   CD1_reward_training  2022-07-19_13h38m_Subject 1.txt    5
# 1   CD1_reward_training  2022-07-18_15h10m_Subject 4.txt    6
# 2   C57_reward_training  2022-07-18_11h27m_Subject 3.txt    3
# 3   CD1_reward_training  2022-07-18_14h04m_Subject 1.txt    5
# 4   C57_reward_training  2022-07-18_11h27m_Subject 4.txt    3
# 5   C57_reward_training  2022-07-19_12h27m_Subject 1.txt    4
# 6   C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 7   C57_reward_training  2022-07-18_16h39m_Subject 2.txt    1
# 8   C57_reward_training  2022-07-18_09h57m_Subject 3.txt    2
# 9   C57_reward_training  2022-07-18_16h39m_Subject 3.txt    1
# 10  CD1_reward_training  2022-07-18_14h04m_Subject 2.txt    5
# 11  C57_reward_training  2022-07-18_16h39m_Subject 4.txt    1
# 12  C57_reward_training  2022-07-18_09h57m_Subject 1.txt    2
# 13  CD1_reward_training  2022-07-18_15h10m_Subject 3.txt    6
# 14  C57_reward_training  2022-07-19_09h54m_Subject 3.txt    2
# 15  C57_reward_training  2022-07-19_11h11m_Subject 2.txt    3
# 16  CD1_reward_training  2022-07-18_12h43m_Subject 4.txt    4
# 17  C57_reward_training  2022-07-18_09h57m_Subject 4.txt    2
# 18  CD1_reward_training  2022-07-18_15h10m_Subject 2.txt    6
# 19  C57_reward_training  2022-07-19_09h54m_Subject 2.txt    2
# 20  CD1_reward_training  2022-07-18_12h43m_Subject 3.txt    4
# 21  C57_reward_training  2022-07-19_11h10m_Subject 4.txt    3
# 22  C57_reward_training  2022-07-19_09h54m_Subject 4.txt    2
# 23  C57_reward_training  2022-07-19_12h27m_Subject 4.txt    4
# 24  C57_reward_training  2022-07-18_08h25m_Subject 2.txt    1
# 25  C57_reward_training  2022-07-18_09h57m_Subject 2.txt    2
# 26  CD1_reward_training  2022-07-19_13h38m_Subject 4.txt    5
# 27  CD1_reward_training  2022-07-19_14h52m_Subject 4.txt    6
# 28  CD1_reward_training  2022-07-18_12h43m_Subject 1.txt    4
# 29  CD1_reward_training  2022-07-18_14h04m_Subject 4.txt    5
# 30  CD1_reward_training  2022-07-18_15h10m_Subject 1.txt    6
# 31  C57_reward_training  2022-07-19_09h54m_Subject 1.txt    2
# 32  C57_reward_training  2022-07-19_12h27m_Subject 2.txt    4
# 33  C57_reward_training  2022-07-19_11h11m_Subject 1.txt    3
# 34  C57_reward_training  2022-07-19_12h27m_Subject 3.txt    4
# 35  C57_reward_training  2022-07-18_08h25m_Subject 3.txt    1
# 36  CD1_reward_training  2022-07-19_13h38m_Subject 3.txt    5
# 37  C57_reward_training  2022-07-19_11h12m_Subject 3.txt    3
# 38  C57_reward_training  2022-07-18_11h27m_Subject 1.txt    3
# 39  CD1_reward_training  2022-07-18_14h04m_Subject 3.txt    5
# 40  C57_reward_training  2022-07-18_16h39m_Subject 1.txt    1
# 41  CD1_reward_training  2022-07-19_13h38m_Subject 2.txt    5
# 42  CD1_reward_training  2022-07-18_12h43m_Subject 2.txt    4
# 43  C57_reward_training  2022-07-18_11h27m_Subject 2.txt    3
#
#     cage_and_subject
# 0   cage_5_subject_1
# 1   cage_6_subject_4
# 2   cage_3_subject_3
# 3   cage_5_subject_1
# 4   cage_3_subject_4
# 5   cage_4_subject_1
# 6   cage_1_subject_1
# 7   cage_1_subject_2
# 8   cage_2_subject_3
# 9   cage_1_subject_3
# 10  cage_5_subject_2
# 11  cage_1_subject_4
# 12  cage_2_subject_1
# 13  cage_6_subject_3
# 14  cage_2_subject_3
# 15  cage_3_subject_2
# 16  cage_4_subject_4
# 17  cage_2_subject_4
# 18  cage_6_subject_2
# 19  cage_2_subject_2
# 20  cage_4_subject_3
# 21  cage_3_subject_4
# 22  cage_2_subject_4
# 23  cage_4_subject_4
# 24  cage_1_subject_2
# 25  cage_2_subject_2
# 26  cage_5_subject_4
# 27  cage_6_subject_4
# 28  cage_4_subject_1
# 29  cage_5_subject_4
# 30  cage_6_subject_1
# 31  cage_2_subject_1
# 32  cage_4_subject_2
# 33  cage_3_subject_1
# 34  cage_4_subject_3
# 35  cage_1_subject_3
# 36  cage_5_subject_3
# 37  cage_3_subject_3
# 38  cage_3_subject_1
# 39  cage_5_subject_3
# 40  cage_1_subject_1
# 41  cage_5_subject_2
# 42  cage_4_subject_2
# 43  cage_3_subject_2

# %% [markdown]
# - Making new columns so that we can use the Start date and End date in other steps

# %%
metadata_df["start_date_datetime"] = metadata_df["Start Date"].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
metadata_df["start_date_int"] = metadata_df["start_date_datetime"].apply(lambda x: int(x.strftime('%Y%m%d')))

metadata_df["end_date_datetime"] = metadata_df["End Date"].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
metadata_df["end_date_int"] = metadata_df["end_date_datetime"].apply(lambda x: int(x.strftime('%Y%m%d')))

# %%
metadata_df
# Out:
#                                                index  \
# 0   ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 1   ./data/textfiles/2022-07-18_15h10m_Subject 4.txt
# 2   ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 3   ./data/textfiles/2022-07-18_14h04m_Subject 1.txt
# 4   ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
# 5   ./data/textfiles/2022-07-19_12h27m_Subject 1.txt
# 6   ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 7   ./data/textfiles/2022-07-18_16h39m_Subject 2.txt
# 8   ./data/textfiles/2022-07-18_09h57m_Subject 3.txt
# 9   ./data/textfiles/2022-07-18_16h39m_Subject 3.txt
# 10  ./data/textfiles/2022-07-18_14h04m_Subject 2.txt
# 11  ./data/textfiles/2022-07-18_16h39m_Subject 4.txt
# 12  ./data/textfiles/2022-07-18_09h57m_Subject 1.txt
# 13  ./data/textfiles/2022-07-18_15h10m_Subject 3.txt
# 14  ./data/textfiles/2022-07-19_09h54m_Subject 3.txt
# 15  ./data/textfiles/2022-07-19_11h11m_Subject 2.txt
# 16  ./data/textfiles/2022-07-18_12h43m_Subject 4.txt
# 17  ./data/textfiles/2022-07-18_09h57m_Subject 4.txt
# 18  ./data/textfiles/2022-07-18_15h10m_Subject 2.txt
# 19  ./data/textfiles/2022-07-19_09h54m_Subject 2.txt
# 20  ./data/textfiles/2022-07-18_12h43m_Subject 3.txt
# 21  ./data/textfiles/2022-07-19_11h10m_Subject 4.txt
# 22  ./data/textfiles/2022-07-19_09h54m_Subject 4.txt
# 23  ./data/textfiles/2022-07-19_12h27m_Subject 4.txt
# 24  ./data/textfiles/2022-07-18_08h25m_Subject 2.txt
# 25  ./data/textfiles/2022-07-18_09h57m_Subject 2.txt
# 26  ./data/textfiles/2022-07-19_13h38m_Subject 4.txt
# 27  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 28  ./data/textfiles/2022-07-18_12h43m_Subject 1.txt
# 29  ./data/textfiles/2022-07-18_14h04m_Subject 4.txt
# 30  ./data/textfiles/2022-07-18_15h10m_Subject 1.txt
# 31  ./data/textfiles/2022-07-19_09h54m_Subject 1.txt
# 32  ./data/textfiles/2022-07-19_12h27m_Subject 2.txt
# 33  ./data/textfiles/2022-07-19_11h11m_Subject 1.txt
# 34  ./data/textfiles/2022-07-19_12h27m_Subject 3.txt
# 35  ./data/textfiles/2022-07-18_08h25m_Subject 3.txt
# 36  ./data/textfiles/2022-07-19_13h38m_Subject 3.txt
# 37  ./data/textfiles/2022-07-19_11h12m_Subject 3.txt
# 38  ./data/textfiles/2022-07-18_11h27m_Subject 1.txt
# 39  ./data/textfiles/2022-07-18_14h04m_Subject 3.txt
# 40  ./data/textfiles/2022-07-18_16h39m_Subject 1.txt
# 41  ./data/textfiles/2022-07-19_13h38m_Subject 2.txt
# 42  ./data/textfiles/2022-07-18_12h43m_Subject 2.txt
# 43  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt   07/19/22  07/19/22
# 1   C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 2   C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 3   C:\MED-PC\Data\2022-07-18_14h04m_Subject 1.txt   07/18/22  07/18/22
# 4   C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
# 5   C:\MED-PC\Data\2022-07-19_12h27m_Subject 1.txt   07/19/22  07/19/22
# 6   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 7   C:\MED-PC\Data\2022-07-18_16h39m_Subject 2.txt   07/18/22  07/19/22
# 8   C:\MED-PC\Data\2022-07-18_09h57m_Subject 3.txt   07/18/22  07/18/22
# 9   C:\MED-PC\Data\2022-07-18_16h39m_Subject 3.txt   07/18/22  07/19/22
# 10  C:\MED-PC\Data\2022-07-18_14h04m_Subject 2.txt   07/18/22  07/18/22
# 11  C:\MED-PC\Data\2022-07-18_16h39m_Subject 4.txt   07/18/22  07/19/22
# 12  C:\MED-PC\Data\2022-07-18_09h57m_Subject 1.txt   07/18/22  07/18/22
# 13  C:\MED-PC\Data\2022-07-18_15h10m_Subject 3.txt   07/18/22  07/18/22
# 14  C:\MED-PC\Data\2022-07-19_09h54m_Subject 3.txt   07/19/22  07/19/22
# 15  C:\MED-PC\Data\2022-07-19_11h11m_Subject 2.txt   07/19/22  07/19/22
# 16  C:\MED-PC\Data\2022-07-18_12h43m_Subject 4.txt   07/18/22  07/18/22
# 17  C:\MED-PC\Data\2022-07-18_09h57m_Subject 4.txt   07/18/22  07/18/22
# 18  C:\MED-PC\Data\2022-07-18_15h10m_Subject 2.txt   07/18/22  07/18/22
# 19  C:\MED-PC\Data\2022-07-19_09h54m_Subject 2.txt   07/19/22  07/19/22
# 20  C:\MED-PC\Data\2022-07-18_12h43m_Subject 3.txt   07/18/22  07/18/22
# 21  C:\MED-PC\Data\2022-07-19_11h10m_Subject 4.txt   07/19/22  07/19/22
# 22  C:\MED-PC\Data\2022-07-19_09h54m_Subject 4.txt   07/19/22  07/19/22
# 23  C:\MED-PC\Data\2022-07-19_12h27m_Subject 4.txt   07/19/22  07/19/22
# 24  C:\MED-PC\Data\2022-07-18_08h25m_Subject 2.txt   07/18/22  07/18/22
# 25  C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 26  C:\MED-PC\Data\2022-07-19_13h38m_Subject 4.txt   07/19/22  07/19/22
# 27  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 28  C:\MED-PC\Data\2022-07-18_12h43m_Subject 1.txt   07/18/22  07/18/22
# 29  C:\MED-PC\Data\2022-07-18_14h04m_Subject 4.txt   07/18/22  07/18/22
# 30  C:\MED-PC\Data\2022-07-18_15h10m_Subject 1.txt   07/18/22  07/18/22
# 31  C:\MED-PC\Data\2022-07-19_09h54m_Subject 1.txt   07/19/22  07/19/22
# 32  C:\MED-PC\Data\2022-07-19_12h27m_Subject 2.txt   07/19/22  07/19/22
# 33  C:\MED-PC\Data\2022-07-19_11h11m_Subject 1.txt   07/19/22  07/19/22
# 34  C:\MED-PC\Data\2022-07-19_12h27m_Subject 3.txt   07/19/22  07/19/22
# 35  C:\MED-PC\Data\2022-07-18_08h25m_Subject 3.txt   07/18/22  07/18/22
# 36  C:\MED-PC\Data\2022-07-19_13h38m_Subject 3.txt   07/19/22  07/19/22
# 37  C:\MED-PC\Data\2022-07-19_11h12m_Subject 3.txt   07/19/22  07/19/22
# 38  C:\MED-PC\Data\2022-07-18_11h27m_Subject 1.txt   07/18/22  07/18/22
# 39  C:\MED-PC\Data\2022-07-18_14h04m_Subject 3.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 41  C:\MED-PC\Data\2022-07-19_13h38m_Subject 2.txt   07/19/22  07/19/22
# 42  C:\MED-PC\Data\2022-07-18_12h43m_Subject 2.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-18_11h27m_Subject 2.txt   07/18/22  07/18/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0        1  C57_vs_CD1_Comparison  Cage 5   2   13:38:55  14:41:48
# 1        4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 2        3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 3        1  C57_vs_CD1_comparison  Cage 5   1   14:04:40  15:08:03
# 4        4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
# 5        1  C57_vs_CD1_Comparison   Cage4   2   12:27:39  13:29:52
# 6        1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  09:50:24
# 7        2  C57_vs_CD1_Comparison  Cage 1   3   16:39:59  09:52:50
# 8        3  C57_vs_CD1_Comparison   Cage2   3   09:57:57  11:10:02
# 9        3  C57_vs_CD1_Comparison  Cage 1   4   16:39:59  09:52:50
# 10       2  C57_vs_CD1_comparison  Cage 5   2   14:04:40  15:08:03
# 11       4  C57_vs_CD1_Comparison  Cage 1   1   16:39:59  09:52:50
# 12       1  C57_vs_CD1_Comparison   Cage2   1   09:57:57  11:10:02
# 13       3  C57_vs_CD1_Comparison  Cage 6   3   15:10:30  16:20:28
# 14       3  C57_vs_CD1_Comparison   Cage2   4   09:54:52  11:05:02
# 15       2  C57_vs_CD1_comparison   Cage3   3   11:11:52  12:18:52
# 16       4  C57_vs_CD1_comparison  Cage 4   4   12:43:28  13:54:48
# 17       4  C57_vs_CD1_Comparison   Cage2   4   09:57:57  11:10:02
# 18       2  C57_vs_CD1_Comparison  Cage 6   2   15:10:30  16:20:28
# 19       2  C57_vs_CD1_Comparison   Cage2   3   09:54:52  11:05:02
# 20       3  C57_vs_CD1_comparison  Cage 4   3   12:43:28  13:54:48
# 21       4  C57_vs_CD1_comparison   Cage3   1   11:10:24  12:18:52
# 22       4  C57_vs_CD1_Comparison   Cage2   1   09:54:52  11:05:02
# 23       4  C57_vs_CD1_Comparison   Cage4   1   12:27:39  13:29:52
# 24       2  C57_vs_CD1_Comparison   Cage1   2   08:25:48  09:50:24
# 25       2  C57_vs_CD1_Comparison   Cage2   2   09:57:57  11:10:02
# 26       4  C57_vs_CD1_Comparison  Cage 5   1   13:38:55  14:41:48
# 27       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  15:55:10
# 28       1  C57_vs_CD1_comparison  Cage 4   1   12:43:28  13:54:48
# 29       4  C57_vs_CD1_comparison  Cage 5   4   14:04:40  15:08:03
# 30       1  C57_vs_CD1_Comparison  Cage 6   1   15:10:30  16:20:28
# 31       1  C57_vs_CD1_Comparison   Cage2   2   09:54:52  11:05:02
# 32       2  C57_vs_CD1_Comparison   Cage4   3   12:27:39  13:29:52
# 33       1  C57_vs_CD1_comparison   Cage3   2   11:11:34  12:18:52
# 34       3  C57_vs_CD1_Comparison   Cage4   4   12:27:39  13:29:52
# 35       3  C57_vs_CD1_Comparison   Cage1   3   08:25:48  09:50:24
# 36       3  C57_vs_CD1_Comparison  Cage 5   4   13:38:55  14:41:48
# 37       3  C57_vs_CD1_comparison   Cage3   4   11:12:05  12:18:52
# 38       1  C57_vs_CD1_Comparison   Cage3   1   11:27:37  12:35:25
# 39       3  C57_vs_CD1_comparison  Cage 5   3   14:04:40  15:08:03
# 40       1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 41       2  C57_vs_CD1_Comparison  Cage 5   3   13:38:55  14:41:48
# 42       2  C57_vs_CD1_comparison  Cage 4   2   12:43:28  13:54:48
# 43       2  C57_vs_CD1_Comparison   Cage3   2   11:27:37  12:35:25
#
#                     MSN                        file_name cage  \
# 0   CD1_reward_training  2022-07-19_13h38m_Subject 1.txt    5
# 1   CD1_reward_training  2022-07-18_15h10m_Subject 4.txt    6
# 2   C57_reward_training  2022-07-18_11h27m_Subject 3.txt    3
# 3   CD1_reward_training  2022-07-18_14h04m_Subject 1.txt    5
# 4   C57_reward_training  2022-07-18_11h27m_Subject 4.txt    3
# 5   C57_reward_training  2022-07-19_12h27m_Subject 1.txt    4
# 6   C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 7   C57_reward_training  2022-07-18_16h39m_Subject 2.txt    1
# 8   C57_reward_training  2022-07-18_09h57m_Subject 3.txt    2
# 9   C57_reward_training  2022-07-18_16h39m_Subject 3.txt    1
# 10  CD1_reward_training  2022-07-18_14h04m_Subject 2.txt    5
# 11  C57_reward_training  2022-07-18_16h39m_Subject 4.txt    1
# 12  C57_reward_training  2022-07-18_09h57m_Subject 1.txt    2
# 13  CD1_reward_training  2022-07-18_15h10m_Subject 3.txt    6
# 14  C57_reward_training  2022-07-19_09h54m_Subject 3.txt    2
# 15  C57_reward_training  2022-07-19_11h11m_Subject 2.txt    3
# 16  CD1_reward_training  2022-07-18_12h43m_Subject 4.txt    4
# 17  C57_reward_training  2022-07-18_09h57m_Subject 4.txt    2
# 18  CD1_reward_training  2022-07-18_15h10m_Subject 2.txt    6
# 19  C57_reward_training  2022-07-19_09h54m_Subject 2.txt    2
# 20  CD1_reward_training  2022-07-18_12h43m_Subject 3.txt    4
# 21  C57_reward_training  2022-07-19_11h10m_Subject 4.txt    3
# 22  C57_reward_training  2022-07-19_09h54m_Subject 4.txt    2
# 23  C57_reward_training  2022-07-19_12h27m_Subject 4.txt    4
# 24  C57_reward_training  2022-07-18_08h25m_Subject 2.txt    1
# 25  C57_reward_training  2022-07-18_09h57m_Subject 2.txt    2
# 26  CD1_reward_training  2022-07-19_13h38m_Subject 4.txt    5
# 27  CD1_reward_training  2022-07-19_14h52m_Subject 4.txt    6
# 28  CD1_reward_training  2022-07-18_12h43m_Subject 1.txt    4
# 29  CD1_reward_training  2022-07-18_14h04m_Subject 4.txt    5
# 30  CD1_reward_training  2022-07-18_15h10m_Subject 1.txt    6
# 31  C57_reward_training  2022-07-19_09h54m_Subject 1.txt    2
# 32  C57_reward_training  2022-07-19_12h27m_Subject 2.txt    4
# 33  C57_reward_training  2022-07-19_11h11m_Subject 1.txt    3
# 34  C57_reward_training  2022-07-19_12h27m_Subject 3.txt    4
# 35  C57_reward_training  2022-07-18_08h25m_Subject 3.txt    1
# 36  CD1_reward_training  2022-07-19_13h38m_Subject 3.txt    5
# 37  C57_reward_training  2022-07-19_11h12m_Subject 3.txt    3
# 38  C57_reward_training  2022-07-18_11h27m_Subject 1.txt    3
# 39  CD1_reward_training  2022-07-18_14h04m_Subject 3.txt    5
# 40  C57_reward_training  2022-07-18_16h39m_Subject 1.txt    1
# 41  CD1_reward_training  2022-07-19_13h38m_Subject 2.txt    5
# 42  CD1_reward_training  2022-07-18_12h43m_Subject 2.txt    4
# 43  C57_reward_training  2022-07-18_11h27m_Subject 2.txt    3
#
#     cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0   cage_5_subject_1          2022-07-19        20220719        2022-07-19
# 1   cage_6_subject_4          2022-07-18        20220718        2022-07-18
# 2   cage_3_subject_3          2022-07-18        20220718        2022-07-18
# 3   cage_5_subject_1          2022-07-18        20220718        2022-07-18
# 4   cage_3_subject_4          2022-07-18        20220718        2022-07-18
# 5   cage_4_subject_1          2022-07-19        20220719        2022-07-19
# 6   cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 7   cage_1_subject_2          2022-07-18        20220718        2022-07-19
# 8   cage_2_subject_3          2022-07-18        20220718        2022-07-18
# 9   cage_1_subject_3          2022-07-18        20220718        2022-07-19
# 10  cage_5_subject_2          2022-07-18        20220718        2022-07-18
# 11  cage_1_subject_4          2022-07-18        20220718        2022-07-19
# 12  cage_2_subject_1          2022-07-18        20220718        2022-07-18
# 13  cage_6_subject_3          2022-07-18        20220718        2022-07-18
# 14  cage_2_subject_3          2022-07-19        20220719        2022-07-19
# 15  cage_3_subject_2          2022-07-19        20220719        2022-07-19
# 16  cage_4_subject_4          2022-07-18        20220718        2022-07-18
# 17  cage_2_subject_4          2022-07-18        20220718        2022-07-18
# 18  cage_6_subject_2          2022-07-18        20220718        2022-07-18
# 19  cage_2_subject_2          2022-07-19        20220719        2022-07-19
# 20  cage_4_subject_3          2022-07-18        20220718        2022-07-18
# 21  cage_3_subject_4          2022-07-19        20220719        2022-07-19
# 22  cage_2_subject_4          2022-07-19        20220719        2022-07-19
# 23  cage_4_subject_4          2022-07-19        20220719        2022-07-19
# 24  cage_1_subject_2          2022-07-18        20220718        2022-07-18
# 25  cage_2_subject_2          2022-07-18        20220718        2022-07-18
# 26  cage_5_subject_4          2022-07-19        20220719        2022-07-19
# 27  cage_6_subject_4          2022-07-19        20220719        2022-07-19
# 28  cage_4_subject_1          2022-07-18        20220718        2022-07-18
# 29  cage_5_subject_4          2022-07-18        20220718        2022-07-18
# 30  cage_6_subject_1          2022-07-18        20220718        2022-07-18
# 31  cage_2_subject_1          2022-07-19        20220719        2022-07-19
# 32  cage_4_subject_2          2022-07-19        20220719        2022-07-19
# 33  cage_3_subject_1          2022-07-19        20220719        2022-07-19
# 34  cage_4_subject_3          2022-07-19        20220719        2022-07-19
# 35  cage_1_subject_3          2022-07-18        20220718        2022-07-18
# 36  cage_5_subject_3          2022-07-19        20220719        2022-07-19
# 37  cage_3_subject_3          2022-07-19        20220719        2022-07-19
# 38  cage_3_subject_1          2022-07-18        20220718        2022-07-18
# 39  cage_5_subject_3          2022-07-18        20220718        2022-07-18
# 40  cage_1_subject_1          2022-07-18        20220718        2022-07-19
# 41  cage_5_subject_2          2022-07-19        20220719        2022-07-19
# 42  cage_4_subject_2          2022-07-18        20220718        2022-07-18
# 43  cage_3_subject_2          2022-07-18        20220718        2022-07-18
#
#     end_date_int
# 0       20220719
# 1       20220718
# 2       20220718
# 3       20220718
# 4       20220718
# 5       20220719
# 6       20220718
# 7       20220719
# 8       20220718
# 9       20220719
# 10      20220718
# 11      20220719
# 12      20220718
# 13      20220718
# 14      20220719
# 15      20220719
# 16      20220718
# 17      20220718
# 18      20220718
# 19      20220719
# 20      20220718
# 21      20220719
# 22      20220719
# 23      20220719
# 24      20220718
# 25      20220718
# 26      20220719
# 27      20220719
# 28      20220718
# 29      20220718
# 30      20220718
# 31      20220719
# 32      20220719
# 33      20220719
# 34      20220719
# 35      20220718
# 36      20220719
# 37      20220719
# 38      20220718
# 39      20220718
# 40      20220719
# 41      20220719
# 42      20220718
# 43      20220718

# %% [markdown]
# - Making a column that is the trial number for each subject

# %%
subject_to_metadata_df = {}
for subject in metadata_df["cage_and_subject"].unique():
    subject_df = metadata_df[metadata_df["cage_and_subject"] == subject]
    subject_df = subject_df.sort_values("file_name", ascending=True)
    subject_df.insert(0, 'trial_number', range(1, 1 + len(subject_df)))
    subject_to_metadata_df[subject] = subject_df

# %%
subject_to_metadata_df = collections.OrderedDict(sorted(subject_to_metadata_df.items()))

# %%
all_subject_to_metadata_df = [v for k,v in subject_to_metadata_df.items()]

# %%
metadata_df = pd.concat(all_subject_to_metadata_df).reset_index(drop=True)

# %%
metadata_df.head(n=25)
# Out:
#     trial_number                                             index  \
# 0              1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 1              2  ./data/textfiles/2022-07-18_16h39m_Subject 1.txt
# 2              1  ./data/textfiles/2022-07-18_08h25m_Subject 2.txt
# 3              2  ./data/textfiles/2022-07-18_16h39m_Subject 2.txt
# 4              1  ./data/textfiles/2022-07-18_08h25m_Subject 3.txt
# 5              2  ./data/textfiles/2022-07-18_16h39m_Subject 3.txt
# 6              1  ./data/textfiles/2022-07-18_16h39m_Subject 4.txt
# 7              1  ./data/textfiles/2022-07-18_09h57m_Subject 1.txt
# 8              2  ./data/textfiles/2022-07-19_09h54m_Subject 1.txt
# 9              1  ./data/textfiles/2022-07-18_09h57m_Subject 2.txt
# 10             2  ./data/textfiles/2022-07-19_09h54m_Subject 2.txt
# 11             1  ./data/textfiles/2022-07-18_09h57m_Subject 3.txt
# 12             2  ./data/textfiles/2022-07-19_09h54m_Subject 3.txt
# 13             1  ./data/textfiles/2022-07-18_09h57m_Subject 4.txt
# 14             2  ./data/textfiles/2022-07-19_09h54m_Subject 4.txt
# 15             1  ./data/textfiles/2022-07-18_11h27m_Subject 1.txt
# 16             2  ./data/textfiles/2022-07-19_11h11m_Subject 1.txt
# 17             1  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
# 18             2  ./data/textfiles/2022-07-19_11h11m_Subject 2.txt
# 19             1  ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 20             2  ./data/textfiles/2022-07-19_11h12m_Subject 3.txt
# 21             1  ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
# 22             2  ./data/textfiles/2022-07-19_11h10m_Subject 4.txt
# 23             1  ./data/textfiles/2022-07-18_12h43m_Subject 1.txt
# 24             2  ./data/textfiles/2022-07-19_12h27m_Subject 1.txt
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1   C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 2   C:\MED-PC\Data\2022-07-18_08h25m_Subject 2.txt   07/18/22  07/18/22
# 3   C:\MED-PC\Data\2022-07-18_16h39m_Subject 2.txt   07/18/22  07/19/22
# 4   C:\MED-PC\Data\2022-07-18_08h25m_Subject 3.txt   07/18/22  07/18/22
# 5   C:\MED-PC\Data\2022-07-18_16h39m_Subject 3.txt   07/18/22  07/19/22
# 6   C:\MED-PC\Data\2022-07-18_16h39m_Subject 4.txt   07/18/22  07/19/22
# 7   C:\MED-PC\Data\2022-07-18_09h57m_Subject 1.txt   07/18/22  07/18/22
# 8   C:\MED-PC\Data\2022-07-19_09h54m_Subject 1.txt   07/19/22  07/19/22
# 9   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 10  C:\MED-PC\Data\2022-07-19_09h54m_Subject 2.txt   07/19/22  07/19/22
# 11  C:\MED-PC\Data\2022-07-18_09h57m_Subject 3.txt   07/18/22  07/18/22
# 12  C:\MED-PC\Data\2022-07-19_09h54m_Subject 3.txt   07/19/22  07/19/22
# 13  C:\MED-PC\Data\2022-07-18_09h57m_Subject 4.txt   07/18/22  07/18/22
# 14  C:\MED-PC\Data\2022-07-19_09h54m_Subject 4.txt   07/19/22  07/19/22
# 15  C:\MED-PC\Data\2022-07-18_11h27m_Subject 1.txt   07/18/22  07/18/22
# 16  C:\MED-PC\Data\2022-07-19_11h11m_Subject 1.txt   07/19/22  07/19/22
# 17  C:\MED-PC\Data\2022-07-18_11h27m_Subject 2.txt   07/18/22  07/18/22
# 18  C:\MED-PC\Data\2022-07-19_11h11m_Subject 2.txt   07/19/22  07/19/22
# 19  C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 20  C:\MED-PC\Data\2022-07-19_11h12m_Subject 3.txt   07/19/22  07/19/22
# 21  C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
# 22  C:\MED-PC\Data\2022-07-19_11h10m_Subject 4.txt   07/19/22  07/19/22
# 23  C:\MED-PC\Data\2022-07-18_12h43m_Subject 1.txt   07/18/22  07/18/22
# 24  C:\MED-PC\Data\2022-07-19_12h27m_Subject 1.txt   07/19/22  07/19/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0        1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  09:50:24
# 1        1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 2        2  C57_vs_CD1_Comparison   Cage1   2   08:25:48  09:50:24
# 3        2  C57_vs_CD1_Comparison  Cage 1   3   16:39:59  09:52:50
# 4        3  C57_vs_CD1_Comparison   Cage1   3   08:25:48  09:50:24
# 5        3  C57_vs_CD1_Comparison  Cage 1   4   16:39:59  09:52:50
# 6        4  C57_vs_CD1_Comparison  Cage 1   1   16:39:59  09:52:50
# 7        1  C57_vs_CD1_Comparison   Cage2   1   09:57:57  11:10:02
# 8        1  C57_vs_CD1_Comparison   Cage2   2   09:54:52  11:05:02
# 9        2  C57_vs_CD1_Comparison   Cage2   2   09:57:57  11:10:02
# 10       2  C57_vs_CD1_Comparison   Cage2   3   09:54:52  11:05:02
# 11       3  C57_vs_CD1_Comparison   Cage2   3   09:57:57  11:10:02
# 12       3  C57_vs_CD1_Comparison   Cage2   4   09:54:52  11:05:02
# 13       4  C57_vs_CD1_Comparison   Cage2   4   09:57:57  11:10:02
# 14       4  C57_vs_CD1_Comparison   Cage2   1   09:54:52  11:05:02
# 15       1  C57_vs_CD1_Comparison   Cage3   1   11:27:37  12:35:25
# 16       1  C57_vs_CD1_comparison   Cage3   2   11:11:34  12:18:52
# 17       2  C57_vs_CD1_Comparison   Cage3   2   11:27:37  12:35:25
# 18       2  C57_vs_CD1_comparison   Cage3   3   11:11:52  12:18:52
# 19       3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 20       3  C57_vs_CD1_comparison   Cage3   4   11:12:05  12:18:52
# 21       4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
# 22       4  C57_vs_CD1_comparison   Cage3   1   11:10:24  12:18:52
# 23       1  C57_vs_CD1_comparison  Cage 4   1   12:43:28  13:54:48
# 24       1  C57_vs_CD1_Comparison   Cage4   2   12:27:39  13:29:52
#
#                     MSN                        file_name cage  \
# 0   C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 1   C57_reward_training  2022-07-18_16h39m_Subject 1.txt    1
# 2   C57_reward_training  2022-07-18_08h25m_Subject 2.txt    1
# 3   C57_reward_training  2022-07-18_16h39m_Subject 2.txt    1
# 4   C57_reward_training  2022-07-18_08h25m_Subject 3.txt    1
# 5   C57_reward_training  2022-07-18_16h39m_Subject 3.txt    1
# 6   C57_reward_training  2022-07-18_16h39m_Subject 4.txt    1
# 7   C57_reward_training  2022-07-18_09h57m_Subject 1.txt    2
# 8   C57_reward_training  2022-07-19_09h54m_Subject 1.txt    2
# 9   C57_reward_training  2022-07-18_09h57m_Subject 2.txt    2
# 10  C57_reward_training  2022-07-19_09h54m_Subject 2.txt    2
# 11  C57_reward_training  2022-07-18_09h57m_Subject 3.txt    2
# 12  C57_reward_training  2022-07-19_09h54m_Subject 3.txt    2
# 13  C57_reward_training  2022-07-18_09h57m_Subject 4.txt    2
# 14  C57_reward_training  2022-07-19_09h54m_Subject 4.txt    2
# 15  C57_reward_training  2022-07-18_11h27m_Subject 1.txt    3
# 16  C57_reward_training  2022-07-19_11h11m_Subject 1.txt    3
# 17  C57_reward_training  2022-07-18_11h27m_Subject 2.txt    3
# 18  C57_reward_training  2022-07-19_11h11m_Subject 2.txt    3
# 19  C57_reward_training  2022-07-18_11h27m_Subject 3.txt    3
# 20  C57_reward_training  2022-07-19_11h12m_Subject 3.txt    3
# 21  C57_reward_training  2022-07-18_11h27m_Subject 4.txt    3
# 22  C57_reward_training  2022-07-19_11h10m_Subject 4.txt    3
# 23  CD1_reward_training  2022-07-18_12h43m_Subject 1.txt    4
# 24  C57_reward_training  2022-07-19_12h27m_Subject 1.txt    4
#
#     cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0   cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 1   cage_1_subject_1          2022-07-18        20220718        2022-07-19
# 2   cage_1_subject_2          2022-07-18        20220718        2022-07-18
# 3   cage_1_subject_2          2022-07-18        20220718        2022-07-19
# 4   cage_1_subject_3          2022-07-18        20220718        2022-07-18
# 5   cage_1_subject_3          2022-07-18        20220718        2022-07-19
# 6   cage_1_subject_4          2022-07-18        20220718        2022-07-19
# 7   cage_2_subject_1          2022-07-18        20220718        2022-07-18
# 8   cage_2_subject_1          2022-07-19        20220719        2022-07-19
# 9   cage_2_subject_2          2022-07-18        20220718        2022-07-18
# 10  cage_2_subject_2          2022-07-19        20220719        2022-07-19
# 11  cage_2_subject_3          2022-07-18        20220718        2022-07-18
# 12  cage_2_subject_3          2022-07-19        20220719        2022-07-19
# 13  cage_2_subject_4          2022-07-18        20220718        2022-07-18
# 14  cage_2_subject_4          2022-07-19        20220719        2022-07-19
# 15  cage_3_subject_1          2022-07-18        20220718        2022-07-18
# 16  cage_3_subject_1          2022-07-19        20220719        2022-07-19
# 17  cage_3_subject_2          2022-07-18        20220718        2022-07-18
# 18  cage_3_subject_2          2022-07-19        20220719        2022-07-19
# 19  cage_3_subject_3          2022-07-18        20220718        2022-07-18
# 20  cage_3_subject_3          2022-07-19        20220719        2022-07-19
# 21  cage_3_subject_4          2022-07-18        20220718        2022-07-18
# 22  cage_3_subject_4          2022-07-19        20220719        2022-07-19
# 23  cage_4_subject_1          2022-07-18        20220718        2022-07-18
# 24  cage_4_subject_1          2022-07-19        20220719        2022-07-19
#
#     end_date_int
# 0       20220718
# 1       20220719
# 2       20220718
# 3       20220719
# 4       20220718
# 5       20220719
# 6       20220719
# 7       20220718
# 8       20220719
# 9       20220718
# 10      20220719
# 11      20220718
# 12      20220719
# 13      20220718
# 14      20220719
# 15      20220718
# 16      20220719
# 17      20220718
# 18      20220719
# 19      20220718
# 20      20220719
# 21      20220718
# 22      20220719
# 23      20220718
# 24      20220719

# %%
metadata_df.tail(n=25)
# Out:
#     trial_number                                             index  \
# 19             1  ./data/textfiles/2022-07-18_11h27m_Subject 3.txt
# 20             2  ./data/textfiles/2022-07-19_11h12m_Subject 3.txt
# 21             1  ./data/textfiles/2022-07-18_11h27m_Subject 4.txt
# 22             2  ./data/textfiles/2022-07-19_11h10m_Subject 4.txt
# 23             1  ./data/textfiles/2022-07-18_12h43m_Subject 1.txt
# 24             2  ./data/textfiles/2022-07-19_12h27m_Subject 1.txt
# 25             1  ./data/textfiles/2022-07-18_12h43m_Subject 2.txt
# 26             2  ./data/textfiles/2022-07-19_12h27m_Subject 2.txt
# 27             1  ./data/textfiles/2022-07-18_12h43m_Subject 3.txt
# 28             2  ./data/textfiles/2022-07-19_12h27m_Subject 3.txt
# 29             1  ./data/textfiles/2022-07-18_12h43m_Subject 4.txt
# 30             2  ./data/textfiles/2022-07-19_12h27m_Subject 4.txt
# 31             1  ./data/textfiles/2022-07-18_14h04m_Subject 1.txt
# 32             2  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 33             1  ./data/textfiles/2022-07-18_14h04m_Subject 2.txt
# 34             2  ./data/textfiles/2022-07-19_13h38m_Subject 2.txt
# 35             1  ./data/textfiles/2022-07-18_14h04m_Subject 3.txt
# 36             2  ./data/textfiles/2022-07-19_13h38m_Subject 3.txt
# 37             1  ./data/textfiles/2022-07-18_14h04m_Subject 4.txt
# 38             2  ./data/textfiles/2022-07-19_13h38m_Subject 4.txt
# 39             1  ./data/textfiles/2022-07-18_15h10m_Subject 1.txt
# 40             1  ./data/textfiles/2022-07-18_15h10m_Subject 2.txt
# 41             1  ./data/textfiles/2022-07-18_15h10m_Subject 3.txt
# 42             1  ./data/textfiles/2022-07-18_15h10m_Subject 4.txt
# 43             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
#
#                                               File Start Date  End Date  \
# 19  C:\MED-PC\Data\2022-07-18_11h27m_Subject 3.txt   07/18/22  07/18/22
# 20  C:\MED-PC\Data\2022-07-19_11h12m_Subject 3.txt   07/19/22  07/19/22
# 21  C:\MED-PC\Data\2022-07-18_11h27m_Subject 4.txt   07/18/22  07/18/22
# 22  C:\MED-PC\Data\2022-07-19_11h10m_Subject 4.txt   07/19/22  07/19/22
# 23  C:\MED-PC\Data\2022-07-18_12h43m_Subject 1.txt   07/18/22  07/18/22
# 24  C:\MED-PC\Data\2022-07-19_12h27m_Subject 1.txt   07/19/22  07/19/22
# 25  C:\MED-PC\Data\2022-07-18_12h43m_Subject 2.txt   07/18/22  07/18/22
# 26  C:\MED-PC\Data\2022-07-19_12h27m_Subject 2.txt   07/19/22  07/19/22
# 27  C:\MED-PC\Data\2022-07-18_12h43m_Subject 3.txt   07/18/22  07/18/22
# 28  C:\MED-PC\Data\2022-07-19_12h27m_Subject 3.txt   07/19/22  07/19/22
# 29  C:\MED-PC\Data\2022-07-18_12h43m_Subject 4.txt   07/18/22  07/18/22
# 30  C:\MED-PC\Data\2022-07-19_12h27m_Subject 4.txt   07/19/22  07/19/22
# 31  C:\MED-PC\Data\2022-07-18_14h04m_Subject 1.txt   07/18/22  07/18/22
# 32  C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt   07/19/22  07/19/22
# 33  C:\MED-PC\Data\2022-07-18_14h04m_Subject 2.txt   07/18/22  07/18/22
# 34  C:\MED-PC\Data\2022-07-19_13h38m_Subject 2.txt   07/19/22  07/19/22
# 35  C:\MED-PC\Data\2022-07-18_14h04m_Subject 3.txt   07/18/22  07/18/22
# 36  C:\MED-PC\Data\2022-07-19_13h38m_Subject 3.txt   07/19/22  07/19/22
# 37  C:\MED-PC\Data\2022-07-18_14h04m_Subject 4.txt   07/18/22  07/18/22
# 38  C:\MED-PC\Data\2022-07-19_13h38m_Subject 4.txt   07/19/22  07/19/22
# 39  C:\MED-PC\Data\2022-07-18_15h10m_Subject 1.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_15h10m_Subject 2.txt   07/18/22  07/18/22
# 41  C:\MED-PC\Data\2022-07-18_15h10m_Subject 3.txt   07/18/22  07/18/22
# 42  C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 19       3  C57_vs_CD1_Comparison   Cage3   3   11:27:37  12:35:25
# 20       3  C57_vs_CD1_comparison   Cage3   4   11:12:05  12:18:52
# 21       4  C57_vs_CD1_Comparison   Cage3   4   11:27:37  12:35:25
# 22       4  C57_vs_CD1_comparison   Cage3   1   11:10:24  12:18:52
# 23       1  C57_vs_CD1_comparison  Cage 4   1   12:43:28  13:54:48
# 24       1  C57_vs_CD1_Comparison   Cage4   2   12:27:39  13:29:52
# 25       2  C57_vs_CD1_comparison  Cage 4   2   12:43:28  13:54:48
# 26       2  C57_vs_CD1_Comparison   Cage4   3   12:27:39  13:29:52
# 27       3  C57_vs_CD1_comparison  Cage 4   3   12:43:28  13:54:48
# 28       3  C57_vs_CD1_Comparison   Cage4   4   12:27:39  13:29:52
# 29       4  C57_vs_CD1_comparison  Cage 4   4   12:43:28  13:54:48
# 30       4  C57_vs_CD1_Comparison   Cage4   1   12:27:39  13:29:52
# 31       1  C57_vs_CD1_comparison  Cage 5   1   14:04:40  15:08:03
# 32       1  C57_vs_CD1_Comparison  Cage 5   2   13:38:55  14:41:48
# 33       2  C57_vs_CD1_comparison  Cage 5   2   14:04:40  15:08:03
# 34       2  C57_vs_CD1_Comparison  Cage 5   3   13:38:55  14:41:48
# 35       3  C57_vs_CD1_comparison  Cage 5   3   14:04:40  15:08:03
# 36       3  C57_vs_CD1_Comparison  Cage 5   4   13:38:55  14:41:48
# 37       4  C57_vs_CD1_comparison  Cage 5   4   14:04:40  15:08:03
# 38       4  C57_vs_CD1_Comparison  Cage 5   1   13:38:55  14:41:48
# 39       1  C57_vs_CD1_Comparison  Cage 6   1   15:10:30  16:20:28
# 40       2  C57_vs_CD1_Comparison  Cage 6   2   15:10:30  16:20:28
# 41       3  C57_vs_CD1_Comparison  Cage 6   3   15:10:30  16:20:28
# 42       4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 43       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  15:55:10
#
#                     MSN                        file_name cage  \
# 19  C57_reward_training  2022-07-18_11h27m_Subject 3.txt    3
# 20  C57_reward_training  2022-07-19_11h12m_Subject 3.txt    3
# 21  C57_reward_training  2022-07-18_11h27m_Subject 4.txt    3
# 22  C57_reward_training  2022-07-19_11h10m_Subject 4.txt    3
# 23  CD1_reward_training  2022-07-18_12h43m_Subject 1.txt    4
# 24  C57_reward_training  2022-07-19_12h27m_Subject 1.txt    4
# 25  CD1_reward_training  2022-07-18_12h43m_Subject 2.txt    4
# 26  C57_reward_training  2022-07-19_12h27m_Subject 2.txt    4
# 27  CD1_reward_training  2022-07-18_12h43m_Subject 3.txt    4
# 28  C57_reward_training  2022-07-19_12h27m_Subject 3.txt    4
# 29  CD1_reward_training  2022-07-18_12h43m_Subject 4.txt    4
# 30  C57_reward_training  2022-07-19_12h27m_Subject 4.txt    4
# 31  CD1_reward_training  2022-07-18_14h04m_Subject 1.txt    5
# 32  CD1_reward_training  2022-07-19_13h38m_Subject 1.txt    5
# 33  CD1_reward_training  2022-07-18_14h04m_Subject 2.txt    5
# 34  CD1_reward_training  2022-07-19_13h38m_Subject 2.txt    5
# 35  CD1_reward_training  2022-07-18_14h04m_Subject 3.txt    5
# 36  CD1_reward_training  2022-07-19_13h38m_Subject 3.txt    5
# 37  CD1_reward_training  2022-07-18_14h04m_Subject 4.txt    5
# 38  CD1_reward_training  2022-07-19_13h38m_Subject 4.txt    5
# 39  CD1_reward_training  2022-07-18_15h10m_Subject 1.txt    6
# 40  CD1_reward_training  2022-07-18_15h10m_Subject 2.txt    6
# 41  CD1_reward_training  2022-07-18_15h10m_Subject 3.txt    6
# 42  CD1_reward_training  2022-07-18_15h10m_Subject 4.txt    6
# 43  CD1_reward_training  2022-07-19_14h52m_Subject 4.txt    6
#
#     cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 19  cage_3_subject_3          2022-07-18        20220718        2022-07-18
# 20  cage_3_subject_3          2022-07-19        20220719        2022-07-19
# 21  cage_3_subject_4          2022-07-18        20220718        2022-07-18
# 22  cage_3_subject_4          2022-07-19        20220719        2022-07-19
# 23  cage_4_subject_1          2022-07-18        20220718        2022-07-18
# 24  cage_4_subject_1          2022-07-19        20220719        2022-07-19
# 25  cage_4_subject_2          2022-07-18        20220718        2022-07-18
# 26  cage_4_subject_2          2022-07-19        20220719        2022-07-19
# 27  cage_4_subject_3          2022-07-18        20220718        2022-07-18
# 28  cage_4_subject_3          2022-07-19        20220719        2022-07-19
# 29  cage_4_subject_4          2022-07-18        20220718        2022-07-18
# 30  cage_4_subject_4          2022-07-19        20220719        2022-07-19
# 31  cage_5_subject_1          2022-07-18        20220718        2022-07-18
# 32  cage_5_subject_1          2022-07-19        20220719        2022-07-19
# 33  cage_5_subject_2          2022-07-18        20220718        2022-07-18
# 34  cage_5_subject_2          2022-07-19        20220719        2022-07-19
# 35  cage_5_subject_3          2022-07-18        20220718        2022-07-18
# 36  cage_5_subject_3          2022-07-19        20220719        2022-07-19
# 37  cage_5_subject_4          2022-07-18        20220718        2022-07-18
# 38  cage_5_subject_4          2022-07-19        20220719        2022-07-19
# 39  cage_6_subject_1          2022-07-18        20220718        2022-07-18
# 40  cage_6_subject_2          2022-07-18        20220718        2022-07-18
# 41  cage_6_subject_3          2022-07-18        20220718        2022-07-18
# 42  cage_6_subject_4          2022-07-18        20220718        2022-07-18
# 43  cage_6_subject_4          2022-07-19        20220719        2022-07-19
#
#     end_date_int
# 19      20220718
# 20      20220719
# 21      20220718
# 22      20220719
# 23      20220718
# 24      20220719
# 25      20220718
# 26      20220719
# 27      20220718
# 28      20220719
# 29      20220718
# 30      20220719
# 31      20220718
# 32      20220719
# 33      20220718
# 34      20220719
# 35      20220718
# 36      20220719
# 37      20220718
# 38      20220719
# 39      20220718
# 40      20220718
# 41      20220718
# 42      20220718
# 43      20220719

# %% [markdown]
# - Getting the number of files that are associated with each subject

# %%
# How many files there are for each subject
metadata_df.groupby("cage_and_subject").count()
# Out:
#                   trial_number  index  File  Start Date  End Date  Subject  \
# cage_and_subject
# cage_1_subject_1             2      2     2           2         2        2
# cage_1_subject_2             2      2     2           2         2        2
# cage_1_subject_3             2      2     2           2         2        2
# cage_1_subject_4             1      1     1           1         1        1
# cage_2_subject_1             2      2     2           2         2        2
# cage_2_subject_2             2      2     2           2         2        2
# cage_2_subject_3             2      2     2           2         2        2
# cage_2_subject_4             2      2     2           2         2        2
# cage_3_subject_1             2      2     2           2         2        2
# cage_3_subject_2             2      2     2           2         2        2
# cage_3_subject_3             2      2     2           2         2        2
# cage_3_subject_4             2      2     2           2         2        2
# cage_4_subject_1             2      2     2           2         2        2
# cage_4_subject_2             2      2     2           2         2        2
# cage_4_subject_3             2      2     2           2         2        2
# cage_4_subject_4             2      2     2           2         2        2
# cage_5_subject_1             2      2     2           2         2        2
# cage_5_subject_2             2      2     2           2         2        2
# cage_5_subject_3             2      2     2           2         2        2
# cage_5_subject_4             2      2     2           2         2        2
# cage_6_subject_1             1      1     1           1         1        1
# cage_6_subject_2             1      1     1           1         1        1
# cage_6_subject_3             1      1     1           1         1        1
# cage_6_subject_4             2      2     2           2         2        2
#
#                   Experiment  Group  Box  Start Time  End Time  MSN  \
# cage_and_subject
# cage_1_subject_1           2      2    2           2         2    2
# cage_1_subject_2           2      2    2           2         2    2
# cage_1_subject_3           2      2    2           2         2    2
# cage_1_subject_4           1      1    1           1         1    1
# cage_2_subject_1           2      2    2           2         2    2
# cage_2_subject_2           2      2    2           2         2    2
# cage_2_subject_3           2      2    2           2         2    2
# cage_2_subject_4           2      2    2           2         2    2
# cage_3_subject_1           2      2    2           2         2    2
# cage_3_subject_2           2      2    2           2         2    2
# cage_3_subject_3           2      2    2           2         2    2
# cage_3_subject_4           2      2    2           2         2    2
# cage_4_subject_1           2      2    2           2         2    2
# cage_4_subject_2           2      2    2           2         2    2
# cage_4_subject_3           2      2    2           2         2    2
# cage_4_subject_4           2      2    2           2         2    2
# cage_5_subject_1           2      2    2           2         2    2
# cage_5_subject_2           2      2    2           2         2    2
# cage_5_subject_3           2      2    2           2         2    2
# cage_5_subject_4           2      2    2           2         2    2
# cage_6_subject_1           1      1    1           1         1    1
# cage_6_subject_2           1      1    1           1         1    1
# cage_6_subject_3           1      1    1           1         1    1
# cage_6_subject_4           2      2    2           2         2    2
#
#                   file_name  cage  start_date_datetime  start_date_int  \
# cage_and_subject
# cage_1_subject_1          2     2                    2               2
# cage_1_subject_2          2     2                    2               2
# cage_1_subject_3          2     2                    2               2
# cage_1_subject_4          1     1                    1               1
# cage_2_subject_1          2     2                    2               2
# cage_2_subject_2          2     2                    2               2
# cage_2_subject_3          2     2                    2               2
# cage_2_subject_4          2     2                    2               2
# cage_3_subject_1          2     2                    2               2
# cage_3_subject_2          2     2                    2               2
# cage_3_subject_3          2     2                    2               2
# cage_3_subject_4          2     2                    2               2
# cage_4_subject_1          2     2                    2               2
# cage_4_subject_2          2     2                    2               2
# cage_4_subject_3          2     2                    2               2
# cage_4_subject_4          2     2                    2               2
# cage_5_subject_1          2     2                    2               2
# cage_5_subject_2          2     2                    2               2
# cage_5_subject_3          2     2                    2               2
# cage_5_subject_4          2     2                    2               2
# cage_6_subject_1          1     1                    1               1
# cage_6_subject_2          1     1                    1               1
# cage_6_subject_3          1     1                    1               1
# cage_6_subject_4          2     2                    2               2
#
#                   end_date_datetime  end_date_int
# cage_and_subject
# cage_1_subject_1                  2             2
# cage_1_subject_2                  2             2
# cage_1_subject_3                  2             2
# cage_1_subject_4                  1             1
# cage_2_subject_1                  2             2
# cage_2_subject_2                  2             2
# cage_2_subject_3                  2             2
# cage_2_subject_4                  2             2
# cage_3_subject_1                  2             2
# cage_3_subject_2                  2             2
# cage_3_subject_3                  2             2
# cage_3_subject_4                  2             2
# cage_4_subject_1                  2             2
# cage_4_subject_2                  2             2
# cage_4_subject_3                  2             2
# cage_4_subject_4                  2             2
# cage_5_subject_1                  2             2
# cage_5_subject_2                  2             2
# cage_5_subject_3                  2             2
# cage_5_subject_4                  2             2
# cage_6_subject_1                  1             1
# cage_6_subject_2                  1             1
# cage_6_subject_3                  1             1
# cage_6_subject_4                  2             2

# %% [markdown]
# ## Looking over the MED-PC scripts

# %% [markdown]
# - MED-PC has scripts(lines of code that act as the instructions for how to operate the MED-PC boxes) that contain the descriptions of what each value in the recordings are. We will extract the descriptions from the MED-PC scripts so that we can label the data points in the MED-PC recordings
# - Below is a list of all the MED-PC Scripts. We will only be looking at the first one

# %%
all_medpc_scripts = glob.glob("./data/**/*.MPC")

# %%
all_medpc_scripts
# Out:
# ['./data/textfiles/C57_reward_competition.MPC',
#  './data/textfiles/CD1_reward_training.MPC',
#  './data/textfiles/CD1_reward_competition.MPC',
#  './data/textfiles/C57_reward_training.MPC']

# %% [markdown]
# - Example of what the MED-PC Script looks like that was ran when recording the behaviors

# %%
with open(all_medpc_scripts[0]) as f:
    lines = f.readlines()
    for line in lines[:100]:
        print(line)
# Out:
# \v3 stop tone with poke
#
# \v3.2 monitor port entries AND exits
#
#
#
# \INPUTS
#
# ^port = 8
#
#
#
# \OUTPUTS
#
# ^fan = 16
#
# ^houselight = 11
#
# ^tone1 = 2
#
# ^tone2 = 3
#
# ^tone3 = 4
#
# ^tone4 = 5
#
# ^pump = 9
#
# ^whitenoise = 1
#
# ^csout = 5
#
# ^peout = 15
#
# ^cs1out = 17
#
# ^cs2out = 13
#
# ^cs3out = 14
#
#
#
# \EXP SETTINGS
#
# ^ncsNoShock = 0
#
# ^initCS1trials = 3
#
#
#
# \ARRAYS
#
# DIM P = 20000 \Port entry time stamp array
#
# DIM Q = 2500 \US delivery time stamp array (absolute)
#
# DIM R = 2500 \US time stamp array (relative to last CS)
#
# DIM W = 2500 \ITI values used for CS
#
# DIM S = 2500 \CS presentation values (absolute - every time light turns on)
#
# DIM N = 20000 \Port exit time stamp array
#
# DIM K = 2500 \CS type
#
# DIM G = 2500 \controlled_stimulus_seconds computer clock time (seconds on clock every time light turns on)
#
# DIM H = 2500 \controlled_stimulus_minutes computer clock time (minutes on clock every time light turns on)
#
# DIM I = 2500 \controlled_stimulus_hours computer clock time (hours every time light turns on)
#
# DIM B = 2500 \port_entry_seconds computer clock time (seconds on clock every time light turns on)
#
# DIM F = 2500 \port_entry_minutes computer clock time (minutes on clock every time light turns on)
#
# DIM J = 2500 \port_entry_hours computer clock time (hours every time light turns on)
#
#
#
# \Original List of ITIs
#
# \LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90", 100", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90" \, 100", 108", 117", 121", 133", 145", 165" \CS ITI values (tone + houselight)
#
# \ 30 Minute Duration for Competition
#
# LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80"
#
# \ 60 Minute Duration for Training
#
# \LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90"
#
#
#
# \Counter and Flag array
#
# DIM C = 10
#
# \All counters are zero-indexed!! Meaning, if C(0) = 3, there were 4 port entries
#
# \C(0) counter for number of port entries
#
# \C(1) counter for CS presentation number
#
# \C(2) counter for US delivery : this is 1-indexed,  meaning number indicates number of sucrose deliveries
#
# \C(3) flag to indicate if sucrose is in port =0 if no port entry was made, =1 if port entry was made (i.e., no sucrose)
#
# \C(4) counter for number of port exits
#
# \C(5) number of CS1
#
# \C(6) number of CS2
#
# \C(7) number of CS3
#
# \C(8) number of sucrose deliveries
#
#
#
# \Z-pulses
#
# \Z1: start task after initial delay
#
# \Z2: start of CS
#
# \Z3: port entry
#
# \Z4: port exit
#
# \Z5: trigger CS1
#
# \Z6: trigger CS2
#
# \Z7: trigger CS3
#
# \Z8: turn off all CS triggers
#
# \Z12: INX trigger TTL
#
#
#
# \Variables
#
# \A - Time since last CS
#
# \B -
#
# \C - Counter array
#
# \D - Current ITI value
#
# \E - CS ITI values for first few trials
#
# \F -
#
# \G -
#
# \H -
#
# \I -
#
# \J -
#
# \K - CS type
#
# \L -
#
# \M - CS type repo
#
# \N - Port exit time stamp array
#
# \O -
#
# \P - Port entry time stamp array
#
# \Q - Sucrose delivery time stamp array (absolute)
#
# \R - Sucrose delivery time stamp array (relative to last CS)
#
# \S - CS presentation time stamp array
#
# \T - Session timer
#
# \U - Time since last CS presentation
#
# \V - List of CS ITI values (tone + houselight)
#
# \W - ITI values used for CS one each trial
#
# \X -
#
# \Y - Beam break monitor variable
#
# \Z -

# %% [markdown]
# - We will be using the comments in the MED-PC script(Everything after the `\` for each line) to create a name for the variables. By default, MED-PC uses a single letter as the name of the variable(programming object that holds some information).
#     - This will use the medpc2excel library found in https://github.com/cyf203/medpc2excel
# - Example of the variable names and their comments in the MED-PC script that we will get the descriptive names from:
#     - MED-PC will squish the first few words to create the name for every variable
#
# ```
# DIM P = 20000 \Port entry time stamp array
#
# DIM Q = 2500 \US delivery time stamp array (absolute)
#
# DIM R = 2500 \US time stamp array (relative to last CS)
#
# DIM W = 2500 \ITI values used for CS
#
# DIM S = 2500 \CS presentation values (absolute - every time light turns on)
#
# DIM N = 20000 \Port exit time stamp array
#
# DIM K = 2500 \CS type
#
# DIM B = 2500 \shock intensity
# ```

# %% [markdown]
# - In the MED-PC recording files, there are values that are labelled with letters. These data type of these letters is described in the MED-PC script file that we just looked at.

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-07-19_13h38m_Subject 1.txt
#
#
#
#
#
#
#
# Start Date: 07/19/22
#
# End Date: 07/19/22
#
# Subject: 1
#
# Experiment: C57_vs_CD1_Comparison
#
# Group: Cage 5
#
# Box: 2
#
# Start Time: 13:38:55
#
# End Time: 14:41:48
#
# MSN: CD1_reward_training
#
# A:    4399.000
#
# D:    9000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    3660.000

# %% [markdown]
# ## **NOTE: Please make sure that the corresponding `.mpc` file (aka the MED-PC script) that was ran to create the log file, is also in the same folder as the recording files. This notebook will fail to extract the data from the recording file if it is missing**

# %% [markdown]
# - Spreadsheet of the data from the MED-PC recording file for all the files combined into one.
# - **NOTE: Each row does not correspond to the same data point. Each row represents the "n"-th data point for each category for each file. AKA, the first row is the first data point for the time the subject entered the port and the first data point for the time that the tone that is played, two seperate things. The second row is the second data point for all the categories, the third row is the third data point and so on. This repeats for all data points in a given file, then it starts over to the next file where the first row of that file is the first for all its data points.**

# %%
concatted_medpc_df = extract.dataframe.get_medpc_dataframe_from_list_of_files(medpc_files=all_med_pc_file)

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0         70.30           64.0      399.0           0.0              60.01
# 1         70.72          144.0      399.0           0.0             140.01
# 2         71.33          234.0      399.0           0.0             230.01
# 3         72.62          314.0      399.0           0.0             310.01
# 4         72.73          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0        70.67        1.0                                    49.0
# 1        71.28        1.0                                     9.0
# 2        72.38        1.0                                    39.0
# 3        72.70        1.0                                    59.0
# 4        73.77        1.0                                    14.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    41.0
# 1                                    43.0
# 2                                    44.0
# 3                                    45.0
# 4                                    47.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  13.0                           59.0
# 1                                  13.0                           59.0
# 2                                  13.0                            0.0
# 3                                  13.0                            1.0
# 4                                  13.0                            1.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           41.0                         13.0  20220719
# 1                           41.0                         13.0  20220719
# 2                           42.0                         13.0  20220719
# 3                           42.0                         13.0  20220719
# 4                           42.0                         13.0  20220719
#
#   subject                                         file_path
# 0       1  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 1       1  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 2       1  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 3       1  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt
# 4       1  ./data/textfiles/2022-07-19_13h38m_Subject 1.txt

# %%
concatted_medpc_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 2507           NaN            NaN        NaN           NaN                NaN
# 2508           NaN            NaN        NaN           NaN                NaN
# 2509           NaN            NaN        NaN           NaN                NaN
# 2510           NaN            NaN        NaN           NaN                NaN
# 2511           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 2507          NaN        NaN                                     NaN
# 2508          NaN        NaN                                     NaN
# 2509          NaN        NaN                                     NaN
# 2510          NaN        NaN                                     NaN
# 2511          NaN        NaN                                     NaN
#
#       (H)controlled_stimulus_minutescomputer  \
# 2507                                     NaN
# 2508                                     NaN
# 2509                                     NaN
# 2510                                     NaN
# 2511                                     NaN
#
#       (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 2507                                   NaN                            0.0
# 2508                                   NaN                            0.0
# 2509                                   NaN                           20.0
# 2510                                   NaN                            0.0
# 2511                                   NaN                            0.0
#
#       (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 2507                            NaN                          NaN  20220718
# 2508                            NaN                          NaN  20220718
# 2509                            NaN                          NaN  20220718
# 2510                            NaN                          NaN  20220718
# 2511                            NaN                          NaN  20220718
#
#      subject                                         file_path
# 2507       2  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
# 2508       2  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
# 2509       2  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
# 2510       2  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt
# 2511       2  ./data/textfiles/2022-07-18_11h27m_Subject 2.txt

# %% [markdown]
# - Combining the recording and the metadata into one dataframe

# %%
recording_and_metadata_df = metadata_df.merge(concatted_medpc_df, right_on='file_path', left_on='index')

# %%
recording_and_metadata_df
# Out:
#         trial_number                                             index  \
# 0                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 1                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 2                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 3                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 4                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# ...              ...                                               ...
# 110523             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110524             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110525             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110526             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110527             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
#
#                                                   File Start Date  End Date  \
# 0       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 110523  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110524  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110525  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110526  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110527  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
#
#        Subject             Experiment   Group Box Start Time  ... (K)CStype  \
# 0            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 1            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 2            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 3            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 4            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# ...        ...                    ...     ...  ..        ...  ...       ...
# 110523       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110524       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110525       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110526       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110527       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 0                                        24.0
# 1                                        44.0
# 2                                        14.0
# 3                                        34.0
# 4                                        49.0
# ...                                       ...
# 110523                                    NaN
# 110524                                    NaN
# 110525                                    NaN
# 110526                                    NaN
# 110527                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 0                                        50.0
# 1                                        51.0
# 2                                        53.0
# 3                                        54.0
# 4                                        55.0
# ...                                       ...
# 110523                                    NaN
# 110524                                    NaN
# 110525                                    NaN
# 110526                                    NaN
# 110527                                    NaN
#
#        (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                       8.0                          47.0
# 1                                       8.0                          48.0
# 2                                       8.0                          11.0
# 3                                       8.0                          26.0
# 4                                       8.0                          27.0
# ...                                     ...                           ...
# 110523                                  NaN                           0.0
# 110524                                  NaN                           0.0
# 110525                                  NaN                          39.0
# 110526                                  NaN                           0.0
# 110527                                  NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                               50.0                          8.0  20220718
# 1                               50.0                          8.0  20220718
# 2                               53.0                          8.0  20220718
# 3                               57.0                          8.0  20220718
# 4                               57.0                          8.0  20220718
# ...                              ...                          ...       ...
# 110523                           NaN                          NaN  20220719
# 110524                           NaN                          NaN  20220719
# 110525                           NaN                          NaN  20220719
# 110526                           NaN                          NaN  20220719
# 110527                           NaN                          NaN  20220719
#
#         subject                                         file_path
# 0             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 1             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 2             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 3             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 4             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# ...         ...                                               ...
# 110523        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110524        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110525        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110526        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110527        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
#
# [110528 rows x 35 columns]

# %%
recording_and_metadata_df
# Out:
#         trial_number                                             index  \
# 0                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 1                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 2                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 3                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 4                  1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# ...              ...                                               ...
# 110523             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110524             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110525             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110526             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110527             2  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
#
#                                                   File Start Date  End Date  \
# 0       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 110523  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110524  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110525  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110526  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 110527  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
#
#        Subject             Experiment   Group Box Start Time  ... (K)CStype  \
# 0            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 1            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 2            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 3            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 4            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# ...        ...                    ...     ...  ..        ...  ...       ...
# 110523       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110524       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110525       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110526       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
# 110527       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 0                                        24.0
# 1                                        44.0
# 2                                        14.0
# 3                                        34.0
# 4                                        49.0
# ...                                       ...
# 110523                                    NaN
# 110524                                    NaN
# 110525                                    NaN
# 110526                                    NaN
# 110527                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 0                                        50.0
# 1                                        51.0
# 2                                        53.0
# 3                                        54.0
# 4                                        55.0
# ...                                       ...
# 110523                                    NaN
# 110524                                    NaN
# 110525                                    NaN
# 110526                                    NaN
# 110527                                    NaN
#
#        (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                       8.0                          47.0
# 1                                       8.0                          48.0
# 2                                       8.0                          11.0
# 3                                       8.0                          26.0
# 4                                       8.0                          27.0
# ...                                     ...                           ...
# 110523                                  NaN                           0.0
# 110524                                  NaN                           0.0
# 110525                                  NaN                          39.0
# 110526                                  NaN                           0.0
# 110527                                  NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                               50.0                          8.0  20220718
# 1                               50.0                          8.0  20220718
# 2                               53.0                          8.0  20220718
# 3                               57.0                          8.0  20220718
# 4                               57.0                          8.0  20220718
# ...                              ...                          ...       ...
# 110523                           NaN                          NaN  20220719
# 110524                           NaN                          NaN  20220719
# 110525                           NaN                          NaN  20220719
# 110526                           NaN                          NaN  20220719
# 110527                           NaN                          NaN  20220719
#
#         subject                                         file_path
# 0             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 1             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 2             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 3             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# 4             1  ./data/textfiles/2022-07-18_08h24m_Subject 1.txt
# ...         ...                                               ...
# 110523        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110524        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110525        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110526        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
# 110527        4  ./data/textfiles/2022-07-19_14h52m_Subject 4.txt
#
# [110528 rows x 35 columns]

# %% [markdown]
# ## Getting the cage numbers and the dates so that we can include it in the file name

# %% [markdown]
# - We will get the metadata from the recording files and use it to name the files we will create. This will help organize the files and make it easy to know where each file came from

# %% [markdown]
# - Getting the group numbers(original cage names)

# %%
# removing blank spaces
group_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["Group"].unique() if number]
# sorting numbers
group_numbers = sorted(group_numbers)
group_numbers_for_title = "_".join(group_numbers)

# %%
group_numbers_for_title
# Out:
# 'Cage1_Cage2_Cage3_Cage4_Cage_1_Cage_4_Cage_5_Cage_6'

# %% [markdown]
# - Getting the cage numbers

# %%
# removing blank spaces
cage_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["cage"].unique() if number]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4_5_6'

# %% [markdown]
# - Getting the dates

# %%
# Getting the first and last recording date to get a range
earliest_date = recording_and_metadata_df["end_date_int"].min()
latest_date = recording_and_metadata_df["end_date_int"].max()

# %%
earliest_date
# Out:
# 20220718

# %%
latest_date
# Out:
# 20220719

# %% [markdown]
# - Getting the subject names

# %%
recording_and_metadata_df["Subject"].unique()
# Out:
# array(['1', '2', '3', '4'], dtype=object)

# %%
# removing blank spaces
subject_numbers = ["subject-" + number for number in recording_and_metadata_df["Subject"].unique() if number]
# sorting numbers
subject_numbers = sorted(subject_numbers)
subject_numbers_for_title = "_".join(subject_numbers)

# %%
subject_numbers_for_title
# Out:
# 'subject-1_subject-2_subject-3_subject-4'

# %% [markdown]
# - Getting the experiment name

# %%
experiment_names = ["_".join(name.upper().split()) for name in recording_and_metadata_df["Experiment"].unique() if name]
# sorting experiment_names
experiment_names = list(set(sorted(experiment_names)))
experiment_names_for_title = "AND".join(experiment_names)

# %%
experiment_names_for_title
# Out:
# 'C57_VS_CD1_COMPARISON'

# %% [markdown]
# - Getting the box numbers

# %%
# removing blank spaces
box_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["Box"].unique() if number]
# sorting numbers
box_numbers = sorted(box_numbers)
box_numbers_for_title = "_".join(box_numbers)

# %%
box_numbers_for_title
# Out:
# '1_2_3_4'

# %% [markdown]
# - Getting the script names

# %%
# removing blank spaces
script_names = ["_".join(name.split()) for name in recording_and_metadata_df["MSN"].unique() if name]
# sorting names
script_names = sorted(script_names)
script_names_for_title = "_".join(script_names)

# %%
script_names_for_title
# Out:
# 'C57_reward_training_CD1_reward_training'

# %% [markdown]
# ## Saving the dataframes(spreadsheets to files) with the metadata as part of the name

# %% [markdown]
# - Making necessary directories
#     - If you want to use any of the other metadata as part of the name, you will have to swap out the variables in the `format()` and change the name of the folder to match your new name. The variable names are the word that's in front of the `=` at the last line of each cell. The `{}` are where the metadata variables will be inserted into the file name. For more information on formatting strings: https://www.w3schools.com/python/ref_string_format.asp
#     - You can also just manually rename the files by replacing everything in `""` and removing the `.format()` part
# - **NOTE: You may get an error that the file does not exist. If this is the case, it could be the file name is too long(an issue that may happen when using Jupyter Notebooks on Windows)**

# %%
output_directory = "./proc/extracted_recording_data_and_metadata/experiment_{}_cage_{}_date_{}_{}".format(experiment_names_for_title, cage_numbers_for_title, earliest_date, latest_date)

# %%
output_directory
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220719'

# %%
os.makedirs(output_directory, exist_ok=True)

# %%
metadata_df.to_csv(os.path.join(output_directory, "metadata_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# metadata_df.to_excel(os.path.join(output_directory, "metadata_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %%
concatted_medpc_df.to_csv(os.path.join(output_directory, "MEDPC_recording_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# concatted_medpc_df.to_excel(os.path.join(output_directory, "MEDPC_recording_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %%
recording_and_metadata_df.to_csv(os.path.join(output_directory, "recording_metadata_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# recording_and_metadata_df.to_excel(os.path.join(output_directory, "recording_and_metadata_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

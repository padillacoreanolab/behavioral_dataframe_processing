# %% [markdown]
# # Home Cage Elo Score Calculation

# %% [markdown]
# ## Importing other Python Libraries/Modules

# %%
import re
import os
import sys
import string
from collections import defaultdict
import glob
import warnings
from datetime import datetime
from datetime import timedelta
import ast

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xlrd

# %%
# setting path
sys.path.append('../../src')

# %%
from eloscore import eloscore

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (18,10)

# %% [markdown]
# ## Summary

# %% [markdown]
# - Experiment
#     - Observing fighting behavior between mice in their home cage in different settings. Mice are categorized as winner and loser based on if they initiated the behavior or if they are recieving it. Recording sessions are usually from 30 minutes to a hour with cages of 2 to 6 mice.
# - Data
#     - Excel spreadsheet of recorded fighting behavior. The relevant columns are those of the "Date" of the recording, the "winner" of the interaction, and the "loser" of the interaction. Each row will be for one interaction between two mice.
#     - There is a cage for each sheet of the spreadsheet
#     - For each recording session, we will assume that the date will be specified for that first row. We will use this to seperate all the rows into seperate sessions.
# - Purpose of this Jupyter Notebook
#     - To calculate the Elo Score of each mice after each interaction. The mice start off with an Elo score of 1000. Elo scores are calculated with the formula from here: https://www.omnicalculator.com/sports/elo . Then we will plot the change of elo score across all interactions. With the number of interactions on the X-Axis and the current Elo score on the Y. There will be a line for mice.

# %% [markdown]
# ## Name of protocol for naming

# %% [markdown]
# - This name will be used to name files and title plots. Please change if you are using a different protocol or adding more details
#     - **NOTE**: This should be changed based on the name the protocol

# %%
protocol_name = "home_cage_observation"

# %% [markdown]
# ## Getting the file name of the raw data

# %% [markdown]
# - Default input folder and keyword to search the files for
#     - **NOTE**: This should not be changed unless there is a consistent change with the file naming convention

# %%
input_folder = "./data"

# %%
# Accomodates for both capitalization of the file names
raw_data_file_keyword = '*[hH]ome*'

# %% [markdown]
# - Asking the user what the path to the recording files are, with the option of using wildcards

# %%
raw_data_glob_pattern = input("""Type out the path(address) of the raw behavioral recording excel sheets.
Remember that if you are using a relative path, it will be based off of the location of this Jupyter Notebook.

Globbing can also be used if you want to search with a wild card(Capitalization matters). 
i.e. './data/*Home*' will be able to find './data/Homecage_observations.xlsx'

NOTE: If left blank, the path will automatically be guessed off of the default settings 
""")
# Out:
# Type out the path(address) of the raw behavioral recording excel sheets.
# Remember that if you are using a relative path, it will be based off of the location of this Jupyter Notebook.
#
# Globbing can also be used if you want to search with a wild card(Capitalization matters).
# i.e. './data/*Home*' will be able to find './data/Homecage_observations.xlsx'
#
# NOTE: If left blank, the path will automatically be guessed off of the default settings
# ./data/*home*

# %% [markdown]
# - By default, this will search for files that are in the `./data` folder (in the folder that this notebook is in) that have key word you specified in the file name

# %%
# Using the user inputted path/pattern
if raw_data_glob_pattern.strip():
    # Getting a list of all matching files
    raw_data_files_list = glob.glob(raw_data_glob_pattern.strip())
    # Checking if there were any files that matched
    if raw_data_files_list:
        raw_data_file_path = raw_data_files_list[0]
    else:
        raise ValueError("No files were found with the path/pattern of {}. Please rerun the previous cell with the correct path".format(raw_data_glob_pattern))

# Using the default pattern
else:
    # Searching for matching files with recursion
    if glob.glob(os.path.join(input_folder + "**", raw_data_file_keyword)):
        raw_data_glob_pattern = os.path.join(input_folder + "**", raw_data_file_keyword)
        # Getting a list of all matching files
        raw_data_files_list = glob.glob(raw_data_glob_pattern)
    # Searching for matching files only in the specified folder
    elif glob.glob(os.path.join(input_folder, raw_data_file_keyword)):
        raw_data_glob_pattern = glob.glob(os.path.join(input_folder, raw_data_file_keyword))
        # Getting a list of all matching files
        raw_data_files_list = glob.glob(raw_data_glob_pattern)
    else:
        raise ValueError("No files were found in {} that had the keyword {} in it".format(input_folder, raw_data_file_keyword))

# %% [markdown]
# - Checking to see if only one file is specified

# %%
if len(raw_data_files_list) >= 2:
    raise ValueError("More than one file was found with the path/pattern of {}. Please rerun the previous cell with the correct path".format(raw_data_glob_pattern))
else:
    # Using the first(and only file) as the file path
    raw_data_file_path = raw_data_files_list[0]

# %%
raw_data_file_path
# Out:
# './data/homecage_observations_iwata.xlsx'

# %% [markdown]
# ## Getting a list of all the sheets

# %%
# Getting the sheet names for the excel file
xls = pd.ExcelFile(raw_data_file_path)
raw_data_sheet_names = xls.sheet_names

# %%
raw_data_sheet_names
# Out:
# ['Cage 1 ', 'Cage 2', 'Cage 3', 'Cage 4']

# %% [markdown]
# - Asking the user what sheets they want to use

# %%
inputted_sheet_names_string = input("""Type out the name of the sheets that you want to be processed. 
Each name must be put in quotes and seperated by a comma(,). i.e. "CAGE3", "CAGE4"

The available sheets are: {}

Alternatively, you can use the index of the list of names above. 
Remember, that Python is zero indexed so the first item will be have the 0 index, second the 1 index, and so on. 
i.e. 1, 2

NOTE: If left blank, all sheets will be used
""".format(raw_data_sheet_names))
# Out:
# Type out the name of the sheets that you want to be processed.
# Each name must be put in quotes and seperated by a comma(,). i.e. "CAGE3", "CAGE4"
#
# The available sheets are: ['Cage 1 ', 'Cage 2', 'Cage 3', 'Cage 4']
#
# Alternatively, you can use the index of the list of names above.
# Remember, that Python is zero indexed so the first item will be have the 0 index, second the 1 index, and so on.
# i.e. 1, 2
#
# NOTE: If left blank, all sheets will be used

# %%
# Making a list out of the string of inputted sheet names
if inputted_sheet_names_string:
    inputted_sheet_names_string = "[" + inputted_sheet_names_string + "]"
    # Turning the string into a list
    inputted_sheet_names_list = ast.literal_eval(inputted_sheet_names_string)
# Using all the sheet names if no sheet name is specified
else:
    inputted_sheet_names_list =  raw_data_sheet_names

# %%
inputted_sheet_names_list
# Out:
# ['Cage 1 ', 'Cage 2', 'Cage 3', 'Cage 4']

# %% [markdown]
# - Converting all the numbers into the sheet name that the index of the number corresponds to

# %%
for index, sheet in enumerate(inputted_sheet_names_list):
    # Checking if the sheet name was a number
    if isinstance(sheet, int) and str(sheet).isdigit():
        inputted_sheet_names_list[index] =  raw_data_sheet_names[sheet]

# %%
inputted_sheet_names_list
# Out:
# ['Cage 1 ', 'Cage 2', 'Cage 3', 'Cage 4']

# %% [markdown]
# - Checking to see if all the sheets are in the excel file

# %%
if not set(inputted_sheet_names_list).issubset(raw_data_sheet_names):
    # Getting all the sheets that were not in the original spreadsheet
    not_included_sheet_names = set(inputted_sheet_names_list) - set(raw_data_sheet_names)
    raise ValueError("All the listed sheet names are not in {}".format(not_included_sheet_names))

# %% [markdown]
# ## Finding the row for the header

# %% [markdown]
# - Headers are the row in a spreadsheet that has all the column names. Sometimes spreadsheets don't use the first row as the row with the column names. So, the row for the header will be asked or assumed to be the first row

# %%
sheet_name_to_everything = defaultdict(dict)
for sheet in inputted_sheet_names_list:
    print("\nCurrent Sheet Name: {}".format(sheet))    
    per_sheet_dataframe = pd.read_excel(raw_data_file_path, sheet_name=sheet, header=0)
    
    # Showing the columns that are chosen with the header being the 0th row
    print("Columns Names: {}".format(per_sheet_dataframe.columns))
    # Show the dataframe that would be created with the header being the 0th row
    print("First few rows of this dataframe:")
    print(pd.read_excel(raw_data_file_path, sheet_name=sheet, header=0).head())
    
    # Allowing the user the choose the row number for the header
    header_row = input("""Type the row number to be used as the header
    (AKA the row with the column name that you want to use.)
    If you want to keep the column names that were displayed, type 0.
    If you want to use a different row, then type the corresponding number. 
    
    The rows displayed in this cell are dataframes created from Pandas. 
    To use the row with the 0 index for column names, type 1. 
    For the row with the 1 index, it will be 2 and so on. i.e. 2
    
    If you are looking at the original spread sheet, remember that Python is zero indexed. 
    So the first row will be 0, second will be 1, and so on. 
    i.e. 1
    
    NOTE: If left blank, the original row that was used will be used.
    """).strip()
    
    if header_row == "":
        header_row = 0
    else:
        header_row = int(header_row)
    
    # Checking if any of the column names are from empty cells
    column_names = "".join([str(col) for col in pd.read_excel(raw_data_file_path, sheet_name=sheet, header=header_row).columns])
    # If a column name came from an empty cell, it would have "Unnamed" in it
    if "Unnamed" in column_names:
        raise ValueError("""Not all the cells in the chosen row are filled in.
                         Please choose a row that has the name of the columns
                         
                         The values in this row are: {}""".format(column_names))
    else:
        sheet_name_to_everything[sheet]["header_row"] = header_row
# Out:
# Current Sheet Name: Cage 1
# Columns Names: Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Who Gets the Point', 'Unnamed: 8'],
#       dtype='object')
# First few rows of this dataframe:
#         Unnamed: 0                                         Unnamed: 1  \
# 0         Observer                                              Notes
# 1  Amelia Chambers  20 minutes after rehousing, removal of enrichm...
# 2              NaN                             observed on right side
# 3              NaN                                                NaN
# 4              NaN               Sniffing but no real agression shown
#
#               Unnamed: 2           Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  Length of Observation                Date      Winner      Loser
# 1             30 minutes  2022-09-05 00:00:00          5          1
# 2                    NaN                  NaN          1          5
# 3                    NaN                  NaN          5          1
# 4                    NaN                  NaN          5          1
#
#   Unnamed: 6  Who Gets the Point  Unnamed: 8
# 0     Action                 1.0         5.0
# 1         FS                 NaN         NaN
# 2         AG                 NaN         NaN
# 3         FS                 NaN         NaN
# 4         FS                 NaN         NaN
# Type the row number to be used as the header
#     (AKA the row with the column name that you want to use.)
#     If you want to keep the column names that were displayed, type 0.
#     If you want to use a different row, then type the corresponding number.
#
#     The rows displayed in this cell are dataframes created from Pandas.
#     To use the row with the 0 index for column names, type 1.
#     For the row with the 1 index, it will be 2 and so on. i.e. 2
#
#     If you are looking at the original spread sheet, remember that Python is zero indexed.
#     So the first row will be 0, second will be 1, and so on.
#     i.e. 1
#
#     NOTE: If left blank, the original row that was used will be used.
#     1
#
# Current Sheet Name: Cage 2
# Columns Names: Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Who Gets the Point', 'Unnamed: 8'],
#       dtype='object')
# First few rows of this dataframe:
#   Unnamed: 0                          Unnamed: 1             Unnamed: 2  \
# 0   Observer                               Notes  Length of Observation
# 1     Naeliz  20 min after rehousing, removal of                 30 min
# 2        NaN          enrichment. Time at 2:05pm                    NaN
# 3        NaN   #2 had excessive digging, i noted                    NaN
# 4        NaN            that with a d for action                    NaN
#
#             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Who Gets the Point  \
# 0                Date      Winner      Loser     Action                 2.0
# 1  2022-09-05 00:00:00          2          6         fs                 NaN
# 2                  NaN          6          2         ag                 NaN
# 3                  NaN          6          2         ag                 NaN
# 4                  NaN          2          6         fs                 NaN
#
#    Unnamed: 8
# 0         6.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# Type the row number to be used as the header
#     (AKA the row with the column name that you want to use.)
#     If you want to keep the column names that were displayed, type 0.
#     If you want to use a different row, then type the corresponding number.
#
#     The rows displayed in this cell are dataframes created from Pandas.
#     To use the row with the 0 index for column names, type 1.
#     For the row with the 1 index, it will be 2 and so on. i.e. 2
#
#     If you are looking at the original spread sheet, remember that Python is zero indexed.
#     So the first row will be 0, second will be 1, and so on.
#     i.e. 1
#
#     NOTE: If left blank, the original row that was used will be used.
#     1
#
# Current Sheet Name: Cage 3
# Columns Names: Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Who Gets the Point', 'Unnamed: 8'],
#       dtype='object')
# First few rows of this dataframe:
#   Unnamed: 0                   Unnamed: 1             Unnamed: 2  \
# 0   Observer                        Notes  Length of Observation
# 1    Amelia   Immediately after rehousing             30 minutes
# 2        NaN        removal of enrichment                    NaN
# 3        NaN             observed at 2:45                    NaN
# 4        NaN       observed on right side                    NaN
#
#             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Who Gets the Point  \
# 0                Date      Winner      Loser     Action                 3.0
# 1  2022-09-05 00:00:00          3        NaN          d                 NaN
# 2                  NaN          7        NaN          d                 NaN
# 3                  NaN          3        NaN          e                 NaN
# 4                  NaN          3        NaN          e                 NaN
#
#    Unnamed: 8
# 0         7.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# Type the row number to be used as the header
#     (AKA the row with the column name that you want to use.)
#     If you want to keep the column names that were displayed, type 0.
#     If you want to use a different row, then type the corresponding number.
#
#     The rows displayed in this cell are dataframes created from Pandas.
#     To use the row with the 0 index for column names, type 1.
#     For the row with the 1 index, it will be 2 and so on. i.e. 2
#
#     If you are looking at the original spread sheet, remember that Python is zero indexed.
#     So the first row will be 0, second will be 1, and so on.
#     i.e. 1
#
#     NOTE: If left blank, the original row that was used will be used.
#     1
#
# Current Sheet Name: Cage 4
# Columns Names: Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Who Gets the Point', 'Unnamed: 8'],
#       dtype='object')
# First few rows of this dataframe:
#   Unnamed: 0                        Unnamed: 1             Unnamed: 2  \
# 0   Observer                             Notes  Length of Observation
# 1     Naeliz       Immediately after rehousing                 30 min
# 2        NaN               observed at 2:45 pm                    NaN
# 3        NaN             removal of enrichment                    NaN
# 4        NaN  observed on left side of L2-164B                    NaN
#
#             Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  Who Gets the Point  \
# 0                Date      Winner      Loser     Action                 4.0
# 1  2022-09-05 00:00:00          4        NaN          d                 NaN
# 2                  NaN          4        NaN          d                 NaN
# 3                  NaN          4        NaN          d                 NaN
# 4                  NaN          4        NaN          d                 NaN
#
#    Unnamed: 8
# 0         8.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# Type the row number to be used as the header
#     (AKA the row with the column name that you want to use.)
#     If you want to keep the column names that were displayed, type 0.
#     If you want to use a different row, then type the corresponding number.
#
#     The rows displayed in this cell are dataframes created from Pandas.
#     To use the row with the 0 index for column names, type 1.
#     For the row with the 1 index, it will be 2 and so on. i.e. 2
#
#     If you are looking at the original spread sheet, remember that Python is zero indexed.
#     So the first row will be 0, second will be 1, and so on.
#     i.e. 1
#
#     NOTE: If left blank, the original row that was used will be used.
#     1

# %%
sheet_name_to_everything
# Out:
# defaultdict(dict,
#             {'Cage 1 ': {'header_row': 1},
#              'Cage 2': {'header_row': 1},
#              'Cage 3': {'header_row': 1},
#              'Cage 4': {'header_row': 1}})

# %% [markdown]
# ## Reading in all the spreadsheets

# %%
# Going through each sheet and creating a dataframe of it
for key, value in sheet_name_to_everything.items():
    sheet_name_to_everything[key]["original_behavior_recording_dataframe"] = pd.read_excel(raw_data_file_path, sheet_name=key, header=value["header_row"])

# %%
sheet_name_to_everything[key]["original_behavior_recording_dataframe"].head()
# Out:
#   Observer                             Notes Length of Observation      Date   \
# 0   Naeliz       Immediately after rehousing                30 min 2022-09-05
# 1      NaN               observed at 2:45 pm                   NaN        NaT
# 2      NaN             removal of enrichment                   NaN        NaT
# 3      NaN  observed on left side of L2-164B                   NaN        NaT
# 4      NaN        #4 was an excessive digger                   NaN        NaT
#
#    Winner  Loser Action   4   8
# 0       4    NaN      d NaN NaN
# 1       4    NaN      d NaN NaN
# 2       4    NaN      d NaN NaN
# 3       4    NaN      d NaN NaN
# 4       4    NaN      d NaN NaN

# %%
sheet_name_to_everything[key]["original_behavior_recording_dataframe"].tail()
# Out:
#    Observer Notes Length of Observation Date   Winner  Loser Action   4   8
# 86      NaN   NaN                   NaN   NaT       4    8.0     ag NaN NaN
# 87      NaN   NaN                   NaN   NaT       4    8.0     ag NaN NaN
# 88      NaN   NaN                   NaN   NaT       4    8.0     ag NaN NaN
# 89      NaN   NaN                   NaN   NaT       4    8.0     ag NaN NaN
# 90      NaN   NaN                   NaN   NaT       4    8.0     ag NaN NaN

# %% [markdown]
# ## Standarizing the Columns

# %% [markdown]
# - Making all the column names lower case and removing any extra spaces in the beginning and at the end

# %%
for key, value in sheet_name_to_everything.items():
    # Creating a dictionary that maps the original column name to the standarized one
    column_name_to_standarized = defaultdict(dict)
    for col in sheet_name_to_everything[key]["original_behavior_recording_dataframe"]:
        # Making the column name lower case and removing the spaces
        column_name_to_standarized[col] = str(col).lower().strip()
    sheet_name_to_everything[key]["column_name_to_standarized"] = column_name_to_standarized

# %%
sheet_name_to_everything[key]["column_name_to_standarized"]
# Out:
# defaultdict(dict,
#             {'Observer': 'observer',
#              'Notes': 'notes',
#              'Length of Observation': 'length of observation',
#              'Date ': 'date',
#              'Winner': 'winner',
#              'Loser': 'loser',
#              'Action': 'action',
#              4: '4',
#              8: '8'})

# %%
# Renaming all the columns to the lower case and space removed version
for key, value in sheet_name_to_everything.items():
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"] = sheet_name_to_everything[key]["original_behavior_recording_dataframe"].rename(columns=sheet_name_to_everything[key]["column_name_to_standarized"])

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].head()
# Out:
#   observer                             notes length of observation       date  \
# 0   Naeliz       Immediately after rehousing                30 min 2022-09-05
# 1      NaN               observed at 2:45 pm                   NaN        NaT
# 2      NaN             removal of enrichment                   NaN        NaT
# 3      NaN  observed on left side of L2-164B                   NaN        NaT
# 4      NaN        #4 was an excessive digger                   NaN        NaT
#
#    winner  loser action   4   8
# 0       4    NaN      d NaN NaN
# 1       4    NaN      d NaN NaN
# 2       4    NaN      d NaN NaN
# 3       4    NaN      d NaN NaN
# 4       4    NaN      d NaN NaN

# %% [markdown]
# ## Adding the session number

# %% [markdown]
# - We are adding the session number to all the trials. The session number is counting the number of recording sessions that have happened up until that trial. Usually, each session in the spreadsheet is divided up by a session's first row having the date filled in. So we will label a new session when a date is filled in.

# %%
for key, value in sheet_name_to_everything.items():
    # Allowing the user to choose the column that indicates a new session
    session_divider_column = input("""Type the name of the column to be used to divide the rows into sessions. 
    Pick a column that has a value in the cell only with the first row of each session.
    This is usually the "date" column.

    If left blank, the session number will not be added to the spreadsheets and plots will not be divided into sessions.

    The available columns are: {}

    NOTE: If left blank, the column with "date" in the name will be used as the column
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))
    # Making the column name lowercase and removing any punctuation
    sheet_name_to_everything[key]["session_divider_column"] = session_divider_column.lower().strip('"').strip("'").strip()

    # Looks for columns with "date" in them if none of inputted
    if not sheet_name_to_everything[key]["session_divider_column"]:
        sheet_name_to_everything[key]["session_divider_column"] = [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "date" in col.lower()][0]

    # Checks if that column is in the dataframe
    if sheet_name_to_everything[key]["session_divider_column"] not in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns:
        raise ValueError("{} is not a column in {}".format(sheet_name_to_everything[key]["session_divider_column"], sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))
# Out:
# Type the name of the column to be used to divide the rows into sessions.
#     Pick a column that has a value in the cell only with the first row of each session.
#     This is usually the "date" column.
#
#     If left blank, the session number will not be added to the spreadsheets and plots will not be divided into sessions.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5'],
#       dtype='object')
#
#     NOTE: If left blank, the column with "date" in the name will be used as the column
#
# Type the name of the column to be used to divide the rows into sessions.
#     Pick a column that has a value in the cell only with the first row of each session.
#     This is usually the "date" column.
#
#     If left blank, the session number will not be added to the spreadsheets and plots will not be divided into sessions.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6'],
#       dtype='object')
#
#     NOTE: If left blank, the column with "date" in the name will be used as the column
#
# Type the name of the column to be used to divide the rows into sessions.
#     Pick a column that has a value in the cell only with the first row of each session.
#     This is usually the "date" column.
#
#     If left blank, the session number will not be added to the spreadsheets and plots will not be divided into sessions.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7'],
#       dtype='object')
#
#     NOTE: If left blank, the column with "date" in the name will be used as the column
#
# Type the name of the column to be used to divide the rows into sessions.
#     Pick a column that has a value in the cell only with the first row of each session.
#     This is usually the "date" column.
#
#     If left blank, the session number will not be added to the spreadsheets and plots will not be divided into sessions.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8'],
#       dtype='object')
#
#     NOTE: If left blank, the column with "date" in the name will be used as the column

# %%
for key, value in sheet_name_to_everything.items():
    # Getting the indexes of all the rows that have the date or the column that divides the sessions up
    sheet_name_to_everything[key]["session_indexes"] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].dropna(axis=0, subset=sheet_name_to_everything[key]["session_divider_column"]).index
    # Adding the session number to each row
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"] = eloscore.add_session_number_column(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"], sheet_name_to_everything[key]["session_indexes"], session_number_column='session_number')
    
    # Filling in the NaNs for the session number
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"]["session_number"] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"]["session_number"].fillna(method='ffill')

# %% [markdown]
# ## Dropping All Rows without a Winner

# %% [markdown]
# - Because we will be filling all empty cells with the previous value, we must remove all rows that don't have any data. This is usually cells that don't have any winners or losers filled in the row.

# %%
for key, value in sheet_name_to_everything.items():
    # Asking users to specify which column is the one with the winner's information
    sheet_name_to_everything[key]["winner_column"] = input("""Type the name of the column of the subject that has won the interaction.
    i.e. "winner"
    
    The available columns are: {}

    Note: If left blank, the column with "winner" in the name will be used as the column
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))
        
    # Looks for columns with "winner" in them if none of inputted
    if not sheet_name_to_everything[key]["winner_column"]:
        sheet_name_to_everything[key]["winner_column"] = [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "winner" in col.lower()][0]

        
    # Asking users to specify which column is the one with the winner's information
    sheet_name_to_everything[key]["loser_column"] = input("""Type the name of the column of the subject that has won the interaction.
    i.e. "loser"

    The available columns are: {}

    Note: If left blank, the column with "loser" in the name will be used as the column
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))

    # Looks for columns with "loser" in them if none of inputted
    if not sheet_name_to_everything[key]["loser_column"]:
        sheet_name_to_everything[key]["loser_column"] = [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "loser" in col.lower()][0]

    # Dropping all rows that don't have any values in the winner column
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].dropna(subset=sheet_name_to_everything[key]["winner_column"])
# Out:
# Type the name of the column of the subject that has won the interaction.
#     i.e. "winner"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "winner" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "loser"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "loser" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "winner"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "winner" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "loser"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "loser" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "winner"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "winner" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "loser"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "loser" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "winner"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "winner" in the name will be used as the column
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "loser"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "loser" in the name will be used as the column

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].head()
# Out:
#   observer                             notes length of observation       date  \
# 0   Naeliz       Immediately after rehousing                30 min 2022-09-05
# 1      NaN               observed at 2:45 pm                   NaN        NaT
# 2      NaN             removal of enrichment                   NaN        NaT
# 3      NaN  observed on left side of L2-164B                   NaN        NaT
# 4      NaN        #4 was an excessive digger                   NaN        NaT
#
#    winner  loser action   4   8  session_number
# 0       4    NaN      d NaN NaN             1.0
# 1       4    NaN      d NaN NaN             1.0
# 2       4    NaN      d NaN NaN             1.0
# 3       4    NaN      d NaN NaN             1.0
# 4       4    NaN      d NaN NaN             1.0

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].tail()
# Out:
#    observer notes length of observation date  winner  loser action   4   8  \
# 86      NaN   NaN                   NaN  NaT       4    8.0     ag NaN NaN
# 87      NaN   NaN                   NaN  NaT       4    8.0     ag NaN NaN
# 88      NaN   NaN                   NaN  NaT       4    8.0     ag NaN NaN
# 89      NaN   NaN                   NaN  NaT       4    8.0     ag NaN NaN
# 90      NaN   NaN                   NaN  NaT       4    8.0     ag NaN NaN
#
#     session_number
# 86             4.0
# 87             4.0
# 88             4.0
# 89             4.0
# 90             4.0

# %% [markdown]
# ## Dropping the rows with only Chase and Fights

# %% [markdown]
# - Specific for home cage observations. This protocol records the type of action that occured between an initiator and reciever. Only certain actions(usually fighting and chasing) are counted towards points for the ELO score. So we will remove all other rows that contain different actions

# %%
for key, value in sheet_name_to_everything.items():
    # Asking the user which column is the column that has the actions recorded
    sheet_name_to_everything[key]["action_column"] = input("""Type the name of the column that has the action recorded.

    The available columns are: {}

    If left blank, the column name will assumed to be "action"
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))

    if sheet_name_to_everything[key]["action_column"]:
        sheet_name_to_everything[key]["action_column"] = sheet_name_to_everything[key]["action_column"].lower().strip()
    else: 
        sheet_name_to_everything[key]["action_column"] = "action"
        
    # Asking the user which actions should count towards ELO score points
    sheet_name_to_everything[key]["elo_counted_actions_string"] = input("""Type the actions that will be counted towards ELO Score points.
    All the available actions: {}
    Each action must be put in quotes and seperated by a comma(,). i.e. "f", "c"

    NOTE: If left blank, the ELO Score counted actions will assumed to be "f", "c"
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"][sheet_name_to_everything[key]["action_column"]].unique()))
    
    # Making a list out of the string of inputted actions
    if sheet_name_to_everything[key]["elo_counted_actions_string"]:
        sheet_name_to_everything[key]["elo_counted_actions_string"] = "[" + sheet_name_to_everything[key]["elo_counted_actions_string"] + "]"
        sheet_name_to_everything[key]["elo_counted_actions_list"] = ast.literal_eval(sheet_name_to_everything[key]["elo_counted_actions_string"])
        # Removing any unnecessary spaces
        sheet_name_to_everything[key]["elo_counted_actions_list"] = [action.strip() for action in sheet_name_to_everything[key]["elo_counted_actions_list"]]
    # Using "f", "c" as defaults if no actions are specified
    else:
        sheet_name_to_everything[key]["elo_counted_actions_list"] =  ["f", "c"]
    
    # Keeping all rows that have the inputted action
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"][sheet_name_to_everything[key]["processed_behavior_recording_dataframe"][sheet_name_to_everything[key]["action_column"]].isin(sheet_name_to_everything[key]["elo_counted_actions_list"])]
# Out:
# Type the name of the column that has the action recorded.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number'],
#       dtype='object')
#
#     If left blank, the column name will assumed to be "action"
#
# Type the actions that will be counted towards ELO Score points.
#     All the available actions: ['FS' 'AG' 'AS' 'f' 'sp' 'm' 'c' 'as' 'fs' 'd' 'ag' 'e']
#     Each action must be put in quotes and seperated by a comma(,). i.e. "f", "c"
#
#     NOTE: If left blank, the ELO Score counted actions will assumed to be "f", "c"
#     'f', 'm', 'c'
# Type the name of the column that has the action recorded.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number'],
#       dtype='object')
#
#     If left blank, the column name will assumed to be "action"
#
# Type the actions that will be counted towards ELO Score points.
#     All the available actions: ['fs' 'ag' 'd' 'as' 'c' 'f' 'm' 'e' 'f ']
#     Each action must be put in quotes and seperated by a comma(,). i.e. "f", "c"
#
#     NOTE: If left blank, the ELO Score counted actions will assumed to be "f", "c"
#     'f', 'm', 'c'
# Type the name of the column that has the action recorded.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number'],
#       dtype='object')
#
#     If left blank, the column name will assumed to be "action"
#
# Type the actions that will be counted towards ELO Score points.
#     All the available actions: ['d' 'e' 'AS' 'FS' 'AG' 'fs' 'as' 'ag']
#     Each action must be put in quotes and seperated by a comma(,). i.e. "f", "c"
#
#     NOTE: If left blank, the ELO Score counted actions will assumed to be "f", "c"
#     'f', 'm', 'c'
# Type the name of the column that has the action recorded.
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number'],
#       dtype='object')
#
#     If left blank, the column name will assumed to be "action"
#
# Type the actions that will be counted towards ELO Score points.
#     All the available actions: ['d' 'as' 'fs' 'ag' 'm' 'c']
#     Each action must be put in quotes and seperated by a comma(,). i.e. "f", "c"
#
#     NOTE: If left blank, the ELO Score counted actions will assumed to be "f", "c"
#     'f', 'm', 'c'

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].head()
# Out:
#    observer notes length of observation date  winner  loser action    4    8  \
# 32      NaN   NaN                   NaN  NaT       8    4.0      m -1.0  1.0
# 54      NaN   NaN                   NaN  NaT       8    4.0      c -1.0  1.0
#
#     session_number
# 32             2.0
# 54             3.0

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].tail()
# Out:
#    observer notes length of observation date  winner  loser action    4    8  \
# 32      NaN   NaN                   NaN  NaT       8    4.0      m -1.0  1.0
# 54      NaN   NaN                   NaN  NaT       8    4.0      c -1.0  1.0
#
#     session_number
# 32             2.0
# 54             3.0

# %% [markdown]
# # Finding the rows with ties

# %% [markdown]
# - If a trial is a tie, there should be another column that indicates that it is a tie. The points will be counted for less. If there is no column, then none of the trials will be counted as ties.

# %%
for key, value in sheet_name_to_everything.items():
    # Asking users to specify which column is the one with the winner's information
    sheet_name_to_everything[key]["ties_column"] = input("""Type the name of the column that specifies whether or not a tie has occured
    i.e. "ties"
    
    The available columns are: {}

    Note: If left blank, the column with "ties" in the name will be used as the column. 
    If there are none, then this part will be skipped

    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))
        
    # Looks for columns with "winner" in them if none of inputted
    if not sheet_name_to_everything[key]["ties_column"]:
        if [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "ties" in col.lower()]:
            sheet_name_to_everything[key]["ties_column"] = [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "ties" in col.lower()][0]
        else: 
            sheet_name_to_everything[key]["ties_column"] = None
# Out:
# Type the name of the column that specifies whether or not a tie has occured
#     i.e. "ties"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "ties" in the name will be used as the column.
#     If there are none, then this part will be skipped
#
#
# Type the name of the column that specifies whether or not a tie has occured
#     i.e. "ties"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "ties" in the name will be used as the column.
#     If there are none, then this part will be skipped
#
#
# Type the name of the column that specifies whether or not a tie has occured
#     i.e. "ties"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "ties" in the name will be used as the column.
#     If there are none, then this part will be skipped
#
#
# Type the name of the column that specifies whether or not a tie has occured
#     i.e. "ties"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number'],
#       dtype='object')
#
#     Note: If left blank, the column with "ties" in the name will be used as the column.
#     If there are none, then this part will be skipped

# %% [markdown]
# # Getting the Session number differences

# %% [markdown]
# - Getting the indexes of where each new session starts. So that we can add the session number to each row.

# %%
list(set(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns) - set([sheet_name_to_everything[key]["ties_column"]]))
# Out:
# ['notes',
#  'session_number',
#  'action',
#  'length of observation',
#  '8',
#  'winner',
#  'observer',
#  'loser',
#  'date',
#  '4']

# %%
for key, value in sheet_name_to_everything.items():
    if sheet_name_to_everything[key]["ties_column"]:
        non_ties_columns = list(set(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns) - set([sheet_name_to_everything[key]["ties_column"]]))
        sheet_name_to_everything[key]["processed_behavior_recording_dataframe"][non_ties_columns] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"][non_ties_columns].fillna(method='ffill')
    else:
        # Filling all the empty cells with the value in the previous cell
        sheet_name_to_everything[key]["processed_behavior_recording_dataframe"] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].fillna(method='ffill')

     # Seeing which rows have a different session than the previous one
    # This will be used to plot vertical lines for each new session
    sheet_name_to_everything[key]["processed_behavior_recording_dataframe"]['session_number_difference'] = sheet_name_to_everything[key]["processed_behavior_recording_dataframe"]['session_number'].diff()

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].head()
# Out:
#     observer  notes  length of observation date  winner  loser action    4  \
# 32       NaN    NaN                    NaN  NaT       8    4.0      m -1.0
# 54       NaN    NaN                    NaN  NaT       8    4.0      c -1.0
#
#       8  session_number  session_number_difference
# 32  1.0             2.0                        NaN
# 54  1.0             3.0                        1.0

# %%
sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].tail()
# Out:
#     observer  notes  length of observation date  winner  loser action    4  \
# 32       NaN    NaN                    NaN  NaT       8    4.0      m -1.0
# 54       NaN    NaN                    NaN  NaT       8    4.0      c -1.0
#
#       8  session_number  session_number_difference
# 32  1.0             2.0                        NaN
# 54  1.0             3.0                        1.0

# %% [markdown]
# ## Calculating ELO Score

# %% [markdown]
# - Example calculation

# %%
eloscore.calculate_elo_score(subject_elo_score=1000, agent_elo_score=2000)
# Out:
# 1019.9

# %%
eloscore.update_elo_score(winner_id="A", loser_id="B")
# Out:
# defaultdict(<function eloscore.eloscore.update_elo_score.<locals>.<lambda>()>,
#             {'A': 1010.0, 'B': 990.0})

# %% [markdown]
# ## Get the Elo score for all the events

# %% [markdown]
# - Going through each row or interaction and calculating the new ELO score for the winner and loser. This will create a new dataframe based off of the processed behavioral recording dataframe

# %%
for key, value in sheet_name_to_everything.items():
    # Asking the user which columns to carry over to the ELO Score calculation dataframe
    sheet_name_to_everything[key]["columns_to_keep_string"] = input("""Type all the columns that will be copied from the original dataframe to the ELO Score calculated dataframe. 

    All the available actions: {}
    Each column must be put in quotes and seperated by a comma(,). i.e. 'length of observations', 'date', 'cage #'

    NOTE: If left blank, all the columns will be kept
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))

    
    # Making a list out of the string of inputted sheet names
    if sheet_name_to_everything[key]["columns_to_keep_string"]:
        sheet_name_to_everything[key]["columns_to_keep_string"] = "[" + sheet_name_to_everything[key]["columns_to_keep_string"] + "]"
        sheet_name_to_everything[key]["columns_to_keep_list"] = ast.literal_eval(sheet_name_to_everything[key]["columns_to_keep_string"])
    # Using all the sheet names if no sheet name is specified
    else:
        sheet_name_to_everything[key]["columns_to_keep_list"] =  sorted(list(set(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns) - set([sheet_name_to_everything[key]["winner_column"]]) - set([sheet_name_to_everything[key]["loser_column"]])))
        
    

    # Calculating the Elo Score    
    sheet_name_to_everything[key]["index_to_elo_score_and_meta_data"] = eloscore.iterate_elo_score_calculation_for_dataframe(dataframe=sheet_name_to_everything[key]["processed_behavior_recording_dataframe"], \
                                                                                                                   winner_column=sheet_name_to_everything[key]["winner_column"], loser_column=sheet_name_to_everything[key]["loser_column"], \
                                                                                                                             additional_columns=sheet_name_to_everything[key]["columns_to_keep_list"], tie_column=sheet_name_to_everything[key]["ties_column"])
    # Making a dataframe from the dictionary 
    sheet_name_to_everything[key]["elo_score_dataframe"] = pd.DataFrame.from_dict(sheet_name_to_everything[key]["index_to_elo_score_and_meta_data"], orient="index")
# Out:
# Type all the columns that will be copied from the original dataframe to the ELO Score calculated dataframe.
#
#     All the available actions: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number', 'session_number_difference'],
#       dtype='object')
#     Each column must be put in quotes and seperated by a comma(,). i.e. 'length of observations', 'date', 'cage #'
#
#     NOTE: If left blank, all the columns will be kept
#
# Type all the columns that will be copied from the original dataframe to the ELO Score calculated dataframe.
#
#     All the available actions: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number', 'session_number_difference'],
#       dtype='object')
#     Each column must be put in quotes and seperated by a comma(,). i.e. 'length of observations', 'date', 'cage #'
#
#     NOTE: If left blank, all the columns will be kept
#
# Type all the columns that will be copied from the original dataframe to the ELO Score calculated dataframe.
#
#     All the available actions: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number', 'session_number_difference'],
#       dtype='object')
#     Each column must be put in quotes and seperated by a comma(,). i.e. 'length of observations', 'date', 'cage #'
#
#     NOTE: If left blank, all the columns will be kept
#
# Type all the columns that will be copied from the original dataframe to the ELO Score calculated dataframe.
#
#     All the available actions: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number', 'session_number_difference'],
#       dtype='object')
#     Each column must be put in quotes and seperated by a comma(,). i.e. 'length of observations', 'date', 'cage #'
#
#     NOTE: If left blank, all the columns will be kept

# %%
sheet_name_to_everything[key]["elo_score_dataframe"].head()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                   1         8.0       4.0              1000.0
# 1                   1         4.0       8.0              1000.0
# 2                   2         8.0       4.0              1010.0
# 3                   2         4.0       8.0               990.0
#
#    updated_elo_score  win_draw_loss    4    8 action date  \
# 0             1010.0              1 -1.0  1.0      m  NaT
# 1              990.0              0 -1.0  1.0      m  NaT
# 2             1019.4              1 -1.0  1.0      c  NaT
# 3              980.6              0 -1.0  1.0      c  NaT
#
#    length of observation  notes  observer  session_number  \
# 0                    NaN    NaN       NaN             2.0
# 1                    NaN    NaN       NaN             2.0
# 2                    NaN    NaN       NaN             3.0
# 3                    NaN    NaN       NaN             3.0
#
#    session_number_difference
# 0                        NaN
# 1                        NaN
# 2                        1.0
# 3                        1.0

# %%
sheet_name_to_everything[key]["elo_score_dataframe"].tail()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                   1         8.0       4.0              1000.0
# 1                   1         4.0       8.0              1000.0
# 2                   2         8.0       4.0              1010.0
# 3                   2         4.0       8.0               990.0
#
#    updated_elo_score  win_draw_loss    4    8 action date  \
# 0             1010.0              1 -1.0  1.0      m  NaT
# 1              990.0              0 -1.0  1.0      m  NaT
# 2             1019.4              1 -1.0  1.0      c  NaT
# 3              980.6              0 -1.0  1.0      c  NaT
#
#    length of observation  notes  observer  session_number  \
# 0                    NaN    NaN       NaN             2.0
# 1                    NaN    NaN       NaN             2.0
# 2                    NaN    NaN       NaN             3.0
# 3                    NaN    NaN       NaN             3.0
#
#    session_number_difference
# 0                        NaN
# 1                        NaN
# 2                        1.0
# 3                        1.0

# %%
sheet_name_to_everything[key]["elo_score_dataframe"].groupby("subject_id").count()
# Out:
#             total_match_number  agent_id  original_elo_score  \
# subject_id
# 4.0                          2         2                   2
# 8.0                          2         2                   2
#
#             updated_elo_score  win_draw_loss  4  8  action  date  \
# subject_id
# 4.0                         2              2  2  2       2     0
# 8.0                         2              2  2  2       2     0
#
#             length of observation  notes  observer  session_number  \
# subject_id
# 4.0                             0      0         0               2
# 8.0                             0      0         0               2
#
#             session_number_difference
# subject_id
# 4.0                                 1
# 8.0                                 1

# %% [markdown]
# ## Getting the cage number

# %% [markdown]
# - The cage number is sometimes not consistent throughout a spreadsheet for the same cage. So we will try to standarize it into one value.
#     - **NOTE**: This assumes cage numbers are actual numbers. And not entirely consisting of letters. If that isn't the case, then you must edit this cell for your needs.

# %%
for key, value in sheet_name_to_everything.items():
    # Asking the user which column has the cage number
    sheet_name_to_everything[key]["cage_column"] = input("""Type the name of the column of the subject that has won the interaction.
    i.e. "cage"

    The available columns are: {}

    Note: If left blank, the column with "cage" will be used as the column. If there is none, then the sheet name will be used.
    """.format(sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns))
    
    # Getting the column that has "cage" in its name if no column is specified
    if not sheet_name_to_everything[key]["cage_column"]:
        if [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "cage" in col.lower()]:
            sheet_name_to_everything[key]["cage_column"] = [col for col in sheet_name_to_everything[key]["processed_behavior_recording_dataframe"].columns if "cage" in col.lower()][0]
        else:
            sheet_name_to_everything[key]["cage_column"] = "cage"
            sheet_name_to_everything[key]["elo_score_dataframe"]["cage"] = key
            
    
    # Creating a dictionary of original cage name to standarized cage namec
    sheet_name_to_everything[key]["cage_string_to_number"] = defaultdict(dict)
    # Getting all the unique cage names
    unique_cage_numbers = sheet_name_to_everything[key]["elo_score_dataframe"][sheet_name_to_everything[key]["cage_column"]].unique()
    for cage_string in unique_cage_numbers:
        # Getting the number from the cage name
        sheet_name_to_everything[key]["cage_string_to_number"][cage_string] = re.findall(r'\d+', str(cage_string))[0]
        print(sheet_name_to_everything[key]["cage_string_to_number"])
    # Making a new column for the processed cage number
    sheet_name_to_everything[key]["elo_score_dataframe"]["processed_cage_number"] = sheet_name_to_everything[key]["elo_score_dataframe"][sheet_name_to_everything[key]["cage_column"]].map(sheet_name_to_everything[key]["cage_string_to_number"])
# Out:
# Type the name of the column of the subject that has won the interaction.
#     i.e. "cage"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '1', '5', 'session_number', 'session_number_difference'],
#       dtype='object')
#
#     Note: If left blank, the column with "cage" will be used as the column. If there is none, then the sheet name will be used.
#
# defaultdict(<class 'dict'>, {'Cage 1 ': '1'})
# Type the name of the column of the subject that has won the interaction.
#     i.e. "cage"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '2', '6', 'session_number', 'session_number_difference'],
#       dtype='object')
#
#     Note: If left blank, the column with "cage" will be used as the column. If there is none, then the sheet name will be used.
#
# defaultdict(<class 'dict'>, {'Cage 2': '2'})
# Type the name of the column of the subject that has won the interaction.
#     i.e. "cage"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '3', '7', 'session_number', 'session_number_difference'],
#       dtype='object')
#
#     Note: If left blank, the column with "cage" will be used as the column. If there is none, then the sheet name will be used.
#
# Type the name of the column of the subject that has won the interaction.
#     i.e. "cage"
#
#     The available columns are: Index(['observer', 'notes', 'length of observation', 'date', 'winner', 'loser',
#        'action', '4', '8', 'session_number', 'session_number_difference'],
#       dtype='object')
#
#     Note: If left blank, the column with "cage" will be used as the column. If there is none, then the sheet name will be used.
#
# defaultdict(<class 'dict'>, {'Cage 4': '4'})

# %%
sheet_name_to_everything[key]["elo_score_dataframe"].head()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                   1         8.0       4.0              1000.0
# 1                   1         4.0       8.0              1000.0
# 2                   2         8.0       4.0              1010.0
# 3                   2         4.0       8.0               990.0
#
#    updated_elo_score  win_draw_loss    4    8 action date  \
# 0             1010.0              1 -1.0  1.0      m  NaT
# 1              990.0              0 -1.0  1.0      m  NaT
# 2             1019.4              1 -1.0  1.0      c  NaT
# 3              980.6              0 -1.0  1.0      c  NaT
#
#    length of observation  notes  observer  session_number  \
# 0                    NaN    NaN       NaN             2.0
# 1                    NaN    NaN       NaN             2.0
# 2                    NaN    NaN       NaN             3.0
# 3                    NaN    NaN       NaN             3.0
#
#    session_number_difference    cage processed_cage_number
# 0                        NaN  Cage 4                     4
# 1                        NaN  Cage 4                     4
# 2                        1.0  Cage 4                     4
# 3                        1.0  Cage 4                     4

# %%
sheet_name_to_everything[key]["elo_score_dataframe"].tail()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                   1         8.0       4.0              1000.0
# 1                   1         4.0       8.0              1000.0
# 2                   2         8.0       4.0              1010.0
# 3                   2         4.0       8.0               990.0
#
#    updated_elo_score  win_draw_loss    4    8 action date  \
# 0             1010.0              1 -1.0  1.0      m  NaT
# 1              990.0              0 -1.0  1.0      m  NaT
# 2             1019.4              1 -1.0  1.0      c  NaT
# 3              980.6              0 -1.0  1.0      c  NaT
#
#    length of observation  notes  observer  session_number  \
# 0                    NaN    NaN       NaN             2.0
# 1                    NaN    NaN       NaN             2.0
# 2                    NaN    NaN       NaN             3.0
# 3                    NaN    NaN       NaN             3.0
#
#    session_number_difference    cage processed_cage_number
# 0                        NaN  Cage 4                     4
# 1                        NaN  Cage 4                     4
# 2                        1.0  Cage 4                     4
# 3                        1.0  Cage 4                     4

# %% [markdown]
# ## Combining all the ELO Score dataframes into one

# %%
# Adding the name of the experiment
for key, value in sheet_name_to_everything.items():
    sheet_name_to_everything[key]["elo_score_dataframe"]["experiment_type"] = "{}".format(protocol_name)

# %%
# Putting all the dataframes into one list
all_sheet_elo_scord_dataframe_list = []
for key, value in sheet_name_to_everything.items():    
    all_sheet_elo_scord_dataframe_list.append(sheet_name_to_everything[key]["elo_score_dataframe"])

# Combining all the dataframes into one
all_sheet_elo_scord_dataframe_combined = pd.concat(all_sheet_elo_scord_dataframe_list)

# %%
all_sheet_elo_scord_dataframe_combined.head()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                 1.0         5.0       1.0              1000.0
# 1                 1.0         1.0       5.0              1000.0
# 2                 2.0         5.0       1.0              1010.0
# 3                 2.0         1.0       5.0               990.0
# 4                 3.0         5.0       1.0              1019.4
#
#    updated_elo_score  win_draw_loss    1    5 action       date  ... observer  \
# 0             1010.0            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 1              990.0            0.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 2             1019.4            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 3              980.6            0.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 4             1028.3            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
#
#   session_number session_number_difference     cage  processed_cage_number  \
# 0            2.0                       NaN  Cage 1                       1
# 1            2.0                       NaN  Cage 1                       1
# 2            2.0                       0.0  Cage 1                       1
# 3            2.0                       0.0  Cage 1                       1
# 4            2.0                       0.0  Cage 1                       1
#
#          experiment_type   2   6   4   8
# 0  home_cage_observation NaN NaN NaN NaN
# 1  home_cage_observation NaN NaN NaN NaN
# 2  home_cage_observation NaN NaN NaN NaN
# 3  home_cage_observation NaN NaN NaN NaN
# 4  home_cage_observation NaN NaN NaN NaN
#
# [5 rows x 22 columns]

# %%
all_sheet_elo_scord_dataframe_combined.tail()
# Out:
#     total_match_number  subject_id  agent_id  original_elo_score  \
# 83                42.0         6.0       2.0               998.8
# 0                  1.0         8.0       4.0              1000.0
# 1                  1.0         4.0       8.0              1000.0
# 2                  2.0         8.0       4.0              1010.0
# 3                  2.0         4.0       8.0               990.0
#
#     updated_elo_score  win_draw_loss   1   5 action       date  ...  \
# 83              988.9            0.0 NaN NaN      f 2022-09-14  ...
# 0              1010.0            1.0 NaN NaN      m        NaT  ...
# 1               990.0            0.0 NaN NaN      m        NaT  ...
# 2              1019.4            1.0 NaN NaN      c        NaT  ...
# 3               980.6            0.0 NaN NaN      c        NaT  ...
#
#            observer session_number session_number_difference    cage  \
# 83  Amelia Chambers            4.0                       0.0  Cage 2
# 0               NaN            2.0                       NaN  Cage 4
# 1               NaN            2.0                       NaN  Cage 4
# 2               NaN            3.0                       1.0  Cage 4
# 3               NaN            3.0                       1.0  Cage 4
#
#     processed_cage_number        experiment_type    2    6    4    8
# 83                      2  home_cage_observation  1.0 -1.0  NaN  NaN
# 0                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 1                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 2                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 3                       4  home_cage_observation  NaN  NaN -1.0  1.0
#
# [5 rows x 22 columns]

# %%
all_sheet_elo_scord_dataframe_combined.groupby(['subject_id','processed_cage_number']).count()
# Out:
#                                   total_match_number  agent_id  \
# subject_id processed_cage_number
# 1.0        1                                      42        42
# 2.0        2                                      42        42
# 4.0        4                                       2         2
# 5.0        1                                      42        42
# 6.0        2                                      42        42
# 8.0        4                                       2         2
#
#                                   original_elo_score  updated_elo_score  \
# subject_id processed_cage_number
# 1.0        1                                      42                 42
# 2.0        2                                      42                 42
# 4.0        4                                       2                  2
# 5.0        1                                      42                 42
# 6.0        2                                      42                 42
# 8.0        4                                       2                  2
#
#                                   win_draw_loss   1   5  action  date  \
# subject_id processed_cage_number
# 1.0        1                                 42  42  42      42    42
# 2.0        2                                 42   0   0      42    41
# 4.0        4                                  2   0   0       2     0
# 5.0        1                                 42  42  42      42    42
# 6.0        2                                 42   0   0      42    41
# 8.0        4                                  2   0   0       2     0
#
#                                   length of observation  notes  observer  \
# subject_id processed_cage_number
# 1.0        1                                         42     42        42
# 2.0        2                                         41     42        41
# 4.0        4                                          0      0         0
# 5.0        1                                         42     42        42
# 6.0        2                                         41     42        41
# 8.0        4                                          0      0         0
#
#                                   session_number  session_number_difference  \
# subject_id processed_cage_number
# 1.0        1                                  42                         41
# 2.0        2                                  42                         41
# 4.0        4                                   2                          1
# 5.0        1                                  42                         41
# 6.0        2                                  42                         41
# 8.0        4                                   2                          1
#
#                                   cage  experiment_type   2   6  4  8
# subject_id processed_cage_number
# 1.0        1                        42               42   0   0  0  0
# 2.0        2                        42               42  42  42  0  0
# 4.0        4                         2                2   0   0  2  2
# 5.0        1                        42               42   0   0  0  0
# 6.0        2                        42               42  42  42  0  0
# 8.0        4                         2                2   0   0  2  2

# %% [markdown]
# ## Creating a dataframe with only the final ELO score for each subject

# %%
# Checking to see which cage and subject combination has more than one row
all_sheet_elo_scord_dataframe_groupby = all_sheet_elo_scord_dataframe_combined.groupby(['subject_id','processed_cage_number']).size().reset_index()
all_sheet_elo_scord_dataframe_groupby = all_sheet_elo_scord_dataframe_groupby[all_sheet_elo_scord_dataframe_groupby[0] >= 1]

# Going through each combination and saving the combination to a dictionary
index_to_subject_id_and_processed_cage_number = defaultdict(dict)
for index, row in all_sheet_elo_scord_dataframe_groupby.iterrows():
    index_to_subject_id_and_processed_cage_number[index]['subject_id'] = row['subject_id']
    index_to_subject_id_and_processed_cage_number[index]['processed_cage_number'] = row['processed_cage_number']

# %%
index_to_subject_id_and_processed_cage_number
# Out:
# defaultdict(dict,
#             {0: {'subject_id': 1.0, 'processed_cage_number': '1'},
#              1: {'subject_id': 2.0, 'processed_cage_number': '2'},
#              2: {'subject_id': 4.0, 'processed_cage_number': '4'},
#              3: {'subject_id': 5.0, 'processed_cage_number': '1'},
#              4: {'subject_id': 6.0, 'processed_cage_number': '2'},
#              5: {'subject_id': 8.0, 'processed_cage_number': '4'}})

# %% [markdown]
# - Getting the final ELO score for each cage and subject combination

# %%
id_to_final_elo_score_dict = defaultdict(dict)
for index, (key, value) in enumerate(index_to_subject_id_and_processed_cage_number.items()):
    # The ELO score dataframe for each cage and subject combination
    per_subject_dataframe = all_sheet_elo_scord_dataframe_combined[(all_sheet_elo_scord_dataframe_combined["subject_id"] == value["subject_id"]) & (all_sheet_elo_scord_dataframe_combined["processed_cage_number"] == value["processed_cage_number"])]
    # Getting the final ELO score for each combination
    id_to_final_elo_score_dict[index]["processed_cage_number"] = value["processed_cage_number"]
    id_to_final_elo_score_dict[index]["subject_id"] = value["subject_id"]
    id_to_final_elo_score_dict[index]["final_elo_score"] = per_subject_dataframe.iloc[-1]["updated_elo_score"]

# %%
id_to_final_elo_score_dict
# Out:
# defaultdict(dict,
#             {0: {'processed_cage_number': '1',
#               'subject_id': 1.0,
#               'final_elo_score': 827.7},
#              1: {'processed_cage_number': '2',
#               'subject_id': 2.0,
#               'final_elo_score': 1011.1},
#              2: {'processed_cage_number': '4',
#               'subject_id': 4.0,
#               'final_elo_score': 980.6},
#              3: {'processed_cage_number': '1',
#               'subject_id': 5.0,
#               'final_elo_score': 1172.3},
#              4: {'processed_cage_number': '2',
#               'subject_id': 6.0,
#               'final_elo_score': 988.9},
#              5: {'processed_cage_number': '4',
#               'subject_id': 8.0,
#               'final_elo_score': 1019.4}})

# %%
# Making a dataframe based on the dictionary
id_to_final_elo_score_dataframe = pd.DataFrame.from_dict(id_to_final_elo_score_dict, orient="index")
id_to_final_elo_score_dataframe["experiment_type"] = "{}".format(protocol_name)

# %%
id_to_final_elo_score_dataframe.head()
# Out:
#   processed_cage_number  subject_id  final_elo_score        experiment_type
# 0                     1         1.0            827.7  home_cage_observation
# 1                     2         2.0           1011.1  home_cage_observation
# 2                     4         4.0            980.6  home_cage_observation
# 3                     1         5.0           1172.3  home_cage_observation
# 4                     2         6.0            988.9  home_cage_observation

# %% [markdown]
# # Making plots for all sheets

# %% [markdown]
# - Getting the dates the files were being recorded to use for the file name

# %%
all_sheet_elo_scord_dataframe_combined.head()
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                 1.0         5.0       1.0              1000.0
# 1                 1.0         1.0       5.0              1000.0
# 2                 2.0         5.0       1.0              1010.0
# 3                 2.0         1.0       5.0               990.0
# 4                 3.0         5.0       1.0              1019.4
#
#    updated_elo_score  win_draw_loss    1    5 action       date  ... observer  \
# 0             1010.0            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 1              990.0            0.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 2             1019.4            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 3              980.6            0.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
# 4             1028.3            1.0 -1.0  1.0      f 2022-09-09  ...   Naeliz
#
#   session_number session_number_difference     cage  processed_cage_number  \
# 0            2.0                       NaN  Cage 1                       1
# 1            2.0                       NaN  Cage 1                       1
# 2            2.0                       0.0  Cage 1                       1
# 3            2.0                       0.0  Cage 1                       1
# 4            2.0                       0.0  Cage 1                       1
#
#          experiment_type   2   6   4   8
# 0  home_cage_observation NaN NaN NaN NaN
# 1  home_cage_observation NaN NaN NaN NaN
# 2  home_cage_observation NaN NaN NaN NaN
# 3  home_cage_observation NaN NaN NaN NaN
# 4  home_cage_observation NaN NaN NaN NaN
#
# [5 rows x 22 columns]

# %%
all_sheet_elo_scord_dataframe_combined.tail()
# Out:
#     total_match_number  subject_id  agent_id  original_elo_score  \
# 83                42.0         6.0       2.0               998.8
# 0                  1.0         8.0       4.0              1000.0
# 1                  1.0         4.0       8.0              1000.0
# 2                  2.0         8.0       4.0              1010.0
# 3                  2.0         4.0       8.0               990.0
#
#     updated_elo_score  win_draw_loss   1   5 action       date  ...  \
# 83              988.9            0.0 NaN NaN      f 2022-09-14  ...
# 0              1010.0            1.0 NaN NaN      m        NaT  ...
# 1               990.0            0.0 NaN NaN      m        NaT  ...
# 2              1019.4            1.0 NaN NaN      c        NaT  ...
# 3               980.6            0.0 NaN NaN      c        NaT  ...
#
#            observer session_number session_number_difference    cage  \
# 83  Amelia Chambers            4.0                       0.0  Cage 2
# 0               NaN            2.0                       NaN  Cage 4
# 1               NaN            2.0                       NaN  Cage 4
# 2               NaN            3.0                       1.0  Cage 4
# 3               NaN            3.0                       1.0  Cage 4
#
#     processed_cage_number        experiment_type    2    6    4    8
# 83                      2  home_cage_observation  1.0 -1.0  NaN  NaN
# 0                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 1                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 2                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 3                       4  home_cage_observation  NaN  NaN -1.0  1.0
#
# [5 rows x 22 columns]

# %% [markdown]
# - Getting the earliest and the latest dates for all the recordings

# %%
all_sheet_elo_scord_dataframe_combined
# Out:
#     total_match_number  subject_id  agent_id  original_elo_score  \
# 0                  1.0         5.0       1.0              1000.0
# 1                  1.0         1.0       5.0              1000.0
# 2                  2.0         5.0       1.0              1010.0
# 3                  2.0         1.0       5.0               990.0
# 4                  3.0         5.0       1.0              1019.4
# ..                 ...         ...       ...                 ...
# 83                42.0         6.0       2.0               998.8
# 0                  1.0         8.0       4.0              1000.0
# 1                  1.0         4.0       8.0              1000.0
# 2                  2.0         8.0       4.0              1010.0
# 3                  2.0         4.0       8.0               990.0
#
#     updated_elo_score  win_draw_loss    1    5 action       date  ...  \
# 0              1010.0            1.0 -1.0  1.0      f 2022-09-09  ...
# 1               990.0            0.0 -1.0  1.0      f 2022-09-09  ...
# 2              1019.4            1.0 -1.0  1.0      f 2022-09-09  ...
# 3               980.6            0.0 -1.0  1.0      f 2022-09-09  ...
# 4              1028.3            1.0 -1.0  1.0      f 2022-09-09  ...
# ..                ...            ...  ...  ...    ...        ...  ...
# 83              988.9            0.0  NaN  NaN      f 2022-09-14  ...
# 0              1010.0            1.0  NaN  NaN      m        NaT  ...
# 1               990.0            0.0  NaN  NaN      m        NaT  ...
# 2              1019.4            1.0  NaN  NaN      c        NaT  ...
# 3               980.6            0.0  NaN  NaN      c        NaT  ...
#
#            observer session_number session_number_difference     cage  \
# 0            Naeliz            2.0                       NaN  Cage 1
# 1            Naeliz            2.0                       NaN  Cage 1
# 2            Naeliz            2.0                       0.0  Cage 1
# 3            Naeliz            2.0                       0.0  Cage 1
# 4            Naeliz            2.0                       0.0  Cage 1
# ..              ...            ...                       ...      ...
# 83  Amelia Chambers            4.0                       0.0   Cage 2
# 0               NaN            2.0                       NaN   Cage 4
# 1               NaN            2.0                       NaN   Cage 4
# 2               NaN            3.0                       1.0   Cage 4
# 3               NaN            3.0                       1.0   Cage 4
#
#     processed_cage_number        experiment_type    2    6    4    8
# 0                       1  home_cage_observation  NaN  NaN  NaN  NaN
# 1                       1  home_cage_observation  NaN  NaN  NaN  NaN
# 2                       1  home_cage_observation  NaN  NaN  NaN  NaN
# 3                       1  home_cage_observation  NaN  NaN  NaN  NaN
# 4                       1  home_cage_observation  NaN  NaN  NaN  NaN
# ..                    ...                    ...  ...  ...  ...  ...
# 83                      2  home_cage_observation  1.0 -1.0  NaN  NaN
# 0                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 1                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 2                       4  home_cage_observation  NaN  NaN -1.0  1.0
# 3                       4  home_cage_observation  NaN  NaN -1.0  1.0
#
# [172 rows x 22 columns]

# %% [raw]
# all_earlist_dates = []
# all_latest_dates = []
# for key, value in sheet_name_to_everything.items():
#     # Getting all the earliest dates for each sheet
#     all_earlist_dates.append(sheet_name_to_everything[key]["elo_score_dataframe"][sheet_name_to_everything[key]["session_divider_column"]].min())
#     # Getting all the latest dates for each sheet
#     all_latest_dates.append(sheet_name_to_everything[key]["elo_score_dataframe"][sheet_name_to_everything[key]["session_divider_column"]].max())

# %%
all_earlist_dates = all_sheet_elo_scord_dataframe_combined[[sheet_name_to_everything[key]["session_divider_column"]]].min()

# %%
min(all_earlist_dates)
# Out:
# Timestamp('2022-09-09 00:00:00')

# %%
all_latest_dates = all_sheet_elo_scord_dataframe_combined[[sheet_name_to_everything[key]["session_divider_column"]]].max()

# %%
max(all_latest_dates)
# Out:
# Timestamp('2022-09-14 00:00:00')

# %% [markdown]
# - Turning the Dates into a easier to read format

# %%
earliest_date = str(min(all_earlist_dates)).split()[0]

# %%
latest_date = str(max(all_latest_dates)).split()[0]

# %%
earliest_date
# Out:
# '2022-09-09'

# %%
latest_date
# Out:
# '2022-09-14'

# %% [markdown]
# - Getting the cage numbers

# %% [raw]
# all_cages_list = []
# # Creating a list of all the cage numbers
# for key, value in sheet_name_to_everything.items():
#     for cage in sheet_name_to_everything[key]["elo_score_dataframe"]["processed_cage_number"].unique():
#         all_cages_list.append(cage)

# %%
all_sheet_elo_scord_dataframe_combined["cage"].unique()
# Out:
# array(['Cage 1 ', 'Cage 2', 'Cage 4'], dtype=object)

# %%
all_cages_string = "_".join(sorted([sheet.lower().strip("cage").strip() for sheet in all_cages_list]))

# %%
all_cages_string
# Out:
# '1_2_4'

# %% [markdown]
# - Creating an output directory to save the plots

# %%
plot_output_directory = "./proc/plots/{}_elo_score/cage_{}_date_{}_{}".format(protocol_name, all_cages_string, earliest_date, latest_date)

# %%
plot_output_directory
# Out:
# './proc/plots/home_cage_observation_elo_score/cage_1_2_4_date_2022-09-09_2022-09-14'

# %%
os.makedirs(plot_output_directory, exist_ok=True)

# %% [markdown]
# # **NOTE**: Sometimes this cell needs to be run again to make sure the size is correct

# %%
plt.rcParams["figure.figsize"] = (13.5,7.5)

# %%
sheet_name_to_everything
# Out:
# defaultdict(dict,
#             {'Cage 1 ': {'header_row': 1,
#               'original_behavior_recording_dataframe':             Observer                                              Notes  \
#               0    Amelia Chambers  20 minutes after rehousing, removal of enrichm...
#               1                NaN                             observed on right side
#               2                NaN                                                NaN
#               3                NaN               Sniffing but no real agression shown
#               4                NaN                                                NaN
#               ..               ...                                                ...
#               134              NaN                                                NaN
#               135              NaN                                                NaN
#               136              NaN                                                NaN
#               137              NaN                                                NaN
#               138              NaN                                                NaN
#
#                   Length of Observation      Date   Winner  Loser Action    1    5
#               0              30 minutes 2022-09-05       5    1.0     FS  NaN  NaN
#               1                     NaN        NaT       1    5.0     AG  NaN  NaN
#               2                     NaN        NaT       5    1.0     FS  NaN  NaN
#               3                     NaN        NaT       5    1.0     FS  NaN  NaN
#               4                     NaN        NaT       5    1.0     AG  NaN  NaN
#               ..                    ...        ...     ...    ...    ...  ...  ...
#               134                   NaN        NaT       5    1.0     as  NaN  NaN
#               135                   NaN        NaT       5    1.0     fs  NaN  NaN
#               136                   NaN        NaT       5    1.0      m -1.0  1.0
#               137                   NaN        NaT       5    1.0      c -1.0  1.0
#               138                   NaN        NaT       5    1.0      m -1.0  1.0
#
#               [139 rows x 9 columns],
#               'column_name_to_standarized': defaultdict(dict,
#                           {'Observer': 'observer',
#                            'Notes': 'notes',
#                            'Length of Observation': 'length of observation',
#                            'Date ': 'date',
#                            'Winner': 'winner',
#                            'Loser': 'loser',
#                            'Action': 'action',
#                            1: '1',
#                            5: '5'}),
#               'processed_behavior_recording_dataframe':             observer                                   notes  \
#               25            Naeliz     right after 30 min social isolation
#               26            Naeliz  observed on the right side of the room
#               28            Naeliz          observed in homecage, isolated
#               29            Naeliz                          in clean cages
#               30            Naeliz                          in clean cages
#               31            Naeliz                          in clean cages
#               32            Naeliz                          in clean cages
#               33            Naeliz                          in clean cages
#               34            Naeliz                          in clean cages
#               35            Naeliz                          in clean cages
#               46            Naeliz                          in clean cages
#               52   Amelia Chambers                        1 hour isolation
#               54   Amelia Chambers                          starts at 2:15
#               56   Amelia Chambers                          starts at 2:15
#               63   Amelia Chambers                          starts at 2:15
#               70   Amelia Chambers                          starts at 2:15
#               71   Amelia Chambers                          starts at 2:15
#               81            Naeliz                        3 hour isolation
#               88            Naeliz                        3 hour isolation
#               89            Naeliz                        3 hour isolation
#               90            Naeliz                        3 hour isolation
#               91            Naeliz                        3 hour isolation
#               98            Naeliz                        3 hour isolation
#               99            Naeliz                        3 hour isolation
#               100           Naeliz                        3 hour isolation
#               101           Naeliz                        3 hour isolation
#               102           Naeliz                        3 hour isolation
#               103           Naeliz                        3 hour isolation
#               116           Naeliz                        3 hour isolation
#               117           Naeliz                        3 hour isolation
#               118           Naeliz                        3 hour isolation
#               119           Naeliz                        3 hour isolation
#               122           Naeliz                        3 hour isolation
#               123           Naeliz                        3 hour isolation
#               124           Naeliz                        3 hour isolation
#               129           Naeliz                        3 hour isolation
#               130           Naeliz                        3 hour isolation
#               131           Naeliz                        3 hour isolation
#               132           Naeliz                        3 hour isolation
#               136           Naeliz                        3 hour isolation
#               137           Naeliz                        3 hour isolation
#               138           Naeliz                        3 hour isolation
#
#                   length of observation       date  winner  loser action    1    5  \
#               25             30 minutes 2022-09-09       5    1.0      f -1.0  1.0
#               26             30 minutes 2022-09-09       5    1.0      f -1.0  1.0
#               28             30 minutes 2022-09-09       5    1.0      f -1.0  1.0
#               29             30 minutes 2022-09-09       5    1.0      m -1.0  1.0
#               30             30 minutes 2022-09-09       5    1.0      m -1.0  1.0
#               31             30 minutes 2022-09-09       5    1.0      m -1.0  1.0
#               32             30 minutes 2022-09-09       5    1.0      m -1.0  1.0
#               33             30 minutes 2022-09-09       5    1.0      c -1.0  1.0
#               34             30 minutes 2022-09-09       5    1.0      m -1.0  1.0
#               35             30 minutes 2022-09-09       5    1.0      c -1.0  1.0
#               46             30 minutes 2022-09-09       5    1.0      c -1.0  1.0
#               52                 30 min 2022-09-13       5    1.0      f -1.0  1.0
#               54                 30 min 2022-09-13       5    1.0      m -1.0  1.0
#               56                 30 min 2022-09-13       5    1.0      f -1.0  1.0
#               63                 30 min 2022-09-13       5    1.0      f -1.0  1.0
#               70                 30 min 2022-09-13       5    1.0      f -1.0  1.0
#               71                 30 min 2022-09-13       5    1.0      m -1.0  1.0
#               81                 30 min 2022-09-14       5    1.0      m -1.0  1.0
#               88                 30 min 2022-09-14       5    1.0      m -1.0  1.0
#               89                 30 min 2022-09-14       5    1.0      c -1.0  1.0
#               90                 30 min 2022-09-14       5    1.0      f -1.0  1.0
#               91                 30 min 2022-09-14       5    1.0      f -1.0  1.0
#               98                 30 min 2022-09-14       5    1.0      m -1.0  1.0
#               99                 30 min 2022-09-14       5    1.0      m -1.0  1.0
#               100                30 min 2022-09-14       5    1.0      c -1.0  1.0
#               101                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               102                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               103                30 min 2022-09-14       5    1.0      f -1.0  1.0
#               116                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               117                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               118                30 min 2022-09-14       5    1.0      f -1.0  1.0
#               119                30 min 2022-09-14       1    5.0      f  1.0 -1.0
#               122                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               123                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               124                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               129                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               130                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               131                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               132                30 min 2022-09-14       5    1.0      c -1.0  1.0
#               136                30 min 2022-09-14       5    1.0      m -1.0  1.0
#               137                30 min 2022-09-14       5    1.0      c -1.0  1.0
#               138                30 min 2022-09-14       5    1.0      m -1.0  1.0
#
#                    session_number  session_number_difference
#               25              2.0                        NaN
#               26              2.0                        0.0
#               28              2.0                        0.0
#               29              2.0                        0.0
#               30              2.0                        0.0
#               31              2.0                        0.0
#               32              2.0                        0.0
#               33              2.0                        0.0
#               34              2.0                        0.0
#               35              2.0                        0.0
#               46              2.0                        0.0
#               52              3.0                        1.0
#               54              3.0                        0.0
#               56              3.0                        0.0
#               63              3.0                        0.0
#               70              3.0                        0.0
#               71              3.0                        0.0
#               81              4.0                        1.0
#               88              4.0                        0.0
#               89              4.0                        0.0
#               90              4.0                        0.0
#               91              4.0                        0.0
#               98              4.0                        0.0
#               99              4.0                        0.0
#               100             4.0                        0.0
#               101             4.0                        0.0
#               102             4.0                        0.0
#               103             4.0                        0.0
#               116             4.0                        0.0
#               117             4.0                        0.0
#               118             4.0                        0.0
#               119             4.0                        0.0
#               122             4.0                        0.0
#               123             4.0                        0.0
#               124             4.0                        0.0
#               129             4.0                        0.0
#               130             4.0                        0.0
#               131             4.0                        0.0
#               132             4.0                        0.0
#               136             4.0                        0.0
#               137             4.0                        0.0
#               138             4.0                        0.0  ,
#               'session_divider_column': 'date',
#               'session_indexes': Int64Index([0, 25, 52, 81], dtype='int64'),
#               'winner_column': 'winner',
#               'loser_column': 'loser',
#               'action_column': 'action',
#               'elo_counted_actions_string': "['f', 'm', 'c']",
#               'elo_counted_actions_list': ['f', 'm', 'c'],
#               'ties_column': None,
#               'columns_to_keep_string': '',
#               'columns_to_keep_list': ['1',
#                '5',
#                'action',
#                'date',
#                'length of observation',
#                'notes',
#                'observer',
#                'session_number',
#                'session_number_difference'],
#               'index_to_elo_score_and_meta_data': defaultdict(dict,
#                           {0: {'total_match_number': 1,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1000,
#                             'updated_elo_score': 1010.0,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'right after 30 min social isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': nan},
#                            1: {'total_match_number': 1,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 1000,
#                             'updated_elo_score': 990.0,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'right after 30 min social isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': nan},
#                            2: {'total_match_number': 2,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1010.0,
#                             'updated_elo_score': 1019.4,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'observed on the right side of the room',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            3: {'total_match_number': 2,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 990.0,
#                             'updated_elo_score': 980.6,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'observed on the right side of the room',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            4: {'total_match_number': 3,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1019.4,
#                             'updated_elo_score': 1028.3,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'observed in homecage, isolated',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            5: {'total_match_number': 3,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 980.6,
#                             'updated_elo_score': 971.7,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'observed in homecage, isolated',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            6: {'total_match_number': 4,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1028.3,
#                             'updated_elo_score': 1036.7,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            7: {'total_match_number': 4,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 971.7,
#                             'updated_elo_score': 963.3,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            8: {'total_match_number': 5,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1036.7,
#                             'updated_elo_score': 1044.6,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            9: {'total_match_number': 5,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 963.3,
#                             'updated_elo_score': 955.4,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            10: {'total_match_number': 6,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1044.6,
#                             'updated_elo_score': 1052.1,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            11: {'total_match_number': 6,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 955.4,
#                             'updated_elo_score': 947.9,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            12: {'total_match_number': 7,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1052.1,
#                             'updated_elo_score': 1059.2,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            13: {'total_match_number': 7,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 947.9,
#                             'updated_elo_score': 940.8,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            14: {'total_match_number': 8,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1059.2,
#                             'updated_elo_score': 1065.9,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            15: {'total_match_number': 8,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 940.8,
#                             'updated_elo_score': 934.1,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            16: {'total_match_number': 9,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1065.9,
#                             'updated_elo_score': 1072.3,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            17: {'total_match_number': 9,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 934.1,
#                             'updated_elo_score': 927.7,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            18: {'total_match_number': 10,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1072.3,
#                             'updated_elo_score': 1078.4,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            19: {'total_match_number': 10,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 927.7,
#                             'updated_elo_score': 921.6,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            20: {'total_match_number': 11,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1078.4,
#                             'updated_elo_score': 1084.2,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            21: {'total_match_number': 11,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 921.6,
#                             'updated_elo_score': 915.8,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-09 00:00:00'),
#                             'length of observation': '30 minutes',
#                             'notes': 'in clean cages',
#                             'observer': 'Naeliz',
#                             'session_number': 2.0,
#                             'session_number_difference': 0.0},
#                            22: {'total_match_number': 12,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1084.2,
#                             'updated_elo_score': 1089.7,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '1 hour isolation',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 1.0},
#                            23: {'total_match_number': 12,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 915.8,
#                             'updated_elo_score': 910.3,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '1 hour isolation',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 1.0},
#                            24: {'total_match_number': 13,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1089.7,
#                             'updated_elo_score': 1095.0,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            25: {'total_match_number': 13,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 910.3,
#                             'updated_elo_score': 905.0,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            26: {'total_match_number': 14,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1095.0,
#                             'updated_elo_score': 1100.0,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            27: {'total_match_number': 14,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 905.0,
#                             'updated_elo_score': 900.0,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            28: {'total_match_number': 15,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1100.0,
#                             'updated_elo_score': 1104.8,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            29: {'total_match_number': 15,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 900.0,
#                             'updated_elo_score': 895.2,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            30: {'total_match_number': 16,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1104.8,
#                             'updated_elo_score': 1109.4,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            31: {'total_match_number': 16,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 895.2,
#                             'updated_elo_score': 890.6,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            32: {'total_match_number': 17,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1109.4,
#                             'updated_elo_score': 1113.8,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            33: {'total_match_number': 17,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 890.6,
#                             'updated_elo_score': 886.2,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-13 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': 'starts at 2:15',
#                             'observer': 'Amelia Chambers',
#                             'session_number': 3.0,
#                             'session_number_difference': 0.0},
#                            34: {'total_match_number': 18,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1113.8,
#                             'updated_elo_score': 1118.0,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 1.0},
#                            35: {'total_match_number': 18,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 886.2,
#                             'updated_elo_score': 882.0,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 1.0},
#                            36: {'total_match_number': 19,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1118.0,
#                             'updated_elo_score': 1122.1,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            37: {'total_match_number': 19,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 882.0,
#                             'updated_elo_score': 877.9,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'm',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            38: {'total_match_number': 20,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1122.1,
#                             'updated_elo_score': 1126.0,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            39: {'total_match_number': 20,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 877.9,
#                             'updated_elo_score': 874.0,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'c',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            40: {'total_match_number': 21,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1126.0,
#                             'updated_elo_score': 1129.8,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            41: {'total_match_number': 21,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 874.0,
#                             'updated_elo_score': 870.2,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            42: {'total_match_number': 22,
#                             'subject_id': 5,
#                             'agent_id': 1.0,
#                             'original_elo_score': 1129.8,
#                             'updated_elo_score': 1133.5,
#                             'win_draw_loss': 1,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
#                             'session_number': 4.0,
#                             'session_number_difference': 0.0},
#                            43: {'total_match_number': 22,
#                             'subject_id': 1.0,
#                             'agent_id': 5,
#                             'original_elo_score': 870.2,
#                             'updated_elo_score': 866.5,
#                             'win_draw_loss': 0,
#                             '1': -1.0,
#                             '5': 1.0,
#                             'action': 'f',
#                             'date': Timestamp('2022-09-14 00:00:00'),
#                             'length of observation': '30 min',
#                             'notes': '3 hour isolation',
#                             'observer': 'Naeliz',
# ...
#               3               980.6              0 -1.0  1.0      f 2022-09-09
#               4              1028.3              1 -1.0  1.0      m 2022-09-09
#               ..                ...            ...  ...  ...    ...        ...
#               79              990.7              0 -1.0  1.0      f 2022-09-14
#               80             1001.2              1  1.0 -1.0      c 2022-09-14
#               81              998.8              0  1.0 -1.0      c 2022-09-14
#               82             1011.1              1  1.0 -1.0      f 2022-09-14
#               83              988.9              0  1.0 -1.0      f 2022-09-14
#
#                  length of observation                                              notes  \
#               0                    NaN           This chase was a short following because
#               1                    NaN           This chase was a short following because
#               2                 30 min  social isolation for 30 minutes prior to obser...
#               3                 30 min  social isolation for 30 minutes prior to obser...
#               4                 30 min  social isolation for 30 minutes prior to obser...
#               ..                   ...                                                ...
#               79                30 min                                  start at 4:35 pm
#               80                30 min                                  start at 4:35 pm
#               81                30 min                                  start at 4:35 pm
#               82                30 min                                  start at 4:35 pm
#               83                30 min                                  start at 4:35 pm
#
#                          observer  session_number  session_number_difference    cage  \
#               0               NaN             1.0                        NaN  Cage 2
#               1               NaN             1.0                        NaN  Cage 2
#               2   Amelia Chambers             2.0                        1.0  Cage 2
#               3   Amelia Chambers             2.0                        1.0  Cage 2
#               4   Amelia Chambers             2.0                        0.0  Cage 2
#               ..              ...             ...                        ...     ...
#               79  Amelia Chambers             4.0                        0.0  Cage 2
#               80  Amelia Chambers             4.0                        0.0  Cage 2
#               81  Amelia Chambers             4.0                        0.0  Cage 2
#               82  Amelia Chambers             4.0                        0.0  Cage 2
#               83  Amelia Chambers             4.0                        0.0  Cage 2
#
#                  processed_cage_number        experiment_type
#               0                      2  home_cage_observation
#               1                      2  home_cage_observation
#               2                      2  home_cage_observation
#               3                      2  home_cage_observation
#               4                      2  home_cage_observation
#               ..                   ...                    ...
#               79                     2  home_cage_observation
#               80                     2  home_cage_observation
#               81                     2  home_cage_observation
#               82                     2  home_cage_observation
#               83                     2  home_cage_observation
#
#               [84 rows x 18 columns],
#               'cage_column': 'cage',
#               'cage_string_to_number': defaultdict(dict, {'Cage 2': '2'})},
#              'Cage 3': {'header_row': 1,
#               'original_behavior_recording_dataframe':     Observer                        Notes Length of Observation      Date   \
#               0    Amelia   Immediately after rehousing            30 minutes 2022-09-05
#               1        NaN        removal of enrichment                   NaN        NaT
#               2        NaN             observed at 2:45                   NaN        NaT
#               3        NaN       observed on right side                   NaN        NaT
#               4        NaN                  d = digging                   NaN        NaT
#               ..       ...                          ...                   ...        ...
#               151      NaN                          NaN                   NaN        NaT
#               152      NaN                          NaN                   NaN        NaT
#               153      NaN                          NaN                   NaN        NaT
#               154      NaN                          NaN                   NaN        NaT
#               155      NaN                          NaN                   NaN        NaT
#
#                   Winner  Loser Action   3   7
#               0        3    NaN      d NaN NaN
#               1        7    NaN      d NaN NaN
#               2        3    NaN      e NaN NaN
#               3        3    NaN      e NaN NaN
#               4        7    NaN      e NaN NaN
#               ..     ...    ...    ...  ..  ..
#               151      3    NaN      e NaN NaN
#               152      3    NaN      e NaN NaN
#               153      3    NaN      e NaN NaN
#               154      3    NaN      e NaN NaN
#               155      3    NaN      e NaN NaN
#
#               [156 rows x 9 columns],
#               'column_name_to_standarized': defaultdict(dict,
#                           {'Observer': 'observer',
#                            'Notes': 'notes',
#                            'Length of Observation': 'length of observation',
#                            'Date ': 'date',
#                            'Winner': 'winner',
#                            'Loser': 'loser',
#                            'Action': 'action',
#                            3: '3',
#                            7: '7'}),
#               'processed_behavior_recording_dataframe': Empty DataFrame
#               Columns: [observer, notes, length of observation, date, winner, loser, action, 3, 7, session_number, session_number_difference]
#               Index: [],
#               'session_divider_column': 'date',
#               'session_indexes': Int64Index([0, 78, 111, 127], dtype='int64'),
#               'winner_column': 'winner',
#               'loser_column': 'loser',
#               'action_column': 'action',
#               'elo_counted_actions_string': "['f', 'm', 'c']",
#               'elo_counted_actions_list': ['f', 'm', 'c'],
#               'ties_column': None,
#               'columns_to_keep_string': '',
#               'columns_to_keep_list': ['3',
#                '7',
#                'action',
#                'date',
#                'length of observation',
#                'notes',
#                'observer',
#                'session_number',
#                'session_number_difference'],
#               'index_to_elo_score_and_meta_data': defaultdict(dict, {}),
#               'elo_score_dataframe': Empty DataFrame
#               Columns: [cage, processed_cage_number, experiment_type]
#               Index: [],
#               'cage_column': 'cage',
#               'cage_string_to_number': defaultdict(dict, {})},
#              'Cage 4': {'header_row': 1,
#               'original_behavior_recording_dataframe':    Observer                             Notes Length of Observation  \
#               0    Naeliz       Immediately after rehousing                30 min
#               1       NaN               observed at 2:45 pm                   NaN
#               2       NaN             removal of enrichment                   NaN
#               3       NaN  observed on left side of L2-164B                   NaN
#               4       NaN        #4 was an excessive digger                   NaN
#               ..      ...                               ...                   ...
#               86      NaN                               NaN                   NaN
#               87      NaN                               NaN                   NaN
#               88      NaN                               NaN                   NaN
#               89      NaN                               NaN                   NaN
#               90      NaN                               NaN                   NaN
#
#                       Date   Winner  Loser Action   4   8
#               0  2022-09-05       4    NaN      d NaN NaN
#               1         NaT       4    NaN      d NaN NaN
#               2         NaT       4    NaN      d NaN NaN
#               3         NaT       4    NaN      d NaN NaN
#               4         NaT       4    NaN      d NaN NaN
#               ..        ...     ...    ...    ...  ..  ..
#               86        NaT       4    8.0     ag NaN NaN
#               87        NaT       4    8.0     ag NaN NaN
#               88        NaT       4    8.0     ag NaN NaN
#               89        NaT       4    8.0     ag NaN NaN
#               90        NaT       4    8.0     ag NaN NaN
#
#               [91 rows x 9 columns],
#               'column_name_to_standarized': defaultdict(dict,
#                           {'Observer': 'observer',
#                            'Notes': 'notes',
#                            'Length of Observation': 'length of observation',
#                            'Date ': 'date',
#                            'Winner': 'winner',
#                            'Loser': 'loser',
#                            'Action': 'action',
#                            4: '4',
#                            8: '8'}),
#               'processed_behavior_recording_dataframe':     observer  notes  length of observation date  winner  loser action    4  \
#               32       NaN    NaN                    NaN  NaT       8    4.0      m -1.0
#               54       NaN    NaN                    NaN  NaT       8    4.0      c -1.0
#
#                     8  session_number  session_number_difference
#               32  1.0             2.0                        NaN
#               54  1.0             3.0                        1.0  ,
#               'session_divider_column': 'date',
#               'session_indexes': Int64Index([0, 24, 51, 64], dtype='int64'),
#               'winner_column': 'winner',
#               'loser_column': 'loser',
#               'action_column': 'action',
#               'elo_counted_actions_string': "['f', 'm', 'c']",
#               'elo_counted_actions_list': ['f', 'm', 'c'],
#               'ties_column': None,
#               'columns_to_keep_string': '',
#               'columns_to_keep_list': ['4',
#                '8',
#                'action',
#                'date',
#                'length of observation',
#                'notes',
#                'observer',
#                'session_number',
#                'session_number_difference'],
#               'index_to_elo_score_and_meta_data': defaultdict(dict,
#                           {0: {'total_match_number': 1,
#                             'subject_id': 8,
#                             'agent_id': 4.0,
#                             'original_elo_score': 1000,
#                             'updated_elo_score': 1010.0,
#                             'win_draw_loss': 1,
#                             '4': -1.0,
#                             '8': 1.0,
#                             'action': 'm',
#                             'date': NaT,
#                             'length of observation': nan,
#                             'notes': nan,
#                             'observer': nan,
#                             'session_number': 2.0,
#                             'session_number_difference': nan},
#                            1: {'total_match_number': 1,
#                             'subject_id': 4.0,
#                             'agent_id': 8,
#                             'original_elo_score': 1000,
#                             'updated_elo_score': 990.0,
#                             'win_draw_loss': 0,
#                             '4': -1.0,
#                             '8': 1.0,
#                             'action': 'm',
#                             'date': NaT,
#                             'length of observation': nan,
#                             'notes': nan,
#                             'observer': nan,
#                             'session_number': 2.0,
#                             'session_number_difference': nan},
#                            2: {'total_match_number': 2,
#                             'subject_id': 8,
#                             'agent_id': 4.0,
#                             'original_elo_score': 1010.0,
#                             'updated_elo_score': 1019.4,
#                             'win_draw_loss': 1,
#                             '4': -1.0,
#                             '8': 1.0,
#                             'action': 'c',
#                             'date': NaT,
#                             'length of observation': nan,
#                             'notes': nan,
#                             'observer': nan,
#                             'session_number': 3.0,
#                             'session_number_difference': 1.0},
#                            3: {'total_match_number': 2,
#                             'subject_id': 4.0,
#                             'agent_id': 8,
#                             'original_elo_score': 990.0,
#                             'updated_elo_score': 980.6,
#                             'win_draw_loss': 0,
#                             '4': -1.0,
#                             '8': 1.0,
#                             'action': 'c',
#                             'date': NaT,
#                             'length of observation': nan,
#                             'notes': nan,
#                             'observer': nan,
#                             'session_number': 3.0,
#                             'session_number_difference': 1.0}}),
#               'elo_score_dataframe':    total_match_number  subject_id  agent_id  original_elo_score  \
#               0                   1         8.0       4.0              1000.0
#               1                   1         4.0       8.0              1000.0
#               2                   2         8.0       4.0              1010.0
#               3                   2         4.0       8.0               990.0
#
#                  updated_elo_score  win_draw_loss    4    8 action date  \
#               0             1010.0              1 -1.0  1.0      m  NaT
#               1              990.0              0 -1.0  1.0      m  NaT
#               2             1019.4              1 -1.0  1.0      c  NaT
#               3              980.6              0 -1.0  1.0      c  NaT
#
#                  length of observation  notes  observer  session_number  \
#               0                    NaN    NaN       NaN             2.0
#               1                    NaN    NaN       NaN             2.0
#               2                    NaN    NaN       NaN             3.0
#               3                    NaN    NaN       NaN             3.0
#
#                  session_number_difference    cage processed_cage_number  \
#               0                        NaN  Cage 4                     4
#               1                        NaN  Cage 4                     4
#               2                        1.0  Cage 4                     4
#               3                        1.0  Cage 4                     4
#
#                        experiment_type
#               0  home_cage_observation
#               1  home_cage_observation
#               2  home_cage_observation
#               3  home_cage_observation  ,
#               'cage_column': 'cage',
#               'cage_string_to_number': defaultdict(dict, {'Cage 4': '4'})}})

# %%
# Getting the highest and lowest ELO score for cutoffs of the Y-axis
max_elo_score = all_sheet_elo_scord_dataframe_combined["updated_elo_score"].max()
min_elo_score = all_sheet_elo_scord_dataframe_combined["updated_elo_score"].min()

# Making a plot for each sheet
for key, value in sheet_name_to_everything.items():
    plt.rcParams["figure.figsize"] = (13.5,7.5)
    print(key)
    elo_score_dataframe = value["elo_score_dataframe"]
    fig, ax = plt.subplots()        
        
    # Drawing vertical lines that represent when each session begins
    # Based on when a row has a different session than the previous row
    for index, row in elo_score_dataframe[elo_score_dataframe['session_number_difference'] != 0.0].iterrows():
        # Offsetting by 0.5 to avoid drawing the line on the dot
        plt.vlines(x=[row["total_match_number"] - 0.5], ymin=min_elo_score-50, ymax=max_elo_score+50, colors='black', linestyle='dashed')

    # Drawing a line for each subject
    for subject in sorted(elo_score_dataframe["subject_id"].unique()):
        # Getting all the rows with the current subject
        subject_dataframe = elo_score_dataframe[elo_score_dataframe["subject_id"] == subject]
        # Making the current match number the X-Axis
        plt.plot(subject_dataframe["total_match_number"], subject_dataframe["updated_elo_score"], '-o', label=subject)

    # Labeling the X/Y Axis and the title
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Elo Score")
    ax.set_title("Elo Score for {}: {}".format(string.capwords(" ".join(protocol_name.split("_"))), key))
    # To show the legend
    ax.legend()
    plt.xticks(rotation=90)
    plt.ylim(min_elo_score-50, max_elo_score+50) 
    # Saving the plot
    file_name = "{}_elo_score_{}_date_{}_{}.png".format(protocol_name, key, earliest_date, latest_date)
    plt.savefig(os.path.join(plot_output_directory, file_name))
    # Showing the plots
    plt.show()
# Out:
# Cage 1
# Cage 2
# Cage 3
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/Projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/Projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'session_number_difference'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [91], in <cell line: 6>()
#      10 fig, ax = plt.subplots()
#      12 # Drawing vertical lines that represent when each session begins
#      13 # Based on when a row has a different session than the previous row
# ---> 14 for index, row in elo_score_dataframe[elo_score_dataframe['session_number_difference'] != 0.0].iterrows():
#      15     # Offsetting by 0.5 to avoid drawing the line on the dot
#      16     plt.vlines(x=[row["total_match_number"] - 0.5], ymin=min_elo_score-50, ymax=max_elo_score+50, colors='black', linestyle='dashed')
#      18 # Drawing a line for each subject
#
# File ~/Projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/Projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'session_number_difference'

# %%
all_sheet_elo_scord_dataframe_combined[all_sheet_elo_scord_dataframe_combined["processed_cage_number"] == "4"]
# Out:
#    total_match_number  subject_id  agent_id  original_elo_score  \
# 0                 1.0         8.0       4.0              1000.0
# 1                 1.0         4.0       8.0              1000.0
# 2                 2.0         8.0       4.0              1010.0
# 3                 2.0         4.0       8.0               990.0
#
#    updated_elo_score  win_draw_loss   1   5 action date  ... observer  \
# 0             1010.0            1.0 NaN NaN      m  NaT  ...      NaN
# 1              990.0            0.0 NaN NaN      m  NaT  ...      NaN
# 2             1019.4            1.0 NaN NaN      c  NaT  ...      NaN
# 3              980.6            0.0 NaN NaN      c  NaT  ...      NaN
#
#   session_number session_number_difference    cage  processed_cage_number  \
# 0            2.0                       NaN  Cage 4                      4
# 1            2.0                       NaN  Cage 4                      4
# 2            3.0                       1.0  Cage 4                      4
# 3            3.0                       1.0  Cage 4                      4
#
#          experiment_type   2   6    4    8
# 0  home_cage_observation NaN NaN -1.0  1.0
# 1  home_cage_observation NaN NaN -1.0  1.0
# 2  home_cage_observation NaN NaN -1.0  1.0
# 3  home_cage_observation NaN NaN -1.0  1.0
#
# [4 rows x 22 columns]

# %% [markdown]
# # Saving the Dataframes

# %%
elo_score_spreadsheet_output_directory = "./proc/elo_score_spread_sheets/{}_elo_score/cage_{}_date_{}_{}".format(protocol_name, all_cages_string, earliest_date, latest_date)

# %%
elo_score_spreadsheet_output_directory

# %%
os.makedirs(elo_score_spreadsheet_output_directory, exist_ok=True)

# %%
file_name = "{}_elo_score_history_cages_{}_date_{}_{}.csv".format(protocol_name, all_cages_string, earliest_date, latest_date)
all_sheet_elo_scord_dataframe_combined.to_csv(os.path.join(elo_score_spreadsheet_output_directory, file_name))

# %%
file_name = "{}_final_elo_score_cages_{}_date_{}_{}.csv".format(protocol_name, all_cages_string, earliest_date, latest_date)
id_to_final_elo_score_dataframe.to_csv(os.path.join(elo_score_spreadsheet_output_directory, file_name))

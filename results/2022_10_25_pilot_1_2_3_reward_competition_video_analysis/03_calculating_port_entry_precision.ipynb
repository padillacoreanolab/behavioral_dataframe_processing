# %% [markdown]
# # MED-PC Data Processing Notebook

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
from medpc2excel.medpc_read import medpc_read

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import extract.metadata
import processing.tone
import processing.port

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# # Loading in Recording and Metadata from Previous Notebook

# %% [markdown]
# # NOTE: If you changed the directory of where the MED-PC recording dataframes, then you must change the directories in the following paths

# %% [markdown]
# - This will get all the files in each specified path

# %%
concatted_medpc_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/MEDPC_recording_cage_*.csv")
metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/metadata_cage_*.csv")
recording_and_metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/recording_metadata_cage_*.csv")

# %% [markdown]
# # NOTE: If there is more than one MED-PC recording dataframes, then you must manually change the path in the `pd.read_csv()` for the corresponding variables. Verify if this is the correct file that you want to use

# %%
metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/metadata_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
concatted_medpc_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/MEDPC_recording_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
recording_and_metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/recording_metadata_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
metadata_df = pd.read_csv(metadata_files[0], index_col=0)
concatted_medpc_df = pd.read_csv(concatted_medpc_files[0], index_col=0)
recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)

# %% [markdown]
# - The Dataframe the contains the metadata(columns) of each recording file(rows)
#     - We will mostly use this to get the cage number for each subject

# %%
metadata_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-21_12h24m_Subject 0.txt   07/21/22  07/21/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 3  C:\MED-PC\Data\2022-07-20_08h09m_Subject 1.txt   07/20/22  07/20/22
# 4  C:\MED-PC\Data\2022-07-21_08h50m_Subject 1.txt   07/21/22  07/21/22
#
#    Subject             Experiment   Group  Box Start Time  End Time  \
# 0        0                      0       0    1   12:24:06  12:35:30
# 1        1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  09:50:24
# 2        1  C57_vs_CD1_Comparison  Cage 1    2   16:39:59  09:52:50
# 3        1  C57_vs_CD1_comparison  Cage 1    3   08:09:22  09:27:22
# 4        1  C57_vs_CD1_comparison  Cage 1    4   08:50:56  09:59:08
#
#                    MSN                        file_name  cage  \
# 0             pumptest  2022-07-21_12h24m_Subject 0.txt     0
# 1  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 2  C57_reward_training  2022-07-18_16h39m_Subject 1.txt     1
# 3  C57_reward_training  2022-07-20_08h09m_Subject 1.txt     1
# 4  C57_reward_training  2022-07-21_08h50m_Subject 1.txt     1
#
#    cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0  cage_0_subject_0          2022-07-21        20220721        2022-07-21
# 1  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 2  cage_1_subject_1          2022-07-18        20220718        2022-07-19
# 3  cage_1_subject_1          2022-07-20        20220720        2022-07-20
# 4  cage_1_subject_1          2022-07-21        20220721        2022-07-21
#
#    end_date_int
# 0      20220721
# 1      20220718
# 2      20220719
# 3      20220720
# 4      20220721

# %% [markdown]
# - The Dataframe the contains the recording data for all the files.
#     - The 1st row is the first data entries for each type of data(with the type being specified by the column label). This does not mean that all these are related or occured for the same trial. i.e. There can be many port entries and exits for a subject before and after a tone is played.
#     - Each recording session will usually have a few thousand rows(although, most of of the columns will probably be blank by the end). And then after the last row of one session, the next row will be the next session with a different `file_path`

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          6.22           64.0      399.0           0.0              60.01
# 1          6.28          144.0      399.0           0.0             140.01
# 2          6.38          234.0      399.0           0.0             230.01
# 3          6.44          314.0      399.0           0.0             310.01
# 4          6.64          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         6.26        1.0                                    44.0
# 1         6.36        1.0                                     4.0
# 2         6.41        1.0                                    34.0
# 3         6.52        1.0                                    54.0
# 4         6.69        1.0                                     9.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    36.0
# 1                                    38.0
# 2                                    39.0
# 3                                    40.0
# 4                                    42.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  12.0                           50.0
# 1                                  12.0                           50.0
# 2                                  12.0                           50.0
# 3                                  12.0                           51.0
# 4                                  12.0                           51.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           35.0                         12.0  20220722
# 1                           35.0                         12.0  20220722
# 2                           35.0                         12.0  20220722
# 3                           35.0                         12.0  20220722
# 4                           35.0                         12.0  20220722
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...

# %% [markdown]
# - This dataframe combines the recording data and metadata dataframes. This is done by using the subject ID as a common column to merge together off of.

# %%
recording_and_metadata_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [markdown]
# # Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %%
all_subjects = sorted(recording_and_metadata_df["cage_and_subject"].unique())

# %%
all_subjects
# Out:
# ['cage_1_subject_1',
#  'cage_1_subject_2',
#  'cage_1_subject_3',
#  'cage_1_subject_4',
#  'cage_2_subject_1',
#  'cage_2_subject_2',
#  'cage_2_subject_3',
#  'cage_2_subject_4',
#  'cage_3_subject_1',
#  'cage_3_subject_2',
#  'cage_3_subject_3',
#  'cage_3_subject_4',
#  'cage_4_subject_1',
#  'cage_4_subject_2',
#  'cage_4_subject_3',
#  'cage_4_subject_4',
#  'cage_5_subject_1',
#  'cage_5_subject_2',
#  'cage_5_subject_3',
#  'cage_5_subject_4',
#  'cage_6_subject_1',
#  'cage_6_subject_2',
#  'cage_6_subject_3',
#  'cage_6_subject_4']

# %% [markdown]
# - List of all the cage numbers

# %%
all_cages = sorted(recording_and_metadata_df["cage"].unique())

# %%
all_cages
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# - List of all the dates

# %%
all_dates = sorted(recording_and_metadata_df["end_date_int"].unique())

# %%
all_dates
# Out:
# [20220718, 20220719, 20220720, 20220721, 20220722, 20220723, 20220724]

# %% [markdown]
# # NOTE: Follow directions below if you want to change which cages or dates to plot`

# %% [markdown]
# - You must change the cell below by clicking on the cell and then pressing the `esc` key. Then press the `Y` button on your keyboard. If you want to switch it back do the same but press the `R` button instead. This switches it from a cell that is run as if it's code, or back to a cell where it's just treated as text
# - Then from above, copy the numbers that you want to use for the cage numbers and the dates

# %% [markdown]
# # TODO: Turn this into trial number and add a default that uses them all

# %% [raw]
# all_cages = [1]
# all_dates = [20220508, 20220509, 20220510, 20220511, 20220512]

# %% [raw]
# recording_and_metadata_df = recording_and_metadata_df[recording_and_metadata_df["cage"].isin(all_cages) & recording_and_metadata_df["date"].isin(all_dates)]

# %% [markdown]
# ## Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %% [raw]
# recording_and_metadata_df[pd.isna(recording_and_metadata_df["cage"])]

# %% [markdown]
# - Dropping the NaN values so we can get the cage numbers

# %%
recording_and_metadata_df = recording_and_metadata_df.dropna(subset=["cage"])

# %%
# removing blank spaces
cage_numbers = [str(int(number)) for number in all_cages if number is not np.nan]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4_5_6'

# %%
recording_and_metadata_df["end_date_int"]
# Out:
# 0         20220718
# 1         20220718
# 2         20220718
# 3         20220718
# 4         20220718
#             ...
# 426071    20220724
# 426072    20220724
# 426073    20220724
# 426074    20220724
# 426075    20220724
# Name: end_date_int, Length: 426076, dtype: int64

# %%
# Getting the first and last recording date to get a range
earliest_date = recording_and_metadata_df["end_date_int"].min()
latest_date = recording_and_metadata_df["end_date_int"].max()

# %%
earliest_date
# Out:
# 20220718

# %%
latest_date
# Out:
# 20220724

# %% [markdown]
# # Getting the Probability that the Mice Is Inside the Port

# %% [markdown]
# - Port entry precision is calculated by finding the number of trials in one recording session that a subject is in the port entry. This is done by divding all of the time of the session into 10ms increments. And then seeing how many times a subject is in that port for a given 10 ms increment for all the sessions.
#     - MED-PC records only in 10ms intervals(the smallest that it can), so a subject is either in the port or not. It is binary.
#     - For example, we may be interested in what's happening 5 seconds after the tone plays. We would look at all the recordings that happened between 5 seconds to 5 seconds and 10ms after the tone for all session. If there was 10 total sessions in one trial and the subject was in the port 4 times during the 5s to 5s 10ms interval, then the probability is 4/10.

# %% [markdown]
# ## 1. Getting All the Time Intervals Between the Port Entry and Port Exit Times

# %% [markdown]
# - We will do an example with just one recording session

# %%
recording_and_metadata_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %%
example_med_pc_file = recording_and_metadata_df["file_name"].iloc[0]

# %%
example_med_pc_df = recording_and_metadata_df[recording_and_metadata_df["file_name"] == example_med_pc_file]

# %%
example_med_pc_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 1.1 Processing the Dataframe to remove all rows with NaNs

# %% [markdown]
# - Our first goal is to get all the port entry and exit times
# - To do this, we must remove all extraneous rows that have NaNs for the port entry and exit times

# %%
example_med_pc_df = example_med_pc_df.dropna(subset=("(P)Portentry", "(N)Portexit"))

# %%
example_med_pc_df
# Out:
#     trial_number                                              index  \
# 0              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 5              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 6              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 7              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 8              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 9              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 10             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 11             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 12             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 13             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 14             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 15             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 16             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 17             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 18             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 19             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 20             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 21             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 22             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 23             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 24             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 25             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 26             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 27             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 28             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 29             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 30             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 31             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 32             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 33             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 34             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 35             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 36             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 37             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 38             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 39             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 40             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 41             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 42             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 43             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 44             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 45             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 5   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 6   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 7   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 8   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 9   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 10  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 11  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 12  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 13  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 14  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 15  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 16  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 17  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 18  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 19  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 20  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 21  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 22  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 23  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 24  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 25  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 26  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 27  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 28  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 29  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 30  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 31  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 32  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 33  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 34  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 35  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 36  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 37  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 38  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 39  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 40  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 41  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 42  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 43  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 44  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 45  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#     Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 5         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 6         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 7         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 8         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 9         1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 10        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 11        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 12        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 13        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 14        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 15        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 16        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 17        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 18        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 19        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 20        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 21        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 22        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 23        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 24        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 25        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 26        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 27        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 28        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 29        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 30        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 31        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 32        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 33        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 34        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 35        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 36        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 37        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 38        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 39        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 40        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 41        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 42        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 43        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 44        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 45        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
#
#    (G)controlled_stimulus_secondscomputer  \
# 0                                    24.0
# 1                                    44.0
# 2                                    14.0
# 3                                    34.0
# 4                                    49.0
# 5                                    29.0
# 6                                     4.0
# 7                                    34.0
# 8                                    54.0
# 9                                    24.0
# 10                                    4.0
# 11                                   34.0
# 12                                   34.0
# 13                                    4.0
# 14                                   29.0
# 15                                   59.0
# 16                                   34.0
# 17                                   34.0
# 18                                   54.0
# 19                                   29.0
# 20                                   49.0
# 21                                   19.0
# 22                                   39.0
# 23                                   54.0
# 24                                   34.0
# 25                                    9.0
# 26                                   39.0
# 27                                   59.0
# 28                                   29.0
# 29                                    9.0
# 30                                   39.0
# 31                                   39.0
# 32                                    9.0
# 33                                   34.0
# 34                                    4.0
# 35                                   39.0
# 36                                    9.0
# 37                                   29.0
# 38                                   59.0
# 39                                    0.0
# 40                                    0.0
# 41                                    0.0
# 42                                    0.0
# 43                                    0.0
# 44                                    0.0
# 45                                    0.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    50.0
# 1                                    51.0
# 2                                    53.0
# 3                                    54.0
# 4                                    55.0
# 5                                    57.0
# 6                                    59.0
# 7                                     0.0
# 8                                     1.0
# 9                                     3.0
# 10                                    5.0
# 11                                    6.0
# 12                                    8.0
# 13                                   10.0
# 14                                   11.0
# 15                                   12.0
# 16                                   14.0
# 17                                   16.0
# 18                                   17.0
# 19                                   19.0
# 20                                   20.0
# 21                                   22.0
# 22                                   23.0
# 23                                   24.0
# 24                                   26.0
# 25                                   28.0
# 26                                   29.0
# 27                                   30.0
# 28                                   32.0
# 29                                   34.0
# 30                                   35.0
# 31                                   37.0
# 32                                   39.0
# 33                                   40.0
# 34                                   42.0
# 35                                   43.0
# 36                                   45.0
# 37                                   46.0
# 38                                   47.0
# 39                                    0.0
# 40                                    0.0
# 41                                    0.0
# 42                                    0.0
# 43                                    0.0
# 44                                    0.0
# 45                                    0.0
#
#     (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                    8.0                          47.0
# 1                                    8.0                          48.0
# 2                                    8.0                          11.0
# 3                                    8.0                          26.0
# 4                                    8.0                          27.0
# 5                                    8.0                          27.0
# 6                                    8.0                          27.0
# 7                                    9.0                          29.0
# 8                                    9.0                          30.0
# 9                                    9.0                          48.0
# 10                                   9.0                          49.0
# 11                                   9.0                          37.0
# 12                                   9.0                          37.0
# 13                                   9.0                          52.0
# 14                                   9.0                          16.0
# 15                                   9.0                          11.0
# 16                                   9.0                          35.0
# 17                                   9.0                          23.0
# 18                                   9.0                          23.0
# 19                                   9.0                          34.0
# 20                                   9.0                          14.0
# 21                                   9.0                           6.0
# 22                                   9.0                           7.0
# 23                                   9.0                          49.0
# 24                                   9.0                          49.0
# 25                                   9.0                          50.0
# 26                                   9.0                          52.0
# 27                                   9.0                          53.0
# 28                                   9.0                          53.0
# 29                                   9.0                          20.0
# 30                                   9.0                          18.0
# 31                                   9.0                          18.0
# 32                                   9.0                          21.0
# 33                                   9.0                          27.0
# 34                                   9.0                          27.0
# 35                                   9.0                          28.0
# 36                                   9.0                          28.0
# 37                                   9.0                          29.0
# 38                                   9.0                          29.0
# 39                                   0.0                          30.0
# 40                                   0.0                          31.0
# 41                                   0.0                          31.0
# 42                                   0.0                          35.0
# 43                                   0.0                          35.0
# 44                                   0.0                          39.0
# 45                                   0.0                          40.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           50.0                          8.0  20220718
# 1                           50.0                          8.0  20220718
# 2                           53.0                          8.0  20220718
# 3                           57.0                          8.0  20220718
# 4                           57.0                          8.0  20220718
# 5                           57.0                          8.0  20220718
# 6                           57.0                          8.0  20220718
# 7                           57.0                          8.0  20220718
# 8                           57.0                          8.0  20220718
# 9                           59.0                          8.0  20220718
# 10                          59.0                          8.0  20220718
# 11                           2.0                          9.0  20220718
# 12                           2.0                          9.0  20220718
# 13                           4.0                          9.0  20220718
# 14                          10.0                          9.0  20220718
# 15                          12.0                          9.0  20220718
# 16                          13.0                          9.0  20220718
# 17                          16.0                          9.0  20220718
# 18                          19.0                          9.0  20220718
# 19                          21.0                          9.0  20220718
# 20                          30.0                          9.0  20220718
# 21                          31.0                          9.0  20220718
# 22                          31.0                          9.0  20220718
# 23                          41.0                          9.0  20220718
# 24                          41.0                          9.0  20220718
# 25                          41.0                          9.0  20220718
# 26                          41.0                          9.0  20220718
# 27                          41.0                          9.0  20220718
# 28                          41.0                          9.0  20220718
# 29                          42.0                          9.0  20220718
# 30                          47.0                          9.0  20220718
# 31                          47.0                          9.0  20220718
# 32                          47.0                          9.0  20220718
# 33                          49.0                          9.0  20220718
# 34                          49.0                          9.0  20220718
# 35                          49.0                          9.0  20220718
# 36                          49.0                          9.0  20220718
# 37                          49.0                          9.0  20220718
# 38                          49.0                          9.0  20220718
# 39                          49.0                          9.0  20220718
# 40                          49.0                          9.0  20220718
# 41                          49.0                          9.0  20220718
# 42                          49.0                          9.0  20220718
# 43                          49.0                          9.0  20220718
# 44                          49.0                          9.0  20220718
# 45                          49.0                          9.0  20220718
#
#     subject                                          file_path
# 0         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 5         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 6         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 7         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 8         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 9         1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 10        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 11        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 12        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 13        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 14        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 15        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 16        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 17        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 18        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 19        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 20        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 21        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 22        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 23        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 24        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 25        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 26        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 27        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 28        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 29        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 30        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 31        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 32        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 33        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 34        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 35        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 36        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 37        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 38        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 39        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 40        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 41        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 42        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 43        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 44        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 45        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [46 rows x 35 columns]

# %% [markdown]
# ## 1.2 Converting All the Port Entry and Port Exit Times in to Whole Numbers

# %% [markdown]
# - We will turn all Port entry and exit times into whole numbers. This needs to be done so that we can use it as an index in a list of `True`/`False` for each 10ms increment.
#     - This will be done with port entry/exit and the tone playing time

# %%
example_med_pc_df["port_entry_scaled"] = example_med_pc_df["(P)Portentry"].apply(lambda x: processing.port.scale_time_to_whole_number(x))
example_med_pc_df["port_exit_scaled"] = example_med_pc_df["(N)Portexit"].apply(lambda x: processing.port.scale_time_to_whole_number(x))
example_med_pc_df["tone_start_scaled"] = example_med_pc_df["(S)CSpresentation"].apply(lambda x: processing.port.scale_time_to_whole_number(x))

# %%
example_med_pc_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ...  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...
#
#   (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                  8.0                          47.0
# 1                                  8.0                          48.0
# 2                                  8.0                          11.0
# 3                                  8.0                          26.0
# 4                                  8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#   subject                                          file_path  \
# 0       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#   port_entry_scaled  port_exit_scaled  tone_start_scaled
# 0              8261              8265               6001
# 1              8333              8355              14001
# 2             22655             22661              23001
# 3             48154             48160              31001
# 4             48236             48289              38501
#
# [5 rows x 38 columns]

# %% [markdown]
# ## 1.3 Getting All the Numbers Between the Port Entry and Exit Times

# %% [markdown]
# - We are creating an array of 10ms intervals as whole numbers that are between the port entry and exit time
#     - For this example, the first would be between 7136 and 7142. And then between 7177 and 8439

# %%
example_port_entry_times = processing.port.get_all_port_entry_increments(port_entry_scaled=example_med_pc_df["port_entry_scaled"], port_exit_scaled=example_med_pc_df["port_exit_scaled"])

# %%
example_port_entry_times[:10]
# Out:
# array([8261, 8262, 8263, 8264, 8265, 8333, 8334, 8335, 8336, 8337])

# %% [markdown]
# ## 1.4 Getting all the numbers from 0 to the time of the last tone plus 2000(or 20 seconds)

# %% [markdown]
# - Creating a list of numbers from 0 to the time of the last tone. This will be used to get all the numbers that are 20 seconds before and after a tone being played
# - We will first get all the times that the tones played

# %%
example_valid_tone_times = processing.tone.get_valid_tones(tone_pd_series=example_med_pc_df["tone_start_scaled"]).astype(int)

# %%
example_valid_tone_times[:10]
# Out:
# 0     6001
# 1    14001
# 2    23001
# 3    31001
# 4    38501
# 5    48501
# 6    58001
# 7    67001
# 8    75001
# 9    84001
# Name: tone_start_scaled, dtype: int64

# %% [markdown]
# - Then getting all the numbers from 0 to the last tone time. We will add 2000(or 20 seconds) to the last tone time

# %%
# Using the last tone and adding 2000(or 20 seconds to it)
example_experiment_interval = np.arange(example_valid_tone_times.max() + 2001)

# %%
example_experiment_interval
# Out:
# array([     0,      1,      2, ..., 353499, 353500, 353501])

# %% [markdown]
# # 2. Make a set and see which numbers are in that set

# %% [markdown]
# ### 2.2 Getting a mask of all the numbers that are within a port entry and port exit time

# %%
example_port_entry_mask = np.isin(example_experiment_interval, example_port_entry_times)

# %%
example_port_entry_mask
# Out:
# array([False, False, False, ..., False, False, False])

# %%
example_experiment_interval[np.isin(example_experiment_interval, example_port_entry_times)]
# Out:
# array([  8261,   8262,   8263,   8264,   8265,   8333,   8334,   8335,
#          8336,   8337,   8338,   8339,   8340,   8341,   8342,   8343,
#          8344,   8345,   8346,   8347,   8348,   8349,   8350,   8351,
#          8352,   8353,   8354,   8355,  22655,  22656,  22657,  22658,
#         22659,  22660,  22661,  48154,  48155,  48156,  48157,  48158,
#         48159,  48160,  48236,  48237,  48238,  48239,  48240,  48241,
#         48242,  48243,  48244,  48245,  48246,  48247,  48248,  48249,
#         48250,  48251,  48252,  48253,  48254,  48255,  48256,  48257,
#         48258,  48259,  48260,  48261,  48262,  48263,  48264,  48265,
#         48266,  48267,  48268,  48269,  48270,  48271,  48272,  48273,
#         48274,  48275,  48276,  48277,  48278,  48279,  48280,  48281,
#         48282,  48283,  48284,  48285,  48286,  48287,  48288,  48289,
#         48291,  48292,  48293,  48294,  48295,  48296,  48297,  48298,
#         48299,  48300,  48301,  48302,  48303,  48304,  48305,  48306,
#         48307,  48308,  48309,  48311,  48312,  48313,  48314,  48315,
#         48316,  48317,  48318,  48319,  48320,  48321,  48521,  48522,
#         48523,  48524,  48525,  48526,  48527,  48528,  48529,  48530,
#         48531,  48606,  48607,  48608,  48609,  48610,  48611,  48612,
#         48613,  62423,  62424,  62425,  62426,  62427,  62428,  62429,
#         62430,  62457,  62458,  62459,  62460,  62461,  62462,  62463,
#         62464,  62465,  62466,  62467,  62468,  62469,  62470,  62471,
#         62472,  62473,  62474,  62475,  62476,  62477,  62478,  79277,
#         79278,  79279,  79280,  79281,  79282,  79285,  79286,  79287,
#         79288,  79289,  79290,  79291,  79292,  92748,  92749,  92750,
#         92751,  92752,  92753,  92754,  92755,  92756,  92757,  92758,
#         92759,  92760,  92761,  92762,  92763, 125197, 125198, 125199,
#        125200, 125201, 125202, 136610, 136611, 136612, 136613, 136614,
#        136615, 136616, 136617, 136618, 136619, 136620, 136621, 136622,
#        136623, 136624, 145097, 145098, 145099, 145100, 161917, 161918,
#        161919, 161920, 161921, 161922, 161923, 161924, 161925, 161926,
#        161927, 161928, 161929, 161930, 161931, 161932, 161933, 161934,
#        161935, 161936, 161937, 161938, 161939, 161940, 161941, 161942,
#        161943, 161944, 161945, 161946, 161947, 161948, 161949, 161950,
#        161951, 161952, 179882, 179883, 179884, 179885, 192934, 192935,
#        192936, 192937, 192938, 192939, 192940, 245032, 245033, 245034,
#        245035, 245036, 245037, 245038, 245039, 245040, 245041, 245042,
#        245043, 245044, 250165, 250166, 250167, 250168, 250169, 250170,
#        250171, 250172, 250173, 250174, 250175, 250176, 250177, 250178,
#        250179, 250180, 250181, 250182, 250183, 250184, 250185, 250186,
#        250187, 250188, 250189, 250190, 250191, 250192, 250193, 250194,
#        250195, 250196, 250197, 250198, 250199, 250200, 250201, 250202,
#        250203, 250204, 250205, 250300, 250301, 250302, 250303, 250304,
#        250305, 250306, 250307, 250308, 250309, 250310, 250311, 250312,
#        250313, 250314, 250315, 250316, 250317, 250318, 250319, 250320,
#        250321, 250322, 250323, 314452, 314453, 314454, 314455, 314456,
#        314457, 314458, 314459, 314460, 314466, 314467, 314468, 314469,
#        314517, 314518, 314519, 314520, 314521, 314522, 314523, 314524,
#        314525, 314526, 314527, 314528, 314529, 314801, 314802, 314803,
#        314804, 314805, 314806, 314822, 314823, 314824, 314825, 314833,
#        314834, 314835, 314836, 314837, 314838, 317604, 317605, 317606,
#        317607, 317608, 317609, 317610, 317611, 317612, 317613, 317614,
#        317615, 317616, 317617, 317618, 317619, 317620, 317621, 317622,
#        317623, 317624, 317625, 317626, 317627, 317628, 317629, 317630,
#        317631, 317632, 317633, 317634, 317635, 317636, 317637, 317638,
#        317639, 317640, 317641, 317642, 317643, 317644, 317645, 317646,
#        317647, 317648, 317649, 317650, 317651, 317652, 317653, 317654,
#        317655, 317656, 317657, 317658, 317659, 317660, 317661, 317662,
#        317663, 317664, 317665, 317666, 317667, 317668, 317669, 317670,
#        317671, 317672, 317673, 317674, 317675, 317676, 317677, 317678,
#        317679, 317680, 317681, 317682, 317683, 317684, 317685, 317686,
#        317687, 317688, 317689, 317690, 317691, 317692, 317693, 317694,
#        317695, 347359, 347360, 347361, 347362, 347363, 347364, 347365,
#        347366, 347367, 347368, 347369, 347370, 347371, 347372, 347373,
#        347374, 347375, 347376, 347377, 347378, 347379, 347384, 347385,
#        347386, 347387, 347388, 347389, 347390, 347391, 347392, 347393,
#        347394, 347395, 347396, 347397, 347398, 347399, 347400, 347401,
#        347402, 347403, 347404, 347405, 347406, 347407, 347408, 347409,
#        347410, 347411, 347412, 347413, 347414, 347415, 347416, 347417,
#        347418, 347419, 347420, 347421, 347422, 347423, 347424, 347425,
#        347426, 347427, 347428, 347429, 347430, 347431, 347432, 347433,
#        347434, 347435, 347716, 347717, 347718, 347719, 347720, 347721,
#        347722, 347723, 347724, 347725, 347726, 347727, 347728, 347729,
#        347730, 347731, 347732, 347733, 347734, 347735, 347736, 347737,
#        347738, 347739, 347740, 347741, 347742, 347743, 347744, 347745,
#        347746, 347747])

# %% [markdown]
# # 2. Create a Mask that is "if a Subject is in the Port or Not for a Given Time Increment"

# %% [markdown]
# - A mask is how Numpy knows whether or not a value in a given index meets a criteria or not. For this, we will create a mask of values that in between all the port start and exit times
#     - For more information: https://jakevdp.github.io/PythonDataScienceHandbook/02.06-boolean-arrays-and-masks.html
# - First we will get the time that the last tone played and add 2000(or 20 seconds to it)

# %%
max_time = example_valid_tone_times.max() + 2001

# %%
max_time
# Out:
# 353502

# %% [markdown]
# - Now we will create the mask of whether or not a given time is between the port entry and exit times

# %%
example_experiment_interval, example_port_entry_mask = processing.port.get_inside_port_mask(max_time=max_time, inside_port_numbers=example_port_entry_times)

# %% [markdown]
# - This is all the numbers between the start of the recording session until the end of the last tone playing

# %%
example_experiment_interval
# Out:
# array([     1,      2,      3, ..., 353500, 353501, 353502])

# %% [markdown]
# - This is the mask of whether or not the subject is in the port or not. It seems like it is all False, but this is only because it's showing the beginning and the end of the recording session. So the subject is likely not in the port yet

# %%
example_port_entry_mask
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# - Although not needed, we can use the mask to get all the times that the subject was inside the port

# %%
example_experiment_interval[example_port_entry_mask]
# Out:
# array([  8261,   8262,   8263,   8264,   8265,   8333,   8334,   8335,
#          8336,   8337,   8338,   8339,   8340,   8341,   8342,   8343,
#          8344,   8345,   8346,   8347,   8348,   8349,   8350,   8351,
#          8352,   8353,   8354,   8355,  22655,  22656,  22657,  22658,
#         22659,  22660,  22661,  48154,  48155,  48156,  48157,  48158,
#         48159,  48160,  48236,  48237,  48238,  48239,  48240,  48241,
#         48242,  48243,  48244,  48245,  48246,  48247,  48248,  48249,
#         48250,  48251,  48252,  48253,  48254,  48255,  48256,  48257,
#         48258,  48259,  48260,  48261,  48262,  48263,  48264,  48265,
#         48266,  48267,  48268,  48269,  48270,  48271,  48272,  48273,
#         48274,  48275,  48276,  48277,  48278,  48279,  48280,  48281,
#         48282,  48283,  48284,  48285,  48286,  48287,  48288,  48289,
#         48291,  48292,  48293,  48294,  48295,  48296,  48297,  48298,
#         48299,  48300,  48301,  48302,  48303,  48304,  48305,  48306,
#         48307,  48308,  48309,  48311,  48312,  48313,  48314,  48315,
#         48316,  48317,  48318,  48319,  48320,  48321,  48521,  48522,
#         48523,  48524,  48525,  48526,  48527,  48528,  48529,  48530,
#         48531,  48606,  48607,  48608,  48609,  48610,  48611,  48612,
#         48613,  62423,  62424,  62425,  62426,  62427,  62428,  62429,
#         62430,  62457,  62458,  62459,  62460,  62461,  62462,  62463,
#         62464,  62465,  62466,  62467,  62468,  62469,  62470,  62471,
#         62472,  62473,  62474,  62475,  62476,  62477,  62478,  79277,
#         79278,  79279,  79280,  79281,  79282,  79285,  79286,  79287,
#         79288,  79289,  79290,  79291,  79292,  92748,  92749,  92750,
#         92751,  92752,  92753,  92754,  92755,  92756,  92757,  92758,
#         92759,  92760,  92761,  92762,  92763, 125197, 125198, 125199,
#        125200, 125201, 125202, 136610, 136611, 136612, 136613, 136614,
#        136615, 136616, 136617, 136618, 136619, 136620, 136621, 136622,
#        136623, 136624, 145097, 145098, 145099, 145100, 161917, 161918,
#        161919, 161920, 161921, 161922, 161923, 161924, 161925, 161926,
#        161927, 161928, 161929, 161930, 161931, 161932, 161933, 161934,
#        161935, 161936, 161937, 161938, 161939, 161940, 161941, 161942,
#        161943, 161944, 161945, 161946, 161947, 161948, 161949, 161950,
#        161951, 161952, 179882, 179883, 179884, 179885, 192934, 192935,
#        192936, 192937, 192938, 192939, 192940, 245032, 245033, 245034,
#        245035, 245036, 245037, 245038, 245039, 245040, 245041, 245042,
#        245043, 245044, 250165, 250166, 250167, 250168, 250169, 250170,
#        250171, 250172, 250173, 250174, 250175, 250176, 250177, 250178,
#        250179, 250180, 250181, 250182, 250183, 250184, 250185, 250186,
#        250187, 250188, 250189, 250190, 250191, 250192, 250193, 250194,
#        250195, 250196, 250197, 250198, 250199, 250200, 250201, 250202,
#        250203, 250204, 250205, 250300, 250301, 250302, 250303, 250304,
#        250305, 250306, 250307, 250308, 250309, 250310, 250311, 250312,
#        250313, 250314, 250315, 250316, 250317, 250318, 250319, 250320,
#        250321, 250322, 250323, 314452, 314453, 314454, 314455, 314456,
#        314457, 314458, 314459, 314460, 314466, 314467, 314468, 314469,
#        314517, 314518, 314519, 314520, 314521, 314522, 314523, 314524,
#        314525, 314526, 314527, 314528, 314529, 314801, 314802, 314803,
#        314804, 314805, 314806, 314822, 314823, 314824, 314825, 314833,
#        314834, 314835, 314836, 314837, 314838, 317604, 317605, 317606,
#        317607, 317608, 317609, 317610, 317611, 317612, 317613, 317614,
#        317615, 317616, 317617, 317618, 317619, 317620, 317621, 317622,
#        317623, 317624, 317625, 317626, 317627, 317628, 317629, 317630,
#        317631, 317632, 317633, 317634, 317635, 317636, 317637, 317638,
#        317639, 317640, 317641, 317642, 317643, 317644, 317645, 317646,
#        317647, 317648, 317649, 317650, 317651, 317652, 317653, 317654,
#        317655, 317656, 317657, 317658, 317659, 317660, 317661, 317662,
#        317663, 317664, 317665, 317666, 317667, 317668, 317669, 317670,
#        317671, 317672, 317673, 317674, 317675, 317676, 317677, 317678,
#        317679, 317680, 317681, 317682, 317683, 317684, 317685, 317686,
#        317687, 317688, 317689, 317690, 317691, 317692, 317693, 317694,
#        317695, 347359, 347360, 347361, 347362, 347363, 347364, 347365,
#        347366, 347367, 347368, 347369, 347370, 347371, 347372, 347373,
#        347374, 347375, 347376, 347377, 347378, 347379, 347384, 347385,
#        347386, 347387, 347388, 347389, 347390, 347391, 347392, 347393,
#        347394, 347395, 347396, 347397, 347398, 347399, 347400, 347401,
#        347402, 347403, 347404, 347405, 347406, 347407, 347408, 347409,
#        347410, 347411, 347412, 347413, 347414, 347415, 347416, 347417,
#        347418, 347419, 347420, 347421, 347422, 347423, 347424, 347425,
#        347426, 347427, 347428, 347429, 347430, 347431, 347432, 347433,
#        347434, 347435, 347716, 347717, 347718, 347719, 347720, 347721,
#        347722, 347723, 347724, 347725, 347726, 347727, 347728, 347729,
#        347730, 347731, 347732, 347733, 347734, 347735, 347736, 347737,
#        347738, 347739, 347740, 347741, 347742, 347743, 347744, 347745,
#        347746, 347747])

# %% [markdown]
# ## 3. Find the Overlap between the Tone Times and the Port Entries

# %% [markdown]
# - Now we will use the mask to see when the subject was in the port for each session.

# %% [markdown]
# ### 3.1 Calculating the probability that the subject is in the port for each time increment between sessions

# %% [markdown]
# - We will first get the inside port mask for the time 20 seconds before and after each session

# %%
# Creating a dictionary for demonstration
tone_time_to_mask = defaultdict(dict)
# We will use a list in the end
example_all_tone_time_masks = []
for index, tone_start in example_valid_tone_times.iteritems():
    # Sometimes the tone start time can be a float
    tone_start_int = int(tone_start)
    example_all_tone_time_masks.append(example_port_entry_mask[tone_start_int - 2000: tone_start_int + 2000])
    tone_time_to_mask[tone_start_int] = example_port_entry_mask[tone_start_int - 2000: tone_start_int + 2000]
# Combining all the masks so that each row is 1 session
stacked_example_all_tone_time_masks = np.stack(example_all_tone_time_masks)

# %%
stacked_example_all_tone_time_masks
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
tone_time_to_mask
# Out:
# defaultdict(dict,
#             {6001: array([False, False, False, ..., False, False, False]),
#              14001: array([False, False, False, ..., False, False, False]),
#              23001: array([False, False, False, ..., False, False, False]),
#              31001: array([False, False, False, ..., False, False, False]),
#              38501: array([False, False, False, ..., False, False, False]),
#              48501: array([False, False, False, ..., False, False, False]),
#              58001: array([False, False, False, ..., False, False, False]),
#              67001: array([False, False, False, ..., False, False, False]),
#              75001: array([False, False, False, ..., False, False, False]),
#              84001: array([False, False, False, ..., False, False, False]),
#              94001: array([False, False, False, ..., False, False, False]),
#              103001: array([False, False, False, ..., False, False, False]),
#              115001: array([False, False, False, ..., False, False, False]),
#              124001: array([False, False, False, ..., False, False, False]),
#              132501: array([False, False, False, ..., False, False, False]),
#              141501: array([False, False, False, ..., False, False, False]),
#              151001: array([False, False, False, ..., False, False, False]),
#              163001: array([False, False, False, ..., False, False, False]),
#              171001: array([False, False, False, ..., False, False, False]),
#              180501: array([False, False, False, ..., False, False, False]),
#              188501: array([False, False, False, ..., False, False, False]),
#              197501: array([False, False, False, ..., False, False, False]),
#              205501: array([False, False, False, ..., False, False, False]),
#              213001: array([False, False, False, ..., False, False, False]),
#              223001: array([False, False, False, ..., False, False, False]),
#              232501: array([False, False, False, ..., False, False, False]),
#              241501: array([False, False, False, ..., False, False, False]),
#              249501: array([False, False, False, ..., False, False, False]),
#              258501: array([False, False, False, ..., False, False, False]),
#              268501: array([False, False, False, ..., False, False, False]),
#              277501: array([False, False, False, ..., False, False, False]),
#              289501: array([False, False, False, ..., False, False, False]),
#              298501: array([False, False, False, ..., False, False, False]),
#              307001: array([False, False, False, ..., False, False, False]),
#              316001: array([False, False, False, ..., False, False, False]),
#              325501: array([False, False, False, ..., False, False, False]),
#              334501: array([False, False, False, ..., False, False, False]),
#              342501: array([False, False, False, ..., False, False, False]),
#              351501: array([False, False, False, ..., False, False, False])})

# %% [markdown]
# - In Numpy, `True` objects have a value of 1, and `False` objects have a value of 0. So we can calculate the mean of the `True` and `False` and that will be the proportion that is `True`. Which will be the proportion that the subject is inside the port
#     - We will calculate the mean by column. So averaging all the same time increments for each session. For exampled, we are seeing the proportion that the subject is inside the port at 5 seconds to 5 seconds 10ms across all sessions

# %%
mean_example_all_tone_time_masks = stacked_example_all_tone_time_masks.mean(axis=0)

# %% [markdown]
# - Each value is the average for the given time increment for all sessions
#     - It starts out at -20 seconds to -19 seconds -990ms. Then it's -19 seconds -990ms to -19seconds to -980ms. Until we reach 19 seconds 990ms to 20 seconds after the tone.

# %%
mean_example_all_tone_time_masks
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
mean_example_all_tone_time_masks.shape
# Out:
# (4000,)

# %% [markdown]
# ## 3.2 Doing it with a function

# %%
processing.port.get_inside_port_probability_averages_for_all_increments(tone_times=example_valid_tone_times, inside_port_mask=example_port_entry_mask)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# ### 3.3 Plotting all the probailities

# %% [markdown]
# - We are going to plot the time before and after the tone plays as X, and the average probability that a subject is in the port for a given time increment as Y

# %%
plt.plot(np.linspace(-20,20,4000), mean_example_all_tone_time_masks)
plt.xlabel("Seconds from the start of the tone")
plt.ylabel("Probability Inside Port")
plt.title("Probability Inside Port for 10ms Increments 20 Seconds Before and After Tone")
# Out:
# Text(0.5, 1.0, 'Probability Inside Port for 10ms Increments 20 Seconds Before and After Tone')

# %% [markdown]
# # 4. Plotting for Multiple Training Sessions

# %% [markdown]
# ## 4.1 Checking Which Sessions Have Valid Tone Times

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          6.22           64.0      399.0           0.0              60.01
# 1          6.28          144.0      399.0           0.0             140.01
# 2          6.38          234.0      399.0           0.0             230.01
# 3          6.44          314.0      399.0           0.0             310.01
# 4          6.64          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         6.26        1.0                                    44.0
# 1         6.36        1.0                                     4.0
# 2         6.41        1.0                                    34.0
# 3         6.52        1.0                                    54.0
# 4         6.69        1.0                                     9.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    36.0
# 1                                    38.0
# 2                                    39.0
# 3                                    40.0
# 4                                    42.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  12.0                           50.0
# 1                                  12.0                           50.0
# 2                                  12.0                           50.0
# 3                                  12.0                           51.0
# 4                                  12.0                           51.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           35.0                         12.0  20220722
# 1                           35.0                         12.0  20220722
# 2                           35.0                         12.0  20220722
# 3                           35.0                         12.0  20220722
# 4                           35.0                         12.0  20220722
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...

# %% [markdown]
# - Getting all the files with valid tone times. Some files were for testing and do not have the times that the tones were played

# %%
valid_files = []
for file_name in recording_and_metadata_df["file_name"].unique():
    current_medpc_df = recording_and_metadata_df[recording_and_metadata_df["file_name"] == file_name]
    valid_tones = processing.tone.get_valid_tones(tone_pd_series= current_medpc_df["(S)CSpresentation"])

    if not valid_tones.empty:
        valid_files.append(file_name)
    else:
        print("Skipped {}".format(key))

# %%
valid_files[:5]
# Out:
# ['2022-07-18_08h24m_Subject 1.txt',
#  '2022-07-18_16h39m_Subject 1.txt',
#  '2022-07-20_08h09m_Subject 1.txt',
#  '2022-07-21_08h50m_Subject 1.txt',
#  '2022-07-22_09h00m_Subject 1.txt']

# %% [markdown]
# - Getting all rows that meet the criteria of being from a vile with valid tone times

# %%
valid_files_df = recording_and_metadata_df[recording_and_metadata_df["file_name"].isin(valid_files)]

# %%
valid_files_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %%
valid_files_df.tail()
# Out:
#         trial_number                                              index  \
# 426071             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                   File Start Date  End Date  \
# 426071  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426072  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426073  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426074  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426075  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
#
#         Subject             Experiment   Group  Box Start Time  ... (K)CStype  \
# 426071        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426072        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426073        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426074        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426075        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#         (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 426071                                   NaN                           0.0
# 426072                                   NaN                           0.0
# 426073                                   NaN                          40.0
# 426074                                   NaN                           0.0
# 426075                                   NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 426071                           NaN                          NaN  20220724
# 426072                           NaN                          NaN  20220724
# 426073                           NaN                          NaN  20220724
# 426074                           NaN                          NaN  20220724
# 426075                           NaN                          NaN  20220724
#
#         subject                                          file_path
# 426071        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 4.2 Going through Each Subject and Each Day to Get the Average Probability of All the Time Increments Across All Trials

# %% [markdown]
# - We will be doing what we did for all the subjects and dates now

# %%
subject_to_date_to_average_probability = defaultdict(dict)
# Going through each subject
for subject in recording_and_metadata_df["cage_and_subject"].unique():
    # Getting all the rows that are for one subject 
    one_subject_all_days = recording_and_metadata_df[recording_and_metadata_df["cage_and_subject"] == subject]
    
    # Going through each date of one subject
    for date in one_subject_all_days["trial_number"].unique():
        # Getting all the rows that correspond to the date
        one_day_df = one_subject_all_days[one_subject_all_days["trial_number"] == date].copy()
        ### Scaling all the dataframes
        one_day_df["port_entry_scaled"] = one_day_df["(P)Portentry"].apply(lambda x: processing.port.scale_time_to_whole_number(x))
        one_day_df["port_exit_scaled"] = one_day_df["(N)Portexit"].apply(lambda x: processing.port.scale_time_to_whole_number(x))
        one_day_df["tone_start_scaled"] = one_day_df["(S)CSpresentation"].apply(lambda x: processing.port.scale_time_to_whole_number(x))
        
        ### All the numbers of times inside port
        one_day_entry_times = processing.port.get_all_port_entry_increments(port_entry_scaled=one_day_df["port_entry_scaled"], port_exit_scaled=one_day_df["port_exit_scaled"])
        ### Getting all the valid tone times and the max tone time
        one_day_valid_tone_times = processing.tone.get_valid_tones(tone_pd_series=one_day_df["tone_start_scaled"]).astype(int)
        one_day_max_time = one_day_valid_tone_times.max() + 2001
        ### Getting a mask of all the times in the port
        one_day_experiment_interval, one_day_entry_mask = processing.port.get_inside_port_mask(max_time=one_day_max_time, inside_port_numbers=one_day_entry_times)
        ### Getting the average probability
        one_day_average_all_tone_time_masks = processing.port.get_inside_port_probability_averages_for_all_increments(tone_times=one_day_valid_tone_times, inside_port_mask=one_day_entry_mask)
        subject_to_date_to_average_probability[subject][date] = one_day_average_all_tone_time_masks

# %%
for key, value in subject_to_date_to_average_probability.items():
    print("Subject: {}".format(key))
    print("Date to probability inside port for each increment: {}".format(value))
    break
# Out:
# Subject: cage_1_subject_1
# Date to probability inside port for each increment: {1: array([0., 0., 0., ..., 0., 0., 0.]), 2: array([0., 0., 0., ..., 0., 0., 0.]), 3: array([0.1025641 , 0.1025641 , 0.1025641 , ..., 0.02564103, 0.02564103,
#        0.02564103]), 4: array([0.07692308, 0.07692308, 0.07692308, ..., 0.17948718, 0.17948718,
#        0.20512821]), 5: array([0.17948718, 0.17948718, 0.15384615, ..., 0.33333333, 0.35897436,
#        0.35897436]), 6: array([0.51282051, 0.51282051, 0.51282051, ..., 0.38461538, 0.38461538,
#        0.41025641]), 7: array([0.56410256, 0.56410256, 0.56410256, ..., 0.66666667, 0.64102564,
#        0.64102564])}

# %%
subject_to_date_to_average_probability[1]
# Out:
# {}

# %%
subject_to_cage = pd.Series(metadata_df["cage"].values.astype(int),index=metadata_df["cage_and_subject"].values).to_dict()

# %%
subject_to_cage
# Out:
# {'cage_0_subject_0': 0,
#  'cage_1_subject_1': 1,
#  'cage_1_subject_2': 1,
#  'cage_1_subject_3': 1,
#  'cage_1_subject_4': 1,
#  'cage_2_subject_1': 2,
#  'cage_2_subject_2': 2,
#  'cage_2_subject_3': 2,
#  'cage_2_subject_4': 2,
#  'cage_3_subject_1': 3,
#  'cage_3_subject_2': 3,
#  'cage_3_subject_3': 3,
#  'cage_3_subject_4': 3,
#  'cage_4_subject_1': 4,
#  'cage_4_subject_2': 4,
#  'cage_4_subject_3': 4,
#  'cage_4_subject_4': 4,
#  'cage_5_subject_1': 5,
#  'cage_5_subject_2': 5,
#  'cage_5_subject_3': 5,
#  'cage_5_subject_4': 5,
#  'cage_6_subject_1': 6,
#  'cage_6_subject_2': 6,
#  'cage_6_subject_3': 6,
#  'cage_6_subject_4': 6}

# %% [markdown]
# - Making directories for output

# %%
probability_inside_port_plots_output_directory = "./proc/plots/probability_inside_port/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
probability_inside_port_plots_output_directory
# Out:
# './proc/plots/probability_inside_port/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(probability_inside_port_plots_output_directory, exist_ok=True)

# %% [markdown]
# ## Plotting the probability that the subject is in the port for a given time increment before or after the tone

# %%
all_colors = ["k", "gray", "b", "m", "fuchsia", "c","g", "lime", "y", "darkorange", "r", "deeppink"]
for subject_id in recording_and_metadata_df["cage_and_subject"].unique():
    fig, ax = plt.subplots()
    cage = int(subject_to_cage[subject_id])
    ax.set_xlabel("Seconds from the start of the tone")
    ax.set_ylabel("Probability Inside Port")
    ax.set_title("Probability Inside Port Before/After Tone for Subject: {} in Cage {}".format(subject_id, cage))
    counter = 0

    for key in sorted(subject_to_date_to_average_probability[subject_id].keys()):
        ax.plot(np.linspace(-20,20,4000), subject_to_date_to_average_probability[subject_id][key], label="Trial {}".format(key), color=all_colors[counter])
        counter += 1
    handles, labels = ax.get_legend_handles_labels()
    labels, handles = zip(*sorted(zip(labels, handles), key=lambda t: t[0]))
    ax.set_ylim(0, 1)
    ax.legend(handles, labels)

    file_name = "probability_inside_port_cage_{}_subject_{}_date_{}_{}.png".format(cage, subject_id, earliest_date, latest_date)
    plt.savefig(os.path.join(probability_inside_port_plots_output_directory, file_name))
# Out:
# /tmp/ipykernel_4354/3658317512.py:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots()

# %% [markdown]
# # 4. Licking Specifity Average

# %% [markdown]
# - Licking specifity is measured by getting that average probability for all time increments that the subject is in a port from either -20 to 0 seconds from the tone playing or 0 to 10 seconds from the tone playing. The goal will be to more easily compare if the subject is correctly associating the tone with the reward by comparing how often they're in the port before and after the tone.

# %% [markdown]
# - Getting the mean of all the port probabilites for each subject + date combination for -20 to 0 seconds from the tone playing or 0 to 10 seconds from the tone playing.

# %%
subject_to_date_to_licking_specificty = defaultdict(lambda: defaultdict(dict))
for subject, all_dates in subject_to_date_to_average_probability.items():
    for date, averages in all_dates.items():
        subject_to_date_to_licking_specificty[subject][date]["-20_to_0"] = averages[0:2000].mean()
        subject_to_date_to_licking_specificty[subject][date]["0_to_10"] = averages[2000:3000].mean()

# %%
for key, value in subject_to_date_to_licking_specificty.items():
    print("Subject: {}".format(key))
    print("Date to licking specifity before and after tone: {}".format(value))
    break
# Out:
# Subject: cage_1_subject_1
# Date to licking specifity before and after tone: defaultdict(<class 'dict'>, {1: {'-20_to_0': 0.002512820512820513, '0_to_10': 0.0021538461538461538}, 2: {'-20_to_0': 0.00015384615384615385, '0_to_10': 0.0}, 3: {'-20_to_0': 0.023371794871794874, '0_to_10': 0.06546153846153845}, 4: {'-20_to_0': 0.08067948717948718, '0_to_10': 0.15879487179487178}, 5: {'-20_to_0': 0.2, '0_to_10': 0.3056153846153846}, 6: {'-20_to_0': 0.4246410256410256, '0_to_10': 0.563}, 7: {'-20_to_0': 0.511102564102564, '0_to_10': 0.718923076923077}})

# %% [markdown]
# - Turning the dictionary into dataframe for plotting

# %%
licking_specifity_df = pd.DataFrame.from_dict({(i,j): subject_to_date_to_licking_specificty[i][j] 
                           for i in subject_to_date_to_licking_specificty.keys() 
                           for j in subject_to_date_to_licking_specificty[i].keys()},
                       orient='index')

# %% [markdown]
# - Adding metadata and formatting the dataframe

# %%
licking_specifity_df = licking_specifity_df.reset_index()
licking_specifity_df = licking_specifity_df.rename(columns={"level_0": "subject", "level_1": "date"})

# %%
licking_specifity_df["date_int"] = licking_specifity_df["date"].astype(int)
licking_specifity_df["cage"] = licking_specifity_df["subject"].map(subject_to_cage)

# %%
licking_specifity_df
# Out:
#               subject  date  -20_to_0   0_to_10  date_int  cage
# 0    cage_1_subject_1     1  0.002513  0.002154         1     1
# 1    cage_1_subject_1     2  0.000154  0.000000         2     1
# 2    cage_1_subject_1     3  0.023372  0.065462         3     1
# 3    cage_1_subject_1     4  0.080679  0.158795         4     1
# 4    cage_1_subject_1     5  0.200000  0.305615         5     1
# ..                ...   ...       ...       ...       ...   ...
# 163  cage_6_subject_4     3  0.029397  0.050821         3     6
# 164  cage_6_subject_4     4  0.268256  0.419615         4     6
# 165  cage_6_subject_4     5  0.096038  0.172128         5     6
# 166  cage_6_subject_4     6  0.103897  0.278436         6     6
# 167  cage_6_subject_4     7  0.116141  0.231103         7     6
#
# [168 rows x 6 columns]

# %%
licking_specifity_df = licking_specifity_df.sort_values(by=["subject", "date_int"])

# %%
licking_specifity_df = licking_specifity_df.reset_index(drop=True)

# %% [markdown]
# - Making Directories

# %%
subject_and_date_rows_licking_specifity_output_directory = "./proc/subject_and_date_rows_licking_specifity_output_directory/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
subject_and_date_rows_licking_specifity_output_directory
# Out:
# './proc/subject_and_date_rows_licking_specifity_output_directory/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(subject_and_date_rows_licking_specifity_output_directory, exist_ok=True)

# %% [markdown]
# - Saving the dataframe to a file

# %%
licking_specifity_df.to_csv(os.path.join(subject_and_date_rows_licking_specifity_output_directory, "lsubject_and_date_rows_licking_specifity_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
licking_specifity_df.to_excel(os.path.join(subject_and_date_rows_licking_specifity_output_directory, "lsubject_and_date_rows_licking_specifity_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# ## Plotting the Licking Specifity

# %% [markdown]
# - Making the output directories

# %%
licking_specifity_plots_output_directory = "./proc/plots/licking_specifity/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
licking_specifity_plots_output_directory
# Out:
# './proc/plots/licking_specifity/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(licking_specifity_plots_output_directory, exist_ok=True)

# %% [markdown]
# - Creating the plots

# %%
licking_specifity_df
# Out:
#               subject  date  -20_to_0   0_to_10  date_int  cage
# 0    cage_1_subject_1     1  0.002513  0.002154         1     1
# 1    cage_1_subject_1     2  0.000154  0.000000         2     1
# 2    cage_1_subject_1     3  0.023372  0.065462         3     1
# 3    cage_1_subject_1     4  0.080679  0.158795         4     1
# 4    cage_1_subject_1     5  0.200000  0.305615         5     1
# ..                ...   ...       ...       ...       ...   ...
# 163  cage_6_subject_4     3  0.029397  0.050821         3     6
# 164  cage_6_subject_4     4  0.268256  0.419615         4     6
# 165  cage_6_subject_4     5  0.096038  0.172128         5     6
# 166  cage_6_subject_4     6  0.103897  0.278436         6     6
# 167  cage_6_subject_4     7  0.116141  0.231103         7     6
#
# [168 rows x 6 columns]

# %%
all_colors = ["b", "g", "y", "r"]

for cage in licking_specifity_df["cage"].unique():
    fig, ax = plt.subplots()
    # only allowing whole number ticks for x
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
    
    cage_df = licking_specifity_df[licking_specifity_df["cage"] == cage]
    counter = 0
    for subject in cage_df["subject"].unique():
        subject_df = cage_df[cage_df["subject"] == subject]
        
        
        ax.plot(subject_df["date_int"], subject_df["-20_to_0"], '--', color=all_colors[counter], label="{} at -20s to 0s".format(subject))
        ax.plot(subject_df["date_int"], subject_df["0_to_10"], '-', color=all_colors[counter], label="{} at 0s to 10s".format(subject))
        counter += 1
        
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Average Licking Specificty Probaility")
    ax.set_title("Licking Specifity Probability Before and After Tone Onset: Cage {}".format(int(cage)))

    ax.set_ylim(0, 1)
    ax.legend()
    
    file_name = "licking_specifity_plot_cage_{}_date_{}_{}.png".format(int(cage), earliest_date, latest_date)
    plt.savefig(os.path.join(licking_specifity_plots_output_directory, file_name))

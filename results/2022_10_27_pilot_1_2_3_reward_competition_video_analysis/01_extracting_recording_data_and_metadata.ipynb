# %% [markdown]
# # Notebook 1: MED-PC Extracting the Recording Data and Metadata

# %% [markdown]
# # Importing the Python Libraries

# %%
import sys
import glob
import collections
from collections import defaultdict
import os
from datetime import datetime
import pathlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from medpc2excel.medpc_read import medpc_read
from moviepy.editor import *

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %% [markdown]
# # Getting the Metadata from all the MED-PC Recording Files

# %% [markdown]
# - Every MED-PC Recording file has Metadata about time, data, subject, group, experiment name, script used, and the MED-PC box number on the top of the recording file. We will first extract that information
#     - Metadata can be background information or context about data(or files) that is often different from the actual data that is intended to be recorded.
#         For more information on Metadata: https://en.wikipedia.org/wiki/Metadata

# %% [raw]
# # Getting all the file paths of the recording files(that happen to all end in `.txt`)
# all_med_pc_file = glob.glob("./example_recordings/*.txt")

# %% [markdown]
# - The path of the directory that this notebook is in. This will be where relative paths will be based off of

# %%
current_working_directory = os.getcwd()

# %%
current_working_directory
# Out:
# '/root/projects/behavioral_dataframe_processing/results/2022_07_20_repeated_id_fix'

# %% [markdown]
# - All the other files in this directory. If you want to use a folder in here such as the `data` folder, you'd type `./data/{name_of_folder}` where you replace `{name_of_folder}` with the name of the folder without the `{}`. You will do this in the cells following the one below
#     - The `./` means the path will reference the current directory that the command is being used from

# %%
os.listdir(current_working_directory)
# Out:
# ['data',
#  'scripts',
#  '03_calculating_port_entry_precision.ipynb',
#  '.ipynb_checkpoints',
#  'README.MD',
#  'proc',
#  '02_calculating_latencies.ipynb',
#  '04_syncing_with_video.ipynb',
#  '01_extracting_recording_data_and_metadata.ipynb']

# %% [markdown]
# ## NOTE: If you are using your own data, the following path must be changed to the directory where your MED-PC recording files are located(if they are not in the specied folder). It is recommended to create a sub folder in the `data` folder(that is in the same folder as this notebook) for each group of session you want to process and put the recording files in there

# %% [markdown]
# - Use the cell below instead if you're using your own data. You must change the cell below by clicking on the cell and then pressing the `esc` key. Then press the `Y` button on your keyboard. If you want to switch it back do the same but press the `R` button instead. This switches it from a cell that is run as if it's code, or back to a cell where it's just treated as text
#     - **NOTE: If you are using a different folder, then change the path in the cell below**
#     - The asterisk is called a wild card which will tell the computer to find all files/folders that match this pattern. The `*` means that any pattern of any length can be replaced with it. The `**` tells the computer to look in all folders that are in the specified folder. For more information: https://linuxhint.com/bash_wildcard_tutorial/
#     - For more information on finding the path of your folder that contains the recording files: https://www.computerhope.com/issues/ch001708.htm

# %%
all_med_pc_file = glob.glob("./data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/*.txt")

# %%
all_med_pc_file[:10]
# Out:
# ['./data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-22_12h26m_Subject 1.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-23_14h55m_Subject 4.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-23_10h06m_Subject 2.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-22_10h11m_Subject 2.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-22_09h00m_Subject 3.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-22_11h19m_Subject 3.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-23_14h55m_Subject 3.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-19_13h38m_Subject 1.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-18_15h10m_Subject 4.txt',
#  './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-20_09h35m_Subject 4.txt']

# %% [markdown]
# - Example of what the MED-PC Recording file looks like

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt
#
#
#
#
#
#
#
# Start Date: 07/22/22
#
# End Date: 07/22/22
#
# Subject: 1
#
# Experiment: C57_vs_CD1_comparison
#
# Group: Cage4
#
# Box: 1
#
# Start Time: 12:26:57
#
# End Time: 13:36:44
#
# MSN: CD1_reward_training
#
# A:    4399.000
#
# D:    9000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    3660.000

# %% [markdown]
# - We will be extracting the first 10 or so lines that look like:
#
# ```
# File: C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (2).txt
#
# Start Date: 05/06/22
#
# End Date: 05/06/22
#
# Subject: 3.4 (2)
#
# Experiment: Pilot of Pilot
#
# Group: Cage 4
#
# Box: 1
#
# Start Time: 12:59:58
#
# End Time: 14:02:38
#
# MSN: levelNP_CS_reward_laserepochON1st_noshock
# ```

# %% [markdown]
# - We will just find all the lines that start with `"File", "Start Date", "End Date", "Subject", "Experiment", "Group", "Box", "Start Time", "End Time", or "MSN"`. And get the metadata from those lines. And then stop once all the metadata types have been collected

# %%
# This makes a nested dictionary of file paths to each individual metadata type
file_path_to_meta_data = extract.metadata.get_all_med_pc_meta_data_from_files(list_of_files=all_med_pc_file)

# %%
# The metadata for the first file
for key, value in file_path_to_meta_data.items():
    print("File path: {}".format(key))
    print("Metadata types and associated values: {}".format(value))
    break
# Out:
# File path: ./data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-22_12h26m_Subject 1.txt
# Metadata types and associated values: {'File': 'C:\\MED-PC\\Data\\2022-07-22_12h26m_Subject 1.txt', 'Start Date': '07/22/22', 'End Date': '07/22/22', 'Subject': '1', 'Experiment': 'C57_vs_CD1_comparison', 'Group': 'Cage4', 'Box': '1', 'Start Time': '12:26:57', 'End Time': '13:36:44', 'MSN': 'CD1_reward_training'}

# %% [markdown]
# ## Making a Dataframe out of the Metadata

# %% [markdown]
# - A Dataframe is essentially a "programmable" spreadsheet. But instead of clicking on cells, you will have to tell Python how you want to interact with the spreadsheet
#     - For more information: https://realpython.com/pandas-dataframe/

# %%
# Turning the dictionary into a Pandas Dataframe
metadata_df = pd.DataFrame.from_dict(file_path_to_meta_data, orient="index")
# Resetting the index because currently the file path is the index 
metadata_df = metadata_df.reset_index()

# %%
metadata_df.head()
# Out:
#                                                index  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt   07/22/22  07/22/22
# 1  C:\MED-PC\Data\2022-07-23_14h55m_Subject 4.txt   07/23/22  07/23/22
# 2  C:\MED-PC\Data\2022-07-23_10h06m_Subject 2.txt   07/23/22  07/23/22
# 3  C:\MED-PC\Data\2022-07-22_10h11m_Subject 2.txt   07/22/22  07/22/22
# 4  C:\MED-PC\Data\2022-07-22_09h00m_Subject 3.txt   07/22/22  07/22/22
#
#   Subject             Experiment   Group Box Start Time  End Time  \
# 0       1  C57_vs_CD1_comparison   Cage4   1   12:26:57  13:36:44
# 1       4  C57_vs_CD1_Comparison  Cage 6   1   14:55:47  16:05:03
# 2       2  C57_vs_CD1_comparison   Cage2   3   10:06:22  11:09:48
# 3       2  C57_vs_CD1_comparison   Cage2   2   10:11:03  11:14:37
# 4       3  C57_vs_CD1_comparison   Cage1   3   09:00:32  10:05:02
#
#                    MSN
# 0  CD1_reward_training
# 1  CD1_reward_training
# 2  CD1_reward_training
# 3  CD1_reward_training
# 4  CD1_reward_training

# %%
metadata_df.tail()
# Out:
#                                                  index  \
# 164  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 165  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 166  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 167  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 168  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                File Start Date  End Date  \
# 164  C:\MED-PC\Data\2022-07-20_10h48m_Subject 4.txt   07/20/22  07/20/22
# 165  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 166  C:\MED-PC\Data\2022-07-22_10h11m_Subject 1.txt   07/22/22  07/22/22
# 167  C:\MED-PC\Data\2022-07-20_10h48m_Subject 3.txt   07/20/22  07/20/22
# 168  C:\MED-PC\Data\2022-07-24_14h53m_Subject 3.txt   07/24/22  07/24/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 164       4  C57_vs_CD1_Comparison   Cage3   2   10:48:32  11:53:40
# 165       2  C57_vs_CD1_Comparison   Cage2   4   10:17:01  11:22:34
# 166       1  C57_vs_CD1_comparison   Cage2   1   10:11:03  11:14:37
# 167       3  C57_vs_CD1_Comparison   Cage3   1   10:48:32  11:53:40
# 168       3  C57_vs_CD1_comparison  Cage 6   1   14:53:31  15:56:03
#
#                      MSN
# 164  C57_reward_training
# 165  C57_reward_training
# 166  C57_reward_training
# 167  C57_reward_training
# 168  CD1_reward_training

# %% [markdown]
# - Make a column that is just the file name

# %%
# Changing the file path to Windows format, then back to Linux format
# Then just taking the file name
metadata_df["file_name"] = metadata_df["File"].apply(lambda x: os.path.basename(pathlib.Path(pathlib.PureWindowsPath(x))).strip())

# %%
metadata_df
# Out:
#                                                  index  \
# 0    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ..                                                 ...
# 164  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 165  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 166  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 167  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 168  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                File Start Date  End Date  \
# 0    C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt   07/22/22  07/22/22
# 1    C:\MED-PC\Data\2022-07-23_14h55m_Subject 4.txt   07/23/22  07/23/22
# 2    C:\MED-PC\Data\2022-07-23_10h06m_Subject 2.txt   07/23/22  07/23/22
# 3    C:\MED-PC\Data\2022-07-22_10h11m_Subject 2.txt   07/22/22  07/22/22
# 4    C:\MED-PC\Data\2022-07-22_09h00m_Subject 3.txt   07/22/22  07/22/22
# ..                                              ...        ...       ...
# 164  C:\MED-PC\Data\2022-07-20_10h48m_Subject 4.txt   07/20/22  07/20/22
# 165  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 166  C:\MED-PC\Data\2022-07-22_10h11m_Subject 1.txt   07/22/22  07/22/22
# 167  C:\MED-PC\Data\2022-07-20_10h48m_Subject 3.txt   07/20/22  07/20/22
# 168  C:\MED-PC\Data\2022-07-24_14h53m_Subject 3.txt   07/24/22  07/24/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 0         1  C57_vs_CD1_comparison   Cage4   1   12:26:57  13:36:44
# 1         4  C57_vs_CD1_Comparison  Cage 6   1   14:55:47  16:05:03
# 2         2  C57_vs_CD1_comparison   Cage2   3   10:06:22  11:09:48
# 3         2  C57_vs_CD1_comparison   Cage2   2   10:11:03  11:14:37
# 4         3  C57_vs_CD1_comparison   Cage1   3   09:00:32  10:05:02
# ..      ...                    ...     ...  ..        ...       ...
# 164       4  C57_vs_CD1_Comparison   Cage3   2   10:48:32  11:53:40
# 165       2  C57_vs_CD1_Comparison   Cage2   4   10:17:01  11:22:34
# 166       1  C57_vs_CD1_comparison   Cage2   1   10:11:03  11:14:37
# 167       3  C57_vs_CD1_Comparison   Cage3   1   10:48:32  11:53:40
# 168       3  C57_vs_CD1_comparison  Cage 6   1   14:53:31  15:56:03
#
#                      MSN                        file_name
# 0    CD1_reward_training  2022-07-22_12h26m_Subject 1.txt
# 1    CD1_reward_training  2022-07-23_14h55m_Subject 4.txt
# 2    CD1_reward_training  2022-07-23_10h06m_Subject 2.txt
# 3    CD1_reward_training  2022-07-22_10h11m_Subject 2.txt
# 4    CD1_reward_training  2022-07-22_09h00m_Subject 3.txt
# ..                   ...                              ...
# 164  C57_reward_training  2022-07-20_10h48m_Subject 4.txt
# 165  C57_reward_training  2022-07-24_10h17m_Subject 2.txt
# 166  C57_reward_training  2022-07-22_10h11m_Subject 1.txt
# 167  C57_reward_training  2022-07-20_10h48m_Subject 3.txt
# 168  CD1_reward_training  2022-07-24_14h53m_Subject 3.txt
#
# [169 rows x 12 columns]

# %% [markdown]
# - Getting the numbers out of the column that contains the cage information

# %%
metadata_df["cage"] = metadata_df["Group"].apply(lambda x: x.lower().strip("cage").strip())

# %%
metadata_df["cage"].head()
# Out:
# 0    4
# 1    6
# 2    2
# 3    2
# 4    1
# Name: cage, dtype: object

# %% [markdown]
# - Adding a new column that combines the cage and subject ID into a new ID

# %%
metadata_df["cage_and_subject"] = metadata_df.apply(lambda x: "cage_{}_subject_{}".format(x["cage"], x["Subject"]), axis=1)

# %%
metadata_df
# Out:
#                                                  index  \
# 0    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ..                                                 ...
# 164  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 165  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 166  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 167  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 168  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                File Start Date  End Date  \
# 0    C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt   07/22/22  07/22/22
# 1    C:\MED-PC\Data\2022-07-23_14h55m_Subject 4.txt   07/23/22  07/23/22
# 2    C:\MED-PC\Data\2022-07-23_10h06m_Subject 2.txt   07/23/22  07/23/22
# 3    C:\MED-PC\Data\2022-07-22_10h11m_Subject 2.txt   07/22/22  07/22/22
# 4    C:\MED-PC\Data\2022-07-22_09h00m_Subject 3.txt   07/22/22  07/22/22
# ..                                              ...        ...       ...
# 164  C:\MED-PC\Data\2022-07-20_10h48m_Subject 4.txt   07/20/22  07/20/22
# 165  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 166  C:\MED-PC\Data\2022-07-22_10h11m_Subject 1.txt   07/22/22  07/22/22
# 167  C:\MED-PC\Data\2022-07-20_10h48m_Subject 3.txt   07/20/22  07/20/22
# 168  C:\MED-PC\Data\2022-07-24_14h53m_Subject 3.txt   07/24/22  07/24/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 0         1  C57_vs_CD1_comparison   Cage4   1   12:26:57  13:36:44
# 1         4  C57_vs_CD1_Comparison  Cage 6   1   14:55:47  16:05:03
# 2         2  C57_vs_CD1_comparison   Cage2   3   10:06:22  11:09:48
# 3         2  C57_vs_CD1_comparison   Cage2   2   10:11:03  11:14:37
# 4         3  C57_vs_CD1_comparison   Cage1   3   09:00:32  10:05:02
# ..      ...                    ...     ...  ..        ...       ...
# 164       4  C57_vs_CD1_Comparison   Cage3   2   10:48:32  11:53:40
# 165       2  C57_vs_CD1_Comparison   Cage2   4   10:17:01  11:22:34
# 166       1  C57_vs_CD1_comparison   Cage2   1   10:11:03  11:14:37
# 167       3  C57_vs_CD1_Comparison   Cage3   1   10:48:32  11:53:40
# 168       3  C57_vs_CD1_comparison  Cage 6   1   14:53:31  15:56:03
#
#                      MSN                        file_name cage  \
# 0    CD1_reward_training  2022-07-22_12h26m_Subject 1.txt    4
# 1    CD1_reward_training  2022-07-23_14h55m_Subject 4.txt    6
# 2    CD1_reward_training  2022-07-23_10h06m_Subject 2.txt    2
# 3    CD1_reward_training  2022-07-22_10h11m_Subject 2.txt    2
# 4    CD1_reward_training  2022-07-22_09h00m_Subject 3.txt    1
# ..                   ...                              ...  ...
# 164  C57_reward_training  2022-07-20_10h48m_Subject 4.txt    3
# 165  C57_reward_training  2022-07-24_10h17m_Subject 2.txt    2
# 166  C57_reward_training  2022-07-22_10h11m_Subject 1.txt    2
# 167  C57_reward_training  2022-07-20_10h48m_Subject 3.txt    3
# 168  CD1_reward_training  2022-07-24_14h53m_Subject 3.txt    6
#
#      cage_and_subject
# 0    cage_4_subject_1
# 1    cage_6_subject_4
# 2    cage_2_subject_2
# 3    cage_2_subject_2
# 4    cage_1_subject_3
# ..                ...
# 164  cage_3_subject_4
# 165  cage_2_subject_2
# 166  cage_2_subject_1
# 167  cage_3_subject_3
# 168  cage_6_subject_3
#
# [169 rows x 14 columns]

# %% [markdown]
# - Making new columns so that we can use the Start date and End date in other steps

# %%
metadata_df["start_date_datetime"] = metadata_df["Start Date"].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
metadata_df["start_date_int"] = metadata_df["start_date_datetime"].apply(lambda x: int(x.strftime('%Y%m%d')))

metadata_df["end_date_datetime"] = metadata_df["End Date"].apply(lambda x: datetime.strptime(x, '%m/%d/%y'))
metadata_df["end_date_int"] = metadata_df["end_date_datetime"].apply(lambda x: int(x.strftime('%Y%m%d')))

# %%
metadata_df
# Out:
#                                                  index  \
# 0    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4    ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ..                                                 ...
# 164  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 165  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 166  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 167  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 168  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                File Start Date  End Date  \
# 0    C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt   07/22/22  07/22/22
# 1    C:\MED-PC\Data\2022-07-23_14h55m_Subject 4.txt   07/23/22  07/23/22
# 2    C:\MED-PC\Data\2022-07-23_10h06m_Subject 2.txt   07/23/22  07/23/22
# 3    C:\MED-PC\Data\2022-07-22_10h11m_Subject 2.txt   07/22/22  07/22/22
# 4    C:\MED-PC\Data\2022-07-22_09h00m_Subject 3.txt   07/22/22  07/22/22
# ..                                              ...        ...       ...
# 164  C:\MED-PC\Data\2022-07-20_10h48m_Subject 4.txt   07/20/22  07/20/22
# 165  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 166  C:\MED-PC\Data\2022-07-22_10h11m_Subject 1.txt   07/22/22  07/22/22
# 167  C:\MED-PC\Data\2022-07-20_10h48m_Subject 3.txt   07/20/22  07/20/22
# 168  C:\MED-PC\Data\2022-07-24_14h53m_Subject 3.txt   07/24/22  07/24/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 0         1  C57_vs_CD1_comparison   Cage4   1   12:26:57  13:36:44
# 1         4  C57_vs_CD1_Comparison  Cage 6   1   14:55:47  16:05:03
# 2         2  C57_vs_CD1_comparison   Cage2   3   10:06:22  11:09:48
# 3         2  C57_vs_CD1_comparison   Cage2   2   10:11:03  11:14:37
# 4         3  C57_vs_CD1_comparison   Cage1   3   09:00:32  10:05:02
# ..      ...                    ...     ...  ..        ...       ...
# 164       4  C57_vs_CD1_Comparison   Cage3   2   10:48:32  11:53:40
# 165       2  C57_vs_CD1_Comparison   Cage2   4   10:17:01  11:22:34
# 166       1  C57_vs_CD1_comparison   Cage2   1   10:11:03  11:14:37
# 167       3  C57_vs_CD1_Comparison   Cage3   1   10:48:32  11:53:40
# 168       3  C57_vs_CD1_comparison  Cage 6   1   14:53:31  15:56:03
#
#                      MSN                        file_name cage  \
# 0    CD1_reward_training  2022-07-22_12h26m_Subject 1.txt    4
# 1    CD1_reward_training  2022-07-23_14h55m_Subject 4.txt    6
# 2    CD1_reward_training  2022-07-23_10h06m_Subject 2.txt    2
# 3    CD1_reward_training  2022-07-22_10h11m_Subject 2.txt    2
# 4    CD1_reward_training  2022-07-22_09h00m_Subject 3.txt    1
# ..                   ...                              ...  ...
# 164  C57_reward_training  2022-07-20_10h48m_Subject 4.txt    3
# 165  C57_reward_training  2022-07-24_10h17m_Subject 2.txt    2
# 166  C57_reward_training  2022-07-22_10h11m_Subject 1.txt    2
# 167  C57_reward_training  2022-07-20_10h48m_Subject 3.txt    3
# 168  CD1_reward_training  2022-07-24_14h53m_Subject 3.txt    6
#
#      cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0    cage_4_subject_1          2022-07-22        20220722        2022-07-22
# 1    cage_6_subject_4          2022-07-23        20220723        2022-07-23
# 2    cage_2_subject_2          2022-07-23        20220723        2022-07-23
# 3    cage_2_subject_2          2022-07-22        20220722        2022-07-22
# 4    cage_1_subject_3          2022-07-22        20220722        2022-07-22
# ..                ...                 ...             ...               ...
# 164  cage_3_subject_4          2022-07-20        20220720        2022-07-20
# 165  cage_2_subject_2          2022-07-24        20220724        2022-07-24
# 166  cage_2_subject_1          2022-07-22        20220722        2022-07-22
# 167  cage_3_subject_3          2022-07-20        20220720        2022-07-20
# 168  cage_6_subject_3          2022-07-24        20220724        2022-07-24
#
#      end_date_int
# 0        20220722
# 1        20220723
# 2        20220723
# 3        20220722
# 4        20220722
# ..            ...
# 164      20220720
# 165      20220724
# 166      20220722
# 167      20220720
# 168      20220724
#
# [169 rows x 18 columns]

# %% [markdown]
# - Making a column that is the trial number for each subject

# %%
subject_to_metadata_df = {}
for subject in metadata_df["cage_and_subject"].unique():
    subject_df = metadata_df[metadata_df["cage_and_subject"] == subject]
    subject_df = subject_df.sort_values("file_name", ascending=True)
    subject_df.insert(0, 'trial_number', range(1, 1 + len(subject_df)))
    subject_to_metadata_df[subject] = subject_df

# %%
subject_to_metadata_df = collections.OrderedDict(sorted(subject_to_metadata_df.items()))

# %%
all_subject_to_metadata_df = [v for k,v in subject_to_metadata_df.items()]

# %%
metadata_df = pd.concat(all_subject_to_metadata_df).reset_index(drop=True)

# %%
metadata_df.head(n=25)
# Out:
#     trial_number                                              index  \
# 0              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2              2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3              3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4              4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 5              5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 6              6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 7              7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 8              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 9              2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 10             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 11             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 12             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 13             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 14             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 15             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 16             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 17             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 18             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 19             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 20             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 21             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 22             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 23             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 24             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                               File Start Date  End Date  \
# 0   C:\MED-PC\Data\2022-07-21_12h24m_Subject 0.txt   07/21/22  07/21/22
# 1   C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2   C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 3   C:\MED-PC\Data\2022-07-20_08h09m_Subject 1.txt   07/20/22  07/20/22
# 4   C:\MED-PC\Data\2022-07-21_08h50m_Subject 1.txt   07/21/22  07/21/22
# 5   C:\MED-PC\Data\2022-07-22_09h00m_Subject 1.txt   07/22/22  07/22/22
# 6   C:\MED-PC\Data\2022-07-23_08h43m_Subject 1.txt   07/23/22  07/23/22
# 7   C:\MED-PC\Data\2022-07-24_08h28m_Subject 1.txt   07/24/22  07/24/22
# 8   C:\MED-PC\Data\2022-07-18_08h25m_Subject 2.txt   07/18/22  07/18/22
# 9   C:\MED-PC\Data\2022-07-18_16h39m_Subject 2.txt   07/18/22  07/19/22
# 10  C:\MED-PC\Data\2022-07-20_08h09m_Subject 2.txt   07/20/22  07/20/22
# 11  C:\MED-PC\Data\2022-07-21_08h50m_Subject 2.txt   07/21/22  07/21/22
# 12  C:\MED-PC\Data\2022-07-22_09h00m_Subject 2.txt   07/22/22  07/22/22
# 13  C:\MED-PC\Data\2022-07-23_08h43m_Subject 2.txt   07/23/22  07/23/22
# 14  C:\MED-PC\Data\2022-07-24_08h28m_Subject 2.txt   07/24/22  07/24/22
# 15  C:\MED-PC\Data\2022-07-18_08h25m_Subject 3.txt   07/18/22  07/18/22
# 16  C:\MED-PC\Data\2022-07-18_16h39m_Subject 3.txt   07/18/22  07/19/22
# 17  C:\MED-PC\Data\2022-07-20_08h09m_Subject 3.txt   07/20/22  07/20/22
# 18  C:\MED-PC\Data\2022-07-21_08h50m_Subject 3.txt   07/21/22  07/21/22
# 19  C:\MED-PC\Data\2022-07-22_09h00m_Subject 3.txt   07/22/22  07/22/22
# 20  C:\MED-PC\Data\2022-07-23_08h43m_Subject 3.txt   07/23/22  07/23/22
# 21  C:\MED-PC\Data\2022-07-24_08h28m_Subject 3.txt   07/24/22  07/24/22
# 22  C:\MED-PC\Data\2022-07-18_08h25m_Subject 4.txt   07/18/22  07/18/22
# 23  C:\MED-PC\Data\2022-07-18_16h39m_Subject 4.txt   07/18/22  07/19/22
# 24  C:\MED-PC\Data\2022-07-20_08h09m_Subject 4.txt   07/20/22  07/20/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0        0                      0       0   1   12:24:06  12:35:30
# 1        1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  09:50:24
# 2        1  C57_vs_CD1_Comparison  Cage 1   2   16:39:59  09:52:50
# 3        1  C57_vs_CD1_comparison  Cage 1   3   08:09:22  09:27:22
# 4        1  C57_vs_CD1_comparison  Cage 1   4   08:50:56  09:59:08
# 5        1  C57_vs_CD1_comparison   Cage1   1   09:00:32  10:05:02
# 6        1  C57_vs_CD1_Comparison   Cage1   2   08:43:28  09:57:37
# 7        1  C57_vs_CD1_Comparison   Cage1   3   08:28:38  10:13:15
# 8        2  C57_vs_CD1_Comparison   Cage1   2   08:25:48  09:50:24
# 9        2  C57_vs_CD1_Comparison  Cage 1   3   16:39:59  09:52:50
# 10       2  C57_vs_CD1_comparison  Cage 1   4   08:09:22  09:27:22
# 11       2  C57_vs_CD1_comparison  Cage 1   1   08:50:38  09:59:08
# 12       2  C57_vs_CD1_comparison   Cage1   2   09:00:32  10:05:02
# 13       2  C57_vs_CD1_Comparison   Cage1   3   08:43:28  09:57:37
# 14       2  C57_vs_CD1_Comparison   Cage1   4   08:28:38  10:13:15
# 15       3  C57_vs_CD1_Comparison   Cage1   3   08:25:48  09:50:24
# 16       3  C57_vs_CD1_Comparison  Cage 1   4   16:39:59  09:52:50
# 17       3  C57_vs_CD1_comparison  Cage 1   1   08:09:22  09:27:22
# 18       3  C57_vs_CD1_comparison  Cage 1   2   08:50:46  09:59:08
# 19       3  C57_vs_CD1_comparison   Cage1   3   09:00:32  10:05:02
# 20       3  C57_vs_CD1_Comparison   Cage1   4   08:43:28  09:57:37
# 21       3  C57_vs_CD1_Comparison   Cage1   1   08:28:38  10:13:15
# 22       4  C57_vs_CD1_Comparison   Cage1   4   08:25:48  09:50:24
# 23       4  C57_vs_CD1_Comparison  Cage 1   1   16:39:59  09:52:50
# 24       4  C57_vs_CD1_comparison  Cage 1   2   08:09:22  09:27:22
#
#                     MSN                        file_name cage  \
# 0              pumptest  2022-07-21_12h24m_Subject 0.txt    0
# 1   C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 2   C57_reward_training  2022-07-18_16h39m_Subject 1.txt    1
# 3   C57_reward_training  2022-07-20_08h09m_Subject 1.txt    1
# 4   C57_reward_training  2022-07-21_08h50m_Subject 1.txt    1
# 5   C57_reward_training  2022-07-22_09h00m_Subject 1.txt    1
# 6   CD1_reward_training  2022-07-23_08h43m_Subject 1.txt    1
# 7   C57_reward_training  2022-07-24_08h28m_Subject 1.txt    1
# 8   C57_reward_training  2022-07-18_08h25m_Subject 2.txt    1
# 9   C57_reward_training  2022-07-18_16h39m_Subject 2.txt    1
# 10  C57_reward_training  2022-07-20_08h09m_Subject 2.txt    1
# 11  C57_reward_training  2022-07-21_08h50m_Subject 2.txt    1
# 12  CD1_reward_training  2022-07-22_09h00m_Subject 2.txt    1
# 13  CD1_reward_training  2022-07-23_08h43m_Subject 2.txt    1
# 14  C57_reward_training  2022-07-24_08h28m_Subject 2.txt    1
# 15  C57_reward_training  2022-07-18_08h25m_Subject 3.txt    1
# 16  C57_reward_training  2022-07-18_16h39m_Subject 3.txt    1
# 17  C57_reward_training  2022-07-20_08h09m_Subject 3.txt    1
# 18  C57_reward_training  2022-07-21_08h50m_Subject 3.txt    1
# 19  CD1_reward_training  2022-07-22_09h00m_Subject 3.txt    1
# 20  CD1_reward_training  2022-07-23_08h43m_Subject 3.txt    1
# 21  C57_reward_training  2022-07-24_08h28m_Subject 3.txt    1
# 22  C57_reward_training  2022-07-18_08h25m_Subject 4.txt    1
# 23  C57_reward_training  2022-07-18_16h39m_Subject 4.txt    1
# 24  C57_reward_training  2022-07-20_08h09m_Subject 4.txt    1
#
#     cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0   cage_0_subject_0          2022-07-21        20220721        2022-07-21
# 1   cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 2   cage_1_subject_1          2022-07-18        20220718        2022-07-19
# 3   cage_1_subject_1          2022-07-20        20220720        2022-07-20
# 4   cage_1_subject_1          2022-07-21        20220721        2022-07-21
# 5   cage_1_subject_1          2022-07-22        20220722        2022-07-22
# 6   cage_1_subject_1          2022-07-23        20220723        2022-07-23
# 7   cage_1_subject_1          2022-07-24        20220724        2022-07-24
# 8   cage_1_subject_2          2022-07-18        20220718        2022-07-18
# 9   cage_1_subject_2          2022-07-18        20220718        2022-07-19
# 10  cage_1_subject_2          2022-07-20        20220720        2022-07-20
# 11  cage_1_subject_2          2022-07-21        20220721        2022-07-21
# 12  cage_1_subject_2          2022-07-22        20220722        2022-07-22
# 13  cage_1_subject_2          2022-07-23        20220723        2022-07-23
# 14  cage_1_subject_2          2022-07-24        20220724        2022-07-24
# 15  cage_1_subject_3          2022-07-18        20220718        2022-07-18
# 16  cage_1_subject_3          2022-07-18        20220718        2022-07-19
# 17  cage_1_subject_3          2022-07-20        20220720        2022-07-20
# 18  cage_1_subject_3          2022-07-21        20220721        2022-07-21
# 19  cage_1_subject_3          2022-07-22        20220722        2022-07-22
# 20  cage_1_subject_3          2022-07-23        20220723        2022-07-23
# 21  cage_1_subject_3          2022-07-24        20220724        2022-07-24
# 22  cage_1_subject_4          2022-07-18        20220718        2022-07-18
# 23  cage_1_subject_4          2022-07-18        20220718        2022-07-19
# 24  cage_1_subject_4          2022-07-20        20220720        2022-07-20
#
#     end_date_int
# 0       20220721
# 1       20220718
# 2       20220719
# 3       20220720
# 4       20220721
# 5       20220722
# 6       20220723
# 7       20220724
# 8       20220718
# 9       20220719
# 10      20220720
# 11      20220721
# 12      20220722
# 13      20220723
# 14      20220724
# 15      20220718
# 16      20220719
# 17      20220720
# 18      20220721
# 19      20220722
# 20      20220723
# 21      20220724
# 22      20220718
# 23      20220719
# 24      20220720

# %%
metadata_df.tail(n=25)
# Out:
#      trial_number                                              index  \
# 144             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 145             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 146             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 147             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 148             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 149             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 150             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 151             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 152             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 153             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 154             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 155             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 156             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 157             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 158             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 159             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 160             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 161             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 162             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 163             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 164             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 165             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 166             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 167             6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 168             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                File Start Date  End Date  \
# 144  C:\MED-PC\Data\2022-07-21_14h53m_Subject 1.txt   07/21/22  07/21/22
# 145  C:\MED-PC\Data\2022-07-22_15h03m_Subject 1.txt   07/22/22  07/22/22
# 146  C:\MED-PC\Data\2022-07-23_14h55m_Subject 1.txt   07/23/22  07/23/22
# 147  C:\MED-PC\Data\2022-07-24_14h53m_Subject 1.txt   07/24/22  07/24/22
# 148  C:\MED-PC\Data\2022-07-18_15h10m_Subject 2.txt   07/18/22  07/18/22
# 149  C:\MED-PC\Data\2022-07-20_12h10m_Subject 2.txt   07/20/22  07/20/22
# 150  C:\MED-PC\Data\2022-07-20_16h01m_Subject 2.txt   07/20/22  07/20/22
# 151  C:\MED-PC\Data\2022-07-21_14h53m_Subject 2.txt   07/21/22  07/21/22
# 152  C:\MED-PC\Data\2022-07-22_15h03m_Subject 2.txt   07/22/22  07/22/22
# 153  C:\MED-PC\Data\2022-07-23_14h55m_Subject 2.txt   07/23/22  07/23/22
# 154  C:\MED-PC\Data\2022-07-24_14h53m_Subject 2.txt   07/24/22  07/24/22
# 155  C:\MED-PC\Data\2022-07-18_15h10m_Subject 3.txt   07/18/22  07/18/22
# 156  C:\MED-PC\Data\2022-07-20_12h10m_Subject 3.txt   07/20/22  07/20/22
# 157  C:\MED-PC\Data\2022-07-20_16h01m_Subject 3.txt   07/20/22  07/20/22
# 158  C:\MED-PC\Data\2022-07-21_14h53m_Subject 3.txt   07/21/22  07/21/22
# 159  C:\MED-PC\Data\2022-07-22_15h03m_Subject 3.txt   07/22/22  07/22/22
# 160  C:\MED-PC\Data\2022-07-23_14h55m_Subject 3.txt   07/23/22  07/23/22
# 161  C:\MED-PC\Data\2022-07-24_14h53m_Subject 3.txt   07/24/22  07/24/22
# 162  C:\MED-PC\Data\2022-07-18_15h10m_Subject 4.txt   07/18/22  07/18/22
# 163  C:\MED-PC\Data\2022-07-19_14h52m_Subject 4.txt   07/19/22  07/19/22
# 164  C:\MED-PC\Data\2022-07-20_16h01m_Subject 4.txt   07/20/22  07/20/22
# 165  C:\MED-PC\Data\2022-07-21_14h53m_Subject 4.txt   07/21/22  07/21/22
# 166  C:\MED-PC\Data\2022-07-22_15h03m_Subject 4.txt   07/22/22  07/22/22
# 167  C:\MED-PC\Data\2022-07-23_14h55m_Subject 4.txt   07/23/22  07/23/22
# 168  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
#
#     Subject             Experiment   Group Box Start Time  End Time  \
# 144       1  C57_vs_CD1_Comparison  Cage 6   4   14:53:27  16:02:17
# 145       1  C57_vs_CD1_Comparison  Cage 6   1   15:03:41  16:06:51
# 146       1  C57_vs_CD1_Comparison  Cage 6   2   14:55:47  16:05:03
# 147       1  C57_vs_CD1_comparison  Cage 6   3   14:53:31  15:56:03
# 148       2  C57_vs_CD1_Comparison  Cage 6   2   15:10:30  16:20:28
# 149       2  C57_vs_CD1_comparison  Cage 6   3   12:10:37  13:16:30
# 150       2  C57_vs_CD1_Comparison   Cage6   4   16:01:17  17:06:16
# 151       2  C57_vs_CD1_Comparison  Cage 6   1   14:53:27  16:02:17
# 152       2  C57_vs_CD1_Comparison  Cage 6   2   15:03:41  16:06:51
# 153       2  C57_vs_CD1_Comparison  Cage 6   3   14:55:47  16:05:03
# 154       2  C57_vs_CD1_comparison  Cage 6   4   14:53:31  15:56:03
# 155       3  C57_vs_CD1_Comparison  Cage 6   3   15:10:30  16:20:28
# 156       3  C57_vs_CD1_comparison  Cage 6   4   12:10:37  13:16:30
# 157       3  C57_vs_CD1_Comparison   Cage6   1   16:01:17  17:06:16
# 158       3  C57_vs_CD1_Comparison  Cage 6   2   14:53:27  16:02:17
# 159       3  C57_vs_CD1_Comparison  Cage 6   3   15:03:41  16:06:51
# 160       3  C57_vs_CD1_Comparison  Cage 6   4   14:55:47  16:05:03
# 161       3  C57_vs_CD1_comparison  Cage 6   1   14:53:31  15:56:03
# 162       4  C57_vs_CD1_Comparison  Cage 6   4   15:10:30  16:20:28
# 163       4  C57_vs_CD1_Comparison  Cage 6   1   14:52:24  15:55:10
# 164       4  C57_vs_CD1_Comparison   Cage6   2   16:01:17  17:06:16
# 165       4  C57_vs_CD1_Comparison  Cage 6   3   14:53:27  16:02:17
# 166       4  C57_vs_CD1_Comparison  Cage 6   4   15:03:41  16:06:51
# 167       4  C57_vs_CD1_Comparison  Cage 6   1   14:55:47  16:05:03
# 168       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  15:56:03
#
#                      MSN                        file_name cage  \
# 144  CD1_reward_training  2022-07-21_14h53m_Subject 1.txt    6
# 145  CD1_reward_training  2022-07-22_15h03m_Subject 1.txt    6
# 146  CD1_reward_training  2022-07-23_14h55m_Subject 1.txt    6
# 147  CD1_reward_training  2022-07-24_14h53m_Subject 1.txt    6
# 148  CD1_reward_training  2022-07-18_15h10m_Subject 2.txt    6
# 149  CD1_reward_training  2022-07-20_12h10m_Subject 2.txt    6
# 150  CD1_reward_training  2022-07-20_16h01m_Subject 2.txt    6
# 151  CD1_reward_training  2022-07-21_14h53m_Subject 2.txt    6
# 152  CD1_reward_training  2022-07-22_15h03m_Subject 2.txt    6
# 153  CD1_reward_training  2022-07-23_14h55m_Subject 2.txt    6
# 154  CD1_reward_training  2022-07-24_14h53m_Subject 2.txt    6
# 155  CD1_reward_training  2022-07-18_15h10m_Subject 3.txt    6
# 156  CD1_reward_training  2022-07-20_12h10m_Subject 3.txt    6
# 157  CD1_reward_training  2022-07-20_16h01m_Subject 3.txt    6
# 158  CD1_reward_training  2022-07-21_14h53m_Subject 3.txt    6
# 159  CD1_reward_training  2022-07-22_15h03m_Subject 3.txt    6
# 160  CD1_reward_training  2022-07-23_14h55m_Subject 3.txt    6
# 161  CD1_reward_training  2022-07-24_14h53m_Subject 3.txt    6
# 162  CD1_reward_training  2022-07-18_15h10m_Subject 4.txt    6
# 163  CD1_reward_training  2022-07-19_14h52m_Subject 4.txt    6
# 164  CD1_reward_training  2022-07-20_16h01m_Subject 4.txt    6
# 165  CD1_reward_training  2022-07-21_14h53m_Subject 4.txt    6
# 166  CD1_reward_training  2022-07-22_15h03m_Subject 4.txt    6
# 167  CD1_reward_training  2022-07-23_14h55m_Subject 4.txt    6
# 168  CD1_reward_training  2022-07-24_14h53m_Subject 4.txt    6
#
#      cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 144  cage_6_subject_1          2022-07-21        20220721        2022-07-21
# 145  cage_6_subject_1          2022-07-22        20220722        2022-07-22
# 146  cage_6_subject_1          2022-07-23        20220723        2022-07-23
# 147  cage_6_subject_1          2022-07-24        20220724        2022-07-24
# 148  cage_6_subject_2          2022-07-18        20220718        2022-07-18
# 149  cage_6_subject_2          2022-07-20        20220720        2022-07-20
# 150  cage_6_subject_2          2022-07-20        20220720        2022-07-20
# 151  cage_6_subject_2          2022-07-21        20220721        2022-07-21
# 152  cage_6_subject_2          2022-07-22        20220722        2022-07-22
# 153  cage_6_subject_2          2022-07-23        20220723        2022-07-23
# 154  cage_6_subject_2          2022-07-24        20220724        2022-07-24
# 155  cage_6_subject_3          2022-07-18        20220718        2022-07-18
# 156  cage_6_subject_3          2022-07-20        20220720        2022-07-20
# 157  cage_6_subject_3          2022-07-20        20220720        2022-07-20
# 158  cage_6_subject_3          2022-07-21        20220721        2022-07-21
# 159  cage_6_subject_3          2022-07-22        20220722        2022-07-22
# 160  cage_6_subject_3          2022-07-23        20220723        2022-07-23
# 161  cage_6_subject_3          2022-07-24        20220724        2022-07-24
# 162  cage_6_subject_4          2022-07-18        20220718        2022-07-18
# 163  cage_6_subject_4          2022-07-19        20220719        2022-07-19
# 164  cage_6_subject_4          2022-07-20        20220720        2022-07-20
# 165  cage_6_subject_4          2022-07-21        20220721        2022-07-21
# 166  cage_6_subject_4          2022-07-22        20220722        2022-07-22
# 167  cage_6_subject_4          2022-07-23        20220723        2022-07-23
# 168  cage_6_subject_4          2022-07-24        20220724        2022-07-24
#
#      end_date_int
# 144      20220721
# 145      20220722
# 146      20220723
# 147      20220724
# 148      20220718
# 149      20220720
# 150      20220720
# 151      20220721
# 152      20220722
# 153      20220723
# 154      20220724
# 155      20220718
# 156      20220720
# 157      20220720
# 158      20220721
# 159      20220722
# 160      20220723
# 161      20220724
# 162      20220718
# 163      20220719
# 164      20220720
# 165      20220721
# 166      20220722
# 167      20220723
# 168      20220724

# %% [markdown]
# - Getting the number of files that are associated with each subject

# %%
# How many files there are for each subject
metadata_df.groupby("cage_and_subject").count()
# Out:
#                   trial_number  index  File  Start Date  End Date  Subject  \
# cage_and_subject
# cage_0_subject_0             1      1     1           1         1        1
# cage_1_subject_1             7      7     7           7         7        7
# cage_1_subject_2             7      7     7           7         7        7
# cage_1_subject_3             7      7     7           7         7        7
# cage_1_subject_4             7      7     7           7         7        7
# cage_2_subject_1             7      7     7           7         7        7
# cage_2_subject_2             7      7     7           7         7        7
# cage_2_subject_3             7      7     7           7         7        7
# cage_2_subject_4             7      7     7           7         7        7
# cage_3_subject_1             7      7     7           7         7        7
# cage_3_subject_2             7      7     7           7         7        7
# cage_3_subject_3             7      7     7           7         7        7
# cage_3_subject_4             7      7     7           7         7        7
# cage_4_subject_1             7      7     7           7         7        7
# cage_4_subject_2             7      7     7           7         7        7
# cage_4_subject_3             7      7     7           7         7        7
# cage_4_subject_4             7      7     7           7         7        7
# cage_5_subject_1             7      7     7           7         7        7
# cage_5_subject_2             7      7     7           7         7        7
# cage_5_subject_3             7      7     7           7         7        7
# cage_5_subject_4             7      7     7           7         7        7
# cage_6_subject_1             7      7     7           7         7        7
# cage_6_subject_2             7      7     7           7         7        7
# cage_6_subject_3             7      7     7           7         7        7
# cage_6_subject_4             7      7     7           7         7        7
#
#                   Experiment  Group  Box  Start Time  End Time  MSN  \
# cage_and_subject
# cage_0_subject_0           1      1    1           1         1    1
# cage_1_subject_1           7      7    7           7         7    7
# cage_1_subject_2           7      7    7           7         7    7
# cage_1_subject_3           7      7    7           7         7    7
# cage_1_subject_4           7      7    7           7         7    7
# cage_2_subject_1           7      7    7           7         7    7
# cage_2_subject_2           7      7    7           7         7    7
# cage_2_subject_3           7      7    7           7         7    7
# cage_2_subject_4           7      7    7           7         7    7
# cage_3_subject_1           7      7    7           7         7    7
# cage_3_subject_2           7      7    7           7         7    7
# cage_3_subject_3           7      7    7           7         7    7
# cage_3_subject_4           7      7    7           7         7    7
# cage_4_subject_1           7      7    7           7         7    7
# cage_4_subject_2           7      7    7           7         7    7
# cage_4_subject_3           7      7    7           7         7    7
# cage_4_subject_4           7      7    7           7         7    7
# cage_5_subject_1           7      7    7           7         7    7
# cage_5_subject_2           7      7    7           7         7    7
# cage_5_subject_3           7      7    7           7         7    7
# cage_5_subject_4           7      7    7           7         7    7
# cage_6_subject_1           7      7    7           7         7    7
# cage_6_subject_2           7      7    7           7         7    7
# cage_6_subject_3           7      7    7           7         7    7
# cage_6_subject_4           7      7    7           7         7    7
#
#                   file_name  cage  start_date_datetime  start_date_int  \
# cage_and_subject
# cage_0_subject_0          1     1                    1               1
# cage_1_subject_1          7     7                    7               7
# cage_1_subject_2          7     7                    7               7
# cage_1_subject_3          7     7                    7               7
# cage_1_subject_4          7     7                    7               7
# cage_2_subject_1          7     7                    7               7
# cage_2_subject_2          7     7                    7               7
# cage_2_subject_3          7     7                    7               7
# cage_2_subject_4          7     7                    7               7
# cage_3_subject_1          7     7                    7               7
# cage_3_subject_2          7     7                    7               7
# cage_3_subject_3          7     7                    7               7
# cage_3_subject_4          7     7                    7               7
# cage_4_subject_1          7     7                    7               7
# cage_4_subject_2          7     7                    7               7
# cage_4_subject_3          7     7                    7               7
# cage_4_subject_4          7     7                    7               7
# cage_5_subject_1          7     7                    7               7
# cage_5_subject_2          7     7                    7               7
# cage_5_subject_3          7     7                    7               7
# cage_5_subject_4          7     7                    7               7
# cage_6_subject_1          7     7                    7               7
# cage_6_subject_2          7     7                    7               7
# cage_6_subject_3          7     7                    7               7
# cage_6_subject_4          7     7                    7               7
#
#                   end_date_datetime  end_date_int
# cage_and_subject
# cage_0_subject_0                  1             1
# cage_1_subject_1                  7             7
# cage_1_subject_2                  7             7
# cage_1_subject_3                  7             7
# cage_1_subject_4                  7             7
# cage_2_subject_1                  7             7
# cage_2_subject_2                  7             7
# cage_2_subject_3                  7             7
# cage_2_subject_4                  7             7
# cage_3_subject_1                  7             7
# cage_3_subject_2                  7             7
# cage_3_subject_3                  7             7
# cage_3_subject_4                  7             7
# cage_4_subject_1                  7             7
# cage_4_subject_2                  7             7
# cage_4_subject_3                  7             7
# cage_4_subject_4                  7             7
# cage_5_subject_1                  7             7
# cage_5_subject_2                  7             7
# cage_5_subject_3                  7             7
# cage_5_subject_4                  7             7
# cage_6_subject_1                  7             7
# cage_6_subject_2                  7             7
# cage_6_subject_3                  7             7
# cage_6_subject_4                  7             7

# %% [markdown]
# ## Looking over the MED-PC scripts

# %% [markdown]
# - MED-PC has scripts(lines of code that act as the instructions for how to operate the MED-PC boxes) that contain the descriptions of what each value in the recordings are. We will extract the descriptions from the MED-PC scripts so that we can label the data points in the MED-PC recordings
# - Below is a list of all the MED-PC Scripts. We will only be looking at the first one

# %%
all_medpc_scripts = glob.glob("./data/**/*.MPC")

# %%
all_medpc_scripts
# Out:
# ['./data/textfiles/C57_reward_competition.MPC',
#  './data/textfiles/CD1_reward_training.MPC',
#  './data/textfiles/CD1_reward_competition.MPC',
#  './data/textfiles/C57_reward_training.MPC']

# %% [markdown]
# - Example of what the MED-PC Script looks like that was ran when recording the behaviors

# %%
with open(all_medpc_scripts[0]) as f:
    lines = f.readlines()
    for line in lines[:100]:
        print(line)
# Out:
# \v3 stop tone with poke
#
# \v3.2 monitor port entries AND exits
#
#
#
# \INPUTS
#
# ^port = 8
#
#
#
# \OUTPUTS
#
# ^fan = 16
#
# ^houselight = 11
#
# ^tone1 = 2
#
# ^tone2 = 3
#
# ^tone3 = 4
#
# ^tone4 = 5
#
# ^pump = 9
#
# ^whitenoise = 1
#
# ^csout = 5
#
# ^peout = 15
#
# ^cs1out = 17
#
# ^cs2out = 13
#
# ^cs3out = 14
#
#
#
# \EXP SETTINGS
#
# ^ncsNoShock = 0
#
# ^initCS1trials = 3
#
#
#
# \ARRAYS
#
# DIM P = 20000 \Port entry time stamp array
#
# DIM Q = 2500 \US delivery time stamp array (absolute)
#
# DIM R = 2500 \US time stamp array (relative to last CS)
#
# DIM W = 2500 \ITI values used for CS
#
# DIM S = 2500 \CS presentation values (absolute - every time light turns on)
#
# DIM N = 20000 \Port exit time stamp array
#
# DIM K = 2500 \CS type
#
# DIM G = 2500 \controlled_stimulus_seconds computer clock time (seconds on clock every time light turns on)
#
# DIM H = 2500 \controlled_stimulus_minutes computer clock time (minutes on clock every time light turns on)
#
# DIM I = 2500 \controlled_stimulus_hours computer clock time (hours every time light turns on)
#
# DIM B = 2500 \port_entry_seconds computer clock time (seconds on clock every time light turns on)
#
# DIM F = 2500 \port_entry_minutes computer clock time (minutes on clock every time light turns on)
#
# DIM J = 2500 \port_entry_hours computer clock time (hours every time light turns on)
#
#
#
# \Original List of ITIs
#
# \LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90", 100", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90" \, 100", 108", 117", 121", 133", 145", 165" \CS ITI values (tone + houselight)
#
# \ 30 Minute Duration for Competition
#
# LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80"
#
# \ 60 Minute Duration for Training
#
# \LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90"
#
#
#
# \Counter and Flag array
#
# DIM C = 10
#
# \All counters are zero-indexed!! Meaning, if C(0) = 3, there were 4 port entries
#
# \C(0) counter for number of port entries
#
# \C(1) counter for CS presentation number
#
# \C(2) counter for US delivery : this is 1-indexed,  meaning number indicates number of sucrose deliveries
#
# \C(3) flag to indicate if sucrose is in port =0 if no port entry was made, =1 if port entry was made (i.e., no sucrose)
#
# \C(4) counter for number of port exits
#
# \C(5) number of CS1
#
# \C(6) number of CS2
#
# \C(7) number of CS3
#
# \C(8) number of sucrose deliveries
#
#
#
# \Z-pulses
#
# \Z1: start task after initial delay
#
# \Z2: start of CS
#
# \Z3: port entry
#
# \Z4: port exit
#
# \Z5: trigger CS1
#
# \Z6: trigger CS2
#
# \Z7: trigger CS3
#
# \Z8: turn off all CS triggers
#
# \Z12: INX trigger TTL
#
#
#
# \Variables
#
# \A - Time since last CS
#
# \B -
#
# \C - Counter array
#
# \D - Current ITI value
#
# \E - CS ITI values for first few trials
#
# \F -
#
# \G -
#
# \H -
#
# \I -
#
# \J -
#
# \K - CS type
#
# \L -
#
# \M - CS type repo
#
# \N - Port exit time stamp array
#
# \O -
#
# \P - Port entry time stamp array
#
# \Q - Sucrose delivery time stamp array (absolute)
#
# \R - Sucrose delivery time stamp array (relative to last CS)
#
# \S - CS presentation time stamp array
#
# \T - Session timer
#
# \U - Time since last CS presentation
#
# \V - List of CS ITI values (tone + houselight)
#
# \W - ITI values used for CS one each trial
#
# \X -
#
# \Y - Beam break monitor variable
#
# \Z -

# %% [markdown]
# - We will be using the comments in the MED-PC script(Everything after the `\` for each line) to create a name for the variables. By default, MED-PC uses a single letter as the name of the variable(programming object that holds some information).
#     - This will use the medpc2excel library found in https://github.com/cyf203/medpc2excel
# - Example of the variable names and their comments in the MED-PC script that we will get the descriptive names from:
#     - MED-PC will squish the first few words to create the name for every variable
#
# ```
# DIM P = 20000 \Port entry time stamp array
#
# DIM Q = 2500 \US delivery time stamp array (absolute)
#
# DIM R = 2500 \US time stamp array (relative to last CS)
#
# DIM W = 2500 \ITI values used for CS
#
# DIM S = 2500 \CS presentation values (absolute - every time light turns on)
#
# DIM N = 20000 \Port exit time stamp array
#
# DIM K = 2500 \CS type
#
# DIM B = 2500 \shock intensity
# ```

# %% [markdown]
# - In the MED-PC recording files, there are values that are labelled with letters. These data type of these letters is described in the MED-PC script file that we just looked at.

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-07-22_12h26m_Subject 1.txt
#
#
#
#
#
#
#
# Start Date: 07/22/22
#
# End Date: 07/22/22
#
# Subject: 1
#
# Experiment: C57_vs_CD1_comparison
#
# Group: Cage4
#
# Box: 1
#
# Start Time: 12:26:57
#
# End Time: 13:36:44
#
# MSN: CD1_reward_training
#
# A:    4399.000
#
# D:    9000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    3660.000

# %% [markdown]
# ## **NOTE: Please make sure that the corresponding `.mpc` file (aka the MED-PC script) that was ran to create the log file, is also in the same folder as the recording files. This notebook will fail to extract the data from the recording file if it is missing**

# %% [markdown]
# - Spreadsheet of the data from the MED-PC recording file for all the files combined into one.
# - **NOTE: Each row does not correspond to the same data point. Each row represents the "n"-th data point for each category for each file. AKA, the first row is the first data point for the time the subject entered the port and the first data point for the time that the tone that is played, two seperate things. The second row is the second data point for all the categories, the third row is the third data point and so on. This repeats for all data points in a given file, then it starts over to the next file where the first row of that file is the first for all its data points.**

# %%
concatted_medpc_df = extract.dataframe.get_medpc_dataframe_from_list_of_files(medpc_files=all_med_pc_file)
# Out:
# Traceback (most recent call last):
#   File "/root/projects/behavioral_dataframe_processing/results/2022_07_20_repeated_id_fix/../../src/extract/dataframe.py", line 71, in get_medpc_dataframe_from_list_of_files
#     ts_df, medpc_log = medpc_read(file=file_path, override=True, replace=False)
#   File "/root/projects/behavioral_dataframe_processing/behavioral_processing_env/lib/python3.9/site-packages/medpc2excel/medpc_read.py", line 134, in medpc_read
#     for var, nm in TS_var_name_maps[program_nm].items():
# KeyError: 'pumptest'
#
# Invalid Formatting for file: ./data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-21_12h24m_Subject 0.txt

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          6.22           64.0      399.0           0.0              60.01
# 1          6.28          144.0      399.0           0.0             140.01
# 2          6.38          234.0      399.0           0.0             230.01
# 3          6.44          314.0      399.0           0.0             310.01
# 4          6.64          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         6.26        1.0                                    44.0
# 1         6.36        1.0                                     4.0
# 2         6.41        1.0                                    34.0
# 3         6.52        1.0                                    54.0
# 4         6.69        1.0                                     9.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    36.0
# 1                                    38.0
# 2                                    39.0
# 3                                    40.0
# 4                                    42.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  12.0                           50.0
# 1                                  12.0                           50.0
# 2                                  12.0                           50.0
# 3                                  12.0                           51.0
# 4                                  12.0                           51.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           35.0                         12.0  20220722
# 1                           35.0                         12.0  20220722
# 2                           35.0                         12.0  20220722
# 3                           35.0                         12.0  20220722
# 4                           35.0                         12.0  20220722
#
#   subject                                          file_path
# 0       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4       1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...

# %%
concatted_medpc_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 2805       3651.72            NaN        NaN           NaN                NaN
# 2806       3651.81            NaN        NaN           NaN                NaN
# 2807       3655.18            NaN        NaN           NaN                NaN
# 2808       3655.31            NaN        NaN           NaN                NaN
# 2809       3655.42            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 2805      3651.74        NaN                                     NaN
# 2806      3651.88        NaN                                     NaN
# 2807      3655.24        NaN                                     NaN
# 2808      3655.36        NaN                                     NaN
# 2809      3655.46        NaN                                     NaN
#
#       (H)controlled_stimulus_minutescomputer  \
# 2805                                     NaN
# 2806                                     NaN
# 2807                                     NaN
# 2808                                     NaN
# 2809                                     NaN
#
#       (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 2805                                   NaN                            NaN
# 2806                                   NaN                            NaN
# 2807                                   NaN                            NaN
# 2808                                   NaN                            NaN
# 2809                                   NaN                            NaN
#
#       (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 2805                            NaN                          NaN  20220724
# 2806                            NaN                          NaN  20220724
# 2807                            NaN                          NaN  20220724
# 2808                            NaN                          NaN  20220724
# 2809                            NaN                          NaN  20220724
#
#      subject                                          file_path
# 2805       3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2806       3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2807       3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2808       3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2809       3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...

# %% [markdown]
# - Combining the recording and the metadata into one dataframe

# %%
recording_and_metadata_df = metadata_df.merge(concatted_medpc_df, right_on='file_path', left_on='index')

# %%
recording_and_metadata_df
# Out:
#         trial_number                                              index  \
# 0                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...              ...                                                ...
# 426071             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                   File Start Date  End Date  \
# 0       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 426071  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426072  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426073  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426074  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426075  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
#
#        Subject             Experiment   Group Box Start Time  ... (K)CStype  \
# 0            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 1            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 2            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 3            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 4            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# ...        ...                    ...     ...  ..        ...  ...       ...
# 426071       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426072       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426073       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426074       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426075       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 0                                        24.0
# 1                                        44.0
# 2                                        14.0
# 3                                        34.0
# 4                                        49.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 0                                        50.0
# 1                                        51.0
# 2                                        53.0
# 3                                        54.0
# 4                                        55.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                       8.0                          47.0
# 1                                       8.0                          48.0
# 2                                       8.0                          11.0
# 3                                       8.0                          26.0
# 4                                       8.0                          27.0
# ...                                     ...                           ...
# 426071                                  NaN                           0.0
# 426072                                  NaN                           0.0
# 426073                                  NaN                          40.0
# 426074                                  NaN                           0.0
# 426075                                  NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                               50.0                          8.0  20220718
# 1                               50.0                          8.0  20220718
# 2                               53.0                          8.0  20220718
# 3                               57.0                          8.0  20220718
# 4                               57.0                          8.0  20220718
# ...                              ...                          ...       ...
# 426071                           NaN                          NaN  20220724
# 426072                           NaN                          NaN  20220724
# 426073                           NaN                          NaN  20220724
# 426074                           NaN                          NaN  20220724
# 426075                           NaN                          NaN  20220724
#
#         subject                                          file_path
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...         ...                                                ...
# 426071        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [426076 rows x 35 columns]

# %%
recording_and_metadata_df
# Out:
#         trial_number                                              index  \
# 0                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...              ...                                                ...
# 426071             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                   File Start Date  End Date  \
# 0       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 426071  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426072  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426073  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426074  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426075  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
#
#        Subject             Experiment   Group Box Start Time  ... (K)CStype  \
# 0            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 1            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 2            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 3            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# 4            1  C57_vs_CD1_Comparison   Cage1   1   08:24:13  ...       1.0
# ...        ...                    ...     ...  ..        ...  ...       ...
# 426071       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426072       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426073       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426074       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
# 426075       4  C57_vs_CD1_comparison  Cage 6   2   14:53:31  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 0                                        24.0
# 1                                        44.0
# 2                                        14.0
# 3                                        34.0
# 4                                        49.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 0                                        50.0
# 1                                        51.0
# 2                                        53.0
# 3                                        54.0
# 4                                        55.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                       8.0                          47.0
# 1                                       8.0                          48.0
# 2                                       8.0                          11.0
# 3                                       8.0                          26.0
# 4                                       8.0                          27.0
# ...                                     ...                           ...
# 426071                                  NaN                           0.0
# 426072                                  NaN                           0.0
# 426073                                  NaN                          40.0
# 426074                                  NaN                           0.0
# 426075                                  NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                               50.0                          8.0  20220718
# 1                               50.0                          8.0  20220718
# 2                               53.0                          8.0  20220718
# 3                               57.0                          8.0  20220718
# 4                               57.0                          8.0  20220718
# ...                              ...                          ...       ...
# 426071                           NaN                          NaN  20220724
# 426072                           NaN                          NaN  20220724
# 426073                           NaN                          NaN  20220724
# 426074                           NaN                          NaN  20220724
# 426075                           NaN                          NaN  20220724
#
#         subject                                          file_path
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...         ...                                                ...
# 426071        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [426076 rows x 35 columns]

# %% [markdown]
# ## Getting the cage numbers and the dates so that we can include it in the file name

# %% [markdown]
# - We will get the metadata from the recording files and use it to name the files we will create. This will help organize the files and make it easy to know where each file came from

# %% [markdown]
# - Getting the group numbers(original cage names)

# %%
# removing blank spaces
group_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["Group"].unique() if number]
# sorting numbers
group_numbers = sorted(group_numbers)
group_numbers_for_title = "_".join(group_numbers)

# %%
group_numbers_for_title
# Out:
# 'Cage1_Cage2_Cage3_Cage4_Cage5_Cage6_Cage_1_Cage_2_Cage_4_Cage_5_Cage_6_cage5'

# %% [markdown]
# - Getting the cage numbers

# %%
# removing blank spaces
cage_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["cage"].unique() if number]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4_5_6'

# %% [markdown]
# - Getting the dates

# %%
# Getting the first and last recording date to get a range
earliest_date = recording_and_metadata_df["end_date_int"].min()
latest_date = recording_and_metadata_df["end_date_int"].max()

# %%
earliest_date
# Out:
# 20220718

# %%
latest_date
# Out:
# 20220724

# %% [markdown]
# - Getting the subject names

# %%
recording_and_metadata_df["Subject"].unique()
# Out:
# array(['1', '2', '3', '4'], dtype=object)

# %%
# removing blank spaces
subject_numbers = ["subject-" + number for number in recording_and_metadata_df["Subject"].unique() if number]
# sorting numbers
subject_numbers = sorted(subject_numbers)
subject_numbers_for_title = "_".join(subject_numbers)

# %%
subject_numbers_for_title
# Out:
# 'subject-1_subject-2_subject-3_subject-4'

# %% [markdown]
# - Getting the experiment name

# %%
experiment_names = ["_".join(name.upper().split()) for name in recording_and_metadata_df["Experiment"].unique() if name]
# sorting experiment_names
experiment_names = list(set(sorted(experiment_names)))
experiment_names_for_title = "AND".join(experiment_names)

# %%
experiment_names_for_title
# Out:
# 'C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON'

# %% [markdown]
# - Getting the box numbers

# %%
# removing blank spaces
box_numbers = ["_".join(number.split()) for number in recording_and_metadata_df["Box"].unique() if number]
# sorting numbers
box_numbers = sorted(box_numbers)
box_numbers_for_title = "_".join(box_numbers)

# %%
box_numbers_for_title
# Out:
# '1_2_3_4'

# %% [markdown]
# - Getting the script names

# %%
# removing blank spaces
script_names = ["_".join(name.split()) for name in recording_and_metadata_df["MSN"].unique() if name]
# sorting names
script_names = sorted(script_names)
script_names_for_title = "_".join(script_names)

# %%
script_names_for_title
# Out:
# 'C57_reward_training_CD1_reward_training'

# %% [markdown]
# ## Saving the dataframes(spreadsheets to files) with the metadata as part of the name

# %% [markdown]
# - Making necessary directories
#     - If you want to use any of the other metadata as part of the name, you will have to swap out the variables in the `format()` and change the name of the folder to match your new name. The variable names are the word that's in front of the `=` at the last line of each cell. The `{}` are where the metadata variables will be inserted into the file name. For more information on formatting strings: https://www.w3schools.com/python/ref_string_format.asp
#     - You can also just manually rename the files by replacing everything in `""` and removing the `.format()` part
# - **NOTE: You may get an error that the file does not exist. If this is the case, it could be the file name is too long(an issue that may happen when using Jupyter Notebooks on Windows)**

# %%
output_directory = "./proc/extracted_recording_data_and_metadata/experiment_{}_cage_{}_date_{}_{}".format(experiment_names_for_title, cage_numbers_for_title, earliest_date, latest_date)

# %%
output_directory
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(output_directory, exist_ok=True)

# %%
metadata_df.to_csv(os.path.join(output_directory, "metadata_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# metadata_df.to_excel(os.path.join(output_directory, "metadata_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %%
concatted_medpc_df.to_csv(os.path.join(output_directory, "MEDPC_recording_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# concatted_medpc_df.to_excel(os.path.join(output_directory, "MEDPC_recording_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %%
recording_and_metadata_df.to_csv(os.path.join(output_directory, "recording_metadata_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
# recording_and_metadata_df.to_excel(os.path.join(output_directory, "recording_and_metadata_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

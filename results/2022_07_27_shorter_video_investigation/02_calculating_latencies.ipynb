# %% [markdown]
# # Notebook 2: MED-PC Calculating Latencies

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from medpc2excel.medpc_read import medpc_read
import matplotlib.ticker as ticker

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %%
# Increase size of plot in jupyter

plt.rcParams["figure.figsize"] = (10,6)

# %% [markdown]
# # Loading in Recording and Metadata from Previous Notebook

# %% [markdown]
# # NOTE: If you changed the directory of where the MED-PC recording dataframes, then you must change the directories in the following paths

# %% [markdown]
# - This will get all the files in each specified path. The `*` is called a wildcard, and it can be replaced with any number of characters.
#     - For more information: https://www.malikbrowne.com/blog/a-beginners-guide-glob-patterns

# %%
concatted_medpc_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/MEDPC_recording_*.csv")
metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/metadata_*.csv")
recording_and_metadata_files = glob.glob("./proc/extracted_recording_data_and_metadata/*/recording_metadata_*.csv")

# %% [markdown]
# # NOTE: If there is more than one MED-PC recording dataframes, then you must manually change the path in the `pd.read_csv()` for the corresponding variables. Verify if this is the correct file that you want to use

# %%
metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/metadata_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
concatted_medpc_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/MEDPC_recording_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
recording_and_metadata_files[0]
# Out:
# './proc/extracted_recording_data_and_metadata/experiment_C57_VS_CD1_COMPARISOMANDC57_VS_CD1_COMPARISON_cage_1_2_3_4_5_6_date_20220718_20220724/recording_metadata_cage_1_2_3_4_5_6_date_20220718_20220724.csv'

# %%
metadata_df = pd.read_csv(metadata_files[0], index_col=0)
concatted_medpc_df = pd.read_csv(concatted_medpc_files[0], index_col=0)
recording_and_metadata_df = pd.read_csv(recording_and_metadata_files[0], index_col=0)

# %% [markdown]
# - The Dataframe the contains the metadata(columns) of each recording file(rows)
#     - We will mostly use this to get the cage number for each subject

# %%
metadata_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-21_12h24m_Subject 0.txt   07/21/22  07/21/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_16h39m_Subject 1.txt   07/18/22  07/19/22
# 3  C:\MED-PC\Data\2022-07-20_08h09m_Subject 1.txt   07/20/22  07/20/22
# 4  C:\MED-PC\Data\2022-07-21_08h50m_Subject 1.txt   07/21/22  07/21/22
#
#    Subject             Experiment   Group  Box Start Time  End Time  \
# 0        0                      0       0    1   12:24:06  12:35:30
# 1        1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  09:50:24
# 2        1  C57_vs_CD1_Comparison  Cage 1    2   16:39:59  09:52:50
# 3        1  C57_vs_CD1_comparison  Cage 1    3   08:09:22  09:27:22
# 4        1  C57_vs_CD1_comparison  Cage 1    4   08:50:56  09:59:08
#
#                    MSN                        file_name  cage  \
# 0             pumptest  2022-07-21_12h24m_Subject 0.txt     0
# 1  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 2  C57_reward_training  2022-07-18_16h39m_Subject 1.txt     1
# 3  C57_reward_training  2022-07-20_08h09m_Subject 1.txt     1
# 4  C57_reward_training  2022-07-21_08h50m_Subject 1.txt     1
#
#    cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0  cage_0_subject_0          2022-07-21        20220721        2022-07-21
# 1  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 2  cage_1_subject_1          2022-07-18        20220718        2022-07-19
# 3  cage_1_subject_1          2022-07-20        20220720        2022-07-20
# 4  cage_1_subject_1          2022-07-21        20220721        2022-07-21
#
#    end_date_int
# 0      20220721
# 1      20220718
# 2      20220719
# 3      20220720
# 4      20220721

# %% [markdown]
# - The Dataframe the contains the recording data for all the files.
#     - The 1st row is the first data entries for each type of data(with the type being specified by the column label). This does not mean that all these are related or occured for the same trial. i.e. There can be many port entries and exits for a subject before and after a tone is played.
#     - Each recording session will usually have a few thousand rows(although, most of of the columns will probably be blank by the end). And then after the last row of one session, the next row will be the next session with a different `file_path`

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          6.22           64.0      399.0           0.0              60.01
# 1          6.28          144.0      399.0           0.0             140.01
# 2          6.38          234.0      399.0           0.0             230.01
# 3          6.44          314.0      399.0           0.0             310.01
# 4          6.64          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         6.26        1.0                                    44.0
# 1         6.36        1.0                                     4.0
# 2         6.41        1.0                                    34.0
# 3         6.52        1.0                                    54.0
# 4         6.69        1.0                                     9.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    36.0
# 1                                    38.0
# 2                                    39.0
# 3                                    40.0
# 4                                    42.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  12.0                           50.0
# 1                                  12.0                           50.0
# 2                                  12.0                           50.0
# 3                                  12.0                           51.0
# 4                                  12.0                           51.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           35.0                         12.0  20220722
# 1                           35.0                         12.0  20220722
# 2                           35.0                         12.0  20220722
# 3                           35.0                         12.0  20220722
# 4                           35.0                         12.0  20220722
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...

# %% [markdown]
# - This dataframe combines the recording data and metadata dataframes. This is done by using the subject ID as a common column to merge together off of.

# %%
recording_and_metadata_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [raw]
# #TODO
# # Creating a new column that combines cage number and subject

# %% [raw]
# - This is needed because previously the code would treat subjects that have the same ID name as the same, even if the cages were different

# %% [raw]
# recording_and_metadata_df["cage_and_subject"] = recording_and_metadata_df.apply(lambda x: "cage_{}_subject_{}".format(x["cage"], x["Subject"]), axis=1)

# %% [raw]
# recording_and_metadata_df.head()

# %% [markdown]
# # Getting the Cage Numbers and the Dates for the file names

# %% [markdown]
# - Seeing if any rows have NaN values for the cages

# %%
recording_and_metadata_df[pd.isna(recording_and_metadata_df["cage"])]
# Out:
# Empty DataFrame
# Columns: [trial_number, index, File, Start Date, End Date, Subject, Experiment, Group, Box, Start Time, End Time, MSN, file_name, cage, cage_and_subject, start_date_datetime, start_date_int, end_date_datetime, end_date_int, (P)Portentry, (Q)USdelivery, (R)UStime, (W)ITIvalues, (S)CSpresentation, (N)Portexit, (K)CStype, (G)controlled_stimulus_secondscomputer, (H)controlled_stimulus_minutescomputer, (I)controlled_stimulus_hourscomputer, (B)port_entry_secondscomputer, (F)port_entry_minutescomputer, (J)port_entry_hourscomputer, date, subject, file_path]
# Index: []
#
# [0 rows x 35 columns]

# %% [markdown]
# - Dropping the NaN values so we can get the cage numbers

# %%
recording_and_metadata_df = recording_and_metadata_df.dropna(subset=["cage"])

# %% [markdown]
# # Adjusting the days and cages that are being looked at

# %% [markdown]
# - List of all the subject names

# %%
all_subjects = sorted(recording_and_metadata_df["cage_and_subject"].unique())

# %%
all_subjects
# Out:
# ['cage_1_subject_1',
#  'cage_1_subject_2',
#  'cage_1_subject_3',
#  'cage_1_subject_4',
#  'cage_2_subject_1',
#  'cage_2_subject_2',
#  'cage_2_subject_3',
#  'cage_2_subject_4',
#  'cage_3_subject_1',
#  'cage_3_subject_2',
#  'cage_3_subject_3',
#  'cage_3_subject_4',
#  'cage_4_subject_1',
#  'cage_4_subject_2',
#  'cage_4_subject_3',
#  'cage_4_subject_4',
#  'cage_5_subject_1',
#  'cage_5_subject_2',
#  'cage_5_subject_3',
#  'cage_5_subject_4',
#  'cage_6_subject_1',
#  'cage_6_subject_2',
#  'cage_6_subject_3',
#  'cage_6_subject_4']

# %% [markdown]
# - List of all the cage numbers

# %%
all_cages = sorted(recording_and_metadata_df["cage"].unique())

# %%
all_cages
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# - List of all the dates

# %%
all_dates = sorted(recording_and_metadata_df["end_date_int"].unique())

# %%
all_dates
# Out:
# [20220718, 20220719, 20220720, 20220721, 20220722, 20220723, 20220724]

# %% [markdown]
# # NOTE: Follow directions below if you want to change which cages or dates to plot

# %% [markdown]
# - You must change the cell below by clicking on the cell and then pressing the `esc` key. Then press the `Y` button on your keyboard. If you want to switch it back do the same but press the `R` button instead. This switches it from a cell that is run as if it's code, or back to a cell where it's just treated as text
# - Then from above, copy the numbers that you want to use for the cage numbers and the dates

# %% [raw]
# all_cages = [1, 2]
# all_dates = [20220504,
#  20220505,
#  20220506,
#  20220507,
#  20220508]

# %%
recording_and_metadata_df = recording_and_metadata_df[recording_and_metadata_df["cage"].isin(all_cages) & recording_and_metadata_df["date"].isin(all_dates)]

# %%
recording_and_metadata_df
# Out:
#         trial_number                                              index  \
# 0                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4                  1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...              ...                                                ...
# 426071             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                   File Start Date  End Date  \
# 0       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4       C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 426071  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426072  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426073  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426074  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
# 426075  C:\MED-PC\Data\2022-07-24_14h53m_Subject 4.txt   07/24/22  07/24/22
#
#         Subject             Experiment   Group  Box Start Time  ... (K)CStype  \
# 0             1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  ...       1.0
# 1             1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  ...       1.0
# 2             1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  ...       1.0
# 3             1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  ...       1.0
# 4             1  C57_vs_CD1_Comparison   Cage1    1   08:24:13  ...       1.0
# ...         ...                    ...     ...  ...        ...  ...       ...
# 426071        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426072        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426073        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426074        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
# 426075        4  C57_vs_CD1_comparison  Cage 6    2   14:53:31  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 0                                        24.0
# 1                                        44.0
# 2                                        14.0
# 3                                        34.0
# 4                                        49.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 0                                        50.0
# 1                                        51.0
# 2                                        53.0
# 3                                        54.0
# 4                                        55.0
# ...                                       ...
# 426071                                    NaN
# 426072                                    NaN
# 426073                                    NaN
# 426074                                    NaN
# 426075                                    NaN
#
#         (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                        8.0                          47.0
# 1                                        8.0                          48.0
# 2                                        8.0                          11.0
# 3                                        8.0                          26.0
# 4                                        8.0                          27.0
# ...                                      ...                           ...
# 426071                                   NaN                           0.0
# 426072                                   NaN                           0.0
# 426073                                   NaN                          40.0
# 426074                                   NaN                           0.0
# 426075                                   NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                               50.0                          8.0  20220718
# 1                               50.0                          8.0  20220718
# 2                               53.0                          8.0  20220718
# 3                               57.0                          8.0  20220718
# 4                               57.0                          8.0  20220718
# ...                              ...                          ...       ...
# 426071                           NaN                          NaN  20220724
# 426072                           NaN                          NaN  20220724
# 426073                           NaN                          NaN  20220724
# 426074                           NaN                          NaN  20220724
# 426075                           NaN                          NaN  20220724
#
#         subject                                          file_path
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...         ...                                                ...
# 426071        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426072        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426073        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426074        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 426075        4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [426076 rows x 35 columns]

# %% [markdown]
# # Getting the Cage Numbers and the Dates to name the files

# %%
# removing blank spaces
cage_numbers = [str(int(number)) for number in all_cages if number is not np.nan]
# sorting numbers
cage_numbers = sorted(cage_numbers)
cage_numbers_for_title = "_".join(cage_numbers)

# %%
cage_numbers_for_title
# Out:
# '1_2_3_4_5_6'

# %%
# Getting the first and last recording date to get a range
earliest_date = min(all_dates)
latest_date = max(all_dates)

# %%
earliest_date
# Out:
# 20220718

# %%
latest_date
# Out:
# 20220724

# %% [markdown]
# # Getting the times that the tones are being played

# %% [markdown]
# - Getting all the rows that correspond to one of the files paths. This will be the equivalent of getting all the rows for one session

# %%
example_file = recording_and_metadata_df["file_path"].unique()[0]

# %%
example_file
# Out:
# './data/pilot_c57_vs_cd1/reward_training/med_pc_text_files/2022-07-18_08h24m_Subject 1.txt'

# %%
example_one_session_recording_df = recording_and_metadata_df[recording_and_metadata_df["file_path"] == example_file]

# %% [markdown]
# - Everything looks normal enough

# %%
example_one_session_recording_df.head()
# Out:
#    trial_number                                              index  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                              File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 1  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 3  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 4  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#    Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 0        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 1        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 2        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 3        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
# 4        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       1.0
#
#   (G)controlled_stimulus_secondscomputer  \
# 0                                   24.0
# 1                                   44.0
# 2                                   14.0
# 3                                   34.0
# 4                                   49.0
#
#   (H)controlled_stimulus_minutescomputer  \
# 0                                   50.0
# 1                                   51.0
# 2                                   53.0
# 3                                   54.0
# 4                                   55.0
#
#    (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 0                                   8.0                          47.0
# 1                                   8.0                          48.0
# 2                                   8.0                          11.0
# 3                                   8.0                          26.0
# 4                                   8.0                          27.0
#
#   (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                          50.0                          8.0  20220718
# 1                          50.0                          8.0  20220718
# 2                          53.0                          8.0  20220718
# 3                          57.0                          8.0  20220718
# 4                          57.0                          8.0  20220718
#
#    subject                                          file_path
# 0        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 1        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 3        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 4        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [markdown]
# - `(S)CSpresentation` is the time that the tone starts playing. MED-PC starts inputting in random numbers that are in the 1000's. So we will remove these

# %%
example_one_session_recording_df[50:60]
# Out:
#     trial_number                                              index  \
# 50             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 51             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 52             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 53             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 54             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 55             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 56             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 57             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 58             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 59             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                               File Start Date  End Date  \
# 50  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 51  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 52  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 53  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 54  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 55  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 56  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 57  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 58  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 59  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#     Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 50        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 51        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 52        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 53        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 54        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 55        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 56        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 57        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 58        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
# 59        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       0.0
#
#    (G)controlled_stimulus_secondscomputer  \
# 50                                    0.0
# 51                                    0.0
# 52                                    0.0
# 53                                    0.0
# 54                                    0.0
# 55                                    0.0
# 56                                    0.0
# 57                                    0.0
# 58                                    0.0
# 59                                    0.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 50                                    0.0
# 51                                    0.0
# 52                                    0.0
# 53                                    0.0
# 54                                    0.0
# 55                                    0.0
# 56                                    0.0
# 57                                    0.0
# 58                                    0.0
# 59                                    0.0
#
#     (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 50                                   0.0                           0.0
# 51                                   0.0                           0.0
# 52                                   0.0                           0.0
# 53                                   0.0                           0.0
# 54                                   0.0                           0.0
# 55                                   0.0                           0.0
# 56                                   0.0                           0.0
# 57                                   0.0                           0.0
# 58                                   0.0                           0.0
# 59                                   0.0                           0.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 50                           0.0                          0.0  20220718
# 51                           0.0                          0.0  20220718
# 52                           0.0                          0.0  20220718
# 53                           0.0                          0.0  20220718
# 54                           0.0                          0.0  20220718
# 55                           0.0                          0.0  20220718
# 56                           0.0                          0.0  20220718
# 57                           0.0                          0.0  20220718
# 58                           0.0                          0.0  20220718
# 59                           0.0                          0.0  20220718
#
#     subject                                          file_path
# 50        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 51        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 52        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 53        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 54        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 55        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 56        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 57        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 58        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 59        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [10 rows x 35 columns]

# %% [markdown]
# - `(S)CSpresentation` then starts adding blanks(NaN) so we will remove these too

# %%
example_one_session_recording_df.tail()
# Out:
#       trial_number                                              index  \
# 2507             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2508             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2509             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2510             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2511             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                 File Start Date  End Date  \
# 2507  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2508  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2509  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2510  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
# 2511  C:\MED-PC\Data\2022-07-18_08h24m_Subject 1.txt   07/18/22  07/18/22
#
#       Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 2507        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       NaN
# 2508        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       NaN
# 2509        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       NaN
# 2510        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       NaN
# 2511        1  C57_vs_CD1_Comparison  Cage1    1   08:24:13  ...       NaN
#
#      (G)controlled_stimulus_secondscomputer  \
# 2507                                    NaN
# 2508                                    NaN
# 2509                                    NaN
# 2510                                    NaN
# 2511                                    NaN
#
#      (H)controlled_stimulus_minutescomputer  \
# 2507                                    NaN
# 2508                                    NaN
# 2509                                    NaN
# 2510                                    NaN
# 2511                                    NaN
#
#       (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 2507                                   NaN                           0.0
# 2508                                   NaN                           0.0
# 2509                                   NaN                          20.0
# 2510                                   NaN                           0.0
# 2511                                   NaN                           0.0
#
#      (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 2507                           NaN                          NaN  20220718
# 2508                           NaN                          NaN  20220718
# 2509                           NaN                          NaN  20220718
# 2510                           NaN                          NaN  20220718
# 2511                           NaN                          NaN  20220718
#
#       subject                                          file_path
# 2507        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2508        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2509        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2510        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 2511        1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [5 rows x 35 columns]

# %% [markdown]
# - We will use a function that removes the `NaN` and the tone times that are divisible by 1000. This will get the tones time that were actually used for the recordings

# %%
example_one_session_valid_tones = processing.tone.get_valid_tones(example_one_session_recording_df["(S)CSpresentation"])

# %%
example_one_session_valid_tones
# Out:
# 0       60.01
# 1      140.01
# 2      230.01
# 3      310.01
# 4      385.01
# 5      485.01
# 6      580.01
# 7      670.01
# 8      750.01
# 9      840.01
# 10     940.01
# 11    1030.01
# 12    1150.01
# 13    1240.01
# 14    1325.01
# 15    1415.01
# 16    1510.01
# 17    1630.01
# 18    1710.01
# 19    1805.01
# 20    1885.01
# 21    1975.01
# 22    2055.01
# 23    2130.01
# 24    2230.01
# 25    2325.01
# 26    2415.01
# 27    2495.01
# 28    2585.01
# 29    2685.01
# 30    2775.01
# 31    2895.01
# 32    2985.01
# 33    3070.01
# 34    3160.01
# 35    3255.01
# 36    3345.01
# 37    3425.01
# 38    3515.01
# Name: (S)CSpresentation, dtype: float64

# %% [markdown]
# # Getting the First Port Entry After Each Tone

# %% [markdown]
# - With these tone playing times, we will get the first port entry that comes after the tone playing time
#     - This was done by getting all the port entries that came after the tone. And then getting the port entry time that was earliest in time(aka smallest number)

# %%
processing.tone.get_first_port_entries_after_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=example_one_session_recording_df["(P)Portentry"], port_exits_pd_series=example_one_session_recording_df["(N)Portexit"])
# Out:
#     current_tone_time  first_port_entry_after_tone  \
# 0               60.01                        82.61
# 1              140.01                       226.55
# 2              230.01                       481.54
# 3              310.01                       481.54
# 4              385.01                       481.54
# 5              485.01                       485.21
# 6              580.01                       624.23
# 7              670.01                       792.77
# 8              750.01                       792.77
# 9              840.01                       927.48
# 10             940.01                      1251.97
# 11            1030.01                      1251.97
# 12            1150.01                      1251.97
# 13            1240.01                      1251.97
# 14            1325.01                      1366.10
# 15            1415.01                      1450.97
# 16            1510.01                      1619.17
# 17            1630.01                      1798.82
# 18            1710.01                      1798.82
# 19            1805.01                      1929.34
# 20            1885.01                      1929.34
# 21            1975.01                      2450.32
# 22            2055.01                      2450.32
# 23            2130.01                      2450.32
# 24            2230.01                      2450.32
# 25            2325.01                      2450.32
# 26            2415.01                      2450.32
# 27            2495.01                      2501.65
# 28            2585.01                      3144.52
# 29            2685.01                      3144.52
# 30            2775.01                      3144.52
# 31            2895.01                      3144.52
# 32            2985.01                      3144.52
# 33            3070.01                      3144.52
# 34            3160.01                      3176.04
# 35            3255.01                      3473.59
# 36            3345.01                      3473.59
# 37            3425.01                      3473.59
# 38            3515.01                      3602.92
#
#     port_exit_after_first_port_entry_after_tone
# 0                                         82.65
# 1                                        226.61
# 2                                        481.60
# 3                                        481.60
# 4                                        481.60
# 5                                        485.31
# 6                                        624.31
# 7                                        792.82
# 8                                        792.82
# 9                                        927.63
# 10                                      1252.02
# 11                                      1252.02
# 12                                      1252.02
# 13                                      1252.02
# 14                                      1366.24
# 15                                      1451.00
# 16                                      1619.52
# 17                                      1798.85
# 18                                      1798.85
# 19                                      1929.40
# 20                                      1929.40
# 21                                      2450.45
# 22                                      2450.45
# 23                                      2450.45
# 24                                      2450.45
# 25                                      2450.45
# 26                                      2450.45
# 27                                      2502.05
# 28                                      3144.60
# 29                                      3144.60
# 30                                      3144.60
# 31                                      3144.60
# 32                                      3144.60
# 33                                      3144.60
# 34                                      3176.95
# 35                                      3473.79
# 36                                      3473.79
# 37                                      3473.79
# 38                                      3602.99

# %% [markdown]
# - Getting the first port entry times for all the sessions

# %%
concatted_first_porty_entry_dataframe = processing.tone.get_concatted_first_porty_entry_after_tone_dataframe(concatted_medpc_df=recording_and_metadata_df)

# %%
concatted_first_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1

# %%
concatted_first_porty_entry_dataframe.tail()
# Out:
#       current_tone_time  first_port_entry_after_tone  \
# 6547            3160.01                      3169.51
# 6548            3255.01                      3259.46
# 6549            3345.01                      3357.60
# 6550            3425.01                      3466.06
# 6551            3515.01                      3517.13
#
#       port_exit_after_first_port_entry_after_tone  \
# 6547                                      3169.83
# 6548                                      3260.27
# 6549                                      3357.62
# 6550                                      3466.30
# 6551                                      3517.17
#
#                                               file_path      date  subject
# 6547  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6548  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6549  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6550  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6551  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4

# %% [markdown]
# # Getting the Last Port Entry Before the Tone

# %% [markdown]
# - We will do the same, but get the port entries that happened before the tone

# %%
port_entries_pd_series = example_one_session_recording_df["(P)Portentry"]
port_exit_pd_series = example_one_session_recording_df["(N)Portexit"]

# %% [markdown]
# - Example run for one session

# %%
example_last_port_entries_before_tone = processing.tone.get_last_port_entries_before_tone(tone_pd_series=example_one_session_valid_tones, port_entries_pd_series=port_entries_pd_series, port_exits_pd_series=port_exit_pd_series)

# %%
example_last_port_entries_before_tone
# Out:
#     current_tone_time  last_port_entry_before_tone  \
# 0               60.01                          NaN
# 1              140.01                        83.33
# 2              230.01                       226.55
# 3              310.01                       226.55
# 4              385.01                       226.55
# 5              485.01                       483.11
# 6              580.01                       486.06
# 7              670.01                       624.57
# 8              750.01                       624.57
# 9              840.01                       792.85
# 10             940.01                       927.48
# 11            1030.01                       927.48
# 12            1150.01                       927.48
# 13            1240.01                       927.48
# 14            1325.01                      1251.97
# 15            1415.01                      1366.10
# 16            1510.01                      1450.97
# 17            1630.01                      1619.17
# 18            1710.01                      1619.17
# 19            1805.01                      1798.82
# 20            1885.01                      1798.82
# 21            1975.01                      1929.34
# 22            2055.01                      1929.34
# 23            2130.01                      1929.34
# 24            2230.01                      1929.34
# 25            2325.01                      1929.34
# 26            2415.01                      1929.34
# 27            2495.01                      2450.32
# 28            2585.01                      2503.00
# 29            2685.01                      2503.00
# 30            2775.01                      2503.00
# 31            2895.01                      2503.00
# 32            2985.01                      2503.00
# 33            3070.01                      2503.00
# 34            3160.01                      3148.33
# 35            3255.01                      3176.04
# 36            3345.01                      3176.04
# 37            3425.01                      3176.04
# 38            3515.01                      3477.16
#
#     port_exit_after_last_port_entry_before_tone
# 0                                           NaN
# 1                                         83.55
# 2                                        226.61
# 3                                        226.61
# 4                                        226.61
# 5                                        483.21
# 6                                        486.13
# 7                                        624.78
# 8                                        624.78
# 9                                        792.92
# 10                                       927.63
# 11                                       927.63
# 12                                       927.63
# 13                                       927.63
# 14                                      1252.02
# 15                                      1366.24
# 16                                      1451.00
# 17                                      1619.52
# 18                                      1619.52
# 19                                      1798.85
# 20                                      1798.85
# 21                                      1929.40
# 22                                      1929.40
# 23                                      1929.40
# 24                                      1929.40
# 25                                      1929.40
# 26                                      1929.40
# 27                                      2450.45
# 28                                      2503.23
# 29                                      2503.23
# 30                                      2503.23
# 31                                      2503.23
# 32                                      2503.23
# 33                                      2503.23
# 34                                      3148.38
# 35                                      3176.95
# 36                                      3176.95
# 37                                      3176.95
# 38                                      3477.47

# %% [markdown]
# - Getting all the port entries that happen before the tone for all sessions

# %%
concatted_last_porty_entry_dataframe = processing.tone.get_concatted_last_porty_entry_before_tone_dataframe(concatted_medpc_df=recording_and_metadata_df)

# %%
concatted_last_porty_entry_dataframe
# Out:
#       current_tone_time  last_port_entry_before_tone  \
# 0                 60.01                          NaN
# 1                140.01                        83.33
# 2                230.01                       226.55
# 3                310.01                       226.55
# 4                385.01                       226.55
# ...                 ...                          ...
# 6547            3160.01                      3153.15
# 6548            3255.01                      3237.52
# 6549            3345.01                      3314.61
# 6550            3425.01                      3419.90
# 6551            3515.01                      3500.19
#
#       port_exit_after_last_port_entry_before_tone  \
# 0                                             NaN
# 1                                           83.55
# 2                                          226.61
# 3                                          226.61
# 4                                          226.61
# ...                                           ...
# 6547                                      3153.28
# 6548                                      3237.70
# 6549                                      3314.69
# 6550                                      3420.18
# 6551                                      3500.25
#
#                                               file_path      date  subject
# 0     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# ...                                                 ...       ...      ...
# 6547  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6548  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6549  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6550  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6551  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
#
# [6552 rows x 6 columns]

# %% [markdown]
# ## Merging the dataframes for the first port entry after the tone and the last tone before the tone

# %%
# Combining it based on the tone times and the file path
concatted_first_and_last_porty_entry_dataframe = pd.merge(concatted_first_porty_entry_dataframe, concatted_last_porty_entry_dataframe,  how='left', left_on=['current_tone_time','file_path'], right_on = ['current_tone_time','file_path'], suffixes=('', '_y'))
# Dropping all columns that are duplicates
concatted_first_and_last_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.drop(concatted_first_and_last_porty_entry_dataframe.filter(regex='_y$').columns.tolist(), axis=1)

# %%
# Adding the metadata
concatted_first_and_last_porty_entry_dataframe = pd.merge(concatted_first_and_last_porty_entry_dataframe, metadata_df,  how='left', left_on=['file_path'], right_on = ["index"], suffixes=('', '_y'))
# Making a new column for cage and subject combined
concatted_first_and_last_porty_entry_dataframe["cage_and_subject"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda x: "cage_{}_subject_{}".format(x["cage"], x["Subject"]), axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                          NaN                                          NaN
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
#
#    trial_number                                              index  ...  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#   Start Time  End Time                  MSN                        file_name  \
# 0   08:24:13  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt
# 1   08:24:13  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt
# 2   08:24:13  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt
# 3   08:24:13  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt
# 4   08:24:13  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt
#
#   cage  cage_and_subject  start_date_datetime start_date_int  \
# 0    1  cage_1_subject_1           2022-07-18       20220718
# 1    1  cage_1_subject_1           2022-07-18       20220718
# 2    1  cage_1_subject_1           2022-07-18       20220718
# 3    1  cage_1_subject_1           2022-07-18       20220718
# 4    1  cage_1_subject_1           2022-07-18       20220718
#
#   end_date_datetime end_date_int
# 0        2022-07-18     20220718
# 1        2022-07-18     20220718
# 2        2022-07-18     20220718
# 3        2022-07-18     20220718
# 4        2022-07-18     20220718
#
# [5 rows x 27 columns]

# %%
concatted_first_and_last_porty_entry_dataframe.shape
# Out:
# (6552, 27)

# %% [markdown]
# - Getting all the rows that have port entry to port exit time that overlaps with the tone playing
#     - This would be the port entries that came before the tone, but had a port exit after

# %%
port_entries_that_overlap = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["port_exit_after_last_port_entry_before_tone"] >= concatted_first_and_last_porty_entry_dataframe["current_tone_time"]]

# %%
port_entries_that_overlap.head()
# Out:
#      current_tone_time  first_port_entry_after_tone  \
# 90             1150.01                      1150.39
# 117              60.01                        71.47
# 154            3425.01                      3446.71
# 171            1415.01                      1415.30
# 175            1805.01                      1805.88
#
#      port_exit_after_first_port_entry_after_tone  \
# 90                                       1150.42
# 117                                        71.71
# 154                                      3446.75
# 171                                      1415.61
# 175                                      1805.90
#
#                                              file_path      date  subject  \
# 90   ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220720        1
# 117  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220721        1
# 154  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220721        1
# 171  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220722        1
# 175  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220722        1
#
#      last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 90                       1149.91                                      1150.30
# 117                        59.95                                        60.01
# 154                      3424.57                                      3426.94
# 171                      1415.00                                      1415.28
# 175                      1804.77                                      1805.86
#
#      trial_number                                              index  ...  \
# 90              3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 117             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 154             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 171             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 175             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#     Start Time  End Time                  MSN  \
# 90    08:09:22  09:27:22  C57_reward_training
# 117   08:50:56  09:59:08  C57_reward_training
# 154   08:50:56  09:59:08  C57_reward_training
# 171   09:00:32  10:05:02  C57_reward_training
# 175   09:00:32  10:05:02  C57_reward_training
#
#                            file_name cage  cage_and_subject  \
# 90   2022-07-20_08h09m_Subject 1.txt    1  cage_1_subject_1
# 117  2022-07-21_08h50m_Subject 1.txt    1  cage_1_subject_1
# 154  2022-07-21_08h50m_Subject 1.txt    1  cage_1_subject_1
# 171  2022-07-22_09h00m_Subject 1.txt    1  cage_1_subject_1
# 175  2022-07-22_09h00m_Subject 1.txt    1  cage_1_subject_1
#
#      start_date_datetime start_date_int end_date_datetime end_date_int
# 90            2022-07-20       20220720        2022-07-20     20220720
# 117           2022-07-21       20220721        2022-07-21     20220721
# 154           2022-07-21       20220721        2022-07-21     20220721
# 171           2022-07-22       20220722        2022-07-22     20220722
# 175           2022-07-22       20220722        2022-07-22     20220722
#
# [5 rows x 27 columns]

# %%
port_entries_that_overlap.shape
# Out:
# (772, 27)

# %% [markdown]
# # Getting the Latency for Each Session of a Tone Playing

# %% [markdown]
# - To calculate latency, we would just subtract the time of the first port entry to that of the tone playing

# %%
concatted_first_and_last_porty_entry_dataframe["latency"] = concatted_first_porty_entry_dataframe["first_port_entry_after_tone"] - concatted_first_and_last_porty_entry_dataframe["current_tone_time"]

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                          NaN                                          NaN
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
#
#    trial_number                                              index  ...  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#    End Time                  MSN                        file_name  cage  \
# 0  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 1  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 2  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 3  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
# 4  09:50:24  C57_reward_training  2022-07-18_08h24m_Subject 1.txt     1
#
#    cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 1  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 2  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 3  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 4  cage_1_subject_1          2022-07-18        20220718        2022-07-18
#
#   end_date_int latency
# 0     20220718   22.60
# 1     20220718   86.54
# 2     20220718  251.53
# 3     20220718  171.53
# 4     20220718   96.53
#
# [5 rows x 28 columns]

# %% [markdown]
# - For all the latencies that are are greater than 30 seconds, we changed the latency to 30 seconds

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"] = concatted_first_and_last_porty_entry_dataframe["latency"].apply(lambda x: 30 if x >= 30 else x)

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["latency"] >= 30].head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
# 6             580.01                       624.23
#
#    port_exit_after_first_port_entry_after_tone  \
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
# 6                                       624.31
#
#                                            file_path      date  subject  \
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 6  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
# 6                       486.06                                       486.13
#
#    trial_number                                              index  ...  \
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 6             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#                    MSN                        file_name cage  \
# 1  C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 2  C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 3  C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 4  C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
# 6  C57_reward_training  2022-07-18_08h24m_Subject 1.txt    1
#
#    cage_and_subject start_date_datetime start_date_int  end_date_datetime  \
# 1  cage_1_subject_1          2022-07-18       20220718         2022-07-18
# 2  cage_1_subject_1          2022-07-18       20220718         2022-07-18
# 3  cage_1_subject_1          2022-07-18       20220718         2022-07-18
# 4  cage_1_subject_1          2022-07-18       20220718         2022-07-18
# 6  cage_1_subject_1          2022-07-18       20220718         2022-07-18
#
#   end_date_int latency latency_adjusted_greater_than_30
# 1     20220718   86.54                             30.0
# 2     20220718  251.53                             30.0
# 3     20220718  171.53                             30.0
# 4     20220718   96.53                             30.0
# 6     20220718   44.22                             30.0
#
# [5 rows x 29 columns]

# %% [markdown]
# # Seeing which port entries and port exit durations overlap with the tone

# %% [markdown]
# - Making a column that states whether or not the last port entry before the tone has a port exit after the tone. This would mean that they are overlapping.

# %%
concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: True if row["port_exit_after_last_port_entry_before_tone"] >= row["current_tone_time"] else False, axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                          NaN                                          NaN
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
#
#    trial_number                                              index  ...  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#                          file_name cage  cage_and_subject  \
# 0  2022-07-18_08h24m_Subject 1.txt    1  cage_1_subject_1
# 1  2022-07-18_08h24m_Subject 1.txt    1  cage_1_subject_1
# 2  2022-07-18_08h24m_Subject 1.txt    1  cage_1_subject_1
# 3  2022-07-18_08h24m_Subject 1.txt    1  cage_1_subject_1
# 4  2022-07-18_08h24m_Subject 1.txt    1  cage_1_subject_1
#
#    start_date_datetime start_date_int end_date_datetime  end_date_int latency  \
# 0           2022-07-18       20220718        2022-07-18      20220718   22.60
# 1           2022-07-18       20220718        2022-07-18      20220718   86.54
# 2           2022-07-18       20220718        2022-07-18      20220718  251.53
# 3           2022-07-18       20220718        2022-07-18      20220718  171.53
# 4           2022-07-18       20220718        2022-07-18      20220718   96.53
#
#   latency_adjusted_greater_than_30 overlapping_port_entry_with_tone
# 0                             22.6                            False
# 1                             30.0                            False
# 2                             30.0                            False
# 3                             30.0                            False
# 4                             30.0                            False
#
# [5 rows x 30 columns]

# %% [markdown]
# - Comparing the latencies of the first port entry after the tone between these two groups:
#     - 1. Those with the last port entry before the tone that has a port exit after the tone("overlapping" group)
#     - 2. Those with the last port entry before the tone that has a port exit before the tone("nonoverlapping" group)

# %%
overlapping_df = concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %%
non_overlapping_df = concatted_first_and_last_porty_entry_dataframe[~concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]]

# %% [markdown]
# - Number of rows of overlapping and nonoverlapping last port entries before the tone

# %%
overlapping_df.shape
# Out:
# (772, 30)

# %%
non_overlapping_df.shape
# Out:
# (5780, 30)

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone

# %%
overlapping_df["latency"].mean()
# Out:
# 5.640505181347044

# %%
non_overlapping_df["latency"].mean()
# Out:
# 34.945430763864614

# %% [markdown]
# - Latency between the tone playing and the first port entry after the tone. This had been adjusted so that all latencies that are greater than 30 seconds were adjusted to be just 30 seconds.

# %%
overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 5.0876813471501565

# %%
non_overlapping_df["latency_adjusted_greater_than_30"].mean()
# Out:
# 11.73130449947669

# %% [markdown]
# # Adjusting the Latencies if the Port Entries/Exit Overlap With the Tone Times

# %% [markdown]
# - For all the rows with overlapping last port entries before the tone, we will adjust the latency of the tone to the first port entry after the tone to 0. (Because the first port entry after the tone would be considered to be the same as the last port entry before the tone)

# %%
concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"] = concatted_first_and_last_porty_entry_dataframe.apply(lambda row: 0 if row["overlapping_port_entry_with_tone"] else row["latency_adjusted_greater_than_30"], axis=1)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                          NaN                                          NaN
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
#
#    trial_number                                              index  ... cage  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...    1
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...    1
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...    1
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...    1
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...    1
#
#    cage_and_subject start_date_datetime  start_date_int end_date_datetime  \
# 0  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 1  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 2  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 3  cage_1_subject_1          2022-07-18        20220718        2022-07-18
# 4  cage_1_subject_1          2022-07-18        20220718        2022-07-18
#
#   end_date_int  latency latency_adjusted_greater_than_30  \
# 0     20220718    22.60                             22.6
# 1     20220718    86.54                             30.0
# 2     20220718   251.53                             30.0
# 3     20220718   171.53                             30.0
# 4     20220718    96.53                             30.0
#
#   overlapping_port_entry_with_tone latency_adjusted_overlap
# 0                            False                     22.6
# 1                            False                     30.0
# 2                            False                     30.0
# 3                            False                     30.0
# 4                            False                     30.0
#
# [5 rows x 31 columns]

# %% [markdown]
# - All the rows with overlapping last port entries before the tone

# %%
concatted_first_and_last_porty_entry_dataframe[concatted_first_and_last_porty_entry_dataframe["overlapping_port_entry_with_tone"]].head()
# Out:
#      current_tone_time  first_port_entry_after_tone  \
# 90             1150.01                      1150.39
# 117              60.01                        71.47
# 154            3425.01                      3446.71
# 171            1415.01                      1415.30
# 175            1805.01                      1805.88
#
#      port_exit_after_first_port_entry_after_tone  \
# 90                                       1150.42
# 117                                        71.71
# 154                                      3446.75
# 171                                      1415.61
# 175                                      1805.90
#
#                                              file_path      date  subject  \
# 90   ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220720        1
# 117  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220721        1
# 154  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220721        1
# 171  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220722        1
# 175  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220722        1
#
#      last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 90                       1149.91                                      1150.30
# 117                        59.95                                        60.01
# 154                      3424.57                                      3426.94
# 171                      1415.00                                      1415.28
# 175                      1804.77                                      1805.86
#
#      trial_number                                              index  ...  \
# 90              3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 117             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 154             4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 171             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 175             5  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#     cage  cage_and_subject start_date_datetime  start_date_int  \
# 90     1  cage_1_subject_1          2022-07-20        20220720
# 117    1  cage_1_subject_1          2022-07-21        20220721
# 154    1  cage_1_subject_1          2022-07-21        20220721
# 171    1  cage_1_subject_1          2022-07-22        20220722
# 175    1  cage_1_subject_1          2022-07-22        20220722
#
#     end_date_datetime end_date_int  latency latency_adjusted_greater_than_30  \
# 90         2022-07-20     20220720     0.38                             0.38
# 117        2022-07-21     20220721    11.46                            11.46
# 154        2022-07-21     20220721    21.70                            21.70
# 171        2022-07-22     20220722     0.29                             0.29
# 175        2022-07-22     20220722     0.87                             0.87
#
#     overlapping_port_entry_with_tone latency_adjusted_overlap
# 90                              True                      0.0
# 117                             True                      0.0
# 154                             True                      0.0
# 171                             True                      0.0
# 175                             True                      0.0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Labeling if a row's latency is less than 10 seconds or not

# %% [markdown]
# - We will be getting the ratio of latencies(from the time that the tone played, to the first port entry after the tone) that are less than 10 seconds for each session. So we will label all the adjusted latencies that are less than 10 seconds as `True`, and the those with latencies that are greater than 10 seconds as `False`

# %%
concatted_first_and_last_porty_entry_dataframe["adjusted_30_second_latency_less_than_10_seconds_ratio"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_greater_than_30"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe["overlap_adjusted_latency_less_than_10_seconds"] = concatted_first_and_last_porty_entry_dataframe["latency_adjusted_overlap"].apply(lambda x: True if x <= 10 else False)

# %%
concatted_first_and_last_porty_entry_dataframe.head()
# Out:
#    current_tone_time  first_port_entry_after_tone  \
# 0              60.01                        82.61
# 1             140.01                       226.55
# 2             230.01                       481.54
# 3             310.01                       481.54
# 4             385.01                       481.54
#
#    port_exit_after_first_port_entry_after_tone  \
# 0                                        82.65
# 1                                       226.61
# 2                                       481.60
# 3                                       481.60
# 4                                       481.60
#
#                                            file_path      date  subject  \
# 0  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
#
#    last_port_entry_before_tone  port_exit_after_last_port_entry_before_tone  \
# 0                          NaN                                          NaN
# 1                        83.33                                        83.55
# 2                       226.55                                       226.61
# 3                       226.55                                       226.61
# 4                       226.55                                       226.61
#
#    trial_number                                              index  ...  \
# 0             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 1             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4             1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#   start_date_datetime start_date_int end_date_datetime  end_date_int latency  \
# 0          2022-07-18       20220718        2022-07-18      20220718   22.60
# 1          2022-07-18       20220718        2022-07-18      20220718   86.54
# 2          2022-07-18       20220718        2022-07-18      20220718  251.53
# 3          2022-07-18       20220718        2022-07-18      20220718  171.53
# 4          2022-07-18       20220718        2022-07-18      20220718   96.53
#
#   latency_adjusted_greater_than_30  overlapping_port_entry_with_tone  \
# 0                             22.6                             False
# 1                             30.0                             False
# 2                             30.0                             False
# 3                             30.0                             False
# 4                             30.0                             False
#
#   latency_adjusted_overlap  \
# 0                     22.6
# 1                     30.0
# 2                     30.0
# 3                     30.0
# 4                     30.0
#
#   adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   overlap_adjusted_latency_less_than_10_seconds
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
# [5 rows x 33 columns]

# %% [markdown]
# # Making Dataframes that have Each Subject as the Row and Each Date as the Column

# %% [markdown]
# - Pivot plots allow us to make columns out of each unique entry in a selected column. (For this, it will be the date column that we will turn into columns) The index for the rows will be each unique entry in another column. (For this, it will be the subject's ID) And the values will be the aggregate of the values that have both the values in the previous two selected columns. (For this it will be the latency columns and we will take the mean)
#     - https://pandas.pydata.org/docs/reference/api/pandas.pivot_table.html

# %% [markdown]
# - Making a folder for all the pivotplots

# %% [markdown]
# # NOTE: If you decide to change the cage numbers or the dates used from the original ones from the imported dataframes, you will need to change the subsequent path to the cage number and dates you are using

# %%
first_port_entry_to_tone_latency_output_directory = "./proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
first_port_entry_to_tone_latency_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/first_port_entry_to_tone_latency/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(first_port_entry_to_tone_latency_output_directory, exist_ok=True)

# %%
latencies_less_than_10_seconds_ratio_output_directory = "./proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
latencies_less_than_10_seconds_ratio_output_directory
# Out:
# './proc/subject_rows_with_date_columns_dataframes/latencies_less_than_10_seconds_ratio/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(latencies_less_than_10_seconds_ratio_output_directory, exist_ok=True)

# %% [markdown]
# ## Making a pivot plot with the original latency

# %%
concatted_first_and_last_porty_entry_dataframe
# Out:
#       current_tone_time  first_port_entry_after_tone  \
# 0                 60.01                        82.61
# 1                140.01                       226.55
# 2                230.01                       481.54
# 3                310.01                       481.54
# 4                385.01                       481.54
# ...                 ...                          ...
# 6547            3160.01                      3169.51
# 6548            3255.01                      3259.46
# 6549            3345.01                      3357.60
# 6550            3425.01                      3466.06
# 6551            3515.01                      3517.13
#
#       port_exit_after_first_port_entry_after_tone  \
# 0                                           82.65
# 1                                          226.61
# 2                                          481.60
# 3                                          481.60
# 4                                          481.60
# ...                                           ...
# 6547                                      3169.83
# 6548                                      3260.27
# 6549                                      3357.62
# 6550                                      3466.30
# 6551                                      3517.17
#
#                                               file_path      date  subject  \
# 0     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 1     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 2     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 3     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# 4     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220718        1
# ...                                                 ...       ...      ...
# 6547  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6548  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6549  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6550  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
# 6551  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  20220724        4
#
#       last_port_entry_before_tone  \
# 0                             NaN
# 1                           83.33
# 2                          226.55
# 3                          226.55
# 4                          226.55
# ...                           ...
# 6547                      3153.15
# 6548                      3237.52
# 6549                      3314.61
# 6550                      3419.90
# 6551                      3500.19
#
#       port_exit_after_last_port_entry_before_tone  trial_number  \
# 0                                             NaN             1
# 1                                           83.55             1
# 2                                          226.61             1
# 3                                          226.61             1
# 4                                          226.61             1
# ...                                           ...           ...
# 6547                                      3153.28             7
# 6548                                      3237.70             7
# 6549                                      3314.69             7
# 6550                                      3420.18             7
# 6551                                      3500.25             7
#
#                                                   index  ...  \
# 0     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 1     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 2     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 3     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 4     ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# ...                                                 ...  ...
# 6547  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 6548  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 6549  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 6550  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
# 6551  ./data/pilot_c57_vs_cd1/reward_training/med_pc...  ...
#
#      start_date_datetime start_date_int end_date_datetime  end_date_int  \
# 0             2022-07-18       20220718        2022-07-18      20220718
# 1             2022-07-18       20220718        2022-07-18      20220718
# 2             2022-07-18       20220718        2022-07-18      20220718
# 3             2022-07-18       20220718        2022-07-18      20220718
# 4             2022-07-18       20220718        2022-07-18      20220718
# ...                  ...            ...               ...           ...
# 6547          2022-07-24       20220724        2022-07-24      20220724
# 6548          2022-07-24       20220724        2022-07-24      20220724
# 6549          2022-07-24       20220724        2022-07-24      20220724
# 6550          2022-07-24       20220724        2022-07-24      20220724
# 6551          2022-07-24       20220724        2022-07-24      20220724
#
#      latency latency_adjusted_greater_than_30  \
# 0      22.60                            22.60
# 1      86.54                            30.00
# 2     251.53                            30.00
# 3     171.53                            30.00
# 4      96.53                            30.00
# ...      ...                              ...
# 6547    9.50                             9.50
# 6548    4.45                             4.45
# 6549   12.59                            12.59
# 6550   41.05                            30.00
# 6551    2.12                             2.12
#
#       overlapping_port_entry_with_tone latency_adjusted_overlap  \
# 0                                False                    22.60
# 1                                False                    30.00
# 2                                False                    30.00
# 3                                False                    30.00
# 4                                False                    30.00
# ...                                ...                      ...
# 6547                             False                     9.50
# 6548                             False                     4.45
# 6549                             False                    12.59
# 6550                             False                    30.00
# 6551                             False                     2.12
#
#      adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 6547                                               True
# 6548                                               True
# 6549                                              False
# 6550                                              False
# 6551                                               True
#
#      overlap_adjusted_latency_less_than_10_seconds
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 6547                                          True
# 6548                                          True
# 6549                                         False
# 6550                                         False
# 6551                                          True
#
# [6552 rows x 33 columns]

# %%
all_latency_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency', \
                                        index=['cage_and_subject'], columns=['trial_number'], aggfunc=np.mean)

# %%
all_latency_pivot_plot.head()
# Out:
# trial_number               1           2          3          4         5  \
# cage_and_subject
# cage_1_subject_1  157.351538  337.954583  11.841538  10.225385  3.167692
# cage_1_subject_2  175.416667  171.389487  10.532564  11.948462  4.707949
# cage_1_subject_3   56.433333   65.062667  11.430000   8.013333  5.231026
# cage_1_subject_4   64.283333   53.292632  17.041538   7.711538  4.524103
# cage_2_subject_1  169.048649   50.398974  17.550513   5.173846  4.044615
#
# trial_number             6         7
# cage_and_subject
# cage_1_subject_1  3.693333  3.345641
# cage_1_subject_2  4.970256  4.732308
# cage_1_subject_3  6.283846  7.037949
# cage_1_subject_4  6.061026  8.447692
# cage_2_subject_1  4.200000  1.376410

# %%
all_latency_pivot_plot.tail()
# Out:
# trial_number               1          2           3          4         5  \
# cage_and_subject
# cage_5_subject_4   43.978718  47.938718    8.513077   6.488974  8.444103
# cage_6_subject_1   90.394103  16.275641   45.918205   6.427949  6.363333
# cage_6_subject_2  108.742564  23.731026    9.358205  10.190769  6.815128
# cage_6_subject_3   13.220256   4.248718    7.255385   3.750769  2.772051
# cage_6_subject_4  243.953333  28.704872  117.289231   3.682051  7.475897
#
# trial_number             6         7
# cage_and_subject
# cage_5_subject_4  7.270000  6.068974
# cage_6_subject_1  6.118974  3.771282
# cage_6_subject_2  3.047692  2.883077
# cage_6_subject_3  1.893077  3.110513
# cage_6_subject_4  4.446923  6.219231

# %% [markdown]
# - Getting the cage numbers for each subject and then making a dictionary out of it
#     - This will be used to add the cage information to the pivot plots

# %% [raw]
# # Converting the cage numbers from floats to integers
# # When the metadata is imported from the csv files, the cage number is imported as a float
# metadata_df["cage"] = metadata_df["cage"].astype(int)

# %% [raw]
# subject_to_cage = pd.Series(metadata_df["cage"].values,index=metadata_df["cage_"].values).to_dict()

# %% [raw]
# subject_to_cage

# %% [markdown]
# - Adding the cage information with the dictionary

# %% [raw]
# all_latency_pivot_plot["cage"] = all_latency_pivot_plot.index.map(subject_to_cage)

# %% [raw]
# all_latency_pivot_plot.head()

# %%
file_path = "original_latency_cage_{}_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    all_latency_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    all_latency_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the latency that were greater than 30 seconds being adjusted

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_greater_than_30', index=['cage_and_subject'],

                    columns=['trial_number'], aggfunc=np.mean)

# %%
latency_greater_than_30_seconds_adjusted_pivot_plot.head()
# Out:
# trial_number              1          2          3         4         5  \
# cage_and_subject
# cage_1_subject_1  27.626410  30.000000  10.510513  9.028718  3.167692
# cage_1_subject_2  25.436410  25.864359  10.166667  9.264359  4.707949
# cage_1_subject_3  20.827179  24.813333  10.916667  8.013333  5.231026
# cage_1_subject_4  24.526154  22.776842  15.767179  7.344359  4.524103
# cage_2_subject_1  25.224324  23.503846  10.259231  5.173846  4.044615
#
# trial_number             6         7
# cage_and_subject
# cage_1_subject_1  3.693333  3.345641
# cage_1_subject_2  4.970256  4.732308
# cage_1_subject_3  6.283846  7.037949
# cage_1_subject_4  5.407179  8.447692
# cage_2_subject_1  4.200000  1.376410

# %%
file_path = "subject_to_date_latency_greater_than_30_seconds_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    latency_greater_than_30_seconds_adjusted_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    latency_greater_than_30_seconds_adjusted_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with adjusted latencies that overlapped with a tone playing

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='latency_adjusted_overlap', index=['cage_and_subject'],

                    columns=['trial_number'], aggfunc=np.mean)

# %%
latency_that_overlaps_with_tone_adjusted_pivot_plot.head()
# Out:
# trial_number              1          2          3         4         5  \
# cage_and_subject
# cage_1_subject_1  27.626410  30.000000  10.500769  8.178462  3.078974
# cage_1_subject_2  25.242051  25.864359   9.492564  8.925641  4.085641
# cage_1_subject_3  20.466667  24.813333  10.819487  7.317949  3.358462
# cage_1_subject_4  22.987692  22.776842  15.767179  5.651795  4.160513
# cage_2_subject_1  25.224324  23.503846  10.128974  4.946154  3.844872
#
# trial_number             6         7
# cage_and_subject
# cage_1_subject_1  1.814359  1.540256
# cage_1_subject_2  4.428718  1.604615
# cage_1_subject_3  5.102564  1.239744
# cage_1_subject_4  3.846154  2.546923
# cage_2_subject_1  2.417692  0.639231

# %%
file_path = "subject_to_date_latency_that_overlaps_with_tone_adjusted_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    latency_that_overlaps_with_tone_adjusted_pivot_plot.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    latency_that_overlaps_with_tone_adjusted_pivot_plot.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the ratio of original latencies that are less than 10 seconds

# %%
original_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='adjusted_30_second_latency_less_than_10_seconds_ratio', index=['cage_and_subject'],

                    columns=['trial_number'], aggfunc=np.mean)

# %%
original_less_than_10_latency_df
# Out:
# trial_number             1         2         3         4         5         6  \
# cage_and_subject
# cage_1_subject_1  0.051282  0.000000  0.538462  0.615385  0.948718  0.948718
# cage_1_subject_2  0.102564  0.076923  0.589744  0.589744  0.897436  0.871795
# cage_1_subject_3  0.282051  0.128205  0.487179  0.743590  0.897436  0.794872
# cage_1_subject_4  0.102564  0.230769  0.256410  0.794872  0.923077  0.871795
# cage_2_subject_1  0.076923  0.179487  0.564103  0.846154  0.871795  0.871795
# cage_2_subject_2  0.179487  0.512821  0.846154  0.641026  0.974359  0.589744
# cage_2_subject_3  0.076923  0.102564  0.717949  0.897436  0.974359  0.846154
# cage_2_subject_4  0.179487  0.153846  0.564103  0.743590  0.820513  0.641026
# cage_3_subject_1  0.051282  0.282051  0.076923  0.641026  0.897436  0.820513
# cage_3_subject_2  0.102564  0.205128  0.358974  0.794872  0.871795  0.974359
# cage_3_subject_3  0.179487  0.358974  0.307692  0.615385  0.871795  0.743590
# cage_3_subject_4  0.205128  0.128205  0.512821  0.846154  0.871795  0.871795
# cage_4_subject_1  0.076923  0.384615  0.641026  0.897436  0.897436  0.923077
# cage_4_subject_2  0.076923  0.435897  0.564103  0.769231  0.769231  0.820513
# cage_4_subject_3  0.153846  0.487179  0.769231  0.794872  0.871795  0.923077
# cage_4_subject_4  0.358974  0.564103  0.743590  0.948718  0.846154  0.948718
# cage_5_subject_1  0.230769  0.615385  0.564103  0.897436  0.846154  0.974359
# cage_5_subject_2  0.282051  0.205128  0.410256  0.589744  0.897436  0.897436
# cage_5_subject_3  0.102564  0.025641  0.076923  0.717949  0.179487  0.666667
# cage_5_subject_4  0.179487  0.256410  0.641026  0.820513  0.666667  0.769231
# cage_6_subject_1  0.076923  0.307692  0.179487  0.743590  0.846154  0.897436
# cage_6_subject_2  0.102564  0.333333  0.538462  0.461538  0.794872  0.974359
# cage_6_subject_3  0.538462  0.897436  0.794872  0.974359  1.000000  1.000000
# cage_6_subject_4  0.051282  0.256410  0.282051  0.948718  0.717949  0.897436
#
# trial_number             7
# cage_and_subject
# cage_1_subject_1  0.948718
# cage_1_subject_2  0.820513
# cage_1_subject_3  0.717949
# cage_1_subject_4  0.717949
# cage_2_subject_1  1.000000
# cage_2_subject_2  0.666667
# cage_2_subject_3  0.692308
# cage_2_subject_4  0.974359
# cage_3_subject_1  0.820513
# cage_3_subject_2  1.000000
# cage_3_subject_3  0.846154
# cage_3_subject_4  0.923077
# cage_4_subject_1  0.923077
# cage_4_subject_2  0.769231
# cage_4_subject_3  0.846154
# cage_4_subject_4  1.000000
# cage_5_subject_1  0.974359
# cage_5_subject_2  0.923077
# cage_5_subject_3  0.769231
# cage_5_subject_4  0.846154
# cage_6_subject_1  0.948718
# cage_6_subject_2  0.974359
# cage_6_subject_3  0.923077
# cage_6_subject_4  0.846154

# %%
file_path = "subject_to_date_less_than_10_seconds_original_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)
output_path = os.path.join(first_port_entry_to_tone_latency_output_directory, file_path)
try:
    original_less_than_10_latency_df.to_csv(output_path)
except:
    output_path = os.path.abspath(output_path)
    # Changing path if using on Windows because it raises an error if the path is longer than 260 characters
    # But adding this suffix bypasses this
    output_path = u"\\\\?\\" + output_path
    original_less_than_10_latency_df.to_csv(output_path)

# %% [markdown]
# ## Making a pivot plot with the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
overlap_adjusted_less_than_10_latency_df = pd.pivot_table(concatted_first_and_last_porty_entry_dataframe, values='overlap_adjusted_latency_less_than_10_seconds', index=['cage_and_subject'],

                    columns=['trial_number'], aggfunc=np.mean)

# %%
overlap_adjusted_less_than_10_latency_df
# Out:
# trial_number             1         2         3         4         5         6  \
# cage_and_subject
# cage_1_subject_1  0.051282  0.000000  0.538462  0.666667  0.948718  0.974359
# cage_1_subject_2  0.102564  0.076923  0.615385  0.615385  0.897436  0.871795
# cage_1_subject_3  0.307692  0.128205  0.487179  0.743590  0.923077  0.871795
# cage_1_subject_4  0.153846  0.230769  0.256410  0.846154  0.923077  0.897436
# cage_2_subject_1  0.076923  0.179487  0.564103  0.846154  0.871795  0.923077
# cage_2_subject_2  0.205128  0.512821  0.846154  0.641026  0.974359  0.589744
# cage_2_subject_3  0.076923  0.128205  0.743590  0.897436  0.974359  0.923077
# cage_2_subject_4  0.179487  0.153846  0.589744  0.794872  0.871795  0.641026
# cage_3_subject_1  0.051282  0.307692  0.102564  0.641026  0.897436  0.871795
# cage_3_subject_2  0.128205  0.230769  0.358974  0.794872  0.871795  0.974359
# cage_3_subject_3  0.179487  0.410256  0.307692  0.615385  0.871795  0.743590
# cage_3_subject_4  0.205128  0.153846  0.538462  0.897436  0.871795  0.897436
# cage_4_subject_1  0.076923  0.435897  0.666667  0.897436  0.923077  0.948718
# cage_4_subject_2  0.076923  0.435897  0.564103  0.769231  0.794872  0.846154
# cage_4_subject_3  0.153846  0.487179  0.769231  0.820513  0.897436  0.948718
# cage_4_subject_4  0.358974  0.564103  0.769231  0.974359  0.846154  0.948718
# cage_5_subject_1  0.230769  0.615385  0.564103  0.897436  0.846154  0.974359
# cage_5_subject_2  0.282051  0.205128  0.410256  0.615385  0.897436  0.897436
# cage_5_subject_3  0.102564  0.025641  0.076923  0.794872  0.205128  0.769231
# cage_5_subject_4  0.179487  0.256410  0.641026  0.846154  0.666667  0.846154
# cage_6_subject_1  0.076923  0.307692  0.205128  0.820513  0.846154  0.897436
# cage_6_subject_2  0.102564  0.358974  0.538462  0.487179  0.794872  0.974359
# cage_6_subject_3  0.564103  0.897436  0.794872  0.974359  1.000000  1.000000
# cage_6_subject_4  0.051282  0.256410  0.282051  0.948718  0.743590  0.897436
#
# trial_number             7
# cage_and_subject
# cage_1_subject_1  1.000000
# cage_1_subject_2  0.948718
# cage_1_subject_3  0.974359
# cage_1_subject_4  0.948718
# cage_2_subject_1  1.000000
# cage_2_subject_2  0.692308
# cage_2_subject_3  1.000000
# cage_2_subject_4  1.000000
# cage_3_subject_1  1.000000
# cage_3_subject_2  1.000000
# cage_3_subject_3  0.846154
# cage_3_subject_4  0.974359
# cage_4_subject_1  0.948718
# cage_4_subject_2  0.794872
# cage_4_subject_3  0.846154
# cage_4_subject_4  1.000000
# cage_5_subject_1  0.974359
# cage_5_subject_2  0.923077
# cage_5_subject_3  0.794872
# cage_5_subject_4  0.871795
# cage_6_subject_1  0.948718
# cage_6_subject_2  0.974359
# cage_6_subject_3  0.923077
# cage_6_subject_4  0.846154

# %%
overlap_adjusted_less_than_10_latency_df.to_csv(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.csv".format(cage_numbers_for_title, earliest_date, latest_date)))
overlap_adjusted_less_than_10_latency_df.to_excel(os.path.join(latencies_less_than_10_seconds_ratio_output_directory, "subject_to_date_less_than_10_seconds_overlap_adjusted_latencies_ratios_cage_{}_date_{}_{}.xlsx".format(cage_numbers_for_title, earliest_date, latest_date)))

# %% [markdown]
# # Plotting the latencies

# %% [markdown]
# ## Getting the averages for all the trials in one subject and one day

# %% [markdown]
# - We will plot a line for each subject. With the X-axis being the days since the first session. And the Y-axis is the latency values averaged across all the trials for one recording session
# - Grouping all the rows with the same subject and date(aka, all the trials in one session). And then getting the mean for each value

# %%
grouped_averaged_first_porty_entry_dataframe = concatted_first_and_last_porty_entry_dataframe.groupby(by=["file_name", "trial_number", "cage_and_subject", "cage", "Subject"]).mean()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                                                                             current_tone_time  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1               1779.75359
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2               1779.75359
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3               1779.75359
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4               1779.75359
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1               1779.75359
#
#                                                                             first_port_entry_after_tone  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                        1937.105128
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                        1955.170256
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                        1836.186923
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                        1844.036923
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                        1857.437027
#
#                                                                             port_exit_after_first_port_entry_after_tone  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                                        1937.229487
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                                        1955.892564
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                                        1836.712051
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                                        1844.652308
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                                        1857.677027
#
#                                                                                   date  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1        20220718.0
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2        20220718.0
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3        20220718.0
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4        20220718.0
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1        20220718.0
#
#                                                                             subject  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1            1.0
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2            2.0
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3            3.0
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4            4.0
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1            1.0
#
#                                                                             last_port_entry_before_tone  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                        1673.343421
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                        1623.441282
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                        1716.366667
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                        1710.828462
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                        1668.948158
#
#                                                                             port_exit_after_last_port_entry_before_tone  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                                        1673.543421
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                                        1624.296667
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                                        1716.822308
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                                        1711.590513
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                                        1669.182368
#
#                                                                             Box  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1        1.0
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2        2.0
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3        3.0
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4        4.0
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1        1.0
#
#                                                                             start_date_int  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1            20220718.0
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2            20220718.0
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3            20220718.0
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4            20220718.0
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1            20220718.0
#
#                                                                             end_date_int  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1          20220718.0
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2          20220718.0
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3          20220718.0
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4          20220718.0
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1          20220718.0
#
#                                                                                latency  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1        157.351538
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2        175.416667
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3         56.433333
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4         64.283333
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1        169.048649
#
#                                                                             latency_adjusted_greater_than_30  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                               27.626410
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                               25.436410
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                               20.827179
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                               24.526154
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                               25.224324
#
#                                                                             overlapping_port_entry_with_tone  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                                0.000000
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                                0.051282
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                                0.051282
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                                0.051282
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                                0.000000
#
#                                                                             latency_adjusted_overlap  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                       27.626410
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                       25.242051
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                       20.466667
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                       22.987692
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                       25.224324
#
#                                                                             adjusted_30_second_latency_less_than_10_seconds_ratio  \
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                                                 0.051282
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                                                 0.102564
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                                                 0.282051
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                                                 0.102564
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                                                 0.076923
#
#                                                                             overlap_adjusted_latency_less_than_10_seconds
# file_name                       trial_number cage_and_subject cage Subject
# 2022-07-18_08h24m_Subject 1.txt 1            cage_1_subject_1 1    1                                             0.051282
# 2022-07-18_08h25m_Subject 2.txt 1            cage_1_subject_2 1    2                                             0.102564
# 2022-07-18_08h25m_Subject 3.txt 1            cage_1_subject_3 1    3                                             0.307692
# 2022-07-18_08h25m_Subject 4.txt 1            cage_1_subject_4 1    4                                             0.153846
# 2022-07-18_09h57m_Subject 1.txt 1            cage_2_subject_1 2    1                                             0.076923

# %% [markdown]
# ## Reformatting the Dataframe for plotting

# %% [markdown]
# - Resetting the index so that we can use the data as a value

# %%
grouped_averaged_first_porty_entry_dataframe = grouped_averaged_first_porty_entry_dataframe.reset_index()

# %%
grouped_averaged_first_porty_entry_dataframe.head()
# Out:
#                          file_name  trial_number  cage_and_subject  cage  \
# 0  2022-07-18_08h24m_Subject 1.txt             1  cage_1_subject_1     1
# 1  2022-07-18_08h25m_Subject 2.txt             1  cage_1_subject_2     1
# 2  2022-07-18_08h25m_Subject 3.txt             1  cage_1_subject_3     1
# 3  2022-07-18_08h25m_Subject 4.txt             1  cage_1_subject_4     1
# 4  2022-07-18_09h57m_Subject 1.txt             1  cage_2_subject_1     2
#
#    Subject  current_tone_time  first_port_entry_after_tone  \
# 0        1         1779.75359                  1937.105128
# 1        2         1779.75359                  1955.170256
# 2        3         1779.75359                  1836.186923
# 3        4         1779.75359                  1844.036923
# 4        1         1779.75359                  1857.437027
#
#    port_exit_after_first_port_entry_after_tone        date  subject  ...  \
# 0                                  1937.229487  20220718.0      1.0  ...
# 1                                  1955.892564  20220718.0      2.0  ...
# 2                                  1836.712051  20220718.0      3.0  ...
# 3                                  1844.652308  20220718.0      4.0  ...
# 4                                  1857.677027  20220718.0      1.0  ...
#
#    port_exit_after_last_port_entry_before_tone  Box  start_date_int  \
# 0                                  1673.543421  1.0      20220718.0
# 1                                  1624.296667  2.0      20220718.0
# 2                                  1716.822308  3.0      20220718.0
# 3                                  1711.590513  4.0      20220718.0
# 4                                  1669.182368  1.0      20220718.0
#
#    end_date_int     latency  latency_adjusted_greater_than_30  \
# 0    20220718.0  157.351538                         27.626410
# 1    20220718.0  175.416667                         25.436410
# 2    20220718.0   56.433333                         20.827179
# 3    20220718.0   64.283333                         24.526154
# 4    20220718.0  169.048649                         25.224324
#
#    overlapping_port_entry_with_tone  latency_adjusted_overlap  \
# 0                          0.000000                 27.626410
# 1                          0.051282                 25.242051
# 2                          0.051282                 20.466667
# 3                          0.051282                 22.987692
# 4                          0.000000                 25.224324
#
#    adjusted_30_second_latency_less_than_10_seconds_ratio  \
# 0                                           0.051282
# 1                                           0.102564
# 2                                           0.282051
# 3                                           0.102564
# 4                                           0.076923
#
#    overlap_adjusted_latency_less_than_10_seconds
# 0                                       0.051282
# 1                                       0.102564
# 2                                       0.307692
# 3                                       0.153846
# 4                                       0.076923
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Plotting the latencies that were adjusted if they greater than 30 seconds

# %%
original_average_latency_output_directory = "./proc/plots/original_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
original_average_latency_output_directory
# Out:
# './proc/plots/original_average_latency_plots/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(original_average_latency_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # only allowing whole number ticks for x
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["cage_and_subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["cage_and_subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["trial_number"], subject_df["latency_adjusted_greater_than_30"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Adjusted Average Latency of First Entry to Tone Onset")
    ax.set_title("Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "original_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(original_average_latency_output_directory, file_name))

# %% [markdown]
# ## Plotting the original ratio of latencies that are less than 10 seconds

# %%
less_than_10_second_original_latency_ratio_plots_output_directory = "./proc/plots/less_than_10_second_original_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_original_latency_ratio_plots_output_directory
# Out:
# './proc/plots/less_than_10_second_original_latency_ratio/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(less_than_10_second_original_latency_ratio_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # only allowing whole number ticks for x
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))

    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["cage_and_subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["cage_and_subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["trial_number"], subject_df["adjusted_30_second_latency_less_than_10_seconds_ratio"], '-o', label=subject)
    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Less Than 10 Seconds Latencies from Tone Onset: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    
    file_name = "less_than_10_second_original_latency_ratio_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_original_latency_ratio_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the Adjusted Latencies for Entries that Overlap with the Tone

# %% [markdown]
# ## Plotting the Latencies

# %%
overlap_adjusted_average_latency_plots_output_directory = "./proc/plots/overlap_adjusted_average_latency_plots/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
overlap_adjusted_average_latency_plots_output_directory
# Out:
# './proc/plots/overlap_adjusted_average_latency_plots/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(overlap_adjusted_average_latency_plots_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # only allowing whole number ticks for x
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["cage_and_subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["cage_and_subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["trial_number"], subject_df["latency_adjusted_overlap"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 30)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Latency of Port Entry to Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    file_name = "overlap_adjusted_average_latency_plot_cage_{}_date_{}_{}.png".format(cage, earliest_date, latest_date)

    plt.savefig(os.path.join(overlap_adjusted_average_latency_plots_output_directory, file_name))

# %% [markdown]
# # Plotting the ratio of overlap adjusted latencies that are less than 10 seconds

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory = "./proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_{}_date_{}_{}".format(cage_numbers_for_title, earliest_date, latest_date)

# %%
less_than_10_second_overlap_adjusted_latency_ratio_output_directory
# Out:
# './proc/plots/less_than_10_second_overlap_adjusted_latency_ratio/cage_1_2_3_4_5_6_date_20220718_20220724'

# %%
os.makedirs(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, exist_ok=True)

# %%
# Plotting for each cage
for cage in grouped_averaged_first_porty_entry_dataframe["cage"].unique():
    fig, ax = plt.subplots()
    # only allowing whole number ticks for x
    ax.xaxis.set_major_locator(ticker.MaxNLocator(integer=True))
    # Getting all the rows with the current cage number
    cage_df = grouped_averaged_first_porty_entry_dataframe[grouped_averaged_first_porty_entry_dataframe["cage"] == cage]
    
    # Plotting a line for each subject
    for subject in cage_df["cage_and_subject"].unique():
        # Getting all the rows with the current subject
        subject_df = cage_df[cage_df["cage_and_subject"] == subject]
        # Making the dates into days after the first session by subtracting all the dates by the first date
        ax.plot(subject_df["trial_number"], subject_df["overlap_adjusted_latency_less_than_10_seconds"], '-o', label=subject)

    # Setting the Y-Axis to only plot from 0 to 30 because we adjusted the latency to always be under 30
    ax.set_ylim(0, 1)
    # Labeling the X/Y Axis and the title
    ax.set_xlabel("Trial Number")
    ax.set_ylabel("Proportion of Latencies")
    ax.set_title("Overlap Adjusted Less Than 10sec Latencies from Tone: Cage {}".format(cage))
    # To show the legend
    ax.legend()
    
    file_name = "less_than_10_second_overlap_adjusted_latency_ratio_plot_cage{}_date_{}_{}.png".format(cage, earliest_date, latest_date)
    plt.savefig(os.path.join(less_than_10_second_overlap_adjusted_latency_ratio_output_directory, file_name))

# %% [markdown]
# # Looking over cage 2 subject 2

# %%
recording_and_metadata_df[recording_and_metadata_df["cage_and_subject"] == "cage_2_subject_2"]
# Out:
#         trial_number                                              index  \
# 88693              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88694              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88695              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88696              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88697              1  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...              ...                                                ...
# 106272             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106273             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106274             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106275             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106276             7  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
#                                                   File Start Date  End Date  \
# 88693   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 88694   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 88695   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 88696   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# 88697   C:\MED-PC\Data\2022-07-18_09h57m_Subject 2.txt   07/18/22  07/18/22
# ...                                                ...        ...       ...
# 106272  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 106273  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 106274  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 106275  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
# 106276  C:\MED-PC\Data\2022-07-24_10h17m_Subject 2.txt   07/24/22  07/24/22
#
#         Subject             Experiment  Group  Box Start Time  ... (K)CStype  \
# 88693         2  C57_vs_CD1_Comparison  Cage2    2   09:57:57  ...       1.0
# 88694         2  C57_vs_CD1_Comparison  Cage2    2   09:57:57  ...       1.0
# 88695         2  C57_vs_CD1_Comparison  Cage2    2   09:57:57  ...       1.0
# 88696         2  C57_vs_CD1_Comparison  Cage2    2   09:57:57  ...       1.0
# 88697         2  C57_vs_CD1_Comparison  Cage2    2   09:57:57  ...       1.0
# ...         ...                    ...    ...  ...        ...  ...       ...
# 106272        2  C57_vs_CD1_Comparison  Cage2    4   10:17:01  ...       NaN
# 106273        2  C57_vs_CD1_Comparison  Cage2    4   10:17:01  ...       NaN
# 106274        2  C57_vs_CD1_Comparison  Cage2    4   10:17:01  ...       NaN
# 106275        2  C57_vs_CD1_Comparison  Cage2    4   10:17:01  ...       NaN
# 106276        2  C57_vs_CD1_Comparison  Cage2    4   10:17:01  ...       NaN
#
#        (G)controlled_stimulus_secondscomputer  \
# 88693                                     2.0
# 88694                                    22.0
# 88695                                    52.0
# 88696                                    12.0
# 88697                                    27.0
# ...                                       ...
# 106272                                    NaN
# 106273                                    NaN
# 106274                                    NaN
# 106275                                    NaN
# 106276                                    NaN
#
#        (H)controlled_stimulus_minutescomputer  \
# 88693                                    10.0
# 88694                                    11.0
# 88695                                    12.0
# 88696                                    14.0
# 88697                                    15.0
# ...                                       ...
# 106272                                    NaN
# 106273                                    NaN
# 106274                                    NaN
# 106275                                    NaN
# 106276                                    NaN
#
#         (I)controlled_stimulus_hourscomputer (B)port_entry_secondscomputer  \
# 88693                                   10.0                          58.0
# 88694                                   10.0                          45.0
# 88695                                   10.0                          45.0
# 88696                                   10.0                          46.0
# 88697                                   10.0                           3.0
# ...                                      ...                           ...
# 106272                                   NaN                           0.0
# 106273                                   NaN                           0.0
# 106274                                   NaN                          40.0
# 106275                                   NaN                           0.0
# 106276                                   NaN                           0.0
#
#        (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 88693                           13.0                         10.0  20220718
# 88694                           15.0                         10.0  20220718
# 88695                           15.0                         10.0  20220718
# 88696                           15.0                         10.0  20220718
# 88697                           18.0                         10.0  20220718
# ...                              ...                          ...       ...
# 106272                           NaN                          NaN  20220724
# 106273                           NaN                          NaN  20220724
# 106274                           NaN                          NaN  20220724
# 106275                           NaN                          NaN  20220724
# 106276                           NaN                          NaN  20220724
#
#         subject                                          file_path
# 88693         2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88694         2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88695         2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88696         2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 88697         2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# ...         ...                                                ...
# 106272        2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106273        2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106274        2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106275        2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
# 106276        2  ./data/pilot_c57_vs_cd1/reward_training/med_pc...
#
# [17584 rows x 35 columns]

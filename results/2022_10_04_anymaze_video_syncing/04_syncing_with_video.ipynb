# %% [markdown]
# # MED-PC Extracting the Recording Data and Metadata

# %% [markdown]
# ## Importing the Python Libraries

# %%
import sys
import glob
from collections import defaultdict
import os
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from moviepy.editor import *
from datetime import datetime
from IPython.display import Video

# %%
from medpc2excel.medpc_read import medpc_read

# %%
# setting path
sys.path.append('../../src')

# %%
# All the libraries that were created for this repository
import extract.dataframe
import processing.tone
import extract.metadata

# %% [markdown]
# ## Getting the Metadata from all the MED-PC Recording Files

# %% [markdown]
# - Getting all the file paths of the recording files(that happen to all end in `.txt`

# %% [markdown]
# # NOTE: The following path must be changed to the directory where your MED-PC recording files are located, if they are not in the specied folder

# %%
all_med_pc_file = sorted(glob.glob("./data/**/*.txt"))

# %% [markdown]
# - Use this instead if you're using you're own data

# %% [raw]
# all_med_pc_file = glob.glob("./data/clock_recording/*.txt")

# %%
all_med_pc_file[:10]
# Out:
# ['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.3v1.4.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.1v2.2.txt',
#  './data/med_pc_recording_files/2022-10-03_09h45m_Subject 2.3v2.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 3.3v3.4.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.1v4.2.txt',
#  './data/med_pc_recording_files/2022-10-03_10h57m_Subject 4.3v4.4.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.1v3.2.txt',
#  './data/med_pc_recording_files/2022-10-03_11h07m_Subject 3.3v3.4.txt']

# %% [markdown]
# - Selecting only one of the files

# %%
all_med_pc_file = [all_med_pc_file[0]]

# %% [markdown]
# - Example of what the MED-PC Recording file looks like

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1.2.txt
#
#
#
#
#
#
#
# Start Date: 10/03/22
#
# End Date: 10/03/22
#
# Subject: 1.1v1.2
#
# Experiment: CD1_vs_C57_Comparison
#
# Group: Cage_1
#
# Box: 1
#
# Start Time: 09:45:25
#
# End Time: 10:46:28
#
# MSN: C57_reward_competition
#
# A:    5399.000
#
# D:    8000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    1860.000

# %% [markdown]
# - We will be extracting the first 10 or so lines that look like:
#
# ```
# File: C:\MED-PC\Data\2022-05-06_12h59m_Subject 3.4 (2).txt
#
# Start Date: 05/06/22
#
# End Date: 05/06/22
#
# Subject: 3.4 (2)
#
# Experiment: Pilot of Pilot
#
# Group: Cage 4
#
# Box: 1
#
# Start Time: 12:59:58
#
# End Time: 14:02:38
#
# MSN: levelNP_CS_reward_laserepochON1st_noshock
# ```
#
# - We will just find all the lines that start with "File", "Start Date", "End Date", "Subject", "Experiment", "Group", "Box", "Start Time", "End Time", or "MSN". And then stop once all the metadata types have been collected

# %%
# This makes a nested dictionary of file paths to each individual metadata type
file_path_to_meta_data = extract.metadata.get_all_med_pc_meta_data_from_files(list_of_files=all_med_pc_file)

# %%
for key, value in file_path_to_meta_data.items():
    print("File path: {}".format(key))
    print("Metadata types and associated values: {}".format(value))
    break
# Out:
# File path: ./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt
# Metadata types and associated values: {'File': 'C:\\MED-PC\\Data\\2022-10-03_09h45m_Subject 1.1v1.2.txt', 'Start Date': '10/03/22', 'End Date': '10/03/22', 'Subject': '1.1v1.2', 'Experiment': 'CD1_vs_C57_Comparison', 'Group': 'Cage_1', 'Box': '1', 'Start Time': '09:45:25', 'End Time': '10:46:28', 'MSN': 'C57_reward_competition'}

# %% [markdown]
# ## Making a Dataframe out of the Metadata

# %%
# Turning the dictionary into a Pandas Dataframe
metadata_df = pd.DataFrame.from_dict(file_path_to_meta_data, orient="index")
# Resetting the index because currently the file path is the index 
metadata_df = metadata_df.reset_index()

# %%
metadata_df.head()
# Out:
#                                                index  \
# 0  ./data/med_pc_recording_files/2022-10-03_09h45...
#
#                                                 File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1...   10/03/22  10/03/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0  1.1v1.2  CD1_vs_C57_Comparison  Cage_1   1   09:45:25  10:46:28
#
#                       MSN
# 0  C57_reward_competition

# %%
metadata_df.tail()
# Out:
#                                                index  \
# 0  ./data/med_pc_recording_files/2022-10-03_09h45...
#
#                                                 File Start Date  End Date  \
# 0  C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1...   10/03/22  10/03/22
#
#    Subject             Experiment   Group Box Start Time  End Time  \
# 0  1.1v1.2  CD1_vs_C57_Comparison  Cage_1   1   09:45:25  10:46:28
#
#                       MSN
# 0  C57_reward_competition

# %% [markdown]
# - Just getting the numbers out of the column that contains the cage information

# %% [markdown]
# ## Inputting all the MED-PC log files

# %% [markdown]
# - Example of what the MED-PC Script looks like that was ran when recording the behaviors

# %%
with open("./data/MPC/C57_reward_competition.MPC") as f:
    lines = f.readlines()
    for line in lines[:100]:
        print(line)
# Out:
# \INPUTS
#
#
#
# ^port = 8
#
#
#
#
#
# \OUTPUTS
#
# ^whitenoise = 1
#
# ^tone1 = 2
#
# ^tone2 = 3
#
# ^pump = 9
#
# ^fan = 16
#
# ^toneled = 17
#
# ^peled = 18
#
#
#
#
#
#
#
# \ARRAYS
#
#
#
# DIM P = 20000 \Port entry time stamp array
#
#
#
# DIM Q = 250 \US delivery time stamp array (absolute)
#
#
#
# DIM R = 250 \US time stamp array (relative to last CS)
#
#
#
# DIM W = 2500 \ITI values used for CS
#
#
#
# DIM S = 2500 \CS presentation values (absolute - every time yellow light turns on)
#
#
#
# DIM N = 20000 \Port exit time stamp array
#
#
#
# DIM K = 250 \CS type
#
#
#
# DIM G = 250 \controlled_stimulus_seconds computer clock time (seconds on clock every time yellow light/tone turns on)
#
#
#
# DIM H = 250 \controlled_stimulus_minutes computer clock time (minutes on clock every time yellow light/tone turns on)
#
#
#
# DIM I = 250 \controlled_stimulus_hours computer clock time (hours every time yellow light/tone turns on)
#
#
#
# DIM B = 2500 \port_entry_seconds computer clock time (seconds on clock every time red light turns on)
#
#
#
# DIM F = 2500 \port_entry_minutes computer clock time (minutes on clock every time red light turns on)
#
#
#
# DIM J = 2500 \port_entry_hours computer clock time (hours every time red light turns on)
#
#
#
#
#
#
#
# \Original List of ITIs
#
#
#
# LIST V = 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 120", 80", 95", 80", 90", 80", 75", 100", 95", 90", 80", 90", 100", 90", 120", 90", 85", 90", 95", 90", 80", 90", 100", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90", 90" \, 100", 108", 117", 121", 133", 145", 165" \CS ITI values (tone + houselight)
#
#
#
#
#
#
#
# \Counter and Flag array
#
# DIM C = 6
#
#
#
# \are all 1-indexed i.e. 3 port entries means 3 port entries
#
#
#
# \C(0) counter for number of port entries
#
#
#
# \C(1) counter for CS presentation number
#
#
#
# \C(2) counter for US delivery
#
#
#
# \C(3) flag to indicate if sucrose is in port =0 if no port entry was made, =1 if port entry was made (i.e., no sucrose)
#
#
#
# \C(4) counter for number of port exits
#
#
#
# \C(5) number of CS1 (tones)
#
#
#
# \C(6) number of sucrose deliveries
#
#
#
#
#
#
#
# \Z-pulses
#
#
#
# \Z1: start task after initial delay
#
#
#
# \Z2: start of CS
#
#
#
# \Z3: port entry
#
#
#
# \Z4: port exit
#
#
#
# \Z5: trigger CS1
#
#
#
# \Z6: turn off CS1 triggers
#
#
#
#
#
#
#
# \Variables
#
#
#
# \A - Time since last CS
#
#
#
# \B -
#
#
#
# \C - Counter array
#
#
#
# \D - Current ITI value
#
#
#
# \E - CS ITI values for first few trials

# %% [markdown]
# - We will be using the comments in the MED-PC script(which starts with the `\`) to create a name for the variables. By default, MED-PC uses a single letter as the name of the variable.
#     - This will use the medpc2excel library found in https://github.com/cyf203/medpc2excel
# - Example of the comments in the MED-PC script that we will use the names from:
#
# ```
# \Variables
#
# \A - Time since last CS
#
# \B - Shock intensity
#
# \C - Counter array
#
# \D - Current ITI value
#
# \E - CS ITI values for first few trials
#
# \F - Shock duration
#
# \G -
#
# \H -
#
# \I -
#
# \J - Shock intensity repo
#
# \K - CS type
#
# \L -
#
# \M - CS type repo
#
# \N - Port exit time stamp array
#
# \O -
#
# \P - Port entry time stamp array
#
# \Q - Sucrose delivery time stamp array (absolute)
#
# \R - Sucrose delivery time stamp array (relative to last CS)
#
# \S - CS presentation time stamp array
#
# \T - Session timer
#
# \U - Time since last CS presentation
#
# \V - List of CS ITI values (tone + houselight)
#
# \W - ITI values used for CS one each trial
#
# \X -
#
# \Y - Beam break monitor variable
#
# \Z -
# ```

# %%
with open(all_med_pc_file[0]) as f:
    lines = f.readlines()
    for line in lines[:20]:
        print(line)
# Out:
# File: C:\MED-PC\Data\2022-10-03_09h45m_Subject 1.1v1.2.txt
#
#
#
#
#
#
#
# Start Date: 10/03/22
#
# End Date: 10/03/22
#
# Subject: 1.1v1.2
#
# Experiment: CD1_vs_C57_Comparison
#
# Group: Cage_1
#
# Box: 1
#
# Start Time: 09:45:25
#
# End Time: 10:46:28
#
# MSN: C57_reward_competition
#
# A:    5399.000
#
# D:    8000.000
#
# E:       0.000
#
# L:       0.000
#
# M:       0.000
#
# O:       0.000
#
# T:    1860.000

# %% [markdown]
# - **Please make sure that the corresponding `.mpc` file (aka the MED-PC script) that was ran to create the log file, is also in the same folder**

# %%
all_med_pc_file
# Out:
# ['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt']

# %%
concatted_medpc_df = extract.dataframe.get_medpc_dataframe_from_list_of_files(medpc_files=all_med_pc_file)
concatted_medpc_df = concatted_medpc_df.reset_index(drop=True)

# %%
concatted_medpc_df.head()
# Out:
#    (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0          0.12           64.0      399.0           0.0              60.01
# 1         10.41          144.0      399.0           0.0             140.01
# 2         10.61          234.0      399.0           0.0             230.01
# 3         11.20          314.0      399.0           0.0             310.01
# 4         11.53          389.0      399.0           0.0             385.01
#
#    (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0         0.16        1.0                                    28.0
# 1        10.43        1.0                                    49.0
# 2        10.63        1.0                                    18.0
# 3        11.42        1.0                                    38.0
# 4        11.56        1.0                                    53.0
#
#    (H)controlled_stimulus_minutescomputer  \
# 0                                    16.0
# 1                                    17.0
# 2                                    19.0
# 3                                    20.0
# 4                                    21.0
#
#    (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                  10.0                           29.0
# 1                                  10.0                           39.0
# 2                                  10.0                           39.0
# 3                                  10.0                           39.0
# 4                                  10.0                           40.0
#
#    (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                           15.0                         10.0  20221003
# 1                           15.0                         10.0  20221003
# 2                           15.0                         10.0  20221003
# 3                           15.0                         10.0  20221003
# 4                           15.0                         10.0  20221003
#
#    subject                                          file_path
# 0  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 1  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 2  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 3  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 4  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %%
concatted_medpc_df.tail()
# Out:
#       (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 5003           NaN            NaN        NaN           NaN                NaN
# 5004           NaN            NaN        NaN           NaN                NaN
# 5005           NaN            NaN        NaN           NaN                NaN
# 5006           NaN            NaN        NaN           NaN                NaN
# 5007           NaN            NaN        NaN           NaN                NaN
#
#       (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 5003          NaN        NaN                                     NaN
# 5004          NaN        NaN                                     NaN
# 5005          NaN        NaN                                     NaN
# 5006          NaN        NaN                                     NaN
# 5007          NaN        NaN                                     NaN
#
#       (H)controlled_stimulus_minutescomputer  \
# 5003                                     NaN
# 5004                                     NaN
# 5005                                     NaN
# 5006                                     NaN
# 5007                                     NaN
#
#       (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 5003                                   NaN                           20.0
# 5004                                   NaN                            1.0
# 5005                                   NaN                         4385.0
# 5006                                   NaN                           19.0
# 5007                                   NaN                           20.0
#
#       (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 5003                            NaN                          NaN  20221003
# 5004                            NaN                          NaN  20221003
# 5005                            NaN                          NaN  20221003
# 5006                            NaN                          NaN  20221003
# 5007                            NaN                          NaN  20221003
#
#       subject                                          file_path
# 5003  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5004  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5005  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5006  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5007  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %% [markdown]
# - Dropping all rows that don't have the CS presentation time

# %%
cs_time_df = concatted_medpc_df[concatted_medpc_df["(S)CSpresentation"] != 0.0].dropna(subset="(S)CSpresentation")

# %%
cs_time_df = cs_time_df[cs_time_df["(S)CSpresentation"] % 100 != 0]

# %%
cs_time_df["file_path"].unique()
# Out:
# array(['./data/med_pc_recording_files/2022-10-03_09h45m_Subject 1.1v1.2.txt'],
#       dtype=object)

# %%
cs_time_df
# Out:
#     (P)Portentry  (Q)USdelivery  (R)UStime  (W)ITIvalues  (S)CSpresentation  \
# 0           0.12           64.0      399.0           0.0              60.01
# 1          10.41          144.0      399.0           0.0             140.01
# 2          10.61          234.0      399.0           0.0             230.01
# 3          11.20          314.0      399.0           0.0             310.01
# 4          11.53          389.0      399.0           0.0             385.01
# 5          11.58          489.0      399.0           0.0             485.01
# 6          11.90          584.0      399.0           0.0             580.01
# 7          12.67          674.0      399.0           0.0             670.01
# 8          14.85          754.0      399.0           0.0             750.01
# 9          18.39          844.0      399.0           0.0             840.01
# 10         18.86          944.0      399.0           0.0             940.01
# 11         19.06         1034.0      399.0           0.0            1030.01
# 12         19.17         1154.0      399.0           0.0            1150.01
# 13         19.45         1244.0      399.0           0.0            1240.01
# 14         19.86         1329.0      399.0           0.0            1325.01
# 15         20.48         1419.0      399.0           0.0            1415.01
# 16         20.58         1514.0      399.0           0.0            1510.01
# 17         21.70         1634.0      399.0           0.0            1630.01
# 18         22.00         1714.0      399.0           0.0            1710.01
#
#     (N)Portexit  (K)CStype  (G)controlled_stimulus_secondscomputer  \
# 0          0.16        1.0                                    28.0
# 1         10.43        1.0                                    49.0
# 2         10.63        1.0                                    18.0
# 3         11.42        1.0                                    38.0
# 4         11.56        1.0                                    53.0
# 5         11.88        1.0                                    33.0
# 6         12.16        1.0                                     8.0
# 7         12.93        1.0                                    38.0
# 8         14.91        1.0                                    58.0
# 9         18.83        1.0                                    28.0
# 10        19.04        1.0                                     8.0
# 11        19.13        1.0                                    38.0
# 12        19.43        1.0                                    39.0
# 13        19.48        1.0                                     8.0
# 14        20.46        1.0                                    33.0
# 15        20.56        1.0                                     4.0
# 16        21.68        1.0                                    39.0
# 17        21.80        1.0                                    38.0
# 18        22.04        1.0                                    58.0
#
#     (H)controlled_stimulus_minutescomputer  \
# 0                                     16.0
# 1                                     17.0
# 2                                     19.0
# 3                                     20.0
# 4                                     21.0
# 5                                     23.0
# 6                                     25.0
# 7                                     26.0
# 8                                     27.0
# 9                                     29.0
# 10                                    31.0
# 11                                    32.0
# 12                                    34.0
# 13                                    36.0
# 14                                    37.0
# 15                                    39.0
# 16                                    40.0
# 17                                    42.0
# 18                                    43.0
#
#     (I)controlled_stimulus_hourscomputer  (B)port_entry_secondscomputer  \
# 0                                   10.0                           29.0
# 1                                   10.0                           39.0
# 2                                   10.0                           39.0
# 3                                   10.0                           39.0
# 4                                   10.0                           40.0
# 5                                   10.0                           40.0
# 6                                   10.0                           40.0
# 7                                   10.0                           41.0
# 8                                   10.0                           43.0
# 9                                   10.0                           47.0
# 10                                  10.0                           47.0
# 11                                  10.0                           48.0
# 12                                  10.0                           48.0
# 13                                  10.0                           48.0
# 14                                  10.0                           48.0
# 15                                  10.0                           49.0
# 16                                  10.0                           49.0
# 17                                  10.0                           50.0
# 18                                  10.0                           50.0
#
#     (F)port_entry_minutescomputer  (J)port_entry_hourscomputer      date  \
# 0                            15.0                         10.0  20221003
# 1                            15.0                         10.0  20221003
# 2                            15.0                         10.0  20221003
# 3                            15.0                         10.0  20221003
# 4                            15.0                         10.0  20221003
# 5                            15.0                         10.0  20221003
# 6                            15.0                         10.0  20221003
# 7                            15.0                         10.0  20221003
# 8                            15.0                         10.0  20221003
# 9                            15.0                         10.0  20221003
# 10                           15.0                         10.0  20221003
# 11                           15.0                         10.0  20221003
# 12                           15.0                         10.0  20221003
# 13                           15.0                         10.0  20221003
# 14                           15.0                         10.0  20221003
# 15                           15.0                         10.0  20221003
# 16                           15.0                         10.0  20221003
# 17                           15.0                         10.0  20221003
# 18                           15.0                         10.0  20221003
#
#     subject                                          file_path
# 0   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 1   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 2   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 3   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 4   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 5   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 6   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 7   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 8   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 9   1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 10  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 11  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 12  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 13  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 14  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 15  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 16  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 17  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...
# 18  1.1v1.2  ./data/med_pc_recording_files/2022-10-03_09h45...

# %%
cs_time_df["cs_minute_only"] = cs_time_df["(S)CSpresentation"] // 60
cs_time_df["cs_second_only"] = cs_time_df["(S)CSpresentation"] % 60

# %% [markdown]
# ## Getting a list of the Tone presentation times

# %%
cs_presentation_time = cs_time_df[["(S)CSpresentation", "cs_minute_only", "cs_second_only"]]

# %%
cs_presentation_time
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only
# 0               60.01             1.0            0.01
# 1              140.01             2.0           20.01
# 2              230.01             3.0           50.01
# 3              310.01             5.0           10.01
# 4              385.01             6.0           25.01
# 5              485.01             8.0            5.01
# 6              580.01             9.0           40.01
# 7              670.01            11.0           10.01
# 8              750.01            12.0           30.01
# 9              840.01            14.0            0.01
# 10             940.01            15.0           40.01
# 11            1030.01            17.0           10.01
# 12            1150.01            19.0           10.01
# 13            1240.01            20.0           40.01
# 14            1325.01            22.0            5.01
# 15            1415.01            23.0           35.01
# 16            1510.01            25.0           10.01
# 17            1630.01            27.0           10.01
# 18            1710.01            28.0           30.01

# %% [markdown]
# # Importing Video Data

# %%
from IPython.display import Video

# %% [markdown]
# 1. Play the video, and go to time where the first tone is played in the dataframe above
#     - Usually 1 minute
# 2. Note when the first tone is playing in the video
# 3. Subtract the difference between the time that the tone is playing in the video and in the dataframe
#     - i.e. 1 minute 12 seconds - 1 minute = 12 seconds

# %%
video_path = "./data/Reward_Competition_D1_videos/10-03-22_Test 1_1-1v1-2.mp4"

# %%
Video(video_path)
# Out:
# <video src="./data/Reward_Competition_D1_videos/10-03-22_Test 1_1-1v1-2.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ## Calculating the predicted tone times in the video based on the difference

# %% [markdown]
# # NOTE: Change the value of the difference below

# %%
cs_time_difference = 12

# %%
cs_presentation_time["video_cs_time"] = cs_presentation_time["(S)CSpresentation"] + cs_time_difference

# %%
cs_presentation_time
# Out:
#     (S)CSpresentation  cs_minute_only  cs_second_only  video_cs_time
# 0               60.01             1.0            0.01          72.01
# 1              140.01             2.0           20.01         152.01
# 2              230.01             3.0           50.01         242.01
# 3              310.01             5.0           10.01         322.01
# 4              385.01             6.0           25.01         397.01
# 5              485.01             8.0            5.01         497.01
# 6              580.01             9.0           40.01         592.01
# 7              670.01            11.0           10.01         682.01
# 8              750.01            12.0           30.01         762.01
# 9              840.01            14.0            0.01         852.01
# 10             940.01            15.0           40.01         952.01
# 11            1030.01            17.0           10.01        1042.01
# 12            1150.01            19.0           10.01        1162.01
# 13            1240.01            20.0           40.01        1252.01
# 14            1325.01            22.0            5.01        1337.01
# 15            1415.01            23.0           35.01        1427.01
# 16            1510.01            25.0           10.01        1522.01
# 17            1630.01            27.0           10.01        1642.01
# 18            1710.01            28.0           30.01        1722.01

# %%
cs_presentation_time["video_cs_minute_only"] = cs_presentation_time["video_cs_time"] // 60
cs_presentation_time["video_cs_second_only"] = cs_presentation_time["video_cs_time"] % 60

# %%
raise ValueError()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 raise ValueError()
#
# ValueError:

# %% [markdown]
# # Trimming the video

# %%
video_object = VideoFileClip(video_path)

# %%
video_object.duration
# Out:
# 1865.05

# %% [markdown]
# fixed func issue with: https://github.com/Zulko/moviepy/issues/1765

# %%
pe1_trimmed_video = video_object.subclip(60, 60 + 20)

# %%
video_path
# Out:
# './data/Reward_Competition_D1_videos/10-03-22_Test 1_1-1v1-2.mp4'

# %%
file_name = os.path.basename(video_path)
file_name_without_extention = os.path.splitext(file_name)[0]
file_name_without_extention = "_".join(file_name_without_extention.split())

# %%
file_name_without_extention
# Out:
# '10-03-22_Test_1_1-1v1-2'

# %%
clip_output_dir = "./proc"

# %%
current_clip_output_dir = os.path.join(clip_output_dir, file_name_without_extention)
os.makedirs(current_clip_output_dir, exist_ok=True)

# %%
for index, row in cs_presentation_time.iterrows():
    cs_trimmed_video = video_object.subclip(row["video_cs_time"] - 5, row["video_cs_time"] + 15)
    cs_trimmed_file_name = "cs_number_{:02d}_date_{}.mp4".format(index + 1, file_name_without_extention)
    print(cs_trimmed_file_name)
    cs_trimmed_video.to_videofile(os.path.join(current_clip_output_dir, cs_trimmed_file_name))
# Out:
# t:  70%|███████████▊     | 418/600 [1:06:17<00:00, 340.55it/s, now=None]
# cs_number_01_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_01_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_01_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▋                   | 22/600 [00:00<00:02, 218.96it/s, now=None]
# t:   8%|█▌                  | 46/600 [00:00<00:02, 229.75it/s, now=None]
# t:  12%|██▎                 | 69/600 [00:00<00:02, 206.42it/s, now=None]
# t:  15%|███                 | 90/600 [00:00<00:02, 195.64it/s, now=None]
# t:  18%|███▌               | 111/600 [00:00<00:02, 199.23it/s, now=None]
# t:  22%|████▏              | 132/600 [00:00<00:02, 197.42it/s, now=None]
# t:  25%|████▊              | 152/600 [00:00<00:02, 196.08it/s, now=None]
# t:  29%|█████▍             | 172/600 [00:00<00:02, 193.65it/s, now=None]
# t:  32%|██████             | 192/600 [00:00<00:02, 194.37it/s, now=None]
# t:  36%|██████▊            | 214/600 [00:01<00:01, 200.45it/s, now=None]
# t:  39%|███████▍           | 235/600 [00:01<00:01, 189.03it/s, now=None]
# t:  43%|████████           | 256/600 [00:01<00:01, 192.96it/s, now=None]
# t:  46%|████████▊          | 277/600 [00:01<00:01, 195.63it/s, now=None]
# t:  50%|█████████▍         | 297/600 [00:01<00:01, 193.12it/s, now=None]
# t:  53%|██████████         | 317/600 [00:01<00:01, 192.77it/s, now=None]
# t:  56%|██████████▋        | 337/600 [00:01<00:01, 189.66it/s, now=None]
# t:  60%|███████████▎       | 357/600 [00:01<00:01, 190.27it/s, now=None]
# t:  63%|███████████▉       | 377/600 [00:01<00:01, 180.82it/s, now=None]
# t:  66%|████████████▌      | 396/600 [00:02<00:01, 174.35it/s, now=None]
# t:  69%|█████████████▏     | 415/600 [00:02<00:01, 177.67it/s, now=None]
# t:  72%|█████████████▋     | 433/600 [00:02<00:00, 178.26it/s, now=None]
# t:  76%|██████████████▍    | 455/600 [00:02<00:00, 187.91it/s, now=None]
# t:  79%|███████████████    | 475/600 [00:02<00:00, 188.91it/s, now=None]
# t:  82%|███████████████▋   | 494/600 [00:02<00:00, 179.15it/s, now=None]
# t:  86%|████████████████▎  | 514/600 [00:02<00:00, 183.37it/s, now=None]
# t:  89%|████████████████▉  | 535/600 [00:02<00:00, 189.31it/s, now=None]
# t:  92%|█████████████████▌ | 555/600 [00:02<00:00, 190.04it/s, now=None]
# t:  96%|██████████████████▎| 577/600 [00:03<00:00, 197.32it/s, now=None]
# t: 100%|██████████████████▉| 597/600 [00:03<00:00, 197.55it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:21<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_01_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_02_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_02_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_02_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   3%|▋                   | 20/600 [00:00<00:03, 192.89it/s, now=None]
# t:   7%|█▎                  | 41/600 [00:00<00:02, 200.38it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:02, 183.87it/s, now=None]
# t:  14%|██▋                 | 81/600 [00:00<00:02, 183.73it/s, now=None]
# t:  17%|███▏               | 102/600 [00:00<00:02, 191.71it/s, now=None]
# t:  20%|███▊               | 122/600 [00:00<00:02, 193.81it/s, now=None]
# t:  24%|████▌              | 144/600 [00:00<00:02, 200.69it/s, now=None]
# t:  28%|█████▏             | 165/600 [00:00<00:02, 202.90it/s, now=None]
# t:  31%|█████▉             | 186/600 [00:00<00:02, 201.03it/s, now=None]
# t:  34%|██████▌            | 207/600 [00:01<00:01, 200.86it/s, now=None]
# t:  38%|███████▎           | 230/600 [00:01<00:01, 208.85it/s, now=None]
# t:  42%|███████▉           | 251/600 [00:01<00:01, 202.55it/s, now=None]
# t:  45%|████████▌          | 272/600 [00:01<00:01, 200.08it/s, now=None]
# t:  49%|█████████▎         | 293/600 [00:01<00:01, 188.50it/s, now=None]
# t:  52%|█████████▉         | 313/600 [00:01<00:01, 182.12it/s, now=None]
# t:  56%|██████████▌        | 333/600 [00:01<00:01, 185.59it/s, now=None]
# t:  59%|███████████▏       | 354/600 [00:01<00:01, 192.13it/s, now=None]
# t:  62%|███████████▉       | 375/600 [00:01<00:01, 193.72it/s, now=None]
# t:  66%|████████████▌      | 395/600 [00:02<00:01, 193.51it/s, now=None]
# t:  70%|█████████████▏     | 417/600 [00:02<00:00, 199.17it/s, now=None]
# t:  73%|█████████████▊     | 438/600 [00:02<00:00, 200.42it/s, now=None]
# t:  76%|██████████████▌    | 459/600 [00:02<00:00, 194.74it/s, now=None]
# t:  80%|███████████████▏   | 479/600 [00:02<00:00, 191.95it/s, now=None]
# t:  83%|███████████████▊   | 499/600 [00:02<00:00, 191.09it/s, now=None]
# t:  86%|████████████████▍  | 519/600 [00:02<00:00, 186.21it/s, now=None]
# t:  90%|█████████████████  | 538/600 [00:02<00:00, 180.90it/s, now=None]
# t:  93%|█████████████████▋ | 557/600 [00:02<00:00, 174.95it/s, now=None]
# t:  96%|██████████████████▏| 576/600 [00:03<00:00, 176.56it/s, now=None]
# t:  99%|██████████████████▊| 596/600 [00:03<00:00, 179.79it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:24<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_02_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_03_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_03_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_03_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   3%|▋                   | 19/600 [00:00<00:03, 185.32it/s, now=None]
# t:   7%|█▍                  | 42/600 [00:00<00:02, 211.28it/s, now=None]
# t:  11%|██▏                 | 64/600 [00:00<00:02, 185.79it/s, now=None]
# t:  14%|██▊                 | 83/600 [00:00<00:02, 183.37it/s, now=None]
# t:  17%|███▏               | 102/600 [00:00<00:02, 177.31it/s, now=None]
# t:  20%|███▊               | 120/600 [00:00<00:02, 175.82it/s, now=None]
# t:  24%|████▍              | 141/600 [00:00<00:02, 185.56it/s, now=None]
# t:  27%|█████▏             | 163/600 [00:00<00:02, 193.40it/s, now=None]
# t:  31%|█████▊             | 185/600 [00:00<00:02, 200.60it/s, now=None]
# t:  34%|██████▌            | 206/600 [00:01<00:02, 196.76it/s, now=None]
# t:  38%|███████▏           | 226/600 [00:01<00:01, 196.02it/s, now=None]
# t:  41%|███████▊           | 246/600 [00:01<00:01, 195.38it/s, now=None]
# t:  44%|████████▍          | 266/600 [00:01<00:01, 195.15it/s, now=None]
# t:  48%|█████████          | 286/600 [00:01<00:01, 193.38it/s, now=None]
# t:  51%|█████████▋         | 306/600 [00:01<00:01, 189.32it/s, now=None]
# t:  55%|██████████▍        | 330/600 [00:01<00:01, 203.23it/s, now=None]
# t:  59%|███████████▏       | 353/600 [00:01<00:01, 209.07it/s, now=None]
# t:  62%|███████████▉       | 375/600 [00:01<00:01, 211.08it/s, now=None]
# t:  66%|████████████▌      | 397/600 [00:02<00:00, 207.92it/s, now=None]
# t:  70%|█████████████▏     | 418/600 [00:02<00:00, 206.80it/s, now=None]
# t:  73%|█████████████▉     | 439/600 [00:02<00:00, 207.05it/s, now=None]
# t:  77%|██████████████▋    | 462/600 [00:02<00:00, 211.34it/s, now=None]
# t:  81%|███████████████▍   | 486/600 [00:02<00:00, 219.42it/s, now=None]
# t:  85%|████████████████   | 509/600 [00:02<00:00, 222.04it/s, now=None]
# t:  89%|████████████████▊  | 532/600 [00:02<00:00, 221.38it/s, now=None]
# t:  92%|█████████████████▌ | 555/600 [00:02<00:00, 219.00it/s, now=None]
# t:  97%|██████████████████▎| 580/600 [00:02<00:00, 227.71it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:27<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_03_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_04_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_04_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_04_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▊                   | 24/600 [00:00<00:02, 238.94it/s, now=None]
# t:   8%|█▌                  | 48/600 [00:00<00:02, 222.08it/s, now=None]
# t:  12%|██▎                 | 71/600 [00:00<00:02, 220.27it/s, now=None]
# t:  16%|███▏                | 95/600 [00:00<00:02, 225.39it/s, now=None]
# t:  20%|███▊               | 119/600 [00:00<00:02, 227.82it/s, now=None]
# t:  24%|████▌              | 143/600 [00:00<00:01, 229.37it/s, now=None]
# t:  28%|█████▎             | 168/600 [00:00<00:01, 233.00it/s, now=None]
# t:  32%|██████▏            | 194/600 [00:00<00:01, 238.99it/s, now=None]
# t:  36%|██████▉            | 218/600 [00:00<00:01, 238.35it/s, now=None]
# t:  40%|███████▋           | 243/600 [00:01<00:01, 241.71it/s, now=None]
# t:  45%|████████▌          | 269/600 [00:01<00:01, 244.12it/s, now=None]
# t:  49%|█████████▎         | 294/600 [00:01<00:01, 240.04it/s, now=None]
# t:  53%|██████████         | 319/600 [00:01<00:01, 235.03it/s, now=None]
# t:  57%|██████████▉        | 344/600 [00:01<00:01, 237.33it/s, now=None]
# t:  62%|███████████▋       | 369/600 [00:01<00:00, 239.57it/s, now=None]
# t:  66%|████████████▌      | 397/600 [00:01<00:00, 250.57it/s, now=None]
# t:  71%|█████████████▍     | 424/600 [00:01<00:00, 254.98it/s, now=None]
# t:  75%|██████████████▎    | 452/600 [00:01<00:00, 262.23it/s, now=None]
# t:  80%|███████████████▏   | 480/600 [00:01<00:00, 266.45it/s, now=None]
# t:  84%|████████████████   | 507/600 [00:02<00:00, 260.51it/s, now=None]
# t:  89%|████████████████▉  | 534/600 [00:02<00:00, 258.66it/s, now=None]
# t:  94%|█████████████████▊ | 564/600 [00:02<00:00, 268.89it/s, now=None]
# t:  99%|██████████████████▊| 595/600 [00:02<00:00, 279.44it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:30<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_04_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_05_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_05_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_05_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 31/600 [00:00<00:01, 307.28it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:01, 284.66it/s, now=None]
# t:  15%|███                 | 92/600 [00:00<00:01, 286.99it/s, now=None]
# t:  20%|███▊               | 122/600 [00:00<00:01, 291.71it/s, now=None]
# t:  25%|████▊              | 152/600 [00:00<00:01, 293.83it/s, now=None]
# t:  30%|█████▊             | 182/600 [00:00<00:01, 294.28it/s, now=None]
# t:  35%|██████▋            | 212/600 [00:00<00:01, 286.48it/s, now=None]
# t:  40%|███████▋           | 241/600 [00:00<00:01, 270.52it/s, now=None]
# t:  45%|████████▌          | 271/600 [00:00<00:01, 277.44it/s, now=None]
# t:  50%|█████████▍         | 299/600 [00:01<00:01, 271.09it/s, now=None]
# t:  55%|██████████▎        | 327/600 [00:01<00:01, 267.68it/s, now=None]
# t:  59%|███████████▏       | 355/600 [00:01<00:00, 268.64it/s, now=None]
# t:  64%|████████████       | 382/600 [00:01<00:00, 267.78it/s, now=None]
# t:  68%|████████████▉      | 409/600 [00:01<00:00, 262.73it/s, now=None]
# t:  73%|█████████████▊     | 436/600 [00:01<00:00, 250.10it/s, now=None]
# t:  77%|██████████████▋    | 462/600 [00:01<00:00, 243.83it/s, now=None]
# t:  81%|███████████████▍   | 487/600 [00:01<00:00, 241.76it/s, now=None]
# t:  85%|████████████████▏  | 512/600 [00:01<00:00, 243.45it/s, now=None]
# t:  90%|█████████████████  | 537/600 [00:02<00:00, 240.57it/s, now=None]
# t:  94%|█████████████████▊ | 563/600 [00:02<00:00, 243.76it/s, now=None]
# t:  98%|██████████████████▌| 588/600 [00:02<00:00, 243.44it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:32<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_05_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_06_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_06_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_06_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|▉                   | 28/600 [00:00<00:02, 270.79it/s, now=None]
# t:   9%|█▊                  | 56/600 [00:00<00:02, 255.07it/s, now=None]
# t:  14%|██▋                 | 82/600 [00:00<00:02, 246.78it/s, now=None]
# t:  18%|███▍               | 107/600 [00:00<00:01, 247.36it/s, now=None]
# t:  22%|████▏              | 132/600 [00:00<00:01, 246.75it/s, now=None]
# t:  26%|████▉              | 157/600 [00:00<00:01, 247.08it/s, now=None]
# t:  30%|█████▊             | 182/600 [00:00<00:01, 242.82it/s, now=None]
# t:  34%|██████▌            | 207/600 [00:00<00:01, 243.72it/s, now=None]
# t:  39%|███████▍           | 233/600 [00:00<00:01, 245.28it/s, now=None]
# t:  43%|████████▏          | 258/600 [00:01<00:01, 245.40it/s, now=None]
# t:  47%|████████▉          | 283/600 [00:01<00:01, 245.84it/s, now=None]
# t:  51%|█████████▊         | 308/600 [00:01<00:01, 244.63it/s, now=None]
# t:  56%|██████████▌        | 334/600 [00:01<00:01, 248.25it/s, now=None]
# t:  60%|███████████▎       | 359/600 [00:01<00:00, 246.26it/s, now=None]
# t:  64%|████████████▏      | 384/600 [00:01<00:00, 241.36it/s, now=None]
# t:  68%|████████████▉      | 409/600 [00:01<00:00, 242.54it/s, now=None]
# t:  72%|█████████████▋     | 434/600 [00:01<00:00, 242.99it/s, now=None]
# t:  76%|██████████████▌    | 459/600 [00:01<00:00, 243.27it/s, now=None]
# t:  81%|███████████████▎   | 484/600 [00:01<00:00, 242.90it/s, now=None]
# t:  85%|████████████████▏  | 510/600 [00:02<00:00, 246.18it/s, now=None]
# t:  89%|████████████████▉  | 536/600 [00:02<00:00, 247.58it/s, now=None]
# t:  94%|█████████████████▊ | 561/600 [00:02<00:00, 247.25it/s, now=None]
# t:  98%|██████████████████▌| 587/600 [00:02<00:00, 248.22it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:35<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_06_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_07_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_07_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_07_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|▉                   | 29/600 [00:00<00:02, 281.33it/s, now=None]
# t:  10%|█▉                  | 58/600 [00:00<00:02, 254.20it/s, now=None]
# t:  14%|██▊                 | 84/600 [00:00<00:02, 252.02it/s, now=None]
# t:  18%|███▍               | 110/600 [00:00<00:01, 254.39it/s, now=None]
# t:  23%|████▎              | 136/600 [00:00<00:01, 254.94it/s, now=None]
# t:  27%|█████▏             | 162/600 [00:00<00:01, 253.64it/s, now=None]
# t:  31%|█████▉             | 188/600 [00:00<00:01, 252.32it/s, now=None]
# t:  36%|██████▊            | 214/600 [00:00<00:01, 252.13it/s, now=None]
# t:  40%|███████▌           | 240/600 [00:00<00:01, 251.52it/s, now=None]
# t:  44%|████████▍          | 266/600 [00:01<00:01, 252.26it/s, now=None]
# t:  49%|█████████▏         | 292/600 [00:01<00:01, 254.18it/s, now=None]
# t:  53%|██████████         | 318/600 [00:01<00:01, 251.59it/s, now=None]
# t:  57%|██████████▉        | 344/600 [00:01<00:01, 252.87it/s, now=None]
# t:  62%|███████████▋       | 370/600 [00:01<00:00, 252.19it/s, now=None]
# t:  66%|████████████▌      | 396/600 [00:01<00:00, 251.94it/s, now=None]
# t:  70%|█████████████▎     | 422/600 [00:01<00:00, 250.14it/s, now=None]
# t:  75%|██████████████▏    | 448/600 [00:01<00:00, 240.66it/s, now=None]
# t:  79%|██████████████▉    | 473/600 [00:01<00:00, 240.64it/s, now=None]
# t:  83%|███████████████▊   | 499/600 [00:01<00:00, 243.56it/s, now=None]
# t:  88%|████████████████▋  | 525/600 [00:02<00:00, 247.66it/s, now=None]
# t:  92%|█████████████████▍ | 550/600 [00:02<00:00, 247.51it/s, now=None]
# t:  96%|██████████████████▏| 575/600 [00:02<00:00, 247.80it/s, now=None]
# t: 100%|███████████████████| 600/600 [00:02<00:00, 242.03it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:38<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_07_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_08_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_08_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_08_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▉                   | 27/600 [00:00<00:02, 261.36it/s, now=None]
# t:   9%|█▊                  | 54/600 [00:00<00:02, 251.66it/s, now=None]
# t:  13%|██▋                 | 80/600 [00:00<00:02, 244.34it/s, now=None]
# t:  18%|███▎               | 106/600 [00:00<00:01, 249.19it/s, now=None]
# t:  22%|████▏              | 131/600 [00:00<00:01, 248.95it/s, now=None]
# t:  26%|████▉              | 157/600 [00:00<00:01, 250.38it/s, now=None]
# t:  30%|█████▊             | 183/600 [00:00<00:01, 249.03it/s, now=None]
# t:  35%|██████▌            | 208/600 [00:00<00:01, 247.19it/s, now=None]
# t:  39%|███████▍           | 234/600 [00:00<00:01, 247.70it/s, now=None]
# t:  43%|████████▏          | 260/600 [00:01<00:01, 248.50it/s, now=None]
# t:  48%|█████████          | 285/600 [00:01<00:01, 246.77it/s, now=None]
# t:  52%|█████████▊         | 310/600 [00:01<00:01, 241.52it/s, now=None]
# t:  56%|██████████▌        | 335/600 [00:01<00:01, 229.75it/s, now=None]
# t:  60%|███████████▍       | 360/600 [00:01<00:01, 233.90it/s, now=None]
# t:  65%|████████████▎      | 389/600 [00:01<00:00, 247.62it/s, now=None]
# t:  70%|█████████████▎     | 419/600 [00:01<00:00, 261.07it/s, now=None]
# t:  75%|██████████████▏    | 449/600 [00:01<00:00, 270.17it/s, now=None]
# t:  80%|███████████████▏   | 479/600 [00:01<00:00, 276.47it/s, now=None]
# t:  85%|████████████████   | 509/600 [00:01<00:00, 281.20it/s, now=None]
# t:  90%|█████████████████  | 538/600 [00:02<00:00, 283.59it/s, now=None]
# t:  94%|█████████████████▉ | 567/600 [00:02<00:00, 283.36it/s, now=None]
# t: 100%|██████████████████▉| 598/600 [00:02<00:00, 289.71it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:40<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_08_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_09_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_09_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_09_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▊                   | 26/600 [00:00<00:02, 257.16it/s, now=None]
# t:   9%|█▋                  | 52/600 [00:00<00:02, 258.06it/s, now=None]
# t:  13%|██▌                 | 78/600 [00:00<00:02, 256.50it/s, now=None]
# t:  17%|███▎               | 104/600 [00:00<00:02, 246.40it/s, now=None]
# t:  22%|████               | 130/600 [00:00<00:01, 248.58it/s, now=None]
# t:  26%|████▉              | 157/600 [00:00<00:01, 253.14it/s, now=None]
# t:  30%|█████▊             | 183/600 [00:00<00:01, 254.54it/s, now=None]
# t:  35%|██████▌            | 209/600 [00:00<00:01, 238.92it/s, now=None]
# t:  39%|███████▍           | 234/600 [00:00<00:01, 235.38it/s, now=None]
# t:  43%|████████▏          | 259/600 [00:01<00:01, 237.24it/s, now=None]
# t:  48%|█████████          | 285/600 [00:01<00:01, 243.10it/s, now=None]
# t:  52%|█████████▊         | 310/600 [00:01<00:01, 242.30it/s, now=None]
# t:  56%|██████████▌        | 335/600 [00:01<00:01, 243.94it/s, now=None]
# t:  60%|███████████▍       | 361/600 [00:01<00:00, 246.64it/s, now=None]
# t:  64%|████████████▎      | 387/600 [00:01<00:00, 250.00it/s, now=None]
# t:  69%|█████████████      | 413/600 [00:01<00:00, 251.20it/s, now=None]
# t:  73%|█████████████▉     | 439/600 [00:01<00:00, 248.38it/s, now=None]
# t:  77%|██████████████▋    | 464/600 [00:01<00:00, 242.71it/s, now=None]
# t:  82%|███████████████▍   | 489/600 [00:01<00:00, 242.47it/s, now=None]
# t:  86%|████████████████▎  | 514/600 [00:02<00:00, 243.24it/s, now=None]
# t:  90%|█████████████████  | 539/600 [00:02<00:00, 244.77it/s, now=None]
# t:  94%|█████████████████▊ | 564/600 [00:02<00:00, 242.41it/s, now=None]
# t:  98%|██████████████████▋| 590/600 [00:02<00:00, 245.09it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:43<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_09_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_10_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_10_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_10_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|▉                   | 28/600 [00:00<00:02, 273.41it/s, now=None]
# t:   9%|█▊                  | 56/600 [00:00<00:02, 254.17it/s, now=None]
# t:  14%|██▋                 | 82/600 [00:00<00:02, 246.89it/s, now=None]
# t:  18%|███▍               | 107/600 [00:00<00:02, 243.07it/s, now=None]
# t:  22%|████▏              | 132/600 [00:00<00:01, 239.87it/s, now=None]
# t:  26%|████▉              | 157/600 [00:00<00:01, 241.72it/s, now=None]
# t:  30%|█████▊             | 183/600 [00:00<00:01, 247.21it/s, now=None]
# t:  35%|██████▌            | 209/600 [00:00<00:01, 250.86it/s, now=None]
# t:  39%|███████▍           | 235/600 [00:00<00:01, 249.67it/s, now=None]
# t:  43%|████████▏          | 260/600 [00:01<00:01, 249.70it/s, now=None]
# t:  48%|█████████          | 286/600 [00:01<00:01, 250.77it/s, now=None]
# t:  52%|█████████▉         | 312/600 [00:01<00:01, 249.30it/s, now=None]
# t:  56%|██████████▋        | 337/600 [00:01<00:01, 247.00it/s, now=None]
# t:  60%|███████████▍       | 363/600 [00:01<00:00, 250.50it/s, now=None]
# t:  65%|████████████▎      | 389/600 [00:01<00:00, 250.65it/s, now=None]
# t:  69%|█████████████▏     | 415/600 [00:01<00:00, 250.86it/s, now=None]
# t:  74%|█████████████▉     | 441/600 [00:01<00:00, 251.64it/s, now=None]
# t:  78%|██████████████▊    | 467/600 [00:01<00:00, 252.69it/s, now=None]
# t:  82%|███████████████▌   | 493/600 [00:01<00:00, 251.40it/s, now=None]
# t:  86%|████████████████▍  | 519/600 [00:02<00:00, 244.48it/s, now=None]
# t:  91%|█████████████████▏ | 544/600 [00:02<00:00, 244.63it/s, now=None]
# t:  95%|██████████████████ | 569/600 [00:02<00:00, 245.84it/s, now=None]
# t:  99%|██████████████████▊| 595/600 [00:02<00:00, 248.54it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:45<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_10_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_11_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_11_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_11_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▉                   | 27/600 [00:00<00:02, 268.47it/s, now=None]
# t:   9%|█▊                  | 54/600 [00:00<00:02, 256.93it/s, now=None]
# t:  13%|██▋                 | 80/600 [00:00<00:02, 251.06it/s, now=None]
# t:  18%|███▎               | 106/600 [00:00<00:01, 252.44it/s, now=None]
# t:  22%|████▏              | 132/600 [00:00<00:01, 245.86it/s, now=None]
# t:  26%|████▉              | 157/600 [00:00<00:01, 241.71it/s, now=None]
# t:  30%|█████▊             | 183/600 [00:00<00:01, 246.24it/s, now=None]
# t:  35%|██████▌            | 209/600 [00:00<00:01, 247.98it/s, now=None]
# t:  39%|███████▍           | 235/600 [00:00<00:01, 249.41it/s, now=None]
# t:  43%|████████▏          | 260/600 [00:01<00:01, 247.22it/s, now=None]
# t:  48%|█████████          | 285/600 [00:01<00:01, 244.95it/s, now=None]
# t:  52%|█████████▊         | 310/600 [00:01<00:01, 231.46it/s, now=None]
# t:  56%|██████████▌        | 335/600 [00:01<00:01, 233.53it/s, now=None]
# t:  60%|███████████▎       | 359/600 [00:01<00:01, 234.96it/s, now=None]
# t:  65%|████████████▎      | 388/600 [00:01<00:00, 250.73it/s, now=None]
# t:  70%|█████████████▏     | 418/600 [00:01<00:00, 262.79it/s, now=None]
# t:  74%|██████████████▏    | 447/600 [00:01<00:00, 270.46it/s, now=None]
# t:  79%|███████████████    | 475/600 [00:01<00:00, 270.06it/s, now=None]
# t:  84%|███████████████▉   | 503/600 [00:01<00:00, 267.91it/s, now=None]
# t:  88%|████████████████▊  | 531/600 [00:02<00:00, 269.32it/s, now=None]
# t:  93%|█████████████████▋ | 560/600 [00:02<00:00, 272.43it/s, now=None]
# t:  98%|██████████████████▌| 588/600 [00:02<00:00, 253.12it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:48<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_11_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_12_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_12_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_12_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 31/600 [00:00<00:01, 302.24it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:01, 280.15it/s, now=None]
# t:  15%|███                 | 92/600 [00:00<00:01, 287.34it/s, now=None]
# t:  20%|███▊               | 122/600 [00:00<00:01, 292.00it/s, now=None]
# t:  26%|████▊              | 153/600 [00:00<00:01, 295.34it/s, now=None]
# t:  31%|█████▊             | 184/600 [00:00<00:01, 297.94it/s, now=None]
# t:  36%|██████▊            | 215/600 [00:00<00:01, 300.17it/s, now=None]
# t:  41%|███████▊           | 246/600 [00:00<00:01, 297.30it/s, now=None]
# t:  46%|████████▋          | 276/600 [00:00<00:01, 289.51it/s, now=None]
# t:  51%|█████████▋         | 305/600 [00:01<00:01, 263.55it/s, now=None]
# t:  56%|██████████▌        | 333/600 [00:01<00:01, 266.54it/s, now=None]
# t:  60%|███████████▍       | 360/600 [00:01<00:00, 262.28it/s, now=None]
# t:  64%|████████████▎      | 387/600 [00:01<00:00, 259.16it/s, now=None]
# t:  69%|█████████████      | 414/600 [00:01<00:00, 257.84it/s, now=None]
# t:  73%|█████████████▉     | 440/600 [00:01<00:00, 256.42it/s, now=None]
# t:  78%|██████████████▊    | 466/600 [00:01<00:00, 248.06it/s, now=None]
# t:  82%|███████████████▌   | 491/600 [00:01<00:00, 234.51it/s, now=None]
# t:  86%|████████████████▎  | 515/600 [00:01<00:00, 232.97it/s, now=None]
# t:  90%|█████████████████  | 540/600 [00:02<00:00, 236.87it/s, now=None]
# t:  94%|█████████████████▊ | 564/600 [00:02<00:00, 235.24it/s, now=None]
# t:  98%|██████████████████▌| 588/600 [00:02<00:00, 234.69it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:50<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_12_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_13_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_13_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_13_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▊                   | 26/600 [00:00<00:02, 254.33it/s, now=None]
# t:   9%|█▋                  | 52/600 [00:00<00:02, 245.15it/s, now=None]
# t:  13%|██▌                 | 77/600 [00:00<00:02, 242.08it/s, now=None]
# t:  17%|███▏               | 102/600 [00:00<00:02, 244.39it/s, now=None]
# t:  21%|████               | 128/600 [00:00<00:01, 247.26it/s, now=None]
# t:  26%|████▊              | 153/600 [00:00<00:01, 240.96it/s, now=None]
# t:  30%|█████▋             | 178/600 [00:00<00:01, 240.71it/s, now=None]
# t:  34%|██████▍            | 203/600 [00:00<00:01, 241.54it/s, now=None]
# t:  38%|███████▏           | 228/600 [00:00<00:01, 241.65it/s, now=None]
# t:  42%|████████           | 253/600 [00:01<00:01, 243.65it/s, now=None]
# t:  46%|████████▊          | 278/600 [00:01<00:01, 242.97it/s, now=None]
# t:  50%|█████████▌         | 303/600 [00:01<00:01, 243.37it/s, now=None]
# t:  55%|██████████▍        | 328/600 [00:01<00:01, 241.97it/s, now=None]
# t:  59%|███████████▏       | 353/600 [00:01<00:01, 240.92it/s, now=None]
# t:  63%|███████████▉       | 378/600 [00:01<00:00, 242.26it/s, now=None]
# t:  67%|████████████▊      | 403/600 [00:01<00:00, 243.16it/s, now=None]
# t:  71%|█████████████▌     | 428/600 [00:01<00:00, 244.56it/s, now=None]
# t:  76%|██████████████▎    | 453/600 [00:01<00:00, 243.70it/s, now=None]
# t:  80%|███████████████▏   | 479/600 [00:01<00:00, 246.18it/s, now=None]
# t:  84%|███████████████▉   | 505/600 [00:02<00:00, 249.29it/s, now=None]
# t:  88%|████████████████▊  | 530/600 [00:02<00:00, 248.98it/s, now=None]
# t:  92%|█████████████████▌ | 555/600 [00:02<00:00, 246.72it/s, now=None]
# t:  97%|██████████████████▍| 581/600 [00:02<00:00, 248.75it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:53<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_13_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_14_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_14_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_14_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▊                   | 26/600 [00:00<00:02, 256.55it/s, now=None]
# t:   9%|█▋                  | 52/600 [00:00<00:02, 245.99it/s, now=None]
# t:  13%|██▌                 | 77/600 [00:00<00:02, 237.76it/s, now=None]
# t:  17%|███▏               | 101/600 [00:00<00:02, 223.96it/s, now=None]
# t:  21%|████               | 127/600 [00:00<00:02, 235.30it/s, now=None]
# t:  26%|████▊              | 153/600 [00:00<00:01, 240.65it/s, now=None]
# t:  30%|█████▋             | 179/600 [00:00<00:01, 245.35it/s, now=None]
# t:  34%|██████▍            | 205/600 [00:00<00:01, 248.01it/s, now=None]
# t:  38%|███████▎           | 231/600 [00:00<00:01, 248.95it/s, now=None]
# t:  43%|████████           | 256/600 [00:01<00:01, 233.72it/s, now=None]
# t:  47%|████████▊          | 280/600 [00:01<00:01, 234.37it/s, now=None]
# t:  51%|█████████▋         | 304/600 [00:01<00:01, 233.19it/s, now=None]
# t:  55%|██████████▍        | 330/600 [00:01<00:01, 239.83it/s, now=None]
# t:  59%|███████████▏       | 355/600 [00:01<00:01, 239.40it/s, now=None]
# t:  63%|████████████       | 380/600 [00:01<00:00, 241.16it/s, now=None]
# t:  68%|████████████▊      | 405/600 [00:01<00:00, 242.80it/s, now=None]
# t:  72%|█████████████▌     | 430/600 [00:01<00:00, 237.04it/s, now=None]
# t:  76%|██████████████▍    | 457/600 [00:01<00:00, 246.02it/s, now=None]
# t:  81%|███████████████▍   | 486/600 [00:02<00:00, 257.00it/s, now=None]
# t:  86%|████████████████▎  | 515/600 [00:02<00:00, 265.33it/s, now=None]
# t:  91%|█████████████████▏ | 544/600 [00:02<00:00, 272.28it/s, now=None]
# t:  96%|██████████████████▏| 573/600 [00:02<00:00, 276.44it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:55<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_14_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_15_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_15_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_15_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|▉                   | 29/600 [00:00<00:02, 285.10it/s, now=None]
# t:  10%|█▉                  | 58/600 [00:00<00:02, 251.76it/s, now=None]
# t:  14%|██▊                 | 84/600 [00:00<00:02, 231.42it/s, now=None]
# t:  18%|███▍               | 110/600 [00:00<00:02, 239.42it/s, now=None]
# t:  23%|████▎              | 136/600 [00:00<00:01, 244.75it/s, now=None]
# t:  28%|█████▏             | 165/600 [00:00<00:01, 257.63it/s, now=None]
# t:  33%|██████▏            | 196/600 [00:00<00:01, 272.40it/s, now=None]
# t:  38%|███████▏           | 226/600 [00:00<00:01, 278.68it/s, now=None]
# t:  43%|████████▏          | 257/600 [00:00<00:01, 285.79it/s, now=None]
# t:  48%|█████████          | 287/600 [00:01<00:01, 289.77it/s, now=None]
# t:  53%|██████████         | 318/600 [00:01<00:00, 294.38it/s, now=None]
# t:  58%|███████████        | 348/600 [00:01<00:00, 292.85it/s, now=None]
# t:  63%|███████████▉       | 378/600 [00:01<00:00, 294.78it/s, now=None]
# t:  68%|████████████▉      | 409/600 [00:01<00:00, 297.75it/s, now=None]
# t:  73%|█████████████▉     | 439/600 [00:01<00:00, 289.91it/s, now=None]
# t:  78%|██████████████▊    | 469/600 [00:01<00:00, 285.34it/s, now=None]
# t:  83%|███████████████▊   | 498/600 [00:01<00:00, 279.63it/s, now=None]
# t:  88%|████████████████▋  | 527/600 [00:01<00:00, 277.15it/s, now=None]
# t:  92%|█████████████████▌ | 555/600 [00:02<00:00, 273.44it/s, now=None]
# t:  97%|██████████████████▍| 584/600 [00:02<00:00, 276.01it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:06:58<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_15_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_16_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_16_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_16_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 31/600 [00:00<00:01, 306.16it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:01, 282.97it/s, now=None]
# t:  15%|███                 | 91/600 [00:00<00:01, 285.92it/s, now=None]
# t:  20%|███▊               | 121/600 [00:00<00:01, 290.44it/s, now=None]
# t:  25%|████▊              | 151/600 [00:00<00:01, 293.24it/s, now=None]
# t:  30%|█████▊             | 182/600 [00:00<00:01, 296.88it/s, now=None]
# t:  35%|██████▋            | 212/600 [00:00<00:01, 297.04it/s, now=None]
# t:  40%|███████▋           | 242/600 [00:00<00:01, 297.59it/s, now=None]
# t:  45%|████████▌          | 272/600 [00:00<00:01, 298.27it/s, now=None]
# t:  50%|█████████▌         | 302/600 [00:01<00:01, 293.76it/s, now=None]
# t:  55%|██████████▌        | 332/600 [00:01<00:00, 294.73it/s, now=None]
# t:  60%|███████████▍       | 363/600 [00:01<00:00, 296.57it/s, now=None]
# t:  66%|████████████▍      | 393/600 [00:01<00:00, 296.57it/s, now=None]
# t:  71%|█████████████▍     | 425/600 [00:01<00:00, 301.60it/s, now=None]
# t:  76%|██████████████▍    | 456/600 [00:01<00:00, 301.71it/s, now=None]
# t:  81%|███████████████▍   | 487/600 [00:01<00:00, 301.62it/s, now=None]
# t:  86%|████████████████▍  | 518/600 [00:01<00:00, 301.50it/s, now=None]
# t:  92%|█████████████████▍ | 549/600 [00:01<00:00, 296.21it/s, now=None]
# t:  97%|██████████████████▎| 580/600 [00:01<00:00, 298.68it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:07:00<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_16_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_17_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_17_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_17_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 31/600 [00:00<00:01, 304.57it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:01, 278.25it/s, now=None]
# t:  15%|███                 | 91/600 [00:00<00:01, 281.57it/s, now=None]
# t:  20%|███▊               | 121/600 [00:00<00:01, 287.05it/s, now=None]
# t:  25%|████▊              | 150/600 [00:00<00:01, 285.33it/s, now=None]
# t:  30%|█████▋             | 180/600 [00:00<00:01, 288.24it/s, now=None]
# t:  35%|██████▋            | 211/600 [00:00<00:01, 292.41it/s, now=None]
# t:  40%|███████▋           | 242/600 [00:00<00:01, 296.85it/s, now=None]
# t:  46%|████████▋          | 273/600 [00:00<00:01, 298.18it/s, now=None]
# t:  51%|█████████▋         | 304/600 [00:01<00:00, 299.77it/s, now=None]
# t:  56%|██████████▌        | 334/600 [00:01<00:00, 296.89it/s, now=None]
# t:  61%|███████████▌       | 365/600 [00:01<00:00, 298.44it/s, now=None]
# t:  66%|████████████▌      | 395/600 [00:01<00:00, 297.94it/s, now=None]
# t:  71%|█████████████▍     | 425/600 [00:01<00:00, 298.17it/s, now=None]
# t:  76%|██████████████▍    | 455/600 [00:01<00:00, 297.38it/s, now=None]
# t:  81%|███████████████▎   | 485/600 [00:01<00:00, 296.77it/s, now=None]
# t:  86%|████████████████▎  | 515/600 [00:01<00:00, 295.57it/s, now=None]
# t:  91%|█████████████████▎ | 545/600 [00:01<00:00, 293.24it/s, now=None]
# t:  96%|██████████████████▏| 575/600 [00:01<00:00, 294.19it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:07:02<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_17_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_18_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_18_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_18_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 32/600 [00:00<00:01, 313.72it/s, now=None]
# t:  11%|██▏                 | 64/600 [00:00<00:01, 285.52it/s, now=None]
# t:  16%|███▏                | 94/600 [00:00<00:01, 290.16it/s, now=None]
# t:  21%|███▉               | 125/600 [00:00<00:01, 294.82it/s, now=None]
# t:  26%|████▉              | 155/600 [00:00<00:01, 295.91it/s, now=None]
# t:  31%|█████▉             | 186/600 [00:00<00:01, 299.22it/s, now=None]
# t:  36%|██████▊            | 217/600 [00:00<00:01, 300.17it/s, now=None]
# t:  41%|███████▊           | 248/600 [00:00<00:01, 300.63it/s, now=None]
# t:  46%|████████▊          | 279/600 [00:00<00:01, 298.57it/s, now=None]
# t:  52%|█████████▊         | 309/600 [00:01<00:00, 296.56it/s, now=None]
# t:  56%|██████████▋        | 339/600 [00:01<00:00, 296.33it/s, now=None]
# t:  62%|███████████▋       | 370/600 [00:01<00:00, 298.07it/s, now=None]
# t:  67%|████████████▋      | 400/600 [00:01<00:00, 295.92it/s, now=None]
# t:  72%|█████████████▌     | 430/600 [00:01<00:00, 293.41it/s, now=None]
# t:  77%|██████████████▌    | 460/600 [00:01<00:00, 294.18it/s, now=None]
# t:  82%|███████████████▌   | 490/600 [00:01<00:00, 295.00it/s, now=None]
# t:  87%|████████████████▍  | 520/600 [00:01<00:00, 292.32it/s, now=None]
# t:  92%|█████████████████▍ | 550/600 [00:01<00:00, 290.05it/s, now=None]
# t:  97%|██████████████████▍| 581/600 [00:01<00:00, 293.51it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:07:04<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_18_date_10-03-22_Test_1_1-1v1-2.mp4
# cs_number_19_date_10-03-22_Test_1_1-1v1-2.mp4
# Moviepy - Building video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_19_date_10-03-22_Test_1_1-1v1-2.mp4.
# Moviepy - Writing video ./proc/10-03-22_Test_1_1-1v1-2/cs_number_19_date_10-03-22_Test_1_1-1v1-2.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   5%|█                   | 31/600 [00:00<00:01, 302.65it/s, now=None]
# t:  10%|██                  | 62/600 [00:00<00:01, 278.28it/s, now=None]
# t:  15%|███                 | 91/600 [00:00<00:01, 281.97it/s, now=None]
# t:  20%|███▊               | 121/600 [00:00<00:01, 287.32it/s, now=None]
# t:  25%|████▊              | 151/600 [00:00<00:01, 290.87it/s, now=None]
# t:  30%|█████▋             | 181/600 [00:00<00:01, 292.60it/s, now=None]
# t:  35%|██████▋            | 211/600 [00:00<00:01, 294.72it/s, now=None]
# t:  40%|███████▋           | 241/600 [00:00<00:01, 295.61it/s, now=None]
# t:  45%|████████▌          | 271/600 [00:00<00:01, 295.99it/s, now=None]
# t:  50%|█████████▌         | 301/600 [00:01<00:01, 296.11it/s, now=None]
# t:  55%|██████████▍        | 331/600 [00:01<00:00, 295.04it/s, now=None]
# t:  60%|███████████▍       | 362/600 [00:01<00:00, 298.75it/s, now=None]
# t:  65%|████████████▍      | 392/600 [00:01<00:00, 298.14it/s, now=None]
# t:  70%|█████████████▍     | 423/600 [00:01<00:00, 300.70it/s, now=None]
# t:  76%|██████████████▍    | 454/600 [00:01<00:00, 300.06it/s, now=None]
# t:  81%|███████████████▎   | 485/600 [00:01<00:00, 298.03it/s, now=None]
# t:  86%|████████████████▎  | 515/600 [00:01<00:00, 294.80it/s, now=None]
# t:  91%|█████████████████▎ | 545/600 [00:01<00:00, 295.34it/s, now=None]
# t:  96%|██████████████████▏| 576/600 [00:01<00:00, 298.77it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:07:06<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready ./proc/10-03-22_Test_1_1-1v1-2/cs_number_19_date_10-03-22_Test_1_1-1v1-2.mp4

# %%
cs_trimmed_video.ipython_display()
# Out:
# t:  70%|███████████▊     | 418/600 [1:01:40<00:00, 340.55it/s, now=None]
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:   0%|                              | 0/600 [00:00<?, ?it/s, now=None]
# t:   4%|▊                   | 25/600 [00:00<00:02, 248.04it/s, now=None]
# t:  10%|█▉                  | 58/600 [00:00<00:01, 291.63it/s, now=None]
# t:  15%|███                 | 90/600 [00:00<00:01, 303.30it/s, now=None]
# t:  20%|███▉               | 123/600 [00:00<00:01, 311.85it/s, now=None]
# t:  26%|████▉              | 156/600 [00:00<00:01, 317.64it/s, now=None]
# t:  32%|██████             | 190/600 [00:00<00:01, 322.44it/s, now=None]
# t:  37%|███████            | 223/600 [00:00<00:01, 323.61it/s, now=None]
# t:  43%|████████           | 256/600 [00:00<00:01, 322.60it/s, now=None]
# t:  48%|█████████▏         | 291/600 [00:00<00:00, 328.65it/s, now=None]
# t:  54%|██████████▎        | 324/600 [00:01<00:00, 321.65it/s, now=None]
# t:  60%|███████████▎       | 357/600 [00:01<00:00, 299.89it/s, now=None]
# t:  65%|████████████▎      | 388/600 [00:01<00:00, 301.47it/s, now=None]
# t:  70%|█████████████▎     | 422/600 [00:01<00:00, 312.44it/s, now=None]
# t:  76%|██████████████▍    | 455/600 [00:01<00:00, 313.91it/s, now=None]
# t:  81%|███████████████▍   | 487/600 [00:01<00:00, 301.26it/s, now=None]
# t:  87%|████████████████▍  | 520/600 [00:01<00:00, 307.96it/s, now=None]
# t:  92%|█████████████████▌ | 554/600 [00:01<00:00, 315.99it/s, now=None]
# t:  98%|██████████████████▌| 587/600 [00:01<00:00, 318.86it/s, now=None]
# t:  70%|███████████▊     | 418/600 [1:01:42<00:00, 340.55it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
pe2_trimmed_video.to_videofile("./data/automatic_30_min_end_test/trimmed_pe2.mp4")

# %%
pe3_trimmed_video.to_videofile("./data/automatic_30_min_end_test//trimmed_pe3.mp4")

# %%
Video("./data/automatic_30_min_end_test/trimmed_cs1.mp4")
